# %%
import json, re, pickle
from typing import List, Dict, Any
from collections import defaultdict

# %% [markdown]
# ## **Read File**

# %%
def read_jsonl_file(file_path: str) -> List[Dict[str, Any]]:
  data: List[Dict[str, Any]] = []
  with open(file_path, 'r', encoding='utf-8') as f:
    for line in f:
      data.append(json.loads(line))
  return data

# %% [markdown]
# **Wikipedia data**

# %%
def clean_text(text):
    text = text.strip()
    text = text.lower()
    text = re.sub(r"\\[nrt]", " ", text)                  # Remove escape characters like \n, \t
    text = re.sub(r"\\?\'\'", '"', text)                  # Replace double single-quotes with "
    text = re.sub(r'\s+', ' ', text)                      # Normalize spaces
    text = re.sub(r'[^a-z0-9.,!?\'" ]', '', text)         # Remove strange characters
    text = re.sub(r'\.{2,}', '.', text)                   # Replace multiple dots with one
    return text.strip()

# %%
wikipedia = read_jsonl_file("/home/maryam/llamaPersonaResp/Data/original/wikipedia.jsonl")

# %%
wikipedia
# Out:
# [{'id': '524288',
#   'root': '524288',
#   'text': 'you should look at all of the point on the template not just the last one, the template also says the image belonging to the republic of macedonia is in the public domain if it being used for "information purposes".',
#   'user': 'Frightner',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189190940E09'},
#  {'id': '524289',
#   'root': '524288',
#   'text': 'yes i agree. the law permits usage of documents, photographs and other materials for educational and informational purposes. there was a normative act issued by the government of the republic of macedonia that even allowed citizens to make photocopies or photograph rare archive materials.',
#   'user': 'Revizionist',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189204860E09'},
#  {'id': '1',
#   'root': '1',
#   'text': "yes, that's good. revathy's page looked very reliable, that's why we used that as a source.",
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.310744280E09'},
#  {'id': '2',
#   'root': '1',
#   'text': "nagma'a site, at least that filmography page, looks like taken from wikipedia itself. i didn't remove it from time being, but i don't think it's true.",
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': '1',
#   'timestamp': '1.310746500E09'},
#  {'id': '3',
#   'root': '1',
#   'text': 'i don\'t think there are many such official reliable sites left yet. the problem is most "official sites" are not really official, and often based on wikipedia itself, and you don\'t know what to believe and what not. we used madras talkies\' page, which is dead now. httpkavithalayaa.com kavithalayaa\'s site is there, also avm production\'s site might be useful perhaps, but i can\'t enter that. generally official sites of production houses seem to be very reliable ones.',
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': '2',
#   'timestamp': '1.310751180E09'},
#  {'id': '4',
#   'root': '1',
#   'text': 'most of the so called "official sites" are maintained by fans or cinema based web companies. not sure how reliable are they. span style"colorgreenfontsizesmallfontfamilysegoe print"ibiillaspan',
#   'user': 'Michael-Billa',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.311762120E09'},
#  {'id': '524290',
#   'root': '524290',
#   'text': 'you closed wikipediaarticles for deletionj. kevin tumlinson after one day without mentioning anything about speedy deletion or giving reasons. not that i\'m objecting "too" much, but did you realize it was only one day?',
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.189197960E09'},
#  {'id': '524291',
#   'root': '524290',
#   'text': 'well, notability cannot be acquired in 4 days. that was my reasoning behind the early closure. however, if you still believe the closure was out of process, you can still refer to the deletion review.',
#   'user': 'FayssalF',
#   'meta': {'is-admin': True},
#   'reply-to': '524290',
#   'timestamp': '1.189200660E09'},
#  {'id': '524292',
#   'root': '524290',
#   'text': "no, no, i was the nominator! just wanted to make sure it wasn't done in error.",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524291',
#   'timestamp': '1.189200720E09'},
#  {'id': '524293',
#   'root': '524290',
#   'text': "i was a bit surprised because i know you were the nominator  no, it wasn't done in error.",
#   'user': 'FayssalF',
#   'meta': {'is-admin': True},
#   'reply-to': '524292',
#   'timestamp': '1.189200960E09'},
#  {'id': '262147',
#   'root': '262147',
#   'text': 'hello dana, thanks for contribute in this templatespanish horsestemplate, but i need tell you that is about horse, and balearic article is about a language of a people, if you think that im not right please tell me for not fixing the edit at last. enjoy your day',
#   'user': 'Venerock',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286157240E09'},
#  {'id': '262148',
#   'root': '262147',
#   'text': 'my apologies, i forgot to include the disambiguator. please check now  it should be right. thanks for letting me know.',
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262147',
#   'timestamp': '1.286157480E09'},
#  {'id': '6',
#   'root': '6',
#   'text': 'hey, who said so? frankly, i have absolutely no idea, sorry!',
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312057320E09'},
#  {'id': '7',
#   'root': '6',
#   'text': "maybe, we should check out who added that, it could be some fanatic ip user. there will have been nominees, since there were nominees in earlier ceremonies and in the telugu section, too, but how to find out? if there was a video coverage of that ceremony available we would know. otherwise, i would remove it as it's unsourced.",
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': '6',
#   'timestamp': '1.312059420E09'},
#  {'id': '262145',
#   'root': '262145',
#   'text': "h dana, totally amiss of me  belated congrats for your promotion! i voted for you without any hesitation. i'm pleased to hear from pike that you might be reviewing the finnhorse, i can't think of anyone better for the job.",
#   'user': 'Kudpung',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286127120E09'},
#  {'id': '262146',
#   'root': '262145',
#   'text': "thank you very much! i am going to try to take a look over finnhorse  actually, i think i'll go start looking at it right now while i have a few minutes.",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262145',
#   'timestamp': '1.286133300E09'},
#  {'id': '262152',
#   'root': '262152',
#   'text': 'hi. just writing that you closed out the wpcfd as a "\'merge and delete"\', but category appears open still at this moment. yours,',
#   'user': 'Rms125a@hotmail.com',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286163540E09'},
#  {'id': '262153',
#   'root': '262152',
#   'text': "yes, i know. it's on the list at wikipediacategoriesfordiscussionworking, and the bot should get to it shortly.",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262152',
#   'timestamp': '1.286163600E09'},
#  {'id': '9',
#   'root': '9',
#   'text': "well, no website is 100 perfect, you got to understand that. are you saying toi is an unreliable source? mention of shankar as shankar mahadevan might have been a mistake, i'll contact them and ask them to correct it. what else do you want me to do?",
#   'user': 'Secret of success',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312136520E09'},
#  {'id': '10',
#   'root': '9',
#   'text': 'i don\'t care. this is not the place to elevate your favourite star\'s films. i\'m not questioning about the credibility of toi. there is a consensus not to add budgetgross figures for any indian movie, if it\'s speculated at a higher rate. i think you might be aware of the "enthiran issue". even official sources were not considered.',
#   'user': 'Vensatry',
#   'meta': {'is-admin': False},
#   'reply-to': '9',
#   'timestamp': '1.312136820E09'},
#  {'id': '262154',
#   'root': '262154',
#   'text': 'could you restore categorysecond wave synthpop acts or at least the bands formerly listed therein to my userspace? i was checking out some of the bands and bookmarked it to check out some others later, but found that it was deleted. thanks!',
#   'user': 'JCDenton2052',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286272380E09'},
#  {'id': '262155',
#   'root': '262154',
#   'text': "there would be nothing to restore, and categories can't be moved even if there were. category pages contain nothing, articles are added to it by an addition of code at the bottom of each article. when a category is deleted, cfd has an adminbot that goes through each article and removes the category. the best you could do would be to find the edits in usercydebot's contribution record, and then you'd be able to see what was in the category predeletion.",
#   'user': 'Courcelles',
#   'meta': {'is-admin': True},
#   'reply-to': '262154',
#   'timestamp': '1.286272740E09'},
#  {'id': '262156',
#   'root': '262154',
#   'text': 'found them. thanks for your help!',
#   'user': 'JCDenton2052',
#   'meta': {'is-admin': False},
#   'reply-to': '262155',
#   'timestamp': '1.286274420E09'},
#  {'id': '11',
#   'root': '11',
#   'text': 'i agree i copied, even he mi8 know it very well. i dont know 2 design and all but some thing inside, i got my own work also. if u dont mind can i copy abit of urs. even ur page looks good!!',
#   'user': 'Karthikndr',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312143840E09'},
#  {'id': '12',
#   'root': '11',
#   'text': 'ok! ty for the info and links. will create new design asap.',
#   'user': 'Karthikndr',
#   'meta': {'is-admin': False},
#   'reply-to': '11',
#   'timestamp': '1.312146060E09'},
#  {'id': '13',
#   'root': '13',
#   'text': "i don't understand what you are saying. could you please be more precise?",
#   'user': 'Secret of success',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312244220E09'},
#  {'id': '14',
#   'root': '13',
#   'text': 'well, i have not made much significant contribution but just a couple of sections in one or two articles. if that is not enough, i have removed the template if that bothers you.',
#   'user': 'Secret of success',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312410120E09'},
#  {'id': '524302',
#   'root': '524302',
#   'text': "if you look at the contrib history of mr. neutron you will find plenty of edits like this, and all of his 'contribs' are exclusively on articles dealing with macedonia, and mostly pushing probulgarian pov in subtle and notsosubtle ways. i just thought you might want to know for future reference",
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189478460E09'},
#  {'id': '524303',
#   'root': '524302',
#   'text': 'thanks. i understand that there is a lot of controversy here, even between respected scholars. we need to document that disagreement in our articles, hopefully without attacking editors.',
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524302',
#   'timestamp': '1.189479180E09'},
#  {'id': '524304',
#   'root': '524302',
#   'text': 'capricornis, stop insinuating. and please refrain from various ad hominem arguments, as they are falacies. comment on contributions please.',
#   'user': 'Mr. Neutron',
#   'meta': {'is-admin': False},
#   'reply-to': '524303',
#   'timestamp': '1.189480920E09'},
#  {'id': '524305',
#   'root': '524302',
#   'text': "you must have misunderstood something? i was commenting on your contributions, not on you as a person please read the ad hominem article before you quote it. also 'insinuations' are statements that cannot be proven, whereas my statements above can be proven by anyone who will take the time to look through your contrib history. have a great day",
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': '524304',
#   'timestamp': '1.189489680E09'},
#  {'id': '524306',
#   'root': '524302',
#   'text': 'you were already warned on your talkpage not to commit any more personal attacks, so dont do it. you have been consistently insinuating against other wikipedia contributors and this is not at all nice going.',
#   'user': 'Mr. Neutron',
#   'meta': {'is-admin': False},
#   'reply-to': '524305',
#   'timestamp': '1.189490280E09'},
#  {'id': '524307',
#   'root': '524302',
#   'text': "you are talking about the distant past. i retracted the unfortunate comments and they were accepted, including by you, at the end of this section httpen.wikipedia.orgwikitalkilindenpreobrazhenieuprisingsearchenginestests . i do not intend to personally attack you at all, but i will attack your contributions and 'content' every time you try to 'slightly' swing the pendulum to your side  you will be reported.",
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': '524306',
#   'timestamp': '1.189491480E09'},
#  {'id': '524308',
#   'root': '524302',
#   'text': 'oh please! "distant past" was only httpen.wikipedia.orgwindex.php?titleusertalkcapricornisdiff156856515oldid156665242 yesterday. report whatever you want, with such consistent agenda against other contributors you only bring suspicion on yourself.',
#   'user': 'Mr. Neutron',
#   'meta': {'is-admin': False},
#   'reply-to': '524307',
#   'timestamp': '1.189493820E09'},
#  {'id': '524309',
#   'root': '524302',
#   'text': "that was a misinformed suggestion by another ordinary user, just like you and me. i still maintain that there were no personal attacks in my words, but only good humored jibs. the statement about the exclusivity of your activity on macedonia related articles stands and is easily verifiable. i suggest if you have something more to say, to do it on my talk page as there is no point continuing this tirade on anonemouse's page who seems to have quite enough work without it. cheers",
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': '524308',
#   'timestamp': '1.189501860E09'},
#  {'id': '524310',
#   'root': '524302',
#   'text': 'and more personal attacks calling people misinformed.',
#   'user': 'Mr. Neutron',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189502040E09'},
#  {'id': '524311',
#   'root': '524302',
#   'text': 'misinformedmisguided are not insults in the english language. maybe brush up on your english or use websters?',
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189502280E09'},
#  {'id': '16',
#   'root': '16',
#   'text': 'hi. i think your statement of the ip being the sockpuppet of sreekar akkineni is true. earlier, a user named niranjaniyengarwho was a sock of sreekar akkineni wrote on my talk page in a similar manner. if you can trace the ip used by them, it would be possible to block him. i also have a doubt if mr. kollyfan, famed for his discussion of the enthiran gross has something to do with this. it would throw some light on this manner. thanks!',
#   'user': 'Secret of success',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312588320E09'},
#  {'id': '17',
#   'root': '16',
#   'text': 'glad that you got my point. actually sreekarakkineni, niranjaniyengar and this ip seems like the same person. will file a case soon.',
#   'user': 'Vensatry',
#   'meta': {'is-admin': False},
#   'reply-to': '16',
#   'timestamp': '1.312588860E09'},
#  {'id': '18',
#   'root': '16',
#   'text': 'so put in a sock puppet investigation to find out.',
#   'user': 'Bollyjeff',
#   'meta': {'is-admin': False},
#   'reply-to': '17',
#   'timestamp': '1.312590060E09'},
#  {'id': '262162',
#   'root': '262162',
#   'text': "hi there dana, when relisting cfd discussions, please be aware that we don't remove the discussions from one log date to the other instead, we close the discussion at add the tlrelisted template instead. as such, httpen.wikipedia.orgwindex.php?titlewikipediacategoriesfordiscussionlog2010september26diff389785157oldid389782135 this edit should be reverted and the discussions should be closed. this is explained at wprelist, last line. thanks. u2014",
#   'user': 'Explicit',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.286691180E09'},
#  {'id': '262163',
#   'root': '262162',
#   'text': "whoops, my apologies. i apparently read the bolded part and completely missed the part in parentheses. thanks for letting me know  please let me know if there is anything else i'm doing wrong i'm new at it, but the backlog needs work so i wanted to chip in. i'll go fix that now.",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262162',
#   'timestamp': '1.286701080E09'},
#  {'id': '262164',
#   'root': '262162',
#   'text': "and just one other note, danau2014after you relist a cfd, don't forget to change the date on the cfd tag on the category itself so that it goes to the new discussion, like httpen.wikipedia.orgwindex.php?titlecategory3achristmasnumberonesinglesintheunitedkingdomactionhistorysubmitdiff389999136oldid387262711 this. thanks for you service in working on closing cfds we are always looking for more help and attention with these.",
#   'user': 'Good Olfactory',
#   'meta': {'is-admin': True},
#   'reply-to': '262162',
#   'timestamp': '1.286793420E09'},
#  {'id': '20',
#   'root': '20',
#   'text': 'hey! hi there are a bunch of things i want to learn here in wikipedia. only you, and maybe 3 others could teach me terribly embarrassing to admit i\'m so ignorant with computers, etc. and so i\'ve decided to send a couple notes and the others for help. is it ok to email you, to save space on our talk pages? mine is activated too. this drives me crazy! one burning question has to do with many grateful deadrelated articles, so i am here. nearly all the biography articles about musicians eventually have a discography section, followed by references, and then external links. some of them have a "see also" section which is essentially trivia, and it is simple enough to see if it\'s warranted or not. however, what i don\'t understand is a "notes" section. what purpose, exactly does it serve, and how do you put info into the text properly to acheive whatever result the editor is trying to accomplish? it\'s really perplexing.',
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.300422840E09'},
#  {'id': '21',
#   'root': '20',
#   'text': 'let me know how that goes. being able to format footnotes is a big plus, and like i said it\'s pretty easy once you\'ve done it a few times. i suggest that you try doing a few on your user page, or on a subpage of your user page, for practice. if you want more help just let me know. font face"cursive"u2014',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '20',
#   'timestamp': '1.300432800E09'},
#  {'id': '262165',
#   'root': '262165',
#   'text': 'i think you should nag mf. he never responds to my nags p "\'',
#   'user': 'YellowMonkey',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.286798880E09'},
#  {'id': '262166',
#   'root': '262165',
#   'text': "i dropped notes to half a dozen editors on various articles already in the farc stage. we'll see if it gets us anywhere.",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262165',
#   'timestamp': '1.286830500E09'},
#  {'id': '262167',
#   'root': '262165',
#   'text': 'outofsinc on british empire is a sockmeat, quite obviously "\'',
#   'user': 'YellowMonkey',
#   'meta': {'is-admin': True},
#   'reply-to': '262166',
#   'timestamp': '1.286867700E09'},
#  {'id': '22',
#   'root': '22',
#   'text': 'my apologies when i come trampling through your pet projects further from my mind to annoy you, seriously. however, i keep seeing esp. in jazz related articles people interchanging sections listed as "references", "notes", "footnotes" "external links", and i\'ve even seen whilst editing a "reflist 2". frankly, i\'m baffled. i\'ve pretty much stuck to the editing of musicians and generally, the articles are biographybiographical and i stick to the typical lead per wpmos which i admit i never really read too deeply. usually, at the end of an article, there\'s the discography and the nowikireferences section, followed by external linksnowiki and often the latter is jampacked with link farms that are longer than the article themselves. can you explain to me how this works, with the notes and all? oh, and feel free to revert my edits when they are done improperly. sorry about messing up articles that i only want to help!',
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.303346700E09'},
#  {'id': '23',
#   'root': '22',
#   'text': 'thanks for the note. yes, i think a lot of editors are a bit confused about notes, references, and external links sections. take a look at what i wrote at user talkmudwaternotes and other things, and at talkskip battinplace references here, for some helpful info. on some articles, most or all of the external links section should really be in the references section. but it\'s important not to remove reliable references from articles. feel free to reply here if you want to talk about this some more. font face"cursive"u2014',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '22',
#   'timestamp': '1.303611720E09'},
#  {'id': '24',
#   'root': '22',
#   'text': "ok, i'll have a look at it. partly, one reason why i'm not a first class editor has some to do with add or laziness, take your pick which explains my difficulty with punctuation as well. anyway, like i said, never feel bad about reverting my work, too.",
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': '23',
#   'timestamp': '1.303737480E09'},
#  {'id': '262168',
#   'root': '262168',
#   'text': 'can you please see wikipedia talkfeatured article reviewsimon byrnearchive1breakingupotherusers\'posts, and help out with regard to this disruption? thank you for your time,  "\'',
#   'user': 'Cirt',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.286894160E09'},
#  {'id': '262169',
#   'root': '262168',
#   'text': 'responded to you, at wikipedia talkfeatured article reviewsimon byrnearchive1.  "\'',
#   'user': 'Cirt',
#   'meta': {'is-admin': True},
#   'reply-to': '262168',
#   'timestamp': '1.286910720E09'},
#  {'id': '262170',
#   'root': '262168',
#   'text': 'seems fixed now.  "\'',
#   'user': 'Cirt',
#   'meta': {'is-admin': True},
#   'reply-to': '262169',
#   'timestamp': '1.286911800E09'},
#  {'id': '524313',
#   'root': '524313',
#   'text': 'who wrote the joe schmidlap article? i had a friend who referenced that name regularly, and was surprised to see it in print. thanks for any info you can provide.',
#   'user': 'Mandsford',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189486980E09'},
#  {'id': '524314',
#   'root': '524313',
#   'text': "usermanualrivera791 was the proud author, but it's a common enough insertnamehere name, just httpwww.google.comsearch?qjoeschmidlap ask google. joe schmoe is another john q. public john doe in legal cases joe bloggs on standardized tests bubba.",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524313',
#   'timestamp': '1.189539780E09'},
#  {'id': '26',
#   'root': '26',
#   'text': 'if you have uploaded other nonfree media, consider checking that you have specified how these images fully satisfy our nonfree content criteria. you can find a list of description pages you have edited by clicking on span class"plainlinks"fullurlspecialcontributionstargetmudwaternamespace6 this linkspan. note that even if you follow steps 1 and 2 above, nonfree media which could be replaced by freely licensed alternatives will be deleted 2 days after this notification 7 days if uploaded before 13 july 2006, per our wikipedianonfree content criterianonfree content policy. if you have any questions please ask them at the wikipediamedia copyright questionsmedia copyright questions page. thank you. ! templatedireplaceable fair usenotice  u02c9u02c9sup',
#   'user': 'Anetode',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.303643760E09'},
#  {'id': '27',
#   'root': '26',
#   'text': 'second, last but not least, there\'s an "\'rfa"\' for usercatfish jim and the soapdish, one of the handful of editors who, like you, have consistently been a help and inspiration. i hope you\'ll take a look wikipediarequests for adminshipcatfish jim and the soapdish please, vote with your heart. thanks as always.',
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': '26',
#   'timestamp': '1.304301000E09'},
#  {'id': '28',
#   'root': '26',
#   'text': 'as far as the scott gorham article, that\'s just a classic case of an article that doesn\'t have enough references. but it looks like someone has added more references since you posted about it here on my talk page. i might add a few more myself if i get around to it. in general, i\'d say don\'t get too hung up about the technical details of naming the sections, or the best way to format references. the most important things are to expand and improve the text of existing articles, and to add reliable references that you find, either on the internet or offline. i happen to be interested in a lot of the technical details myself, as i\'ve explained a bit here on my talk page, but if you find it confusing, don\'t worry about it. the content is the most important thing, someone can always come along later and fix the formatting. "p.s." looks like your buddy made admin, congratulations to him or her. font face"cursive"u2014',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '27',
#   'timestamp': '1.304837580E09'},
#  {'id': '29',
#   'root': '26',
#   'text': 'thanks for the response. ok, then. the editor who just brought thin lizzy to ga status becomes more motivated with the thin lizzy related articles like scott gorham when i bring in new photos that are good. if there isn\'t enough text to place the article, it doesn\'t work, and he\'s good that way. like the photo for bo diddley and eric bell. so that must be him. oh, and as for usercatfish jim and the soapdish\'s rfa, it is good! i was really surprised to hear he jumped into the ring of fire without my knowing he planned to do it. he said he didn\'t want to look like he might be fishing for votes, which just goes to show what a decent guy he is. not to mention all those positive votes, and i think, 2 votes not for his adminship, which is a really decent outcome! i thought you knew him already. you may benefit from doing so. he\'s been so helpful to me over the last year or so, and is a good editor as well as good at sniffing out vandalism, which is why he finally asked for the mop more tools in which to deal with those problems. i\'m glad for him! i\'ll only vote in an rfa if i "really" know the individual, so it\'s just been three times altogether.',
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': '28',
#   'timestamp': '1.305304320E09'},
#  {'id': '524315',
#   'root': '524315',
#   'text': "anonemouse, when you get a chance could you take a look at the material jamesd1 has added to the article? my view is that much of it is nothing but original research.for instance, the section comparing bailey's writing to theosophical society literature which is based on nothing but bailey quotes and links that do not even mention bailey, all held together by original research of jamesd1. if you think i am wrong, i will not bother the others editors on this point. thanks for making the spelling correction",
#   'user': 'Kwork',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189552920E09'},
#  {'id': '524316',
#   'root': '524315',
#   'text': "as an editing rule here, it's better to add to people's edits, rephrase, rearrange, etc., rather than remove their changes wholesale. that way there is some back and forth, but in general a kind of incremental progress, and the article improves. just reverting leads to deadlock, and should be avoided. don't insist on perfection all at once. when you find something wrong, fix it, but don't just delete it unless there really is no other choice.",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524315',
#   'timestamp': '1.189557480E09'},
#  {'id': '262173',
#   'root': '262173',
#   'text': 'how can the far notice be removed from chess? i commented it out on the talk page, but it stills says "review" on the article page.',
#   'user': 'Bubba73',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287010080E09'},
#  {'id': '262174',
#   'root': '262173',
#   'text': "the bot will come through and close the review in a while the schedule tends to be wednesday and saturday nights, but this varies sometimes. i'm going to uncomment the tag on the talk page so that it doesn't screw up the bot.",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262173',
#   'timestamp': '1.287010980E09'},
#  {'id': '30',
#   'root': '30',
#   'text': 'it doesn\'t look like we\'re getting much feedback on splitting the "gun laws in the united states by state" article. i posted notices on wikipediawikiproject lawwikiproject law and wikipediawikiproject united stateswikiproject united states, to no avail.',
#   'user': 'Jax 0677',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.305965820E09'},
#  {'id': '31',
#   'root': '30',
#   'text': 'i agree, not much feedback so far. seven editors have commented, including you and me. and one of the seven also posted about it on wikipediawikiproject firearmswikiproject firearms. font face"cursive"u2014',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '30',
#   'timestamp': '1.305966720E09'},
#  {'id': '32',
#   'root': '32',
#   'text': "hi.  i appreciate all your work in that article and particularly in your diplomatic resolution to the nationality question. mr. cage would like us to set the record straight, and he's provided us with a published source so that we can. i've added that his nationality is american. it's kind an irritable blog entry, but it contains some other biographical information that you might like to incorporate httpwww.roadcage.com?p60. i just wanted to ask you, if you happen to be continuing to maintain the article as you so ably have in the past, to kind of keep an eye out for the return of canadianism, if it should show up. mr. cage vigorously contests its accuracy.",
#   'user': 'Moonriddengirl',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.306266540E09'},
#  {'id': '33',
#   'root': '32',
#   'text': 'wow, this is great. and i love mr. cage\'s explanation of his situation, and his views on the wikipedia process from the perspective of being the subject of an article. thanks very much for your help with this! font face"cursive"u2014',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '32',
#   'timestamp': '1.306267560E09'},
#  {'id': '262177',
#   'root': '262177',
#   'text': 'dana, wikipedia talkfeatured article reviewworld science festivalarchive1this was an incorrect bad hack that occurred at far and only came to my attention because an error was made in the "signpost", indicating the fa had been delisted.httpen.wikipedia.orgwindex.php?titlewikipediawikipediasignpost20101018featuresandadminsdiffprevoldid391348494 when i went to check, i found that 2009 content had simply been deleted,httpen.wikipedia.orgwindex.php?titleworldsciencefestival,2008diff386458978oldid386458738 and the main article notable had gone away via a redirect to a world science festival, 20082008 article. i have done a partial cleanup, but more work is likely needed specifically, i don\'t know what else may have been deleted during the far, and what improvements from the 2008 version need to be restored to the main article. i will leave a note for userdank and direct him to this conversation. the main article will need review to restore any changes made since 2008. someone else may want to update the main article to include 2010 and 2011, which are mentioned in the festival website. there are also dead links at the 2008 article that should have been picked up on the far.',
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287453960E09'},
#  {'id': '262178',
#   'root': '262177',
#   'text': 'you are correct that the main wsf article should exist and include information from all of the years. however, all of the reviewers including malleus! agreed that the wsf 2008 article met fa standards. most of the dead link tags were invalid  i\'ve removed those and fixed the couple of valid ones. easy enough. the 2009 info was the only stuff deleted afaik during the far, but i\'m not sure what you mean by the "improvements from the 2008 version need to be restored to the main article".',
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262177',
#   'timestamp': '1.287467340E09'},
#  {'id': '262179',
#   'root': '262177',
#   'text': "i dunno i may have confused myself between the two versions, but i think it's all up to snuff now! thanks! i was surprised by that far",
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': '262178',
#   'timestamp': '1.287467520E09'},
#  {'id': '34',
#   'root': '34',
#   'text': 'hey, i noticed httpen.wikipedia.orgwindex.php?titlegarciaalbumdiffprevoldid434347681 this yesterday and was wondering if the 24.2ems should be made part of the actual template. there was a discussion on this a short while ago on the template\'s talk page, but i didn\'t think it was possible. didn\'t occur to me to try decimals. u2013nbspfont color"06266f"keru03b1ufontfont color"1240ab"nou03c2cofontfont color"4671ds"piafontfont color"a60000"supu25c1supfontisubfont color"5e1fff"',
#   'user': 'Keraunoscopia',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.308218820E09'},
#  {'id': '35',
#   'root': '34',
#   'text': 'i missed that discussion, but i definitely think it would be very good if the default width of the template was 24.2, so that it would be i think the same width as the infobox. and as an additional point, i would also favor making "stateplain" the default. font face"cursive"u2014',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '34',
#   'timestamp': '1.308219120E09'},
#  {'id': '36',
#   'root': '34',
#   'text': 'i\'m not familiar enough with the states thing, but here\'s the discussion templatetalkalbumratingswidth. it\'s not very old at all. i would support the 24.2. u2013nbspfont color"06266f"keru03b1ufontfont color"1240ab"nou03c2cofontfont color"4671ds"piafontfont color"a60000"supu25c1supfontisubfont color"5e1fff"',
#   'user': 'Keraunoscopia',
#   'meta': {'is-admin': False},
#   'reply-to': '35',
#   'timestamp': '1.308219240E09'},
#  {'id': '37',
#   'root': '34',
#   'text': 'i was wondering if the widths of the infobox and the album ratings template would vary by browser andor by skin, but i didn\'t try to figure that out. it sounds like they do. but i think that using 24.2em would make them the same width for most readers, so i would still favor that. as for "state", that\'s explained on the templatealbum ratings page. in my opinion "stateplain" would be the best default, because it displays the ratings without the options to hide or show them. in most cases having the option is an unnecessary complication, in my view. font face"cursive"u2014',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '36',
#   'timestamp': '1.308219660E09'},
#  {'id': '38',
#   'root': '34',
#   'text': 'oh, i remember states now. yeah, not sure why one would collapse the template at all. kind of a silly option. well, when i messed around with ems, they varied between skins i tried vector, and i always use modern, otherwise, and i\'m using safari for a browser, and your 24.2 thing looked fine on safariskinmodern, so i assume you\'ve figured out the secret width needed. not sure how well it would work, but you could always put an infobox and the album ratings template on an otherwiseempty sandbox, then throw that url into httpbrowsershots.org browsershots.org and see if the widths vary from browser to browser. they\'d all be in vector default skin, i think. u2013nbspfont color"06266f"keru03b1ufontfont color"1240ab"nou03c2cofontfont color"4671ds"piafontfont color"a60000"supu25c1supfontisubfont color"5e1fff"',
#   'user': 'Keraunoscopia',
#   'meta': {'is-admin': False},
#   'reply-to': '37',
#   'timestamp': '1.308220200E09'},
#  {'id': '87387',
#   'root': '87387',
#   'text': 'thanks for your edits to this article. the thing is, though, they didn\'t play the australia national cricket team they played the australians. apologies if you already knew this, but there\'s a rigid distinction in operation here "australia" as such "only" play international cricket all matches against counties, universities and so on are listed as "australians". ditto with other countries, so that for example "worcestershire v pakistanis" doesn\'t mean any old pakistanis, but always the national team playing a noninternational match. for that reason i\'m inclined to change those edits back, but i\'ll leave it a day or two in case you want to come back at me.',
#   'user': 'Loganberry',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.238805900E09'},
#  {'id': '87388',
#   'root': '87387',
#   'text': 'to answer the obvious question, where there is no convenient adjectival form, one just adds "xi" to the team name, so that you have "barbados v england xi" or whatever. for historical reasons, until the 1970s, england played as "mcc" in noninternational tour games.',
#   'user': 'Loganberry',
#   'meta': {'is-admin': False},
#   'reply-to': '87387',
#   'timestamp': '1.238806140E09'},
#  {'id': '87389',
#   'root': '87387',
#   'text': "thanks for the explanation loganberry. i didn't know about that distinction. i'll change it back.",
#   'user': 'Qwfp',
#   'meta': {'is-admin': False},
#   'reply-to': '87388',
#   'timestamp': '1.238806860E09'},
#  {'id': '87390',
#   'root': '87387',
#   'text': 'thanks. as with most things cricket, the logic isn\'t perfect eg theengland matches against the australian forces in 1945 "are" "england", not "england xi" but it\'s usually reliable otherwise.',
#   'user': 'Loganberry',
#   'meta': {'is-admin': False},
#   'reply-to': '87389',
#   'timestamp': '1.239397380E09'},
#  {'id': '262180',
#   'root': '262180',
#   'text': "new photo added by a driveby to marwari horse. nice image, superficial image check suggests licensing is ok, but it's your article, so may want to peek. it was in a bad spot, so i moved it, but not sure i improved matters.",
#   'user': 'Montanabw',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287465720E09'},
#  {'id': '262181',
#   'root': '262180',
#   'text': "licensing isn't quite right. i've dropped a note on the editor's talk won't remove the image for now, but if it's not cleared up shortly it'll need to go.",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262180',
#   'timestamp': '1.287467160E09'},
#  {'id': '262182',
#   'root': '262180',
#   'text': "allright, licensing fixed. all good now  it's a nice image.",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262181',
#   'timestamp': '1.287468840E09'},
#  {'id': '262150',
#   'root': '262150',
#   'text': 'mamasita means lady in my native language for not misunderstanding',
#   'user': 'Venerock',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286164740E09'},
#  {'id': '262151',
#   'root': '262150',
#   'text': "took a quick peek at this. may be a good idea to review list of horse breeds and iberian horse to see if we already have articles under a different spelling for some of the breeds currently redlinked in the template. also not sure if we really need a nav template for this group  wpeq is a bit template heavy already. and i'd dread to see separate german, italian, english and god fobid! usa templates, especially if we got fights going over which country claims which breed like we have at lipizzan!. the italian, japanese, and indonesian horse breed articles just have extensive see also sections that crossref the others, or, if the spanish horse list is too huge for a see also, we could expand iberian horse into a list something along the lines of stock horse or gaited horse. just a thought, and should this whole thread go over to wpeq for more folks to discuss?",
#   'user': 'Montanabw',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286195520E09'},
#  {'id': '524328',
#   'root': '524327',
#   'text': "don't worry about it. i doubt many email harvesters will go digging in page histories, and don't know of any downstream sites that copy our histories, just our pages. removing it from the page should be sufficient.",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524327',
#   'timestamp': '1.189720920E09'},
#  {'id': '262184',
#   'root': '262184',
#   'text': 'see also my discussion at user talkgood olfactory, leading to this inquiry.',
#   'user': 'Bsherr',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287490620E09'},
#  {'id': '262185',
#   'root': '262184',
#   'text': "i've responded at good olfactory's page to keep this all in one spot.",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262184',
#   'timestamp': '1.287509340E09'},
#  {'id': '524330',
#   'root': '524330',
#   'text': 'my wiki mail option is working but i have to type in the following, httpen.wikipedia.orgwikispecialemailuser plus the username to get it to do so. anyway problem solved and please feel free to not respond to any of my messages today including the 2 i sent by email. and thanks for your help. .',
#   'user': 'Albion moonlight',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189668060E09'},
#  {'id': '524331',
#   'root': '524330',
#   'text': "i received your 2 emails. i'm not sure i understood the second, but if it's taken care of, that's good too.",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524330',
#   'timestamp': '1.189720800E09'},
#  {'id': '524332',
#   'root': '524332',
#   'text': 'what is the policy when someone writes something like httpen.wikipedia.orgwindex.php?titletalkrepublicofmacedoniadiff157152659oldid156689101 this ? does their ip get banned and their comment purged from the talk page?',
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189663740E09'},
#  {'id': '524333',
#   'root': '524332',
#   'text': 'i left a warning on their talk page. looks like others have already removed the offensive comment.',
#   'user': 'Videmus Omnia',
#   'meta': {'is-admin': False},
#   'reply-to': '524332',
#   'timestamp': '1.189668900E09'},
#  {'id': '524334',
#   'root': '524332',
#   'text': "they would be wikipediablocking policyblocked, yes, but it looks like they haven't been repeating. ip addresses are usually not wikipediabanning policybanned, because an ip is usually just a number handed out by a service provider, and will be given to a different person eventually certainly when the person signs up with a new service provider, and sometimes even faster than that. our acquaintaince from perth editing on that subject has shown the ability to get a new ip number within minutes of the old one being blocked, sometimes several times a day fortunately, however, this isn't him.",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524333',
#   'timestamp': '1.189721400E09'},
#  {'id': '524335',
#   'root': '524332',
#   'text': 'i see a similar address made a similar comment. httpen.wikipedia.orgwindex.php?titletalkrepublicofmacedoniadiff157578888oldid157499660 if it becomes a regular thing, tell me, and i will semiprotect the article talk page. that will stop all ip addresses without an account from editing there apparently some do make nonabusive commentshttpen.wikipedia.orgwindex.php?titletalkrepublicofmacedoniadiff156689101oldid156496906 but if we have to, we will.',
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524334',
#   'timestamp': '1.189721700E09'},
#  {'id': '262189',
#   'root': '262189',
#   'text': 'hi dana. thanks for closing wikipediacategoriesfordiscussionlog2010october14categorywikipediansopentowhalesquishing. that was a decent close. i might have said "no consensus for deviating from policybased arguments" instead of mentioning iar. you put your closing note at the bottom of the debate. that is a bit unusual. usually, the closing explanation goes at the top, with the close, doesn\'t it?',
#   'user': 'SmokeyJoe',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287993420E09'},
#  {'id': '262190',
#   'root': '262189',
#   'text': "hi smokey! thanks for the nice note! lol, i guess i'm more used to far closures, where closing notes go at the bottom. feel free to move the comment if you would like.",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262189',
#   'timestamp': '1.287993720E09'},
#  {'id': '262191',
#   'root': '262191',
#   'text': 'i think you should close the first one too, as i gave it as an example of a bad fa a few times "\'',
#   'user': 'YellowMonkey',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.287993960E09'},
#  {'id': '262192',
#   'root': '262191',
#   'text': "will do. when i closed dorset it wasn't exactly 14 days for those. i'll get to them tomorrow morning it's getting to be bedtime here! have you had a chance to check out the two i pinged you about?",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262191',
#   'timestamp': '1.287994200E09'},
#  {'id': '524336',
#   'root': '524336',
#   'text': 'hello, i did an edit on one of the porn stars pages and i have an editor who just joined wikipedia who is going onto the article and adding things at random. i removed the personal info like where he lives and the editor put it right back on. then the editor made an edit and place a description as this httpen.wikipedia.orgwindex.php?titlearpadmiklosdiffprevoldid157524752. could you please look at this? i did go onto theri talk page and explain about putting personal info and advertisement onto an article. i hope it helps. thank you',
#   'user': 'Junebug52',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189676400E09'},
#  {'id': '524337',
#   'root': '524336',
#   'text': 'you have the right idea we certainly want confirmation before accusing someone of being an escort, which is usually a euphemism for being a prostitute. however, in this case, he\'s apparently a prizewinning escort. yes, i didn\'t know there was a prize for that either, but it seems there is . live and learn. i\'ll be making an article for the international escort awards soon it got coverage from the "village voice", "dna magazine", and even a bit from the "new york daily news". winning the prize is fairly clear confirmation that he does work as an escort.',
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524336',
#   'timestamp': '1.189713300E09'},
#  {'id': '524338',
#   'root': '524336',
#   'text': 'i had no idea! i just reverted the edit because he stated that the subject was a close friend and wanted the info on the page. as you and i both know, there has to be more to the verification than just saying "the subject wants the info included" that is why i made the edit and then went to his talk page to advise him that we would need sourcing for that if he wanted the info to remain. i had no idea! lol well if i ever need another job, now i know where i can get one and get an award for doing it! lol thanks man',
#   'user': 'Junebug52',
#   'meta': {'is-admin': False},
#   'reply-to': '524337',
#   'timestamp': '1.189713600E09'},
#  {'id': '262193',
#   'root': '262193',
#   'text': "thanks for your feedback on the above. i wonder if you could give a tip on what is needed inwhich direction could be taken regarding the lead. it does seem to present a good synopsisof the what is covered in article wo going into details later discussed. is it the prose? is it the info? is it the order? not sure, and don't wanna go messin' wo a focus. thanks",
#   'user': 'Djflem',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.288047660E09'},
#  {'id': '262194',
#   'root': '262193',
#   'text': "i've responded on the review page, and have that page watchlisted. thanks for your work on the article!",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262193',
#   'timestamp': '1.288052460E09'},
#  {'id': '524339',
#   'root': '524339',
# ...
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '517',
#   'timestamp': '1.244618220E09'},
#  {'id': '519',
#   'root': '517',
#   'text': "ok, thanks. it doesn't seem to be too much of an issue, if you cannot find it. its just something that bugged me since i want to collect as much information as possible. regards,",
#   'user': 'FullMetal Falcon',
#   'meta': {'is-admin': False},
#   'reply-to': '518',
#   'timestamp': '1.244761140E09'},
#  {'id': '524807',
#   'root': '524807',
#   'text': 'thanks for finding a free image of quanell x from flickr! it is like a late christmas present. how did you know to look for one??',
#   'user': 'Deatonjr',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.199792820E09'},
#  {'id': '524808',
#   'root': '524807',
#   'text': "you're welcome. i read the article talk page and saw the request. why was i looking at the article talk page? i was probably clicking around following interesting links from people's user pages, or contributions, or articles. i'm not sure myself, really.",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524807',
#   'timestamp': '1.199832840E09'},
#  {'id': '521',
#   'root': '521',
#   'text': 'phew, that was quick. you beat me to wpaiv with the report on 202.155.92.10. persistent isn\'t she? regards span style"textshadowgrey 0.2em 0.2em 0.1em classtexhtml"',
#   'user': 'Davidelit',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.253802180E09'},
#  {'id': '522',
#   'root': '521',
#   'text': "indeed heshe is. i've been keeping a track of this person for over a year now they're an indonesian user who constantly vandalizes anime, game and movie studio articles with misinformation. he's ip jumped so many times that i don't think he'll ever be stopped.",
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '521',
#   'timestamp': '1.253802240E09'},
#  {'id': '523',
#   'root': '521',
#   'text': 'yes, it is a problem. 202.70.61.148 is another of the ips. well, let\'s see what happens. i\'ll wait to see if she is blocked before reverting again. span style"textshadowgrey 0.2em 0.2em 0.1em classtexhtml"',
#   'user': 'Davidelit',
#   'meta': {'is-admin': False},
#   'reply-to': '522',
#   'timestamp': '1.253803500E09'},
#  {'id': '524',
#   'root': '521',
#   'text': 'ditto. that guy\'s persistent, i know and annoying as well. i\'ve also encountered this guy numerous times, and i was the one who first reported him on wpani wikipediaadministrators\' noticeboardincidentarchive341re big problem caused by "61.5.61.94." ip userthis is the report as archived. the guy also operated on the following ranges 202.70.61.133, 202.70.61.146, 114.59.100.70, and the 118.137.x.x range which i know you\'re aware already, as well as many others that i can\'t mention here as of this moment, all in indonesia. it seems no amount of warning, not even in indonesian, stopped him. i\'ve already told everything about this guy to user talknja247nja247, so nja247 has oftentimes become my goto admin whenever the vandal strikes or has striken within the last few minuteshours of his last attack.',
#   'user': '{unknown-10}',
#   'meta': {'is-admin': False},
#   'reply-to': '523',
#   'timestamp': '1.253815620E09'},
#  {'id': '525',
#   'root': '521',
#   'text': 'i wonder if it would be possible to request multiple, longterm range blocks on the offending ranges. i know i requested such a thing from admin usernihonjoe a while back, and he blocked several offending ranges for 6 months, during which vandalism from this user was relatively quiet as far as i could tell, anyway as a result. maybe a similar set of range blocks hopefully for a year or longer could deter this user.',
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '524',
#   'timestamp': '1.253834220E09'},
#  {'id': '526',
#   'root': '521',
#   'text': "since the 202.70.61.x range will be automatically unblocked a few minutes from now muzemike did the block on 202.70.61.12827 a week ago as an immediate action to wikipediaadministrators' noticeboardincidentarchive564an already big problem by misinformation vandalmy report on the vandal, i'm sure the vandal will show up on that range once again.",
#   'user': '{unknown-11}',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.253834820E09'},
#  {'id': '527',
#   'root': '521',
#   'text': '"\'p. s."\' i\'ve already told nja247 about 202.155.92.10, btw.',
#   'user': '{unknown-12}',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.253835240E09'},
#  {'id': '262666',
#   'root': '262666',
#   'text': 'am doing. after a cursory look, nothing jumps outu2014except the fact it was quite wellwritten  i\'ll read more thoroughly later, but right now i can\'t fault it on anything major. i thought of perhaps breaking "life" up into "personal life" and "work", but that doesn\'t seem like much of an idea it might make those sections too short.',
#   'user': 'Fvasconcellos',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.175132280E09'},
#  {'id': '262667',
#   'root': '262666',
#   'text': 'catching up on the guidelines is always a good idea',
#   'user': 'Fvasconcellos',
#   'meta': {'is-admin': False},
#   'reply-to': '262666',
#   'timestamp': '1.175133300E09'},
#  {'id': '262668',
#   'root': '262666',
#   'text': "glad to have helped. i'll have to check my dictionary now, that was force of habit and my spellchecker, set to u.s. english",
#   'user': 'Fvasconcellos',
#   'meta': {'is-admin': False},
#   'reply-to': '262667',
#   'timestamp': '1.175138640E09'},
#  {'id': '262669',
#   'root': '262669',
#   'text': 'there\'s some discussion going on regarding cite news and the other cite templates on template talkcite newsthat talk page. would love your input   span style"backgroundcolor eeccff"',
#   'user': 'SatyrTN',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.175504160E09'},
#  {'id': '262670',
#   'root': '262669',
#   'text': 'please see my reply to the ongoing discussion the very "\'last"\' thing we want is people charging off in all directions using their own "pet" styles for citations. we want to get the various citation templates in such a condition that "\'anybody"\' can use them to produce useful citations, rather than placing further artificial restrictions and limiting citation to those "experts" who "know how to format citations correctly". we need to stop trying to follow any particular existing "manual of style" and synthesise our own why else did the various "manuals" come into being other than the particular needs of the originating situation? hth hand u2014',
#   'user': 'Phil Boswell',
#   'meta': {'is-admin': True},
#   'reply-to': '262669',
#   'timestamp': '1.175547480E09'},
#  {'id': '262671',
#   'root': '262671',
#   'text': 'ok, i admit that i got distracted because of all of my travel can we try to finish this up and poll for consensus? httpen.wikipedia.orgwikiwikipediatalkmanualofstyle28medicinerelatedarticles29historical.3f',
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.175811180E09'},
#  {'id': '262672',
#   'root': '262671',
#   'text': "ok, enough procrastinating from me  have you noticed that i really hate working on policy pages ? grin i'd much rather edit and review articles. i'm going to settle in to my upstairs computer and catch up on this thing, finally.",
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': '262671',
#   'timestamp': '1.176421320E09'},
#  {'id': '529',
#   'root': '529',
#   'text': 'specialcontributions220.255.178.29220.255.178.29',
#   'user': '220.255.178.29',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.264443540E09'},
#  {'id': '530',
#   'root': '529',
#   'text': "because you didn't supply references for the criticisms you listed. per the sites' wikipediaverifiabilityverifiability policy, any information that can be challenged has to be backed up by a wikipediareliable sourcesreliable source that is cited in writing. if there is no source supplied, the material added can be removed. find some reliable sources to cite on the issues you brought up, and what you wrote can stand.",
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '529',
#   'timestamp': '1.264458360E09'},
#  {'id': '524818',
#   'root': '524818',
#   'text': "hi again, anonemouse. i've just added several avn magazineavn magazine reviewsprofiles, but for some reason the links aren't working. since it's i think a print source as well, the reference is still valid. but is there a trick to linking to the online source?",
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.200106500E09'},
#  {'id': '524819',
#   'root': '524818',
#   'text': 'looking at your recent edit history, the httpen.wikipedia.orgwindex.php?titleyukiasukadiffprevoldid183679223 link you added to yuki asuka, for example, worked for me.',
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524818',
#   'timestamp': '1.200106740E09'},
#  {'id': '524820',
#   'root': '524818',
#   'text': 'ok must just be this computer. thanks.',
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': '524819',
#   'timestamp': '1.200107340E09'},
#  {'id': '524821',
#   'root': '524818',
#   'text': "that said, i'm not sure that every review of every film a star has appeared in is a good use of external links. just from sheer numbers, i know japanese stars appear in fewer films than american stars, but still, ten films, each reviewed in two magazines, that's twenty external links, and the content isn't usually very focused on the single actor our article is supposed to be about.",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524820',
#   'timestamp': '1.200107760E09'},
#  {'id': '524822',
#   'root': '524818',
#   'text': "well, on these particular subjects suzi suzuki excepted, these are japanese films being reviewed in an englishlanguage source pretty rare, and, i would think, some indication of international notability. also the films are not likely to get their own articles, and most not all of the reviews do carry on quite a bit about the actress in question, since she's the star attraction. about suzuki though, i've long thought she does not belong in category japanese porn stars. she's an actress of japanese i think descent who appears in u.s. porn. these ethnicnationality issues get sticky though, and removing her from the category might set off some kind of a squabbling storm.",
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': '524821',
#   'timestamp': '1.200108360E09'},
#  {'id': '532',
#   'root': '532',
#   'text': "you're quite right. i have removed both existing spam links. by the way, you should place your messages at the bottom of talk pages, as that is where editors will look for them.",
#   'user': 'Jongleur100',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.289115180E09'},
#  {'id': '533',
#   'root': '532',
#   'text': 'ok. best.',
#   'user': 'Jongleur100',
#   'meta': {'is-admin': False},
#   'reply-to': '532',
#   'timestamp': '1.262928660E09'},
#  {'id': '515031',
#   'root': '515031',
#   'text': 'situation unravelling quickly.',
#   'user': 'Ronz',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.240304400E09'},
#  {'id': '515032',
#   'root': '515031',
#   'text': "i'd take it to afd and let the community determine notability or not. don't try to take it on your own shoulders.",
#   'user': 'GTBacchus',
#   'meta': {'is-admin': True},
#   'reply-to': '515031',
#   'timestamp': '1.240304700E09'},
#  {'id': '515033',
#   'root': '515031',
#   'text': "sounds good. i'm going to make a suggestion to the upset editor.",
#   'user': 'Ronz',
#   'meta': {'is-admin': False},
#   'reply-to': '515032',
#   'timestamp': '1.240306200E09'},
#  {'id': '535',
#   'root': '535',
#   'text': 'example.specialcontributions78.149.71.1778.149.71.17',
#   'user': '78.149.71.17',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.264924980E09'},
#  {'id': '536',
#   'root': '535',
#   'text': 'hope this helps, cheers,',
#   'user': 'Jongleur100',
#   'meta': {'is-admin': False},
#   'reply-to': '535',
#   'timestamp': '1.265224380E09'},
#  {'id': '524824',
#   'root': '524824',
#   'text': "anonemouse, if i wanted to change my user name, how would i go about it? i can't seem to find innfo that would help me to accomplish this. i keep being mistaken for a woman because of the name and thought i would change it to something a little more masculine lol.",
#   'user': 'Junebug52',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.200121020E09'},
#  {'id': '524825',
#   'root': '524824',
#   'text': 'nevermind my friend, i found it. if it would have been a snake, it would have bit me!',
#   'user': 'Junebug52',
#   'meta': {'is-admin': False},
#   'reply-to': '524824',
#   'timestamp': '1.200122040E09'},
#  {'id': '537',
#   'root': '537',
#   'text': 'i did not enter the vandalism you removed. please check the history of the edits at the site, and retract your statement.',
#   'user': 'Iss246',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.266050460E09'},
#  {'id': '538',
#   'root': '537',
#   'text': 'i think it is you who should check the history. i reverted vandalism by 208.93.60.193 9 an education facility in texas who are now banned for a year and reinstated your edit. please read my edit summary again  slowly.',
#   'user': 'Jongleur100',
#   'meta': {'is-admin': False},
#   'reply-to': '537',
#   'timestamp': '1.266070380E09'},
#  {'id': '262682',
#   'root': '262682',
#   'text': 'marco responded by creating a prototype usermarcotolosandboxpoliomyelitistestpoliomyelitis test page in his userspace with an accompanying usermarcotolosandboxhistoryofpoliomyelitistesthistory of poliomyelitis article. when you get a chance could you take a look at the prototypes and let us know what you think? our ongoing discussion can be found user talkmarcotolowelcome back marco!here. thanks again for your input.',
#   'user': 'DO11.10',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.178617200E09'},
#  {'id': '262683',
#   'root': '262682',
#   'text': "colin, i'm going to be traveling over mother's day, so will try to focus on this next week. insinuations on the project talk page are beginning to bother me, so best i work on it later. best,",
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': '262682',
#   'timestamp': '1.178831280E09'},
#  {'id': '539',
#   'root': '539',
#   'text': 'you are right. i apologize.',
#   'user': 'Iss246',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.266107640E09'},
#  {'id': '540',
#   'root': '539',
#   'text': 'accepted, but please be more careful in future.',
#   'user': 'Jongleur100',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.266107760E09'},
#  {'id': '262684',
#   'root': '262684',
#   'text': "any of that sound strikingly familiar broke the last link because it's blacklisted",
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.179365160E09'},
#  {'id': '262685',
#   'root': '262684',
#   'text': "polish  yikes ! i know someone who will help with articles give me a list of the ones you want. i haven't yet read kushner, so not sure yet what his pov is . i can't wait  have you seen the schizophrenia far? one to watch, in terms of interplay between psych and medicine on medmos. i redid the toc to agree with medmos, because all of their content basically conformed anyway mdash just needed better organization.",
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': '262684',
#   'timestamp': '1.179450960E09'},
#  ...]

# %%
for item in wikipedia:
    item['text'] = clean_text(item['text'])

# %%
wikipedia[:] = [item for item in wikipedia if item['text'].strip() != '']

# %% [markdown]
# ## **Converting Original Datasets to prefered format.**

# %%
def data_transformation(dataset: List[Dict[str, Any]]) -> Dict[str, List[Dict[str, Any]]]:
    for utt in dataset:
        if 'reply-to' in utt:
            utt['reply_to'] = utt.pop('reply-to')

    filtered_utt: List[Dict[str, Any]] = []
    for utt in dataset:
        filtered_utt.append({key: utt[key] for key in ["id","user",'root', "reply_to", 'text', "timestamp"]})

    conversations: defaultdict[str, List[Dict[str, Any]]] = defaultdict(list)
    for utt in filtered_utt:
        root = utt["root"]
        conversations[root].append(utt)

    for id, conversation in conversations.items():
        for utterance in conversation:
            if utterance.get('reply_to') is not None:
                try:
                    utterance['reply_to'] = int(utterance['reply_to'])
                except ValueError:
                    utterance['reply_to'] = utterance['reply_to']
            if utterance.get('id') == utterance.get('root'):
                pass
            elif utterance.get('reply_to') is None:
                try:
                    utterance['reply_to'] = int(utterance['id']) - 1
                except ValueError:
                    utterance['reply_to'] = utterance['root']

    print(f"We have {len(conversations)} conversations in this dataset")

    return conversations

# %%
wikipedia_dataset = data_transformation(wikipedia)
# Out:
# We have 125059 conversations in this dataset

# %%
wikipedia_dataset
# Out:
# defaultdict(list,
#             {'524288': [{'id': '524288',
#                'user': 'Frightner',
#                'root': '524288',
#                'reply_to': None,
#                'text': 'you should look at all of the point on the template not just the last one, the template also says the image belonging to the republic of macedonia is in the public domain if it being used for "information purposes".',
#                'timestamp': '1.189190940E09'},
#               {'id': '524289',
#                'user': 'Revizionist',
#                'root': '524288',
#                'reply_to': 524288,
#                'text': 'yes i agree. the law permits usage of documents, photographs and other materials for educational and informational purposes. there was a normative act issued by the government of the republic of macedonia that even allowed citizens to make photocopies or photograph rare archive materials.',
#                'timestamp': '1.189204860E09'}],
#              '1': [{'id': '1',
#                'user': 'Johannes003',
#                'root': '1',
#                'reply_to': None,
#                'text': "yes, that's good. revathy's page looked very reliable, that's why we used that as a source.",
#                'timestamp': '1.310744280E09'},
#               {'id': '2',
#                'user': 'Johannes003',
#                'root': '1',
#                'reply_to': 1,
#                'text': "nagma'a site, at least that filmography page, looks like taken from wikipedia itself. i didn't remove it from time being, but i don't think it's true.",
#                'timestamp': '1.310746500E09'},
#               {'id': '3',
#                'user': 'Johannes003',
#                'root': '1',
#                'reply_to': 2,
#                'text': 'i don\'t think there are many such official reliable sites left yet. the problem is most "official sites" are not really official, and often based on wikipedia itself, and you don\'t know what to believe and what not. we used madras talkies\' page, which is dead now. httpkavithalayaa.com kavithalayaa\'s site is there, also avm production\'s site might be useful perhaps, but i can\'t enter that. generally official sites of production houses seem to be very reliable ones.',
#                'timestamp': '1.310751180E09'},
#               {'id': '4',
#                'user': 'Michael-Billa',
#                'root': '1',
#                'reply_to': 3,
#                'text': 'most of the so called "official sites" are maintained by fans or cinema based web companies. not sure how reliable are they. span style"colorgreenfontsizesmallfontfamilysegoe print"ibiillaspan',
#                'timestamp': '1.311762120E09'}],
#              '524290': [{'id': '524290',
#                'user': 'AnonEMouse',
#                'root': '524290',
#                'reply_to': None,
#                'text': 'you closed wikipediaarticles for deletionj. kevin tumlinson after one day without mentioning anything about speedy deletion or giving reasons. not that i\'m objecting "too" much, but did you realize it was only one day?',
#                'timestamp': '1.189197960E09'},
#               {'id': '524291',
#                'user': 'FayssalF',
#                'root': '524290',
#                'reply_to': 524290,
#                'text': 'well, notability cannot be acquired in 4 days. that was my reasoning behind the early closure. however, if you still believe the closure was out of process, you can still refer to the deletion review.',
#                'timestamp': '1.189200660E09'},
#               {'id': '524292',
#                'user': 'AnonEMouse',
#                'root': '524290',
#                'reply_to': 524291,
#                'text': "no, no, i was the nominator! just wanted to make sure it wasn't done in error.",
#                'timestamp': '1.189200720E09'},
#               {'id': '524293',
#                'user': 'FayssalF',
#                'root': '524290',
#                'reply_to': 524292,
#                'text': "i was a bit surprised because i know you were the nominator no, it wasn't done in error.",
#                'timestamp': '1.189200960E09'}],
#              '262147': [{'id': '262147',
#                'user': 'Venerock',
#                'root': '262147',
#                'reply_to': None,
#                'text': 'hello dana, thanks for contribute in this templatespanish horsestemplate, but i need tell you that is about horse, and balearic article is about a language of a people, if you think that im not right please tell me for not fixing the edit at last. enjoy your day',
#                'timestamp': '1.286157240E09'},
#               {'id': '262148',
#                'user': 'Dana boomer',
#                'root': '262147',
#                'reply_to': 262147,
#                'text': 'my apologies, i forgot to include the disambiguator. please check now it should be right. thanks for letting me know.',
#                'timestamp': '1.286157480E09'}],
#              '6': [{'id': '6',
#                'user': 'Johannes003',
#                'root': '6',
#                'reply_to': None,
#                'text': 'hey, who said so? frankly, i have absolutely no idea, sorry!',
#                'timestamp': '1.312057320E09'},
#               {'id': '7',
#                'user': 'Johannes003',
#                'root': '6',
#                'reply_to': 6,
#                'text': "maybe, we should check out who added that, it could be some fanatic ip user. there will have been nominees, since there were nominees in earlier ceremonies and in the telugu section, too, but how to find out? if there was a video coverage of that ceremony available we would know. otherwise, i would remove it as it's unsourced.",
#                'timestamp': '1.312059420E09'}],
#              '262145': [{'id': '262145',
#                'user': 'Kudpung',
#                'root': '262145',
#                'reply_to': None,
#                'text': "h dana, totally amiss of me belated congrats for your promotion! i voted for you without any hesitation. i'm pleased to hear from pike that you might be reviewing the finnhorse, i can't think of anyone better for the job.",
#                'timestamp': '1.286127120E09'},
#               {'id': '262146',
#                'user': 'Dana boomer',
#                'root': '262145',
#                'reply_to': 262145,
#                'text': "thank you very much! i am going to try to take a look over finnhorse actually, i think i'll go start looking at it right now while i have a few minutes.",
#                'timestamp': '1.286133300E09'}],
#              '262152': [{'id': '262152',
#                'user': 'Rms125a@hotmail.com',
#                'root': '262152',
#                'reply_to': None,
#                'text': 'hi. just writing that you closed out the wpcfd as a "\'merge and delete"\', but category appears open still at this moment. yours,',
#                'timestamp': '1.286163540E09'},
#               {'id': '262153',
#                'user': 'Dana boomer',
#                'root': '262152',
#                'reply_to': 262152,
#                'text': "yes, i know. it's on the list at wikipediacategoriesfordiscussionworking, and the bot should get to it shortly.",
#                'timestamp': '1.286163600E09'}],
#              '9': [{'id': '9',
#                'user': 'Secret of success',
#                'root': '9',
#                'reply_to': None,
#                'text': "well, no website is 100 perfect, you got to understand that. are you saying toi is an unreliable source? mention of shankar as shankar mahadevan might have been a mistake, i'll contact them and ask them to correct it. what else do you want me to do?",
#                'timestamp': '1.312136520E09'},
#               {'id': '10',
#                'user': 'Vensatry',
#                'root': '9',
#                'reply_to': 9,
#                'text': 'i don\'t care. this is not the place to elevate your favourite star\'s films. i\'m not questioning about the credibility of toi. there is a consensus not to add budgetgross figures for any indian movie, if it\'s speculated at a higher rate. i think you might be aware of the "enthiran issue". even official sources were not considered.',
#                'timestamp': '1.312136820E09'}],
#              '262154': [{'id': '262154',
#                'user': 'JCDenton2052',
#                'root': '262154',
#                'reply_to': None,
#                'text': 'could you restore categorysecond wave synthpop acts or at least the bands formerly listed therein to my userspace? i was checking out some of the bands and bookmarked it to check out some others later, but found that it was deleted. thanks!',
#                'timestamp': '1.286272380E09'},
#               {'id': '262155',
#                'user': 'Courcelles',
#                'root': '262154',
#                'reply_to': 262154,
#                'text': "there would be nothing to restore, and categories can't be moved even if there were. category pages contain nothing, articles are added to it by an addition of code at the bottom of each article. when a category is deleted, cfd has an adminbot that goes through each article and removes the category. the best you could do would be to find the edits in usercydebot's contribution record, and then you'd be able to see what was in the category predeletion.",
#                'timestamp': '1.286272740E09'},
#               {'id': '262156',
#                'user': 'JCDenton2052',
#                'root': '262154',
#                'reply_to': 262155,
#                'text': 'found them. thanks for your help!',
#                'timestamp': '1.286274420E09'}],
#              '11': [{'id': '11',
#                'user': 'Karthikndr',
#                'root': '11',
#                'reply_to': None,
#                'text': 'i agree i copied, even he mi8 know it very well. i dont know 2 design and all but some thing inside, i got my own work also. if u dont mind can i copy abit of urs. even ur page looks good!!',
#                'timestamp': '1.312143840E09'},
#               {'id': '12',
#                'user': 'Karthikndr',
#                'root': '11',
#                'reply_to': 11,
#                'text': 'ok! ty for the info and links. will create new design asap.',
#                'timestamp': '1.312146060E09'}],
#              '13': [{'id': '13',
#                'user': 'Secret of success',
#                'root': '13',
#                'reply_to': None,
#                'text': "i don't understand what you are saying. could you please be more precise?",
#                'timestamp': '1.312244220E09'},
#               {'id': '14',
#                'user': 'Secret of success',
#                'root': '13',
#                'reply_to': 13,
#                'text': 'well, i have not made much significant contribution but just a couple of sections in one or two articles. if that is not enough, i have removed the template if that bothers you.',
#                'timestamp': '1.312410120E09'}],
#              '524302': [{'id': '524302',
#                'user': 'Capricornis',
#                'root': '524302',
#                'reply_to': None,
#                'text': "if you look at the contrib history of mr. neutron you will find plenty of edits like this, and all of his 'contribs' are exclusively on articles dealing with macedonia, and mostly pushing probulgarian pov in subtle and notsosubtle ways. i just thought you might want to know for future reference",
#                'timestamp': '1.189478460E09'},
#               {'id': '524303',
#                'user': 'AnonEMouse',
#                'root': '524302',
#                'reply_to': 524302,
#                'text': 'thanks. i understand that there is a lot of controversy here, even between respected scholars. we need to document that disagreement in our articles, hopefully without attacking editors.',
#                'timestamp': '1.189479180E09'},
#               {'id': '524304',
#                'user': 'Mr. Neutron',
#                'root': '524302',
#                'reply_to': 524303,
#                'text': 'capricornis, stop insinuating. and please refrain from various ad hominem arguments, as they are falacies. comment on contributions please.',
#                'timestamp': '1.189480920E09'},
#               {'id': '524305',
#                'user': 'Capricornis',
#                'root': '524302',
#                'reply_to': 524304,
#                'text': "you must have misunderstood something? i was commenting on your contributions, not on you as a person please read the ad hominem article before you quote it. also 'insinuations' are statements that cannot be proven, whereas my statements above can be proven by anyone who will take the time to look through your contrib history. have a great day",
#                'timestamp': '1.189489680E09'},
#               {'id': '524306',
#                'user': 'Mr. Neutron',
#                'root': '524302',
#                'reply_to': 524305,
#                'text': 'you were already warned on your talkpage not to commit any more personal attacks, so dont do it. you have been consistently insinuating against other wikipedia contributors and this is not at all nice going.',
#                'timestamp': '1.189490280E09'},
#               {'id': '524307',
#                'user': 'Capricornis',
#                'root': '524302',
#                'reply_to': 524306,
#                'text': "you are talking about the distant past. i retracted the unfortunate comments and they were accepted, including by you, at the end of this section httpen.wikipedia.orgwikitalkilindenpreobrazhenieuprisingsearchenginestests . i do not intend to personally attack you at all, but i will attack your contributions and 'content' every time you try to 'slightly' swing the pendulum to your side you will be reported.",
#                'timestamp': '1.189491480E09'},
#               {'id': '524308',
#                'user': 'Mr. Neutron',
#                'root': '524302',
#                'reply_to': 524307,
#                'text': 'oh please! "distant past" was only httpen.wikipedia.orgwindex.php?titleusertalkcapricornisdiff156856515oldid156665242 yesterday. report whatever you want, with such consistent agenda against other contributors you only bring suspicion on yourself.',
#                'timestamp': '1.189493820E09'},
#               {'id': '524309',
#                'user': 'Capricornis',
#                'root': '524302',
#                'reply_to': 524308,
#                'text': "that was a misinformed suggestion by another ordinary user, just like you and me. i still maintain that there were no personal attacks in my words, but only good humored jibs. the statement about the exclusivity of your activity on macedonia related articles stands and is easily verifiable. i suggest if you have something more to say, to do it on my talk page as there is no point continuing this tirade on anonemouse's page who seems to have quite enough work without it. cheers",
#                'timestamp': '1.189501860E09'},
#               {'id': '524310',
#                'user': 'Mr. Neutron',
#                'root': '524302',
#                'reply_to': 524309,
#                'text': 'and more personal attacks calling people misinformed.',
#                'timestamp': '1.189502040E09'},
#               {'id': '524311',
#                'user': 'Capricornis',
#                'root': '524302',
#                'reply_to': 524310,
#                'text': 'misinformedmisguided are not insults in the english language. maybe brush up on your english or use websters?',
#                'timestamp': '1.189502280E09'}],
#              '16': [{'id': '16',
#                'user': 'Secret of success',
#                'root': '16',
#                'reply_to': None,
#                'text': 'hi. i think your statement of the ip being the sockpuppet of sreekar akkineni is true. earlier, a user named niranjaniyengarwho was a sock of sreekar akkineni wrote on my talk page in a similar manner. if you can trace the ip used by them, it would be possible to block him. i also have a doubt if mr. kollyfan, famed for his discussion of the enthiran gross has something to do with this. it would throw some light on this manner. thanks!',
#                'timestamp': '1.312588320E09'},
#               {'id': '17',
#                'user': 'Vensatry',
#                'root': '16',
#                'reply_to': 16,
#                'text': 'glad that you got my point. actually sreekarakkineni, niranjaniyengar and this ip seems like the same person. will file a case soon.',
#                'timestamp': '1.312588860E09'},
#               {'id': '18',
#                'user': 'Bollyjeff',
#                'root': '16',
#                'reply_to': 17,
#                'text': 'so put in a sock puppet investigation to find out.',
#                'timestamp': '1.312590060E09'}],
#              '262162': [{'id': '262162',
#                'user': 'Explicit',
#                'root': '262162',
#                'reply_to': None,
#                'text': "hi there dana, when relisting cfd discussions, please be aware that we don't remove the discussions from one log date to the other instead, we close the discussion at add the tlrelisted template instead. as such, httpen.wikipedia.orgwindex.php?titlewikipediacategoriesfordiscussionlog2010september26diff389785157oldid389782135 this edit should be reverted and the discussions should be closed. this is explained at wprelist, last line. thanks. u2014",
#                'timestamp': '1.286691180E09'},
#               {'id': '262163',
#                'user': 'Dana boomer',
#                'root': '262162',
#                'reply_to': 262162,
#                'text': "whoops, my apologies. i apparently read the bolded part and completely missed the part in parentheses. thanks for letting me know please let me know if there is anything else i'm doing wrong i'm new at it, but the backlog needs work so i wanted to chip in. i'll go fix that now.",
#                'timestamp': '1.286701080E09'},
#               {'id': '262164',
#                'user': 'Good Olfactory',
#                'root': '262162',
#                'reply_to': 262162,
#                'text': "and just one other note, danau2014after you relist a cfd, don't forget to change the date on the cfd tag on the category itself so that it goes to the new discussion, like httpen.wikipedia.orgwindex.php?titlecategory3achristmasnumberonesinglesintheunitedkingdomactionhistorysubmitdiff389999136oldid387262711 this. thanks for you service in working on closing cfds we are always looking for more help and attention with these.",
#                'timestamp': '1.286793420E09'}],
#              '20': [{'id': '20',
#                'user': 'Leahtwosaints',
#                'root': '20',
#                'reply_to': None,
#                'text': 'hey! hi there are a bunch of things i want to learn here in wikipedia. only you, and maybe 3 others could teach me terribly embarrassing to admit i\'m so ignorant with computers, etc. and so i\'ve decided to send a couple notes and the others for help. is it ok to email you, to save space on our talk pages? mine is activated too. this drives me crazy! one burning question has to do with many grateful deadrelated articles, so i am here. nearly all the biography articles about musicians eventually have a discography section, followed by references, and then external links. some of them have a "see also" section which is essentially trivia, and it is simple enough to see if it\'s warranted or not. however, what i don\'t understand is a "notes" section. what purpose, exactly does it serve, and how do you put info into the text properly to acheive whatever result the editor is trying to accomplish? it\'s really perplexing.',
#                'timestamp': '1.300422840E09'},
#               {'id': '21',
#                'user': 'Mudwater',
#                'root': '20',
#                'reply_to': 20,
#                'text': 'let me know how that goes. being able to format footnotes is a big plus, and like i said it\'s pretty easy once you\'ve done it a few times. i suggest that you try doing a few on your user page, or on a subpage of your user page, for practice. if you want more help just let me know. font face"cursive"u2014',
#                'timestamp': '1.300432800E09'}],
#              '262165': [{'id': '262165',
#                'user': 'YellowMonkey',
#                'root': '262165',
#                'reply_to': None,
#                'text': 'i think you should nag mf. he never responds to my nags p "\'',
#                'timestamp': '1.286798880E09'},
#               {'id': '262166',
#                'user': 'Dana boomer',
#                'root': '262165',
#                'reply_to': 262165,
#                'text': "i dropped notes to half a dozen editors on various articles already in the farc stage. we'll see if it gets us anywhere.",
#                'timestamp': '1.286830500E09'},
#               {'id': '262167',
#                'user': 'YellowMonkey',
#                'root': '262165',
#                'reply_to': 262166,
#                'text': 'outofsinc on british empire is a sockmeat, quite obviously "\'',
#                'timestamp': '1.286867700E09'}],
#              '22': [{'id': '22',
#                'user': 'Leahtwosaints',
#                'root': '22',
#                'reply_to': None,
#                'text': 'my apologies when i come trampling through your pet projects further from my mind to annoy you, seriously. however, i keep seeing esp. in jazz related articles people interchanging sections listed as "references", "notes", "footnotes" "external links", and i\'ve even seen whilst editing a "reflist 2". frankly, i\'m baffled. i\'ve pretty much stuck to the editing of musicians and generally, the articles are biographybiographical and i stick to the typical lead per wpmos which i admit i never really read too deeply. usually, at the end of an article, there\'s the discography and the nowikireferences section, followed by external linksnowiki and often the latter is jampacked with link farms that are longer than the article themselves. can you explain to me how this works, with the notes and all? oh, and feel free to revert my edits when they are done improperly. sorry about messing up articles that i only want to help!',
#                'timestamp': '1.303346700E09'},
#               {'id': '23',
#                'user': 'Mudwater',
#                'root': '22',
#                'reply_to': 22,
#                'text': 'thanks for the note. yes, i think a lot of editors are a bit confused about notes, references, and external links sections. take a look at what i wrote at user talkmudwaternotes and other things, and at talkskip battinplace references here, for some helpful info. on some articles, most or all of the external links section should really be in the references section. but it\'s important not to remove reliable references from articles. feel free to reply here if you want to talk about this some more. font face"cursive"u2014',
#                'timestamp': '1.303611720E09'},
#               {'id': '24',
#                'user': 'Leahtwosaints',
#                'root': '22',
#                'reply_to': 23,
#                'text': "ok, i'll have a look at it. partly, one reason why i'm not a first class editor has some to do with add or laziness, take your pick which explains my difficulty with punctuation as well. anyway, like i said, never feel bad about reverting my work, too.",
#                'timestamp': '1.303737480E09'}],
#              '262168': [{'id': '262168',
#                'user': 'Cirt',
#                'root': '262168',
#                'reply_to': None,
#                'text': 'can you please see wikipedia talkfeatured article reviewsimon byrnearchive1breakingupotherusers\'posts, and help out with regard to this disruption? thank you for your time, "\'',
#                'timestamp': '1.286894160E09'},
#               {'id': '262169',
#                'user': 'Cirt',
#                'root': '262168',
#                'reply_to': 262168,
#                'text': 'responded to you, at wikipedia talkfeatured article reviewsimon byrnearchive1. "\'',
#                'timestamp': '1.286910720E09'},
#               {'id': '262170',
#                'user': 'Cirt',
#                'root': '262168',
#                'reply_to': 262169,
#                'text': 'seems fixed now. "\'',
#                'timestamp': '1.286911800E09'}],
#              '524313': [{'id': '524313',
#                'user': 'Mandsford',
#                'root': '524313',
#                'reply_to': None,
#                'text': 'who wrote the joe schmidlap article? i had a friend who referenced that name regularly, and was surprised to see it in print. thanks for any info you can provide.',
#                'timestamp': '1.189486980E09'},
#               {'id': '524314',
#                'user': 'AnonEMouse',
#                'root': '524313',
#                'reply_to': 524313,
#                'text': "usermanualrivera791 was the proud author, but it's a common enough insertnamehere name, just httpwww.google.comsearch?qjoeschmidlap ask google. joe schmoe is another john q. public john doe in legal cases joe bloggs on standardized tests bubba.",
#                'timestamp': '1.189539780E09'}],
#              '26': [{'id': '26',
#                'user': 'Anetode',
#                'root': '26',
#                'reply_to': None,
#                'text': 'if you have uploaded other nonfree media, consider checking that you have specified how these images fully satisfy our nonfree content criteria. you can find a list of description pages you have edited by clicking on span class"plainlinks"fullurlspecialcontributionstargetmudwaternamespace6 this linkspan. note that even if you follow steps 1 and 2 above, nonfree media which could be replaced by freely licensed alternatives will be deleted 2 days after this notification 7 days if uploaded before 13 july 2006, per our wikipedianonfree content criterianonfree content policy. if you have any questions please ask them at the wikipediamedia copyright questionsmedia copyright questions page. thank you. ! templatedireplaceable fair usenotice u02c9u02c9sup',
#                'timestamp': '1.303643760E09'},
#               {'id': '27',
#                'user': 'Leahtwosaints',
#                'root': '26',
#                'reply_to': 26,
#                'text': 'second, last but not least, there\'s an "\'rfa"\' for usercatfish jim and the soapdish, one of the handful of editors who, like you, have consistently been a help and inspiration. i hope you\'ll take a look wikipediarequests for adminshipcatfish jim and the soapdish please, vote with your heart. thanks as always.',
#                'timestamp': '1.304301000E09'},
#               {'id': '28',
#                'user': 'Mudwater',
#                'root': '26',
#                'reply_to': 27,
#                'text': 'as far as the scott gorham article, that\'s just a classic case of an article that doesn\'t have enough references. but it looks like someone has added more references since you posted about it here on my talk page. i might add a few more myself if i get around to it. in general, i\'d say don\'t get too hung up about the technical details of naming the sections, or the best way to format references. the most important things are to expand and improve the text of existing articles, and to add reliable references that you find, either on the internet or offline. i happen to be interested in a lot of the technical details myself, as i\'ve explained a bit here on my talk page, but if you find it confusing, don\'t worry about it. the content is the most important thing, someone can always come along later and fix the formatting. "p.s." looks like your buddy made admin, congratulations to him or her. font face"cursive"u2014',
#                'timestamp': '1.304837580E09'},
#               {'id': '29',
#                'user': 'Leahtwosaints',
#                'root': '26',
#                'reply_to': 28,
#                'text': 'thanks for the response. ok, then. the editor who just brought thin lizzy to ga status becomes more motivated with the thin lizzy related articles like scott gorham when i bring in new photos that are good. if there isn\'t enough text to place the article, it doesn\'t work, and he\'s good that way. like the photo for bo diddley and eric bell. so that must be him. oh, and as for usercatfish jim and the soapdish\'s rfa, it is good! i was really surprised to hear he jumped into the ring of fire without my knowing he planned to do it. he said he didn\'t want to look like he might be fishing for votes, which just goes to show what a decent guy he is. not to mention all those positive votes, and i think, 2 votes not for his adminship, which is a really decent outcome! i thought you knew him already. you may benefit from doing so. he\'s been so helpful to me over the last year or so, and is a good editor as well as good at sniffing out vandalism, which is why he finally asked for the mop more tools in which to deal with those problems. i\'m glad for him! i\'ll only vote in an rfa if i "really" know the individual, so it\'s just been three times altogether.',
#                'timestamp': '1.305304320E09'}],
#              '524315': [{'id': '524315',
#                'user': 'Kwork',
#                'root': '524315',
#                'reply_to': None,
#                'text': "anonemouse, when you get a chance could you take a look at the material jamesd1 has added to the article? my view is that much of it is nothing but original research.for instance, the section comparing bailey's writing to theosophical society literature which is based on nothing but bailey quotes and links that do not even mention bailey, all held together by original research of jamesd1. if you think i am wrong, i will not bother the others editors on this point. thanks for making the spelling correction",
#                'timestamp': '1.189552920E09'},
#               {'id': '524316',
#                'user': 'AnonEMouse',
#                'root': '524315',
#                'reply_to': 524315,
#                'text': "as an editing rule here, it's better to add to people's edits, rephrase, rearrange, etc., rather than remove their changes wholesale. that way there is some back and forth, but in general a kind of incremental progress, and the article improves. just reverting leads to deadlock, and should be avoided. don't insist on perfection all at once. when you find something wrong, fix it, but don't just delete it unless there really is no other choice.",
#                'timestamp': '1.189557480E09'}],
#              '262173': [{'id': '262173',
#                'user': 'Bubba73',
#                'root': '262173',
#                'reply_to': None,
#                'text': 'how can the far notice be removed from chess? i commented it out on the talk page, but it stills says "review" on the article page.',
#                'timestamp': '1.287010080E09'},
#               {'id': '262174',
#                'user': 'Dana boomer',
#                'root': '262173',
#                'reply_to': 262173,
#                'text': "the bot will come through and close the review in a while the schedule tends to be wednesday and saturday nights, but this varies sometimes. i'm going to uncomment the tag on the talk page so that it doesn't screw up the bot.",
#                'timestamp': '1.287010980E09'}],
#              '30': [{'id': '30',
#                'user': 'Jax 0677',
#                'root': '30',
#                'reply_to': None,
#                'text': 'it doesn\'t look like we\'re getting much feedback on splitting the "gun laws in the united states by state" article. i posted notices on wikipediawikiproject lawwikiproject law and wikipediawikiproject united stateswikiproject united states, to no avail.',
#                'timestamp': '1.305965820E09'},
#               {'id': '31',
#                'user': 'Mudwater',
#                'root': '30',
#                'reply_to': 30,
#                'text': 'i agree, not much feedback so far. seven editors have commented, including you and me. and one of the seven also posted about it on wikipediawikiproject firearmswikiproject firearms. font face"cursive"u2014',
#                'timestamp': '1.305966720E09'}],
#              '32': [{'id': '32',
#                'user': 'Moonriddengirl',
#                'root': '32',
#                'reply_to': None,
#                'text': "hi. i appreciate all your work in that article and particularly in your diplomatic resolution to the nationality question. mr. cage would like us to set the record straight, and he's provided us with a published source so that we can. i've added that his nationality is american. it's kind an irritable blog entry, but it contains some other biographical information that you might like to incorporate httpwww.roadcage.com?p60. i just wanted to ask you, if you happen to be continuing to maintain the article as you so ably have in the past, to kind of keep an eye out for the return of canadianism, if it should show up. mr. cage vigorously contests its accuracy.",
#                'timestamp': '1.306266540E09'},
#               {'id': '33',
#                'user': 'Mudwater',
#                'root': '32',
#                'reply_to': 32,
#                'text': 'wow, this is great. and i love mr. cage\'s explanation of his situation, and his views on the wikipedia process from the perspective of being the subject of an article. thanks very much for your help with this! font face"cursive"u2014',
#                'timestamp': '1.306267560E09'}],
#              '262177': [{'id': '262177',
#                'user': 'SandyGeorgia',
#                'root': '262177',
#                'reply_to': None,
#                'text': 'dana, wikipedia talkfeatured article reviewworld science festivalarchive1this was an incorrect bad hack that occurred at far and only came to my attention because an error was made in the "signpost", indicating the fa had been delisted.httpen.wikipedia.orgwindex.php?titlewikipediawikipediasignpost20101018featuresandadminsdiffprevoldid391348494 when i went to check, i found that 2009 content had simply been deleted,httpen.wikipedia.orgwindex.php?titleworldsciencefestival,2008diff386458978oldid386458738 and the main article notable had gone away via a redirect to a world science festival, 20082008 article. i have done a partial cleanup, but more work is likely needed specifically, i don\'t know what else may have been deleted during the far, and what improvements from the 2008 version need to be restored to the main article. i will leave a note for userdank and direct him to this conversation. the main article will need review to restore any changes made since 2008. someone else may want to update the main article to include 2010 and 2011, which are mentioned in the festival website. there are also dead links at the 2008 article that should have been picked up on the far.',
#                'timestamp': '1.287453960E09'},
#               {'id': '262178',
#                'user': 'Dana boomer',
#                'root': '262177',
#                'reply_to': 262177,
#                'text': 'you are correct that the main wsf article should exist and include information from all of the years. however, all of the reviewers including malleus! agreed that the wsf 2008 article met fa standards. most of the dead link tags were invalid i\'ve removed those and fixed the couple of valid ones. easy enough. the 2009 info was the only stuff deleted afaik during the far, but i\'m not sure what you mean by the "improvements from the 2008 version need to be restored to the main article".',
#                'timestamp': '1.287467340E09'},
#               {'id': '262179',
#                'user': 'SandyGeorgia',
#                'root': '262177',
#                'reply_to': 262178,
#                'text': "i dunno i may have confused myself between the two versions, but i think it's all up to snuff now! thanks! i was surprised by that far",
#                'timestamp': '1.287467520E09'}],
#              '34': [{'id': '34',
#                'user': 'Keraunoscopia',
#                'root': '34',
#                'reply_to': None,
#                'text': 'hey, i noticed httpen.wikipedia.orgwindex.php?titlegarciaalbumdiffprevoldid434347681 this yesterday and was wondering if the 24.2ems should be made part of the actual template. there was a discussion on this a short while ago on the template\'s talk page, but i didn\'t think it was possible. didn\'t occur to me to try decimals. u2013nbspfont color"06266f"keru03b1ufontfont color"1240ab"nou03c2cofontfont color"4671ds"piafontfont color"a60000"supu25c1supfontisubfont color"5e1fff"',
#                'timestamp': '1.308218820E09'},
#               {'id': '35',
#                'user': 'Mudwater',
#                'root': '34',
#                'reply_to': 34,
#                'text': 'i missed that discussion, but i definitely think it would be very good if the default width of the template was 24.2, so that it would be i think the same width as the infobox. and as an additional point, i would also favor making "stateplain" the default. font face"cursive"u2014',
#                'timestamp': '1.308219120E09'},
#               {'id': '36',
#                'user': 'Keraunoscopia',
#                'root': '34',
#                'reply_to': 35,
#                'text': 'i\'m not familiar enough with the states thing, but here\'s the discussion templatetalkalbumratingswidth. it\'s not very old at all. i would support the 24.2. u2013nbspfont color"06266f"keru03b1ufontfont color"1240ab"nou03c2cofontfont color"4671ds"piafontfont color"a60000"supu25c1supfontisubfont color"5e1fff"',
#                'timestamp': '1.308219240E09'},
#               {'id': '37',
#                'user': 'Mudwater',
#                'root': '34',
#                'reply_to': 36,
#                'text': 'i was wondering if the widths of the infobox and the album ratings template would vary by browser andor by skin, but i didn\'t try to figure that out. it sounds like they do. but i think that using 24.2em would make them the same width for most readers, so i would still favor that. as for "state", that\'s explained on the templatealbum ratings page. in my opinion "stateplain" would be the best default, because it displays the ratings without the options to hide or show them. in most cases having the option is an unnecessary complication, in my view. font face"cursive"u2014',
#                'timestamp': '1.308219660E09'},
#               {'id': '38',
#                'user': 'Keraunoscopia',
#                'root': '34',
#                'reply_to': 37,
#                'text': 'oh, i remember states now. yeah, not sure why one would collapse the template at all. kind of a silly option. well, when i messed around with ems, they varied between skins i tried vector, and i always use modern, otherwise, and i\'m using safari for a browser, and your 24.2 thing looked fine on safariskinmodern, so i assume you\'ve figured out the secret width needed. not sure how well it would work, but you could always put an infobox and the album ratings template on an otherwiseempty sandbox, then throw that url into httpbrowsershots.org browsershots.org and see if the widths vary from browser to browser. they\'d all be in vector default skin, i think. u2013nbspfont color"06266f"keru03b1ufontfont color"1240ab"nou03c2cofontfont color"4671ds"piafontfont color"a60000"supu25c1supfontisubfont color"5e1fff"',
#                'timestamp': '1.308220200E09'}],
#              '87387': [{'id': '87387',
#                'user': 'Loganberry',
#                'root': '87387',
#                'reply_to': None,
#                'text': 'thanks for your edits to this article. the thing is, though, they didn\'t play the australia national cricket team they played the australians. apologies if you already knew this, but there\'s a rigid distinction in operation here "australia" as such "only" play international cricket all matches against counties, universities and so on are listed as "australians". ditto with other countries, so that for example "worcestershire v pakistanis" doesn\'t mean any old pakistanis, but always the national team playing a noninternational match. for that reason i\'m inclined to change those edits back, but i\'ll leave it a day or two in case you want to come back at me.',
#                'timestamp': '1.238805900E09'},
#               {'id': '87388',
#                'user': 'Loganberry',
#                'root': '87387',
#                'reply_to': 87387,
#                'text': 'to answer the obvious question, where there is no convenient adjectival form, one just adds "xi" to the team name, so that you have "barbados v england xi" or whatever. for historical reasons, until the 1970s, england played as "mcc" in noninternational tour games.',
#                'timestamp': '1.238806140E09'},
#               {'id': '87389',
#                'user': 'Qwfp',
#                'root': '87387',
#                'reply_to': 87388,
#                'text': "thanks for the explanation loganberry. i didn't know about that distinction. i'll change it back.",
#                'timestamp': '1.238806860E09'},
#               {'id': '87390',
#                'user': 'Loganberry',
#                'root': '87387',
#                'reply_to': 87389,
#                'text': 'thanks. as with most things cricket, the logic isn\'t perfect eg theengland matches against the australian forces in 1945 "are" "england", not "england xi" but it\'s usually reliable otherwise.',
#                'timestamp': '1.239397380E09'}],
#              '262180': [{'id': '262180',
#                'user': 'Montanabw',
#                'root': '262180',
#                'reply_to': None,
#                'text': "new photo added by a driveby to marwari horse. nice image, superficial image check suggests licensing is ok, but it's your article, so may want to peek. it was in a bad spot, so i moved it, but not sure i improved matters.",
#                'timestamp': '1.287465720E09'},
#               {'id': '262181',
#                'user': 'Dana boomer',
#                'root': '262180',
#                'reply_to': 262180,
#                'text': "licensing isn't quite right. i've dropped a note on the editor's talk won't remove the image for now, but if it's not cleared up shortly it'll need to go.",
#                'timestamp': '1.287467160E09'},
#               {'id': '262182',
#                'user': 'Dana boomer',
#                'root': '262180',
#                'reply_to': 262181,
#                'text': "allright, licensing fixed. all good now it's a nice image.",
#                'timestamp': '1.287468840E09'}],
#              '262150': [{'id': '262150',
#                'user': 'Venerock',
#                'root': '262150',
#                'reply_to': None,
#                'text': 'mamasita means lady in my native language for not misunderstanding',
#                'timestamp': '1.286164740E09'},
#               {'id': '262151',
#                'user': 'Montanabw',
#                'root': '262150',
#                'reply_to': 262150,
#                'text': "took a quick peek at this. may be a good idea to review list of horse breeds and iberian horse to see if we already have articles under a different spelling for some of the breeds currently redlinked in the template. also not sure if we really need a nav template for this group wpeq is a bit template heavy already. and i'd dread to see separate german, italian, english and god fobid! usa templates, especially if we got fights going over which country claims which breed like we have at lipizzan!. the italian, japanese, and indonesian horse breed articles just have extensive see also sections that crossref the others, or, if the spanish horse list is too huge for a see also, we could expand iberian horse into a list something along the lines of stock horse or gaited horse. just a thought, and should this whole thread go over to wpeq for more folks to discuss?",
#                'timestamp': '1.286195520E09'}],
#              '524327': [{'id': '524328',
#                'user': 'AnonEMouse',
#                'root': '524327',
#                'reply_to': 524327,
#                'text': "don't worry about it. i doubt many email harvesters will go digging in page histories, and don't know of any downstream sites that copy our histories, just our pages. removing it from the page should be sufficient.",
#                'timestamp': '1.189720920E09'}],
#              '262184': [{'id': '262184',
#                'user': 'Bsherr',
#                'root': '262184',
#                'reply_to': None,
#                'text': 'see also my discussion at user talkgood olfactory, leading to this inquiry.',
#                'timestamp': '1.287490620E09'},
#               {'id': '262185',
#                'user': 'Dana boomer',
#                'root': '262184',
#                'reply_to': 262184,
#                'text': "i've responded at good olfactory's page to keep this all in one spot.",
#                'timestamp': '1.287509340E09'}],
#              '524330': [{'id': '524330',
#                'user': 'Albion moonlight',
#                'root': '524330',
#                'reply_to': None,
#                'text': 'my wiki mail option is working but i have to type in the following, httpen.wikipedia.orgwikispecialemailuser plus the username to get it to do so. anyway problem solved and please feel free to not respond to any of my messages today including the 2 i sent by email. and thanks for your help. .',
#                'timestamp': '1.189668060E09'},
#               {'id': '524331',
#                'user': 'AnonEMouse',
#                'root': '524330',
#                'reply_to': 524330,
#                'text': "i received your 2 emails. i'm not sure i understood the second, but if it's taken care of, that's good too.",
#                'timestamp': '1.189720800E09'}],
#              '524332': [{'id': '524332',
#                'user': 'Capricornis',
#                'root': '524332',
#                'reply_to': None,
#                'text': 'what is the policy when someone writes something like httpen.wikipedia.orgwindex.php?titletalkrepublicofmacedoniadiff157152659oldid156689101 this ? does their ip get banned and their comment purged from the talk page?',
#                'timestamp': '1.189663740E09'},
#               {'id': '524333',
#                'user': 'Videmus Omnia',
#                'root': '524332',
#                'reply_to': 524332,
#                'text': 'i left a warning on their talk page. looks like others have already removed the offensive comment.',
#                'timestamp': '1.189668900E09'},
#               {'id': '524334',
#                'user': 'AnonEMouse',
#                'root': '524332',
#                'reply_to': 524333,
#                'text': "they would be wikipediablocking policyblocked, yes, but it looks like they haven't been repeating. ip addresses are usually not wikipediabanning policybanned, because an ip is usually just a number handed out by a service provider, and will be given to a different person eventually certainly when the person signs up with a new service provider, and sometimes even faster than that. our acquaintaince from perth editing on that subject has shown the ability to get a new ip number within minutes of the old one being blocked, sometimes several times a day fortunately, however, this isn't him.",
#                'timestamp': '1.189721400E09'},
#               {'id': '524335',
#                'user': 'AnonEMouse',
#                'root': '524332',
#                'reply_to': 524334,
#                'text': 'i see a similar address made a similar comment. httpen.wikipedia.orgwindex.php?titletalkrepublicofmacedoniadiff157578888oldid157499660 if it becomes a regular thing, tell me, and i will semiprotect the article talk page. that will stop all ip addresses without an account from editing there apparently some do make nonabusive commentshttpen.wikipedia.orgwindex.php?titletalkrepublicofmacedoniadiff156689101oldid156496906 but if we have to, we will.',
#                'timestamp': '1.189721700E09'}],
#              '262189': [{'id': '262189',
#                'user': 'SmokeyJoe',
#                'root': '262189',
#                'reply_to': None,
# ...
#                'timestamp': '1.155444840E09'}],
#              '1594': [{'id': '1594',
#                'user': 'Viriditas',
#                'root': '1594',
#                'reply_to': None,
#                'text': 'the same primary contributors who have worked on both nixon and reagan have whitewashed both subjects, carefully, cleverly, and purposefully couching major critical aspects in ambiguous terms and light prose. this is pure propaganda.',
#                'timestamp': '1.298040960E09'},
#               {'id': '1595',
#                'user': 'William S. Saturn',
#                'root': '1594',
#                'reply_to': 1594,
#                'text': 'my removal of nonsense does not imply that i would like additional nonsense to be added to my talk page. if you have a specific concern, please bring it up on the article talk page.',
#                'timestamp': '1.298041260E09'},
#               {'id': '1596',
#                'user': 'Viriditas',
#                'root': '1594',
#                'reply_to': 1595,
#                'text': "will do. give me a few days as i'm in the middle of something right now. feel free to remove this nonsense from your talk page.",
#                'timestamp': '1.298047980E09'}],
#              '525883': [{'id': '525883',
#                'user': 'Marine 69-71',
#                'root': '525883',
#                'reply_to': None,
#                'text': 'it is done! now all you have to do is replace the old image with this one "imagehagee in marpat with marine.jpg" i hope that this has solved the problem. semper fi',
#                'timestamp': '1.136683500E09'},
#               {'id': '525884',
#                'user': 'Marine 69-71',
#                'root': '525883',
#                'reply_to': 525883,
#                'text': 'i saw the article that\'s up for deletion. i\'m against its deletion and in favor of the article being merged to the "united states marine corps" article. i\'ll keep my eye on it and merge it myself, if it isn\'t deleted.',
#                'timestamp': '1.136804580E09'},
#               {'id': '525885',
#                'user': 'Marine 69-71',
#                'root': '525883',
#                'reply_to': 525884,
#                'text': "i agree with you on the redirect and that's the way i would do it. semper fi",
#                'timestamp': '1.136807460E09'}],
#              '263741': [{'id': '263742',
#                'user': 'The JPS',
#                'root': '263741',
#                'reply_to': 263741,
#                'text': 'the artist does not meet out guidelines concerning notability. once cohen satisfies the criteria at wpmusic then an article can be created.',
#                'timestamp': '1.155777780E09'}],
#              '1599': [{'id': '1599',
#                'user': 'Steve98052',
#                'root': '1599',
#                'reply_to': None,
#                'text': 'also, feel free to revise my comments about your parody of the video on your comments page if you wish. not that it matters, but i stumbled upon the article by way of an editconflict warning on an unrelated usertalkvquakrtalk page i was editing. u2014',
#                'timestamp': '1.299733860E09'},
#               {'id': '1600',
#                'user': 'William S. Saturn',
#                'root': '1599',
#                'reply_to': 1599,
#                'text': 'davison\'s recent appearance on "tosh.o" has increased media attention. the second afd from november two months after the speech pointed to "persistent coverage" as a main deletionredirection argument. since davison is still receiving press six months after his wellpublicized speech, coverage is persistent.',
#                'timestamp': '1.299740820E09'}],
#              '1601': [{'id': '1601',
#                'user': 'Stargat',
#                'root': '1601',
#                'reply_to': None,
#                'text': 'i\'m confused why you believe that i am edit warring usertalkstargateditwarriorthis note on my page. last week we discussed the inclusion of the fact that stock photography was used on the newt gingrich fundraising committee website, which you seem to think is important but i think is trivial. i gave a talknewtgingrichpresidentialcampaign,2012perfectly reasonable explanation for why it should not be included, but you did not respond. specifically, i challenged your claim that it was "widely covered" and demonstrated it was not. several days later, without any response, i changed it back. now, i see that you still have not responded on the talk page, but your edit summary stated that "there is no clear dispute of the material on the talk page". that\'s not true. i don\'t dispute that it\'s factual, but i do dispute that it\'s relevant. based on guidelines, i don\'t think it belongs. and please do not accuse me of edit warring. i aim to be polite and discuss changes based on policy, but for some reason you won\'t talk to me.',
#                'timestamp': '1.300151280E09'},
#               {'id': '1602',
#                'user': 'William S. Saturn',
#                'root': '1601',
#                'reply_to': 1601,
#                'text': 'the only meaningful things on the talk page are the links to several news stories about the stock footage, which you provided from the news search i linked. such a large number of stories describing the website which is the campaign at this point certainly merits inclusion. i see no valid argument on the talk page as to why the the material should be erased. therefore, i conclude that you are edit warring.',
#                'timestamp': '1.300152480E09'},
#               {'id': '1603',
#                'user': 'Stargat',
#                'root': '1601',
#                'reply_to': 1602,
#                'text': 'three blog posts from the same day, then no further coverage or apparent impact is a "large number of stories"? that\'s just silly. surely the standard for "widely covered" must be higher than that. what\'s more, i\'ve pointed out how it appears to be a textbook case of wprecentism. these are valid arguments, are they not?',
#                'timestamp': '1.300154880E09'},
#               {'id': '1604',
#                'user': 'William S. Saturn',
#                'root': '1601',
#                'reply_to': 1603,
#                'text': 'recentism can only apply when something minor is added to something major that has been going on for a long time. the newt gingrich presidential campaign is neither major nor longstanding. i will assume good faith and accept that your removal was based on a misinterpretation of recentism.',
#                'timestamp': '1.300156260E09'},
#               {'id': '1605',
#                'user': 'Stargat',
#                'root': '1601',
#                'reply_to': 1604,
#                'text': 'the nutshell definition says "some wikipedia articles tend to focus on recent events. wikipedia has been praised for the way it deals with current news breaks. nevertheless, it is appropriate to be aware of balance and historical perspective." that seems to support my point that it wasn\'t a significant event and so shouldn\'t be there.',
#                'timestamp': '1.300159320E09'},
#               {'id': '1606',
#                'user': 'William S. Saturn',
#                'root': '1601',
#                'reply_to': 1605,
#                'text': 'again, you are misunderstanding the guideline. it has absolutely nothing to do with your blanking. please reread what i wrote above.',
#                'timestamp': '1.300160280E09'}],
#              '263746': [{'id': '263747',
#                'user': 'The JPS',
#                'root': '263746',
#                'reply_to': 263746,
#                'text': "no, i didn't fail to see the summary. on this occasion, redvers is incorrect. the copyright holder is the photographer. on the reverse of most school, and other professional portraits, the imperative 'do not copy' can be found. the parent aka customer buys a print, not the copyright. i spent a few years working for a photographic retailer, and this law was made clear to us. indeed, disciplinary action could have been taken had we allowed the reproduction of such material. most customers were unhappy when they discovered that they didn't own the copyright.",
#                'timestamp': '1.155932160E09'}],
#              '525891': [{'id': '525891',
#                'user': 'ERcheck',
#                'root': '525891',
#                'reply_to': None,
#                'text': "in addition, i've been logged out midedit. is wikipedia currently experiencing a problem? or is it my session? mdash",
#                'timestamp': '1.139563020E09'},
#               {'id': '525892',
#                'user': 'Commander Keane',
#                'root': '525891',
#                'reply_to': 525891,
#                'text': "i don't think wikipedia is experiencing a problem. i have experiecned these problems before, try clearing your browser's cache to fix the problem mozillasafarikonqueror hold down shift while clicking reload or press ctrlshiftr, ie press ctrlf5, opera press f5.",
#                'timestamp': '1.139563560E09'}],
#              '263749': [{'id': '263749',
#                'user': 'Jfp-24',
#                'root': '263749',
#                'reply_to': None,
#                'text': 'hi! thanks for your warm welcome. i have a one question to ask you, i wanted to know how you can become an administrator like you on wikipedia, can anyone eventually become an administrator, iu2019m quite knew to this site and would love to know how.',
#                'timestamp': '1.156011000E09'},
#               {'id': '263750',
#                'user': 'The JPS',
#                'root': '263749',
#                'reply_to': 263749,
#                'text': "hiya. admins are selected by community consensus, at wprfa. you'll see from the current votes at that page the standards required. you are expected to have at last a few thousand edits, knowledge of policy, evidence of mature conduct, little evidence of immatureincivil conduct, etc, and participation in some community activities fighting vandalism, copyright problems, etc. as a new user, it's waaay off for you, but that's what's roughly expected before you're nominated. the tone of your comment i.e. the final phrase at talkthe texas chain saw massacre is one such example that might be used against you, because it is rather confrontational.",
#                'timestamp': '1.156012740E09'},
#               {'id': '263751',
#                'user': 'Merbabu',
#                'root': '263749',
#                'reply_to': 263750,
#                'text': "hi jps, just to fill you in, this is the latest sock by infamous and indefinitely blocked userjackp. mostly famous, but by no means limited to, his disruptive and impenatrably clueless edits on the sydney page. check out the discussion tab most of it is trying to reason with jackp. other socks include userjfp24 and usermovielover93 and userjfpearce. we've spent a lot of time coaching jack and providing him with the benefit of the doubt. once bloked he reappeared under other names or anonymous with behaviour identical to that he had promised he wouldn't repeat while pleading to be unblocked.",
#                'timestamp': '1.156022760E09'}],
#              '263752': [{'id': '263752',
#                'user': 'Rebecca',
#                'root': '263752',
#                'reply_to': None,
#                'text': "could you please be a bit more careful about who you choose to welcome? posting a message on jack's talk page urging him to stick around is not helpful when he's a community banned user editing under his umpteenth sockpuppet.",
#                'timestamp': '1.156071900E09'},
#               {'id': '263753',
#                'user': 'Merbabu',
#                'root': '263752',
#                'reply_to': 263752,
#                'text': 'lol chances are that jps did not know about jackp let alone that jfp24 is another sock for him. but rebecca, you have done some mighty fine work keeping a check on him. thanks',
#                'timestamp': '1.156073580E09'},
#               {'id': '263754',
#                'user': 'The JPS',
#                'root': '263752',
#                'reply_to': 263753,
#                'text': 'yes, thanks, merbabu, for both the heads up and also the defence from that rather lacklustre admonishment. when i think about it, i had a brief run in with the original user which might explain why we came here. but, that was the other side of the summer, and my little brain can only store so many things.',
#                'timestamp': '1.156097880E09'},
#               {'id': '263755',
#                'user': 'Merbabu',
#                'root': '263752',
#                'reply_to': 263754,
#                'text': 'lol he might be back. user userkillbill93 looks suspiciously similar. note the 93 and article choice.',
#                'timestamp': '1.156100100E09'},
#               {'id': '263756',
#                'user': 'The JPS',
#                'root': '263752',
#                'reply_to': 263755,
#                'text': 'yeah, chances are it is. how long do you reckon it will be before he edits a sydney related article?',
#                'timestamp': '1.156100580E09'},
#               {'id': '263757',
#                'user': 'Merbabu',
#                'root': '263752',
#                'reply_to': 263756,
#                'text': "how long before he edits sydney?? less than 24 hours httpen.wikipedia.orgwindex.php?titlesydneyactionhistory. it's actually quite entertaining. on my user page yesterday he claimed he wasn't jackp, yet in sydney he goes and makes the same edits that have been made dozens of times under jackp then removed by other editors.",
#                'timestamp': '1.156188600E09'},
#               {'id': '263758',
#                'user': 'JPD',
#                'root': '263752',
#                'reply_to': 263757,
#                'text': "oh yes, it's all quite fun. but yes, the jps has run into jack before somehow jack thought it was me! httpen.wikipedia.orgwindex.php?titletalk3athetexaschainsawmassacrediff62324367oldid62004890",
#                'timestamp': '1.156270620E09'}],
#              '1611': [{'id': '1611',
#                'user': 'The ed17',
#                'root': '1611',
#                'reply_to': None,
#                'text': 'sorry this newsletter is going out a little earlier than expected there is a busy weekend coming up! a running total of claims can be seen wikipediawikicuphistory2011running totalshere. if you are concerned that your nomination will not receive the necessary reviews, and you hope to get it promoted before the end of the round, please list it on wikipediawikicupreviews. however, please remember to continue to offer reviews at gac, fac and all the other pages that require them to prevent any backlogs which could otherwise be caused by the cup. as ever, questions are welcome on wikipedia talkwikicup and the judges are reachable on their talk pages, or by email. good luck! smallif you wish to start receiving or stop receiving this newsletter, please feel free to add or remove yourself from wikipediawikicupnewslettersend.small userj milburnj milburn and',
#                'timestamp': '1.304130840E09'},
#               {'id': '1612',
#                'user': 'William S. Saturn',
#                'root': '1611',
#                'reply_to': 1611,
#                'text': 'my apologies for that.',
#                'timestamp': '1.304812980E09'}],
#              '541254': [{'id': '541254',
#                'user': 'thumperward',
#                'root': '541254',
#                'reply_to': None,
#                'text': 'can i ask why this page was deleted, considering that it was already a redirect to the current talk for the relative article?',
#                'timestamp': '1.234512120E09'},
#               {'id': '541255',
#                'user': 'thumperward',
#                'root': '541254',
#                'reply_to': 541254,
#                'text': "i've now restored this as a redirect to talktruth in numbers.",
#                'timestamp': '1.234813440E09'}],
#              ...})

# %%
with open('/home/maryam/llamaPersonaResp/Data/common/wikipedia_conv.pkl', 'wb') as f:
    pickle.dump(wikipedia_dataset, f)
