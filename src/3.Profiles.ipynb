# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import spacy
import re
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import torch
import plotly.express as px
import numpy as np


from transformers import pipeline
from google.colab import drive
from collections import Counter, defaultdict
from urllib.parse import unquote
from collections import Counter
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
if torch.cuda.is_available():
    spacy.require_gpu()
    print("Using GPU for spaCy")
else:
    print("GPU not available, using CPU for spaCy")

nlp = spacy.load("en_core_web_sm")
# Out:
# Using GPU for spaCy

# %%
def read_jsonl_file(file_path):
  """Reads a JSONL file and returns a list of dictionaries."""
  data = []
  with open(file_path, 'r') as f:
    for line in f:
      try:
        data.append(json.loads(line))
      except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
  return data

# =============================
# 1️⃣ Load Dataset
# =============================
file_path = '/content/drive/MyDrive/Perspective Paper/Original_Data/wikipedia.jsonl'
data = read_jsonl_file(file_path)

# %%
data
# Out:
# [{'id': '524288',
#   'root': '524288',
#   'text': 'You should look at all of the point on the template not just the last one, the template also says the image belonging to the republic of macedonia is in the public domain if it being used for \\"information purposes\\". ',
#   'user': 'Frightner',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189190940E09'},
#  {'id': '524289',
#   'root': '524288',
#   'text': 'Yes I agree. The law permits usage of documents, photographs and other materials for educational and informational purposes. There was a normative act issued by the government of the Republic of Macedonia that even allowed citizens to make photocopies or photograph rare archive materials. ',
#   'user': 'Revizionist',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189204860E09'},
#  {'id': '1',
#   'root': '1',
#   'text': "Yes, that's good. Revathy's page looked very reliable, that's why we used that as a source. ",
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.310744280E09'},
#  {'id': '2',
#   'root': '1',
#   'text': "Nagma'a site, at least that filmography page, looks like taken from Wikipedia itself. I didn't remove it from time being, but I don't think it's true. ",
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': '1',
#   'timestamp': '1.310746500E09'},
#  {'id': '3',
#   'root': '1',
#   'text': 'I don\'t think there are many such official reliable sites left yet. The problem is most \\"official sites\\" are not really official, and often based on Wikipedia itself, and you don\'t know what to believe and what not. We used Madras Talkies\' page, which is dead now. [http:\\/\\/kavithalayaa.com\\/ Kavithalayaa]\'s site is there, also AVM Production\'s site might be useful perhaps, but I can\'t enter that. Generally official sites of production houses seem to be very reliable ones. ',
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': '2',
#   'timestamp': '1.310751180E09'},
#  {'id': '4',
#   'root': '1',
#   'text': 'Most of the so called \\"official sites\\" are maintained by fans or cinema based web companies. Not sure how reliable are they. <span style=\\"color:green;font-size:small;;font-family:Segoe Print;\\">-<i>B<\\/i>iLLa-<\\/span>',
#   'user': 'Michael-Billa',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.311762120E09'},
#  {'id': '524290',
#   'root': '524290',
#   'text': "You closed [[Wikipedia:Articles for deletion\\/J. Kevin Tumlinson]] after one day without mentioning anything about speedy deletion or giving reasons. Not that I'm objecting ''too'' much, but did you realize it was only one day? --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.189197960E09'},
#  {'id': '524291',
#   'root': '524290',
#   'text': 'Well, notability cannot be acquired in 4 days. That was my reasoning behind the early closure. However, if you still believe the closure was out of process, you can still refer to the deletion review. - ',
#   'user': 'FayssalF',
#   'meta': {'is-admin': True},
#   'reply-to': '524290',
#   'timestamp': '1.189200660E09'},
#  {'id': '524292',
#   'root': '524290',
#   'text': "No, no, I was the nominator! Just wanted to make sure it wasn't done in error. --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524291',
#   'timestamp': '1.189200720E09'},
#  {'id': '524293',
#   'root': '524290',
#   'text': "I was a bit surprised because i know you were the nominator ;) No, it wasn't done in error. - ",
#   'user': 'FayssalF',
#   'meta': {'is-admin': True},
#   'reply-to': '524292',
#   'timestamp': '1.189200960E09'},
#  {'id': '262147',
#   'root': '262147',
#   'text': 'Hello Dana, thanks for contribute in this [[Template:Spanish horses|template]], but i need tell you that is about horse, and balearic article is about a language of a people, if you think that im not right please tell me for not fixing the edit at last. Enjoy your day ;)--',
#   'user': 'Venerock',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286157240E09'},
#  {'id': '262148',
#   'root': '262147',
#   'text': 'My apologies, I forgot to include the disambiguator. Please check now - it should be right. Thanks for letting me know. ',
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262147',
#   'timestamp': '1.286157480E09'},
#  {'id': '6',
#   'root': '6',
#   'text': 'Hey, who said so? Frankly, I have absolutely no idea, sorry! ',
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312057320E09'},
#  {'id': '7',
#   'root': '6',
#   'text': "Maybe, we should check out who added that, it could be some fanatic IP user. There will have been nominees, since there were nominees in earlier ceremonies and in the Telugu section, too, but how to find out? If there was a video coverage of that ceremony available we would know. Otherwise, I would remove it as it's unsourced. ",
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': '6',
#   'timestamp': '1.312059420E09'},
#  {'id': '262145',
#   'root': '262145',
#   'text': "H  Dana, totally  amiss of me - belated congrats for  your promotion! I  voted for  you  without  any  hesitation. I'm  pleased to  hear from  Pike  that  you  might  be reviewing  the Finnhorse, I  can't  think  of anyone better for  the job. --",
#   'user': 'Kudpung',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286127120E09'},
#  {'id': '262146',
#   'root': '262145',
#   'text': "Thank you very much! I am going to try to take a look over Finnhorse - actually, I think I'll go start looking at it right now while I have a few minutes. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262145',
#   'timestamp': '1.286133300E09'},
#  {'id': '262152',
#   'root': '262152',
#   'text': "Hi. Just writing that you closed out the [[WP:CFD]] as a '''merge and delete''', but category appears open still at this moment. Yours, ",
#   'user': 'Rms125a@hotmail.com',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286163540E09'},
#  {'id': '262153',
#   'root': '262152',
#   'text': "Yes, I know. It's on the list at [[Wikipedia:Categories_for_discussion\\/Working]], and the bot should get to it shortly. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262152',
#   'timestamp': '1.286163600E09'},
#  {'id': '9',
#   'root': '9',
#   'text': "Well, no website is 100% perfect, you got to understand that. Are you saying TOI is an unreliable source? Mention of Shankar as Shankar Mahadevan might have been a mistake, I'll contact them and ask them to correct it. What else do you want me to do? ",
#   'user': 'Secret of success',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312136520E09'},
#  {'id': '10',
#   'root': '9',
#   'text': 'I don\'t care. This is not the place to elevate your favourite Star\'s films. I\'m not questioning about the credibility of TOI. There is a consensus not to add budget\\/gross figures for any Indian movie, if it\'s speculated at a higher rate. I think you might be aware of the \\"Enthiran issue\\". Even official sources were not considered. --',
#   'user': 'Vensatry',
#   'meta': {'is-admin': False},
#   'reply-to': '9',
#   'timestamp': '1.312136820E09'},
#  {'id': '262154',
#   'root': '262154',
#   'text': 'Could you restore Category:Second wave synthpop acts (or at least the bands formerly listed therein) to my userspace? I was checking out some of the bands and bookmarked it to check out some others later, but found that it was deleted. Thanks! ',
#   'user': 'JCDenton2052',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286272380E09'},
#  {'id': '262155',
#   'root': '262154',
#   'text': "There would be nothing to restore, and categories can't be moved even if there were.  Category pages contain nothing, articles are added to it by an addition of code at the bottom of each article.  When a category is deleted, CFD has an Adminbot that goes through each article and removes the category.  The best you could do would be to find the edits in [[User:Cydebot]]'s contribution record, and then you'd be able to see what was in the category pre-deletion. ",
#   'user': 'Courcelles',
#   'meta': {'is-admin': True},
#   'reply-to': '262154',
#   'timestamp': '1.286272740E09'},
#  {'id': '262156',
#   'root': '262154',
#   'text': 'Found them. Thanks for your help! ',
#   'user': 'JCDenton2052',
#   'meta': {'is-admin': False},
#   'reply-to': '262155',
#   'timestamp': '1.286274420E09'},
#  {'id': '11',
#   'root': '11',
#   'text': 'I agree i copied, even he mi8 know it very well. I dont know 2 design and all but some thing inside, i got my own work also. If u dont mind can i copy abit of urs. Even ur page looks good!! ',
#   'user': 'Karthikndr',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312143840E09'},
#  {'id': '12',
#   'root': '11',
#   'text': 'Ok! Ty for the info and links. Will create new design asap. ',
#   'user': 'Karthikndr',
#   'meta': {'is-admin': False},
#   'reply-to': '11',
#   'timestamp': '1.312146060E09'},
#  {'id': '13',
#   'root': '13',
#   'text': "I don't understand what you are saying. Could you please be more precise? ",
#   'user': 'Secret of success',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312244220E09'},
#  {'id': '14',
#   'root': '13',
#   'text': 'Well, I have not made much significant contribution but just a couple of sections in one or two articles. If that is not enough, I have removed the template if that bothers you. ',
#   'user': 'Secret of success',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312410120E09'},
#  {'id': '524302',
#   'root': '524302',
#   'text': "If you look at the contrib history of Mr. Neutron you will find plenty of edits like this, and all of his 'contribs' are EXCLUSIVELY on articles dealing with Macedonia, and mostly pushing pro-bulgarian POV in subtle and not-so-subtle ways. I just thought you might want to know for future reference :) ",
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189478460E09'},
#  {'id': '524303',
#   'root': '524302',
#   'text': 'Thanks. I understand that there is a lot of controversy here, even between respected scholars. We need to document that disagreement in our articles, hopefully without attacking editors. --',
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524302',
#   'timestamp': '1.189479180E09'},
#  {'id': '524304',
#   'root': '524302',
#   'text': 'Capricornis, stop insinuating. And please refrain from various [[Ad hominem]] arguments, as they are falacies. Comment on contributions please. ',
#   'user': 'Mr. Neutron',
#   'meta': {'is-admin': False},
#   'reply-to': '524303',
#   'timestamp': '1.189480920E09'},
#  {'id': '524305',
#   'root': '524302',
#   'text': "You must have misunderstood something? I was commenting on your contributions, not on you as a person (please read the Ad Hominem article before you quote it). Also 'insinuations' are statements that cannot be proven, whereas my statements above can be proven by anyone who will take the time to look through your contrib history. have a great day ",
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': '524304',
#   'timestamp': '1.189489680E09'},
#  {'id': '524306',
#   'root': '524302',
#   'text': 'You were already warned on your talkpage not to commit any more personal attacks, so dont do it. You have been consistently insinuating against other Wikipedia contributors and this is not at all nice going. ',
#   'user': 'Mr. Neutron',
#   'meta': {'is-admin': False},
#   'reply-to': '524305',
#   'timestamp': '1.189490280E09'},
#  {'id': '524307',
#   'root': '524302',
#   'text': "You are talking about the distant past. I retracted the unfortunate comments and they were accepted, including by you, at the end of this section http:\\/\\/en.wikipedia.org\\/wiki\\/Talk:Ilinden-Preobrazhenie_Uprising#Search_engines_tests . I do not intend to personally attack you at all, but I will attack your contributions and 'content' every time you try to 'slightly' swing the pendulum to your side - you will be reported. ",
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': '524306',
#   'timestamp': '1.189491480E09'},
#  {'id': '524308',
#   'root': '524302',
#   'text': 'Oh please! \\"Distant past\\" was only [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=User_talk:Capricornis&diff=156856515&oldid=156665242 yesterday]. Report whatever you want, with such consistent agenda against other contributors you only bring suspicion on yourself. ',
#   'user': 'Mr. Neutron',
#   'meta': {'is-admin': False},
#   'reply-to': '524307',
#   'timestamp': '1.189493820E09'},
#  {'id': '524309',
#   'root': '524302',
#   'text': "That was a misinformed suggestion by another ordinary user, just like you and me. I still maintain that there were no personal attacks in my words, but only good humored jibs. The statement about the exclusivity of your activity on Macedonia related articles stands and is easily verifiable. I suggest if you have something more to say, to do it on my talk page as there is no point continuing this tirade on AnonEMouse's page who seems to have quite enough work without it. -cheers ",
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': '524308',
#   'timestamp': '1.189501860E09'},
#  {'id': '524310',
#   'root': '524302',
#   'text': 'And more personal attacks calling people misinformed... ',
#   'user': 'Mr. Neutron',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189502040E09'},
#  {'id': '524311',
#   'root': '524302',
#   'text': 'Misinformed\\/misguided are not insults in the English language. Maybe brush up on your English or use [[Websters]]? :) ',
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189502280E09'},
#  {'id': '16',
#   'root': '16',
#   'text': 'Hi. I think your statement of the ip being the sockpuppet of sreekar akkineni is true. Earlier, a user named Niranjaniyengar(who was a sock of sreekar akkineni) wrote on my talk page in a similar manner. If you can trace the ip used by them, it would be possible to block him. I also have a doubt if Mr. Kollyfan, famed for his discussion of the Enthiran gross has something to do with this. It would throw some light on this manner. Thanks! ',
#   'user': 'Secret of success',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312588320E09'},
#  {'id': '17',
#   'root': '16',
#   'text': 'Glad that you got my point. Actually Sreekarakkineni, Niranjaniyengar and this IP seems like the same person. Will file a case soon.--',
#   'user': 'Vensatry',
#   'meta': {'is-admin': False},
#   'reply-to': '16',
#   'timestamp': '1.312588860E09'},
#  {'id': '18',
#   'root': '16',
#   'text': 'So put in a sock puppet investigation to find out. ',
#   'user': 'Bollyjeff',
#   'meta': {'is-admin': False},
#   'reply-to': '17',
#   'timestamp': '1.312590060E09'},
#  {'id': '262162',
#   'root': '262162',
#   'text': "Hi there Dana, when relisting CFD discussions, please be aware that we don't remove the discussions from one log date to the other; instead, we close the discussion at add the {{tl|Relisted}} template instead. As such, [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Wikipedia:Categories_for_discussion\\/Log\\/2010_September_26&diff=389785157&oldid=389782135 this] edit should be reverted and the discussions should be closed. This is explained at [[WP:RELIST]], last line. Thanks. \\u2014 ",
#   'user': 'Explicit',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.286691180E09'},
#  {'id': '262163',
#   'root': '262162',
#   'text': "Whoops, my apologies. I apparently read the bolded part and completely missed the part in parentheses. Thanks for letting me know - please let me know if there is anything else I'm doing wrong: I'm new at it, but the backlog needs work so I wanted to chip in. I'll go fix that now. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262162',
#   'timestamp': '1.286701080E09'},
#  {'id': '262164',
#   'root': '262162',
#   'text': "And just one other note, Dana\\u2014after you relist a CFD, don't forget to change the date on the cfd tag on the category itself so that it goes to the new discussion, like [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Category%3AChristmas_number-one_singles_in_the_United_Kingdom&action=historysubmit&diff=389999136&oldid=387262711 this]. Thanks for you service in working on closing CFDs; we are always looking for more help and attention with these. ",
#   'user': 'Good Olfactory',
#   'meta': {'is-admin': True},
#   'reply-to': '262162',
#   'timestamp': '1.286793420E09'},
#  {'id': '20',
#   'root': '20',
#   'text': 'Hey! Hi -There are a bunch of things I want to learn here in [[Wikipedia]]. Only you, and maybe 3 others could teach me (terribly embarrassing to admit I\'m so ignorant with computers, etc.) and so I\'ve decided to send a couple notes and the others for help. Is it OK to email you, to save space on our talk pages? Mine is activated too. This drives me crazy! One burning question has to do with many [[Grateful Dead]]-related articles, so I am here. Nearly all the biography articles about [[musician]]s eventually have a Discography section, followed by References, and then External links. Some of them have a \\"see also\\" section which is essentially [[trivia]], and it is simple enough to see if it\'s warranted or not. However, what I don\'t understand is a \\"Notes\\" section. What purpose, exactly does it serve, and how do you put info into the text properly to acheive whatever result the editor is trying to accomplish? It\'s really perplexing. --',
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.300422840E09'},
#  {'id': '21',
#   'root': '20',
#   'text': 'Let me know how that goes.  Being able to format footnotes is a big plus, and like I said it\'s pretty easy once you\'ve done it a few times.  I suggest that you try doing a few on your user page, or on a sub-page of your user page, for practice.  If you want more help just let me know. <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '20',
#   'timestamp': '1.300432800E09'},
#  {'id': '262165',
#   'root': '262165',
#   'text': "I think you should nag MF. He never responds to my nags :P '''",
#   'user': 'YellowMonkey',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.286798880E09'},
#  {'id': '262166',
#   'root': '262165',
#   'text': "I dropped notes to half a dozen editors on various articles already in the FARC stage. We'll see if it gets us anywhere. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262165',
#   'timestamp': '1.286830500E09'},
#  {'id': '262167',
#   'root': '262165',
#   'text': "Outofsinc on British Empire is a sock\\/meat, quite obviously '''",
#   'user': 'YellowMonkey',
#   'meta': {'is-admin': True},
#   'reply-to': '262166',
#   'timestamp': '1.286867700E09'},
#  {'id': '22',
#   'root': '22',
#   'text': 'My apologies when I come trampling through your pet projects-- further from my mind to annoy you, seriously.  However, I keep seeing (esp. in [[jazz]] related articles) people interchanging sections listed as \\"References\\", \\"Notes\\", \\"Footnotes\\" \\"External links\\", and I\'ve even seen (whilst editing) a \\"Reflist 2\\". Frankly, I\'m baffled. I\'ve pretty much stuck to the editing of [[musician]]s and generally, the articles are [[biography|biographical]] and I stick to the typical lead per [[WP:MOS]] (which I admit I never really read too deeply). Usually, at the end of an  article, there\'s the [[discography]] and the <nowiki>references section, followed by External links<\\/nowiki> and often the latter is jam-packed with link farms that are longer than the article themselves. Can you explain to me how this works, with the Notes and all? OH, and feel free to revert my edits when they are done improperly. Sorry about messing up articles that I only want to help! --',
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.303346700E09'},
#  {'id': '23',
#   'root': '22',
#   'text': 'Thanks for the note.  Yes, I think a lot of editors are a bit confused about Notes, References, and External links sections.  Take a look at what I wrote at [[User talk:Mudwater#Notes and other things]], and at [[Talk:Skip Battin#Place references here]], for some helpful info.  On some articles, most or all of the External links section should really be in the References section.  But it\'s important not to remove reliable references from articles.  Feel free to reply here if you want to talk about this some more.  <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '22',
#   'timestamp': '1.303611720E09'},
#  {'id': '24',
#   'root': '22',
#   'text': "OK, I'll have a look at it. Partly, one reason why I'm not a first class editor has some to do with [[ADD]] (or laziness, take your pick) which explains my difficulty with [[punctuation]] as well.. anyway, like I said, never feel bad about reverting my work, too. --",
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': '23',
#   'timestamp': '1.303737480E09'},
#  {'id': '262168',
#   'root': '262168',
#   'text': "Can you please see [[Wikipedia talk:Featured article review\\/Simon Byrne\\/archive1#Breaking_up_other_users'_posts]], and help out with regard to this disruption? Thank you for your time, -- '''",
#   'user': 'Cirt',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.286894160E09'},
#  {'id': '262169',
#   'root': '262168',
#   'text': "Responded to you, at [[Wikipedia talk:Featured article review\\/Simon Byrne\\/archive1]]. -- '''",
#   'user': 'Cirt',
#   'meta': {'is-admin': True},
#   'reply-to': '262168',
#   'timestamp': '1.286910720E09'},
#  {'id': '262170',
#   'root': '262168',
#   'text': "Seems fixed now. -- '''",
#   'user': 'Cirt',
#   'meta': {'is-admin': True},
#   'reply-to': '262169',
#   'timestamp': '1.286911800E09'},
#  {'id': '524313',
#   'root': '524313',
#   'text': 'Who wrote the Joe Schmidlap article?  I had a friend who referenced that name regularly, and was surprised to see it in print.  Thanks for any info you can provide.  ',
#   'user': 'Mandsford',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189486980E09'},
#  {'id': '524314',
#   'root': '524313',
#   'text': "[[User:ManualRivera791]] was the proud author, but it's a common enough insert-name-here name, just [http:\\/\\/www.google.com\\/search?q=Joe+Schmidlap ask Google]. Joe Schmoe is another; John Q. Public; John Doe in legal cases; Joe Bloggs on standardized tests; Bubba... --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524313',
#   'timestamp': '1.189539780E09'},
#  {'id': '26',
#   'root': '26',
#   'text': 'If you have uploaded other non-free media, consider checking that you have specified how these images fully satisfy our non-free content criteria. You can find a list of description pages you have edited by clicking on <span class=\\"plainlinks\\">[{{fullurl:Special:Contributions|target=Mudwater&namespace=6}} this link]<\\/span>. Note that even if you follow steps 1 and 2 above, non-free media which could be replaced by freely licensed alternatives will be deleted 2 days after this notification (7 days if uploaded before 13 July 2006), per our [[Wikipedia:Non-free content criteria|non-free content policy]].  If you have any questions please ask them at the [[Wikipedia:Media copyright questions|Media copyright questions page]]. Thank you. <!-- Template:di-replaceable fair use-notice --> \\u02c9\\u02c9<sup>',
#   'user': 'Anetode',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.303643760E09'},
#  {'id': '27',
#   'root': '26',
#   'text': "Second, last but not least, There's an '''Rfa''' for [[User:Catfish Jim and the soapdish]], one of the handful of editors who, like you, have consistently been a help and inspiration. I hope you'll take a look: [[Wikipedia:Requests for adminship\\/Catfish Jim and the soapdish]] Please, vote with your heart. Thanks as always. --",
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': '26',
#   'timestamp': '1.304301000E09'},
#  {'id': '28',
#   'root': '26',
#   'text': 'As far as the [[Scott Gorham]] article, that\'s just a classic case of an article that doesn\'t have enough references.  But it looks like someone has added more references since you posted about it here on my talk page.  I might add a few more myself if I get around to it.  In general, I\'d say don\'t get too hung up about the technical details of naming the sections, or the best way to format references.  The most important things are to expand and improve the text of existing articles, and to add reliable references that you find, either on the internet or offline.  I happen to be interested in a lot of the technical details myself, as I\'ve explained a bit here on my talk page, but if you find it confusing, don\'t worry about it.  The content is the most important thing, someone can always come along later and fix the formatting.  \\"P.S.\\" Looks like your buddy made admin, congratulations to him (or her). <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '27',
#   'timestamp': '1.304837580E09'},
#  {'id': '29',
#   'root': '26',
#   'text': "Thanks for the response. OK, then. The editor who just brought [[Thin Lizzy]] to GA status becomes more motivated with the Thin Lizzy related articles (like [[Scott Gorham]]) when I bring in new photos that are good. If there isn't enough text to place the article, it doesn't work, and he's good that way.. like the photo for [[Bo Diddley]] and [[Eric Bell]].. so that must be him. Oh, and as for [[User:Catfish Jim and the soapdish]]'s Rfa, it is good! I was really surprised to hear he jumped into the ring of fire without my knowing he planned to do it.. he said he didn't want to look like he might be fishing for votes, which just goes to show what a decent guy he is.. not to mention all those positive votes, and I think, 2 votes not for his Adminship, which is a really decent outcome! I thought you knew him already. You may benefit from doing so. He's been so helpful to me over the last year or so, and is a good editor as well as good at sniffing out vandalism, which is why he finally asked for the mop-- more tools in which to deal with those problems. I'm glad for him! I'll only vote in an Rfa if I ''really'' know the individual, so it's just been three times altogether. --",
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': '28',
#   'timestamp': '1.305304320E09'},
#  {'id': '524315',
#   'root': '524315',
#   'text': "AnonEMouse, when you get a chance could you take a look at the material Jamesd1 has added to the article? My view is that much of it is nothing but original research....for instance, the section comparing Bailey's writing to Theosophical Society literature which is based on nothing but Bailey quotes and links that do not even mention Bailey, all held together by original research of Jamesd1. If you think I am wrong, I will not bother the others editors on this point. (thanks for making the spelling correction) ",
#   'user': 'Kwork',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189552920E09'},
#  {'id': '524316',
#   'root': '524315',
#   'text': "As an editing rule here, it's better to add to people's edits, rephrase, rearrange, etc., rather than remove their changes wholesale. That way there is some back and forth, but in general a kind of incremental progress, and the article improves. Just reverting leads to deadlock, and should be avoided. Don't insist on perfection all at once. When you find something wrong, fix it, but don't just delete it unless there really is no other choice. --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524315',
#   'timestamp': '1.189557480E09'},
#  {'id': '262173',
#   'root': '262173',
#   'text': 'How can the FAR notice be removed from [[chess]]?  I commented it out on the talk page, but it stills says \\"review\\" on the article page.  ',
#   'user': 'Bubba73',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287010080E09'},
#  {'id': '262174',
#   'root': '262173',
#   'text': "The bot will come through and close the review in a while (the schedule tends to be Wednesday and Saturday nights, but this varies sometimes). I'm going to uncomment the tag on the talk page so that it doesn't screw up the bot. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262173',
#   'timestamp': '1.287010980E09'},
#  {'id': '30',
#   'root': '30',
#   'text': 'It doesn\'t look like we\'re getting much feedback on splitting the \\"Gun laws in the United States (by state)\\" article.  I posted notices on [[Wikipedia:WikiProject Law|WikiProject Law]] and [[Wikipedia:WikiProject United States|WikiProject United States]], to no avail.--',
#   'user': 'Jax 0677',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.305965820E09'},
#  {'id': '31',
#   'root': '30',
#   'text': 'I agree, not much feedback so far.  Seven editors have commented, including you and me.  And one of the seven also posted about it on [[Wikipedia:WikiProject Firearms|WikiProject Firearms]]. <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '30',
#   'timestamp': '1.305966720E09'},
#  {'id': '32',
#   'root': '32',
#   'text': "Hi. :) I appreciate all your work in that article and particularly in your diplomatic resolution to the nationality question. Mr. Cage would like us to set the record straight, and he's provided us with a published source so that we can. I've added that his nationality is American. (It's kind an irritable blog entry, but it contains some other biographical information that you might like to incorporate: [http:\\/\\/www.roadcage.com\\/?p=60].) I just wanted to ask you, if you happen to be continuing to maintain the article as you so ably have in the past, to kind of keep an eye out for the return of Canadianism, if it should show up. Mr. Cage vigorously contests its accuracy. --",
#   'user': 'Moonriddengirl',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.306266540E09'},
#  {'id': '33',
#   'root': '32',
#   'text': 'Wow, this is great.  And I love Mr. Cage\'s explanation of his situation, and his views on the Wikipedia process from the perspective of being the subject of an article.  Thanks very much for your help with this!  <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '32',
#   'timestamp': '1.306267560E09'},
#  {'id': '262177',
#   'root': '262177',
#   'text': "Dana, [[Wikipedia talk:Featured article review\\/World Science Festival\\/archive1|this was an incorrect (bad) hack]] that occurred at FAR and only came to my attention because an error was made in the ''Signpost'', indicating the FA had been delisted.[http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Wikipedia:Wikipedia_Signpost\\/2010-10-18\\/Features_and_admins&diff=prev&oldid=391348494]  When I went to check, I found that 2009 content had simply been deleted,[http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=World_Science_Festival,_2008&diff=386458978&oldid=386458738] and the main article (notable) had gone away via a redirect to a [[World Science Festival, 2008|2008 article]].  I have done a partial cleanup, but more work is likely needed-- specifically, I don't know what else may have been deleted during the FAR, and what improvements from the 2008 version need to be restored to the main article.  I will leave a note for {{user|Dank}} and direct him to this conversation. The main article will need review to restore any changes made since 2008.  Someone else may want to update the main article to include 2010 and 2011, which are mentioned in the Festival website.  There are also dead links at the 2008 article that should have been picked up on the FAR.  ",
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287453960E09'},
#  {'id': '262178',
#   'root': '262177',
#   'text': 'You are correct that the main WSF article should exist and include information from all of the years. However, all of the reviewers (including Malleus!) agreed that the WSF 2008 article met FA standards. Most of the dead link tags were invalid - I\'ve removed those and fixed the couple of valid ones. Easy enough. The 2009 info was the only stuff deleted (AFAIK) during the FAR, but I\'m not sure what you mean by the \\"improvements from the 2008 version need to be restored to the main article\\". ',
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262177',
#   'timestamp': '1.287467340E09'},
#  {'id': '262179',
#   'root': '262177',
#   'text': "I dunno-- I may have confused myself between the two versions, but I think it's all up to snuff now!  Thanks!  I was surprised by that FAR :)  ",
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': '262178',
#   'timestamp': '1.287467520E09'},
#  {'id': '34',
#   'root': '34',
#   'text': 'Hey, I noticed [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Garcia_(album)&diff=prev&oldid=434347681 this] yesterday and was wondering if the 24.2ems should be made part of the actual template. There was a discussion on this a short while ago on the template\'s talk page, but I didn\'t think it was possible. Didn\'t occur to me to try decimals. \\u2013&nbsp;<font color=\\"#06266f\\">Ker\\u03b1u<\\/font><font color=\\"#1240AB\\">no\\u03c2co<\\/font><font color=\\"#4671DS\\">pia<\\/font><font color=\\"#A60000\\"><sup>\\u25c1<\\/sup><\\/font><i><sub><font color=\\"#5E1FFF\\">',
#   'user': 'Keraunoscopia',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.308218820E09'},
#  {'id': '35',
#   'root': '34',
#   'text': 'I missed that discussion, but I definitely think it would be very good if the default width of the template was 24.2, so that it would be (I think) the same width as the infobox.  (And as an additional point, I would also favor making \\"state=plain\\" the default.)  <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '34',
#   'timestamp': '1.308219120E09'},
#  {'id': '36',
#   'root': '34',
#   'text': 'I\'m not familiar enough with the states thing, but here\'s the discussion: [[Template_talk:Album_ratings#Width]]. It\'s not very old at all. I would support the 24.2. \\u2013&nbsp;<font color=\\"#06266f\\">Ker\\u03b1u<\\/font><font color=\\"#1240AB\\">no\\u03c2co<\\/font><font color=\\"#4671DS\\">pia<\\/font><font color=\\"#A60000\\"><sup>\\u25c1<\\/sup><\\/font><i><sub><font color=\\"#5E1FFF\\">',
#   'user': 'Keraunoscopia',
#   'meta': {'is-admin': False},
#   'reply-to': '35',
#   'timestamp': '1.308219240E09'},
#  {'id': '37',
#   'root': '34',
#   'text': 'I was wondering if the widths of the infobox and the album ratings template would vary by browser and\\/or by skin, but I didn\'t try to figure that out.  It sounds like they do.  But I think that using 24.2em would make them the same width for most readers, so I would still favor that.  As for \\"state\\", that\'s explained on the [[:Template:Album ratings]] page.  In my opinion \\"state=plain\\" would be the best default, because it displays the ratings without the options to hide or show them.  In most cases having the option is an unnecessary complication, in my view. <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '36',
#   'timestamp': '1.308219660E09'},
#  {'id': '38',
#   'root': '34',
#   'text': 'Oh, I remember states now. Yeah, not sure why one would collapse the template at all. Kind of a silly option. Well, when I messed around with ems, they varied between skins (I tried Vector, and I always use Modern, otherwise), and I\'m using Safari for a browser, and your 24.2 thing looked fine on Safari\\/skin=Modern, so I assume you\'ve figured out the secret width needed. Not sure how well it would work, but you could always put an infobox and the album ratings template on an otherwise-empty sandbox, then throw that URL into [http:\\/\\/browsershots.org\\/ browsershots.org] and see if the widths vary from browser to browser. They\'d all be in Vector (default) skin, I think. \\u2013&nbsp;<font color=\\"#06266f\\">Ker\\u03b1u<\\/font><font color=\\"#1240AB\\">no\\u03c2co<\\/font><font color=\\"#4671DS\\">pia<\\/font><font color=\\"#A60000\\"><sup>\\u25c1<\\/sup><\\/font><i><sub><font color=\\"#5E1FFF\\">',
#   'user': 'Keraunoscopia',
#   'meta': {'is-admin': False},
#   'reply-to': '37',
#   'timestamp': '1.308220200E09'},
#  {'id': '87387',
#   'root': '87387',
#   'text': 'Thanks for your edits to this article. The thing is, though, they didn\'t play the Australia national cricket team; they played the Australians. Apologies if you already knew this, but there\'s a rigid distinction in operation here: \\"Australia\\" as such \'\'only\'\' play international cricket; all matches against counties, universities and so on are listed as \\"Australians\\". Ditto with other countries, so that (for example) \\"Worcestershire v Pakistanis\\" doesn\'t mean any old Pakistanis, but always the national team playing a non-international match. For that reason I\'m inclined to change those edits back, but I\'ll leave it a day or two in case you want to come back at me. ',
#   'user': 'Loganberry',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.238805900E09'},
#  {'id': '87388',
#   'root': '87387',
#   'text': 'To answer the obvious question, where there is no convenient adjectival form, one just adds \\"XI\\" to the team name, so that you have \\"Barbados v England XI\\" or whatever. For historical reasons, until the 1970s, England played as \\"MCC\\" in non-international tour games. ',
#   'user': 'Loganberry',
#   'meta': {'is-admin': False},
#   'reply-to': '87387',
#   'timestamp': '1.238806140E09'},
#  {'id': '87389',
#   'root': '87387',
#   'text': "Thanks for the explanation Loganberry. I didn't know about that distinction. I'll change it back. ",
#   'user': 'Qwfp',
#   'meta': {'is-admin': False},
#   'reply-to': '87388',
#   'timestamp': '1.238806860E09'},
#  {'id': '87390',
#   'root': '87387',
#   'text': 'Thanks. As with most things cricket, the logic isn\'t perfect (eg theEngland matches against the Australian Forces in 1945 \'\'are\'\' \\"England\\", not \\"England XI\\") but it\'s usually reliable otherwise. ',
#   'user': 'Loganberry',
#   'meta': {'is-admin': False},
#   'reply-to': '87389',
#   'timestamp': '1.239397380E09'},
#  {'id': '262180',
#   'root': '262180',
#   'text': "New photo added by a drive-by to [[Marwari horse]]. Nice image, superficial image check suggests licensing is OK, but it's your article, so may want to peek.  It was in a bad spot, so I moved it, but not sure I improved matters.  ",
#   'user': 'Montanabw',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287465720E09'},
#  {'id': '262181',
#   'root': '262180',
#   'text': "Licensing isn't quite right. I've dropped a note on the editor's talk; won't remove the image for now, but if it's not cleared up shortly it'll need to go. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262180',
#   'timestamp': '1.287467160E09'},
#  {'id': '262182',
#   'root': '262180',
#   'text': "Allright, licensing fixed. All good now - it's a nice image. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262181',
#   'timestamp': '1.287468840E09'},
#  {'id': '262150',
#   'root': '262150',
#   'text': 'mamasita means lady in my native language (for not misunderstanding)--',
#   'user': 'Venerock',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286164740E09'},
#  {'id': '262151',
#   'root': '262150',
#   'text': "Took a quick peek at this.  May be a good idea to review [[List of horse breeds]] and [[Iberian horse]] to see if we already have articles (under a different spelling) for some of the breeds currently redlinked in the template.  Also not sure if we really need a nav template for this group -- WPEQ is a bit template heavy already... and I'd dread to see separate German, Italian, English and (god fobid!) USA templates, especially if we got fights going over which country claims which breed (like we have at Lipizzan!)...  The Italian, Japanese, and Indonesian horse breed articles just have extensive see also sections that cross-ref the others, or, if the Spanish horse list is too huge for a see also, we could expand [[Iberian horse]] into a list something along the lines of [[stock horse]] or [[gaited horse]].  Just a thought, and should this whole thread go over to WPEQ for more folks to discuss?  ",
#   'user': 'Montanabw',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286195520E09'},
#  {'id': '524327',
#   'root': '524327',
#   'text': '',
#   'user': 'Vicond',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189657020E09'},
#  {'id': '524328',
#   'root': '524327',
#   'text': "Don't worry about it. I doubt many email harvesters will go digging in page histories, and don't know of any downstream sites that copy our histories, just our pages. Removing it from the page should be sufficient. --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524327',
#   'timestamp': '1.189720920E09'},
#  {'id': '262184',
#   'root': '262184',
#   'text': 'See also my discussion at [[User talk:Good Olfactory]], leading to this inquiry. --',
#   'user': 'Bsherr',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287490620E09'},
#  {'id': '262185',
#   'root': '262184',
#   'text': "I've responded at Good Olfactory's page to keep this all in one spot. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262184',
#   'timestamp': '1.287509340E09'},
#  {'id': '524330',
#   'root': '524330',
#   'text': 'My wiki mail option is working but I have to type in the following, http:\\/\\/en.wikipedia.org\\/wiki\\/Special:Emailuser\\/ plus the username to get it to do so. Anyway problem solved and please feel free to not respond to any of my messages today including the 2 I sent by email. And thanks for your help. ...',
#   'user': 'Albion moonlight',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189668060E09'},
#  {'id': '524331',
#   'root': '524330',
#   'text': "I received your 2 emails. I'm not sure I understood the second, but if it's taken care of, that's good too. :-) --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524330',
#   'timestamp': '1.189720800E09'},
#  {'id': '524332',
#   'root': '524332',
#   'text': 'What is the policy when someone writes something like [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Talk:Republic_of_Macedonia&diff=157152659&oldid=156689101 this] ? Does their IP get banned and their comment purged from the talk page? ',
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189663740E09'},
#  {'id': '524333',
#   'root': '524332',
#   'text': 'I left a warning on their talk page. Looks like others have already removed the offensive comment. ',
#   'user': 'Videmus Omnia',
#   'meta': {'is-admin': False},
#   'reply-to': '524332',
#   'timestamp': '1.189668900E09'},
#  {'id': '524334',
#   'root': '524332',
#   'text': "They would be [[Wikipedia:blocking policy|blocked]], yes, but it looks like they haven't been repeating. [[IP address]]es are usually not [[Wikipedia:Banning policy|banned]], because an IP is usually just a number handed out by a service provider, and will be given to a different person  eventually; certainly when the person signs up with a new service provider, and sometimes even faster than that. Our acquaintaince from Perth editing on that subject has shown the ability to get a new IP number within minutes of the old one being blocked, sometimes several times a day; fortunately, however, this isn't him. --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524333',
#   'timestamp': '1.189721400E09'},
#  {'id': '524335',
#   'root': '524332',
#   'text': 'I see a similar address made a similar comment. [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Talk:Republic_of_Macedonia&diff=157578888&oldid=157499660] If it becomes a regular thing, tell me, and I will semi-protect the article talk page. That will stop all IP addresses without an account from editing there (apparently some do make non-abusive comments[http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Talk:Republic_of_Macedonia&diff=156689101&oldid=156496906]) but if we have to, we will. --',
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524334',
#   'timestamp': '1.189721700E09'},
#  {'id': '262189',
#   'root': '262189',
#   'text': 'Hi Dana.  Thanks for closing [[Wikipedia:Categories_for_discussion\\/Log\\/2010_October_14#Category:Wikipedians_open_to_whale_squishing]].  That was a decent close.  I might have said \\"no consensus for deviating from policy-based arguments\\" instead of mentioning IAR.  You put your closing note at the bottom of the debate.  That is a bit unusual.  Usually, the closing explanation goes at the top, with the close, doesn\'t it?  --',
#   'user': 'SmokeyJoe',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287993420E09'},
#  {'id': '262190',
#   'root': '262189',
#   'text': "Hi Smokey! Thanks for the nice note! LOL, I guess I'm more used to FAR closures, where closing notes go at the bottom. Feel free to move the comment if you would like. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262189',
#   'timestamp': '1.287993720E09'},
#  {'id': '262191',
#   'root': '262191',
#   'text': "I think you should close the first one too, as I gave it as an example of a bad FA a few times '''",
#   'user': 'YellowMonkey',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.287993960E09'},
#  {'id': '262192',
#   'root': '262191',
#   'text': "Will do. When I closed Dorset it wasn't exactly 14 days for those. I'll get to them tomorrow morning (it's getting to be bedtime here!) Have you had a chance to check out the two I pinged you about? ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262191',
#   'timestamp': '1.287994200E09'},
#  {'id': '524336',
#   'root': '524336',
#   'text': 'Hello, I did an edit on one of the porn stars pages and I have an editor who just joined [[wikipedia]] who is going onto the article and adding things at random. I removed the personal info like where he lives and the editor put it right back on. Then the editor made an edit and place a description as this [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Arpad_Miklos&diff=prev&oldid=157524752]. COuld you please look at this? I did go onto theri talk page and explain about putting personal info and advertisement onto an article. I hope it helps. Thank you ',
#   'user': 'Junebug52',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189676400E09'},
#  {'id': '524337',
#   'root': '524336',
#   'text': "You have the right idea; we certainly want confirmation before accusing someone of being an escort, which is usually a euphemism for being a prostitute. However, in this case, he's apparently a prizewinning escort. (Yes, I didn't know there was a prize for that either, but it seems there is ... live and learn. I'll be making an article for the [[International Escort Awards]] soon; it got coverage from the ''[[Village Voice]]'', ''[[DNA Magazine]]'', and even a bit from the ''[[New York Daily News]]''.) Winning the prize is fairly clear confirmation that he does work as an escort. --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524336',
#   'timestamp': '1.189713300E09'},
#  {'id': '524338',
#   'root': '524336',
# ...
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524797',
#   'timestamp': '1.199745000E09'},
#  {'id': '393301',
#   'root': '393301',
#   'text': 'Nope. Thanks. --',
#   'user': 'Calton',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.180452300E09'},
#  {'id': '393302',
#   'root': '393301',
#   'text': 'OK I have an asshole stalking me. Great. ',
#   'user': 'Kappa',
#   'meta': {'is-admin': False},
#   'reply-to': '393301',
#   'timestamp': '1.180452360E09'},
#  {'id': '393303',
#   'root': '393301',
#   'text': 'Not even wrong, but thanks for playing. Oh, by the way, [[WP:NPA|this]] makes for informative reading. Remember it when you comment on the [[Wikipedia:Miscellany for deletion\\/User:Kappa\\/Kaaos|MFD discussion]]. --',
#   'user': 'Calton',
#   'meta': {'is-admin': False},
#   'reply-to': '393302',
#   'timestamp': '1.180453380E09'},
#  {'id': '393304',
#   'root': '393301',
#   'text': 'I voted to keep the material in your userspace.  However, your comments above constitue a personal attack.  Consider this a warning.  <em>&mdash;<font color=\\"Indigo\\">',
#   'user': 'Gaff',
#   'meta': {'is-admin': False},
#   'reply-to': '393303',
#   'timestamp': '1.180491660E09'},
#  {'id': '524801',
#   'root': '524801',
#   'text': "Big day for the Japanese porn project, Anon-- [[Tetsuji Takechi]]-- We've got a GA to our credit! Thank you for prodding me to go through with the process, for all your help and advice with my work here. Cheers! ",
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.199524320E09'},
#  {'id': '524802',
#   'root': '524801',
#   'text': 'Congratulations! Your next steps are either nominating another one or two for GA, or this one for FA. From recent experience, the FA review will naturally be tougher - expect about five people rather than one - but the GA will take a month and a half, rather than a week and a half, so may be more frustrating in that respect. :-) --19:49, 7 January 2008 (UTC)',
#   'user': '{unknown-9}',
#   'meta': {'is-admin': False},
#   'reply-to': '524801',
#   'timestamp': '-1'},
#  {'id': '524803',
#   'root': '524801',
#   'text': "Thanks, Anon. I read through the Takechi article after its passing, and cringed at the awkward wording... I'll keep working away at it, and eventually try it for FA, but not for a while. I think I'll try for more GAs in the meantime. I've found a good, long analysis of ''[[Wife to Be Sacrificed]]'' by a professor of Film. The article's already in fairly good shape. Think I should try for that one next? And, by the way, Happy New Year! ",
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': '524802',
#   'timestamp': '1.199776920E09'},
#  {'id': '524804',
#   'root': '524801',
#   'text': "Seems reasonable. I personally worry about the prominence given to a specific ''sixth of a second'' of film...  <small>squeamish? me?<\\/small>--",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524803',
#   'timestamp': '1.199842740E09'},
#  {'id': '524805',
#   'root': '524801',
#   'text': "Oh? Personally, I'm cackling like a mad scientist and rubbing my hands with glee at just the thought of that appearing on the main page some day... ;) ",
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': '524804',
#   'timestamp': '1.199843400E09'},
#  {'id': '515',
#   'root': '515',
#   'text': '[http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Tatsunoko_vs._Capcom:_Ultimate_All_Stars&diff=next&oldid=238961371 About this edit]. Can you tell me if this date is for the arcade or Wii version? ',
#   'user': 'FullMetal Falcon',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.242804720E09'},
#  {'id': '516',
#   'root': '515',
#   'text': "It's for the Wii version. http:\\/\\/www.1up.com\\/do\\/newsStory?cId=3169973 Why do you ask? ",
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '515',
#   'timestamp': '1.242811200E09'},
#  {'id': '517',
#   'root': '517',
#   'text': 'Out of curiosity, do you remember what \\"materials\\" [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Tatsunoko_vs._Capcom:_Ultimate_All_Stars&diff=next&oldid=231556863] Capcom released stating its number seven? ',
#   'user': 'FullMetal Falcon',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.244612040E09'},
#  {'id': '518',
#   'root': '517',
#   'text': "If I can find a source corroborating that statement, I will present it. However, the only thing I can remember is Capcom promotional materials promoting it as the continuation of the [[Marvel vs. Capcom series]], but I can't recall Capcom specifically numerating which installment it was (Seventh game would indicate that it includes the Capcom vs. SNK games, which have generally been considered as their own series, not combined with the Marvel vs. games). ",
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '517',
#   'timestamp': '1.244618220E09'},
#  {'id': '519',
#   'root': '517',
#   'text': "Ok, thanks. It doesn't seem to be too much of an issue, if you cannot find it. Its just something that bugged me since I want to collect as much information as possible. Regards, ",
#   'user': 'FullMetal Falcon',
#   'meta': {'is-admin': False},
#   'reply-to': '518',
#   'timestamp': '1.244761140E09'},
#  {'id': '524807',
#   'root': '524807',
#   'text': 'Thanks for finding a free image of [[Quanell X]] from Flickr!  It is like a late Christmas present.  How did you know to look for one??  ',
#   'user': 'Deatonjr',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.199792820E09'},
#  {'id': '524808',
#   'root': '524807',
#   'text': "You're welcome. I read the article talk page and saw the request. Why was I looking at the article talk page? I was probably clicking around following interesting links from people's user pages, or contributions, or articles. I'm not sure myself, really. :-) --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524807',
#   'timestamp': '1.199832840E09'},
#  {'id': '521',
#   'root': '521',
#   'text': 'Phew, that was quick. You beat me to [[WP:AIV]] with the report on 202.155.92.10. Persistent isn\'t s\\/he? Regards <span style=\\"text-shadow:grey 0.2em 0.2em 0.1em; class=texhtml\\"> ',
#   'user': 'Davidelit',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.253802180E09'},
#  {'id': '522',
#   'root': '521',
#   'text': "Indeed he\\/she is. I've been keeping a track of this person for over a year now; they're an Indonesian user who constantly vandalizes anime, game and movie studio articles with misinformation. He's IP jumped so many times that I don't think he'll ever be stopped. ",
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '521',
#   'timestamp': '1.253802240E09'},
#  {'id': '523',
#   'root': '521',
#   'text': 'Yes, it is a problem. 202.70.61.148 is another of the IPs. Well, let\'s see what happens. I\'ll wait to see if s\\/he is blocked before reverting again. <span style=\\"text-shadow:grey 0.2em 0.2em 0.1em; class=texhtml\\"> ',
#   'user': 'Davidelit',
#   'meta': {'is-admin': False},
#   'reply-to': '522',
#   'timestamp': '1.253803500E09'},
#  {'id': '524',
#   'root': '521',
#   'text': 'Ditto. That guy\'s persistent, I know (and annoying as well). I\'ve also encountered this guy numerous times, and I was the one who first reported him on WP:AN\\/I ([[Wikipedia:Administrators\' noticeboard\\/IncidentArchive341#Re: Big problem caused by \\"61.5.*.*\\/61.94.*.*\\" IP user|this is the report as archived]]). The guy also operated on the following ranges: 202.70.61.133, 202.70.61.146, 114.59.100.70, and the 118.137.x.x range (which I know you\'re aware already), as well as many others that I can\'t mention here as of this moment, all in Indonesia. It seems no amount of warning, not even in Indonesian, stopped him. I\'ve already told everything about this guy to [[User talk:Nja247|Nja247]], so Nja247 has oftentimes become my go-to admin whenever the vandal strikes or has striken within the last few minutes\\/hours of his last attack. - ',
#   'user': '{unknown-10}',
#   'meta': {'is-admin': False},
#   'reply-to': '523',
#   'timestamp': '1.253815620E09'},
#  {'id': '525',
#   'root': '521',
#   'text': 'I wonder if it would be possible to request multiple, long-term range blocks on the offending ranges. I know I requested such a thing from admin [[User:Nihonjoe]] a while back, and he blocked several offending ranges for 6 months, during which vandalism from this user was relatively quiet (as far as I could tell, anyway) as a result. Maybe a similar set of range blocks (hopefully for a year or longer) could deter this user. ',
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '524',
#   'timestamp': '1.253834220E09'},
#  {'id': '526',
#   'root': '521',
#   'text': "Since the 202.70.61.x range will be automatically unblocked a few minutes from now (MuZemike did the block on 202.70.61.128\\/27 a week ago as an immediate action to [[Wikipedia:Administrators' noticeboard\\/IncidentArchive564#An already big problem by misinformation vandal|my report on the vandal]]), I'm sure the vandal will show up on that range once again. - ",
#   'user': '{unknown-11}',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.253834820E09'},
#  {'id': '527',
#   'root': '521',
#   'text': "'''P. S.:''' I've already told Nja247 about 202.155.92.10, BTW. - ",
#   'user': '{unknown-12}',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.253835240E09'},
#  {'id': '262666',
#   'root': '262666',
#   'text': 'Am doing. After a cursory look, nothing jumps out\\u2014except the fact it was quite well-written :) I\'ll read more thoroughly later, but right now I can\'t fault it on anything major. I thought of perhaps breaking \\"Life\\" up into \\"Personal life\\" and \\"Work\\", but that doesn\'t seem like much of an idea; it might make those sections too short. ',
#   'user': 'Fvasconcellos',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.175132280E09'},
#  {'id': '262667',
#   'root': '262666',
#   'text': 'Catching up on the guidelines is always a good idea :) ',
#   'user': 'Fvasconcellos',
#   'meta': {'is-admin': False},
#   'reply-to': '262666',
#   'timestamp': '1.175133300E09'},
#  {'id': '262668',
#   'root': '262666',
#   'text': "Glad to have helped. I'll have to check my dictionary now, that was force of habit (and my spell-checker, set to U.S. English) ",
#   'user': 'Fvasconcellos',
#   'meta': {'is-admin': False},
#   'reply-to': '262667',
#   'timestamp': '1.175138640E09'},
#  {'id': '262669',
#   'root': '262669',
#   'text': 'There\'s some discussion going on regarding Cite News and the other cite templates on [[Template talk:Cite news|that talk page]].  Would love your input :) -- <span style=\\"background-color: #EECCFF;\\">',
#   'user': 'SatyrTN',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.175504160E09'},
#  {'id': '262670',
#   'root': '262669',
#   'text': 'Please see my reply to the ongoing discussion: the very \'\'\'last\'\'\' thing we want is people charging off in all directions using their own \\"pet\\" styles for citations. We want to get the various citation templates in such a condition that \'\'\'anybody\'\'\' can use them to produce useful citations, rather than placing further artificial restrictions and limiting citation to those \\"experts\\" who \\"know how to format citations correctly\\". We need to stop trying to follow any particular existing \\"Manual of Style\\" and synthesise our own: why else did the various \\"Manuals\\" come into being other than the particular needs of the originating situation? HTH HAND \\u2014',
#   'user': 'Phil Boswell',
#   'meta': {'is-admin': True},
#   'reply-to': '262669',
#   'timestamp': '1.175547480E09'},
#  {'id': '262671',
#   'root': '262671',
#   'text': 'OK, I admit that I got distracted because of all of my travel; can we try to finish this up and poll for consensus?  [http:\\/\\/en.wikipedia.org\\/wiki\\/Wikipedia_talk:Manual_of_Style_%28medicine-related_articles%29#Historical_.3F]  ',
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.175811180E09'},
#  {'id': '262672',
#   'root': '262671',
#   'text': "OK, enough procrastinating from me :-)  Have you noticed that I *really* hate working on policy pages ? <grin> I'd much rather edit and review articles.  I'm going to settle in to my upstairs computer and catch up on this thing, finally.  ",
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': '262671',
#   'timestamp': '1.176421320E09'},
#  {'id': '529',
#   'root': '529',
#   'text': '[[Special:Contributions\\/220.255.178.29|220.255.178.29]] (',
#   'user': '220.255.178.29',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.264443540E09'},
#  {'id': '530',
#   'root': '529',
#   'text': "Because you didn't supply references for the criticisms you listed. Per the sites' [[Wikipedia:Verifiability|verifiability]] policy, any information that can be challenged has to be backed up by a [[Wikipedia:Reliable sources|reliable source]] that is cited in writing. If there is no source supplied, the material added can be removed. Find some reliable sources to cite on the issues you brought up, and what you wrote can stand. ",
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '529',
#   'timestamp': '1.264458360E09'},
#  {'id': '524818',
#   'root': '524818',
#   'text': "Hi again, AnonEMouse. I've just added several [[AVN (magazine)|AVN (magazine)]] reviews\\/profiles, but for some reason the links aren't working. Since it's (I think) a print source as well, the reference is still valid. But is there a trick to linking to the online source? ",
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.200106500E09'},
#  {'id': '524819',
#   'root': '524818',
#   'text': 'Looking at your recent edit history, the [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Yuki_Asuka&diff=prev&oldid=183679223 link you added to Yuki Asuka], for example, worked for me.  --',
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524818',
#   'timestamp': '1.200106740E09'},
#  {'id': '524820',
#   'root': '524818',
#   'text': 'OK-- must just be this computer. Thanks. ',
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': '524819',
#   'timestamp': '1.200107340E09'},
#  {'id': '524821',
#   'root': '524818',
#   'text': "That said, I'm not sure that every review of every film a star has appeared in is a good use of external links. Just from sheer numbers, I know Japanese stars appear in fewer films than American stars, but still, ten films, each reviewed in two magazines, that's twenty external links, and the content isn't usually very focused on the single actor our article is supposed to be about. --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524820',
#   'timestamp': '1.200107760E09'},
#  {'id': '524822',
#   'root': '524818',
#   'text': "Well, on these particular subjects (Suzi Suzuki excepted), these are Japanese films being reviewed in an English-language source-- pretty rare, and, I would think, some indication of international notability. Also the films are not likely to get their own articles, and most (not all) of the reviews do carry on quite a bit about the actress in question, since she's the star attraction. About Suzuki though, I've long thought she does not belong in Category Japanese porn stars. She's an actress of Japanese (I think) descent who appears in U.S. porn. These ethnic\\/nationality issues get sticky though, and removing her from the category might set off some kind of a squabbling storm... ",
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': '524821',
#   'timestamp': '1.200108360E09'},
#  ...]

# %%
wikipedia = defaultdict(list)

for utterance in data:
    wikipedia[utterance['root']].append(utterance)

# %%
data
# Out:
# [{'id': '524288',
#   'root': '524288',
#   'text': 'You should look at all of the point on the template not just the last one, the template also says the image belonging to the republic of macedonia is in the public domain if it being used for \\"information purposes\\". ',
#   'user': 'Frightner',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189190940E09'},
#  {'id': '524289',
#   'root': '524288',
#   'text': 'Yes I agree. The law permits usage of documents, photographs and other materials for educational and informational purposes. There was a normative act issued by the government of the Republic of Macedonia that even allowed citizens to make photocopies or photograph rare archive materials. ',
#   'user': 'Revizionist',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189204860E09'},
#  {'id': '1',
#   'root': '1',
#   'text': "Yes, that's good. Revathy's page looked very reliable, that's why we used that as a source. ",
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.310744280E09'},
#  {'id': '2',
#   'root': '1',
#   'text': "Nagma'a site, at least that filmography page, looks like taken from Wikipedia itself. I didn't remove it from time being, but I don't think it's true. ",
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': '1',
#   'timestamp': '1.310746500E09'},
#  {'id': '3',
#   'root': '1',
#   'text': 'I don\'t think there are many such official reliable sites left yet. The problem is most \\"official sites\\" are not really official, and often based on Wikipedia itself, and you don\'t know what to believe and what not. We used Madras Talkies\' page, which is dead now. [http:\\/\\/kavithalayaa.com\\/ Kavithalayaa]\'s site is there, also AVM Production\'s site might be useful perhaps, but I can\'t enter that. Generally official sites of production houses seem to be very reliable ones. ',
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': '2',
#   'timestamp': '1.310751180E09'},
#  {'id': '4',
#   'root': '1',
#   'text': 'Most of the so called \\"official sites\\" are maintained by fans or cinema based web companies. Not sure how reliable are they. <span style=\\"color:green;font-size:small;;font-family:Segoe Print;\\">-<i>B<\\/i>iLLa-<\\/span>',
#   'user': 'Michael-Billa',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.311762120E09'},
#  {'id': '524290',
#   'root': '524290',
#   'text': "You closed [[Wikipedia:Articles for deletion\\/J. Kevin Tumlinson]] after one day without mentioning anything about speedy deletion or giving reasons. Not that I'm objecting ''too'' much, but did you realize it was only one day? --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.189197960E09'},
#  {'id': '524291',
#   'root': '524290',
#   'text': 'Well, notability cannot be acquired in 4 days. That was my reasoning behind the early closure. However, if you still believe the closure was out of process, you can still refer to the deletion review. - ',
#   'user': 'FayssalF',
#   'meta': {'is-admin': True},
#   'reply-to': '524290',
#   'timestamp': '1.189200660E09'},
#  {'id': '524292',
#   'root': '524290',
#   'text': "No, no, I was the nominator! Just wanted to make sure it wasn't done in error. --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524291',
#   'timestamp': '1.189200720E09'},
#  {'id': '524293',
#   'root': '524290',
#   'text': "I was a bit surprised because i know you were the nominator ;) No, it wasn't done in error. - ",
#   'user': 'FayssalF',
#   'meta': {'is-admin': True},
#   'reply-to': '524292',
#   'timestamp': '1.189200960E09'},
#  {'id': '262147',
#   'root': '262147',
#   'text': 'Hello Dana, thanks for contribute in this [[Template:Spanish horses|template]], but i need tell you that is about horse, and balearic article is about a language of a people, if you think that im not right please tell me for not fixing the edit at last. Enjoy your day ;)--',
#   'user': 'Venerock',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286157240E09'},
#  {'id': '262148',
#   'root': '262147',
#   'text': 'My apologies, I forgot to include the disambiguator. Please check now - it should be right. Thanks for letting me know. ',
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262147',
#   'timestamp': '1.286157480E09'},
#  {'id': '6',
#   'root': '6',
#   'text': 'Hey, who said so? Frankly, I have absolutely no idea, sorry! ',
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312057320E09'},
#  {'id': '7',
#   'root': '6',
#   'text': "Maybe, we should check out who added that, it could be some fanatic IP user. There will have been nominees, since there were nominees in earlier ceremonies and in the Telugu section, too, but how to find out? If there was a video coverage of that ceremony available we would know. Otherwise, I would remove it as it's unsourced. ",
#   'user': 'Johannes003',
#   'meta': {'is-admin': False},
#   'reply-to': '6',
#   'timestamp': '1.312059420E09'},
#  {'id': '262145',
#   'root': '262145',
#   'text': "H  Dana, totally  amiss of me - belated congrats for  your promotion! I  voted for  you  without  any  hesitation. I'm  pleased to  hear from  Pike  that  you  might  be reviewing  the Finnhorse, I  can't  think  of anyone better for  the job. --",
#   'user': 'Kudpung',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286127120E09'},
#  {'id': '262146',
#   'root': '262145',
#   'text': "Thank you very much! I am going to try to take a look over Finnhorse - actually, I think I'll go start looking at it right now while I have a few minutes. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262145',
#   'timestamp': '1.286133300E09'},
#  {'id': '262152',
#   'root': '262152',
#   'text': "Hi. Just writing that you closed out the [[WP:CFD]] as a '''merge and delete''', but category appears open still at this moment. Yours, ",
#   'user': 'Rms125a@hotmail.com',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286163540E09'},
#  {'id': '262153',
#   'root': '262152',
#   'text': "Yes, I know. It's on the list at [[Wikipedia:Categories_for_discussion\\/Working]], and the bot should get to it shortly. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262152',
#   'timestamp': '1.286163600E09'},
#  {'id': '9',
#   'root': '9',
#   'text': "Well, no website is 100% perfect, you got to understand that. Are you saying TOI is an unreliable source? Mention of Shankar as Shankar Mahadevan might have been a mistake, I'll contact them and ask them to correct it. What else do you want me to do? ",
#   'user': 'Secret of success',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312136520E09'},
#  {'id': '10',
#   'root': '9',
#   'text': 'I don\'t care. This is not the place to elevate your favourite Star\'s films. I\'m not questioning about the credibility of TOI. There is a consensus not to add budget\\/gross figures for any Indian movie, if it\'s speculated at a higher rate. I think you might be aware of the \\"Enthiran issue\\". Even official sources were not considered. --',
#   'user': 'Vensatry',
#   'meta': {'is-admin': False},
#   'reply-to': '9',
#   'timestamp': '1.312136820E09'},
#  {'id': '262154',
#   'root': '262154',
#   'text': 'Could you restore Category:Second wave synthpop acts (or at least the bands formerly listed therein) to my userspace? I was checking out some of the bands and bookmarked it to check out some others later, but found that it was deleted. Thanks! ',
#   'user': 'JCDenton2052',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286272380E09'},
#  {'id': '262155',
#   'root': '262154',
#   'text': "There would be nothing to restore, and categories can't be moved even if there were.  Category pages contain nothing, articles are added to it by an addition of code at the bottom of each article.  When a category is deleted, CFD has an Adminbot that goes through each article and removes the category.  The best you could do would be to find the edits in [[User:Cydebot]]'s contribution record, and then you'd be able to see what was in the category pre-deletion. ",
#   'user': 'Courcelles',
#   'meta': {'is-admin': True},
#   'reply-to': '262154',
#   'timestamp': '1.286272740E09'},
#  {'id': '262156',
#   'root': '262154',
#   'text': 'Found them. Thanks for your help! ',
#   'user': 'JCDenton2052',
#   'meta': {'is-admin': False},
#   'reply-to': '262155',
#   'timestamp': '1.286274420E09'},
#  {'id': '11',
#   'root': '11',
#   'text': 'I agree i copied, even he mi8 know it very well. I dont know 2 design and all but some thing inside, i got my own work also. If u dont mind can i copy abit of urs. Even ur page looks good!! ',
#   'user': 'Karthikndr',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312143840E09'},
#  {'id': '12',
#   'root': '11',
#   'text': 'Ok! Ty for the info and links. Will create new design asap. ',
#   'user': 'Karthikndr',
#   'meta': {'is-admin': False},
#   'reply-to': '11',
#   'timestamp': '1.312146060E09'},
#  {'id': '13',
#   'root': '13',
#   'text': "I don't understand what you are saying. Could you please be more precise? ",
#   'user': 'Secret of success',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312244220E09'},
#  {'id': '14',
#   'root': '13',
#   'text': 'Well, I have not made much significant contribution but just a couple of sections in one or two articles. If that is not enough, I have removed the template if that bothers you. ',
#   'user': 'Secret of success',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312410120E09'},
#  {'id': '524302',
#   'root': '524302',
#   'text': "If you look at the contrib history of Mr. Neutron you will find plenty of edits like this, and all of his 'contribs' are EXCLUSIVELY on articles dealing with Macedonia, and mostly pushing pro-bulgarian POV in subtle and not-so-subtle ways. I just thought you might want to know for future reference :) ",
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189478460E09'},
#  {'id': '524303',
#   'root': '524302',
#   'text': 'Thanks. I understand that there is a lot of controversy here, even between respected scholars. We need to document that disagreement in our articles, hopefully without attacking editors. --',
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524302',
#   'timestamp': '1.189479180E09'},
#  {'id': '524304',
#   'root': '524302',
#   'text': 'Capricornis, stop insinuating. And please refrain from various [[Ad hominem]] arguments, as they are falacies. Comment on contributions please. ',
#   'user': 'Mr. Neutron',
#   'meta': {'is-admin': False},
#   'reply-to': '524303',
#   'timestamp': '1.189480920E09'},
#  {'id': '524305',
#   'root': '524302',
#   'text': "You must have misunderstood something? I was commenting on your contributions, not on you as a person (please read the Ad Hominem article before you quote it). Also 'insinuations' are statements that cannot be proven, whereas my statements above can be proven by anyone who will take the time to look through your contrib history. have a great day ",
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': '524304',
#   'timestamp': '1.189489680E09'},
#  {'id': '524306',
#   'root': '524302',
#   'text': 'You were already warned on your talkpage not to commit any more personal attacks, so dont do it. You have been consistently insinuating against other Wikipedia contributors and this is not at all nice going. ',
#   'user': 'Mr. Neutron',
#   'meta': {'is-admin': False},
#   'reply-to': '524305',
#   'timestamp': '1.189490280E09'},
#  {'id': '524307',
#   'root': '524302',
#   'text': "You are talking about the distant past. I retracted the unfortunate comments and they were accepted, including by you, at the end of this section http:\\/\\/en.wikipedia.org\\/wiki\\/Talk:Ilinden-Preobrazhenie_Uprising#Search_engines_tests . I do not intend to personally attack you at all, but I will attack your contributions and 'content' every time you try to 'slightly' swing the pendulum to your side - you will be reported. ",
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': '524306',
#   'timestamp': '1.189491480E09'},
#  {'id': '524308',
#   'root': '524302',
#   'text': 'Oh please! \\"Distant past\\" was only [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=User_talk:Capricornis&diff=156856515&oldid=156665242 yesterday]. Report whatever you want, with such consistent agenda against other contributors you only bring suspicion on yourself. ',
#   'user': 'Mr. Neutron',
#   'meta': {'is-admin': False},
#   'reply-to': '524307',
#   'timestamp': '1.189493820E09'},
#  {'id': '524309',
#   'root': '524302',
#   'text': "That was a misinformed suggestion by another ordinary user, just like you and me. I still maintain that there were no personal attacks in my words, but only good humored jibs. The statement about the exclusivity of your activity on Macedonia related articles stands and is easily verifiable. I suggest if you have something more to say, to do it on my talk page as there is no point continuing this tirade on AnonEMouse's page who seems to have quite enough work without it. -cheers ",
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': '524308',
#   'timestamp': '1.189501860E09'},
#  {'id': '524310',
#   'root': '524302',
#   'text': 'And more personal attacks calling people misinformed... ',
#   'user': 'Mr. Neutron',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189502040E09'},
#  {'id': '524311',
#   'root': '524302',
#   'text': 'Misinformed\\/misguided are not insults in the English language. Maybe brush up on your English or use [[Websters]]? :) ',
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189502280E09'},
#  {'id': '16',
#   'root': '16',
#   'text': 'Hi. I think your statement of the ip being the sockpuppet of sreekar akkineni is true. Earlier, a user named Niranjaniyengar(who was a sock of sreekar akkineni) wrote on my talk page in a similar manner. If you can trace the ip used by them, it would be possible to block him. I also have a doubt if Mr. Kollyfan, famed for his discussion of the Enthiran gross has something to do with this. It would throw some light on this manner. Thanks! ',
#   'user': 'Secret of success',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.312588320E09'},
#  {'id': '17',
#   'root': '16',
#   'text': 'Glad that you got my point. Actually Sreekarakkineni, Niranjaniyengar and this IP seems like the same person. Will file a case soon.--',
#   'user': 'Vensatry',
#   'meta': {'is-admin': False},
#   'reply-to': '16',
#   'timestamp': '1.312588860E09'},
#  {'id': '18',
#   'root': '16',
#   'text': 'So put in a sock puppet investigation to find out. ',
#   'user': 'Bollyjeff',
#   'meta': {'is-admin': False},
#   'reply-to': '17',
#   'timestamp': '1.312590060E09'},
#  {'id': '262162',
#   'root': '262162',
#   'text': "Hi there Dana, when relisting CFD discussions, please be aware that we don't remove the discussions from one log date to the other; instead, we close the discussion at add the {{tl|Relisted}} template instead. As such, [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Wikipedia:Categories_for_discussion\\/Log\\/2010_September_26&diff=389785157&oldid=389782135 this] edit should be reverted and the discussions should be closed. This is explained at [[WP:RELIST]], last line. Thanks. \\u2014 ",
#   'user': 'Explicit',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.286691180E09'},
#  {'id': '262163',
#   'root': '262162',
#   'text': "Whoops, my apologies. I apparently read the bolded part and completely missed the part in parentheses. Thanks for letting me know - please let me know if there is anything else I'm doing wrong: I'm new at it, but the backlog needs work so I wanted to chip in. I'll go fix that now. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262162',
#   'timestamp': '1.286701080E09'},
#  {'id': '262164',
#   'root': '262162',
#   'text': "And just one other note, Dana\\u2014after you relist a CFD, don't forget to change the date on the cfd tag on the category itself so that it goes to the new discussion, like [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Category%3AChristmas_number-one_singles_in_the_United_Kingdom&action=historysubmit&diff=389999136&oldid=387262711 this]. Thanks for you service in working on closing CFDs; we are always looking for more help and attention with these. ",
#   'user': 'Good Olfactory',
#   'meta': {'is-admin': True},
#   'reply-to': '262162',
#   'timestamp': '1.286793420E09'},
#  {'id': '20',
#   'root': '20',
#   'text': 'Hey! Hi -There are a bunch of things I want to learn here in [[Wikipedia]]. Only you, and maybe 3 others could teach me (terribly embarrassing to admit I\'m so ignorant with computers, etc.) and so I\'ve decided to send a couple notes and the others for help. Is it OK to email you, to save space on our talk pages? Mine is activated too. This drives me crazy! One burning question has to do with many [[Grateful Dead]]-related articles, so I am here. Nearly all the biography articles about [[musician]]s eventually have a Discography section, followed by References, and then External links. Some of them have a \\"see also\\" section which is essentially [[trivia]], and it is simple enough to see if it\'s warranted or not. However, what I don\'t understand is a \\"Notes\\" section. What purpose, exactly does it serve, and how do you put info into the text properly to acheive whatever result the editor is trying to accomplish? It\'s really perplexing. --',
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.300422840E09'},
#  {'id': '21',
#   'root': '20',
#   'text': 'Let me know how that goes.  Being able to format footnotes is a big plus, and like I said it\'s pretty easy once you\'ve done it a few times.  I suggest that you try doing a few on your user page, or on a sub-page of your user page, for practice.  If you want more help just let me know. <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '20',
#   'timestamp': '1.300432800E09'},
#  {'id': '262165',
#   'root': '262165',
#   'text': "I think you should nag MF. He never responds to my nags :P '''",
#   'user': 'YellowMonkey',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.286798880E09'},
#  {'id': '262166',
#   'root': '262165',
#   'text': "I dropped notes to half a dozen editors on various articles already in the FARC stage. We'll see if it gets us anywhere. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262165',
#   'timestamp': '1.286830500E09'},
#  {'id': '262167',
#   'root': '262165',
#   'text': "Outofsinc on British Empire is a sock\\/meat, quite obviously '''",
#   'user': 'YellowMonkey',
#   'meta': {'is-admin': True},
#   'reply-to': '262166',
#   'timestamp': '1.286867700E09'},
#  {'id': '22',
#   'root': '22',
#   'text': 'My apologies when I come trampling through your pet projects-- further from my mind to annoy you, seriously.  However, I keep seeing (esp. in [[jazz]] related articles) people interchanging sections listed as \\"References\\", \\"Notes\\", \\"Footnotes\\" \\"External links\\", and I\'ve even seen (whilst editing) a \\"Reflist 2\\". Frankly, I\'m baffled. I\'ve pretty much stuck to the editing of [[musician]]s and generally, the articles are [[biography|biographical]] and I stick to the typical lead per [[WP:MOS]] (which I admit I never really read too deeply). Usually, at the end of an  article, there\'s the [[discography]] and the <nowiki>references section, followed by External links<\\/nowiki> and often the latter is jam-packed with link farms that are longer than the article themselves. Can you explain to me how this works, with the Notes and all? OH, and feel free to revert my edits when they are done improperly. Sorry about messing up articles that I only want to help! --',
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.303346700E09'},
#  {'id': '23',
#   'root': '22',
#   'text': 'Thanks for the note.  Yes, I think a lot of editors are a bit confused about Notes, References, and External links sections.  Take a look at what I wrote at [[User talk:Mudwater#Notes and other things]], and at [[Talk:Skip Battin#Place references here]], for some helpful info.  On some articles, most or all of the External links section should really be in the References section.  But it\'s important not to remove reliable references from articles.  Feel free to reply here if you want to talk about this some more.  <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '22',
#   'timestamp': '1.303611720E09'},
#  {'id': '24',
#   'root': '22',
#   'text': "OK, I'll have a look at it. Partly, one reason why I'm not a first class editor has some to do with [[ADD]] (or laziness, take your pick) which explains my difficulty with [[punctuation]] as well.. anyway, like I said, never feel bad about reverting my work, too. --",
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': '23',
#   'timestamp': '1.303737480E09'},
#  {'id': '262168',
#   'root': '262168',
#   'text': "Can you please see [[Wikipedia talk:Featured article review\\/Simon Byrne\\/archive1#Breaking_up_other_users'_posts]], and help out with regard to this disruption? Thank you for your time, -- '''",
#   'user': 'Cirt',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.286894160E09'},
#  {'id': '262169',
#   'root': '262168',
#   'text': "Responded to you, at [[Wikipedia talk:Featured article review\\/Simon Byrne\\/archive1]]. -- '''",
#   'user': 'Cirt',
#   'meta': {'is-admin': True},
#   'reply-to': '262168',
#   'timestamp': '1.286910720E09'},
#  {'id': '262170',
#   'root': '262168',
#   'text': "Seems fixed now. -- '''",
#   'user': 'Cirt',
#   'meta': {'is-admin': True},
#   'reply-to': '262169',
#   'timestamp': '1.286911800E09'},
#  {'id': '524313',
#   'root': '524313',
#   'text': 'Who wrote the Joe Schmidlap article?  I had a friend who referenced that name regularly, and was surprised to see it in print.  Thanks for any info you can provide.  ',
#   'user': 'Mandsford',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189486980E09'},
#  {'id': '524314',
#   'root': '524313',
#   'text': "[[User:ManualRivera791]] was the proud author, but it's a common enough insert-name-here name, just [http:\\/\\/www.google.com\\/search?q=Joe+Schmidlap ask Google]. Joe Schmoe is another; John Q. Public; John Doe in legal cases; Joe Bloggs on standardized tests; Bubba... --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524313',
#   'timestamp': '1.189539780E09'},
#  {'id': '26',
#   'root': '26',
#   'text': 'If you have uploaded other non-free media, consider checking that you have specified how these images fully satisfy our non-free content criteria. You can find a list of description pages you have edited by clicking on <span class=\\"plainlinks\\">[{{fullurl:Special:Contributions|target=Mudwater&namespace=6}} this link]<\\/span>. Note that even if you follow steps 1 and 2 above, non-free media which could be replaced by freely licensed alternatives will be deleted 2 days after this notification (7 days if uploaded before 13 July 2006), per our [[Wikipedia:Non-free content criteria|non-free content policy]].  If you have any questions please ask them at the [[Wikipedia:Media copyright questions|Media copyright questions page]]. Thank you. <!-- Template:di-replaceable fair use-notice --> \\u02c9\\u02c9<sup>',
#   'user': 'Anetode',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.303643760E09'},
#  {'id': '27',
#   'root': '26',
#   'text': "Second, last but not least, There's an '''Rfa''' for [[User:Catfish Jim and the soapdish]], one of the handful of editors who, like you, have consistently been a help and inspiration. I hope you'll take a look: [[Wikipedia:Requests for adminship\\/Catfish Jim and the soapdish]] Please, vote with your heart. Thanks as always. --",
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': '26',
#   'timestamp': '1.304301000E09'},
#  {'id': '28',
#   'root': '26',
#   'text': 'As far as the [[Scott Gorham]] article, that\'s just a classic case of an article that doesn\'t have enough references.  But it looks like someone has added more references since you posted about it here on my talk page.  I might add a few more myself if I get around to it.  In general, I\'d say don\'t get too hung up about the technical details of naming the sections, or the best way to format references.  The most important things are to expand and improve the text of existing articles, and to add reliable references that you find, either on the internet or offline.  I happen to be interested in a lot of the technical details myself, as I\'ve explained a bit here on my talk page, but if you find it confusing, don\'t worry about it.  The content is the most important thing, someone can always come along later and fix the formatting.  \\"P.S.\\" Looks like your buddy made admin, congratulations to him (or her). <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '27',
#   'timestamp': '1.304837580E09'},
#  {'id': '29',
#   'root': '26',
#   'text': "Thanks for the response. OK, then. The editor who just brought [[Thin Lizzy]] to GA status becomes more motivated with the Thin Lizzy related articles (like [[Scott Gorham]]) when I bring in new photos that are good. If there isn't enough text to place the article, it doesn't work, and he's good that way.. like the photo for [[Bo Diddley]] and [[Eric Bell]].. so that must be him. Oh, and as for [[User:Catfish Jim and the soapdish]]'s Rfa, it is good! I was really surprised to hear he jumped into the ring of fire without my knowing he planned to do it.. he said he didn't want to look like he might be fishing for votes, which just goes to show what a decent guy he is.. not to mention all those positive votes, and I think, 2 votes not for his Adminship, which is a really decent outcome! I thought you knew him already. You may benefit from doing so. He's been so helpful to me over the last year or so, and is a good editor as well as good at sniffing out vandalism, which is why he finally asked for the mop-- more tools in which to deal with those problems. I'm glad for him! I'll only vote in an Rfa if I ''really'' know the individual, so it's just been three times altogether. --",
#   'user': 'Leahtwosaints',
#   'meta': {'is-admin': False},
#   'reply-to': '28',
#   'timestamp': '1.305304320E09'},
#  {'id': '524315',
#   'root': '524315',
#   'text': "AnonEMouse, when you get a chance could you take a look at the material Jamesd1 has added to the article? My view is that much of it is nothing but original research....for instance, the section comparing Bailey's writing to Theosophical Society literature which is based on nothing but Bailey quotes and links that do not even mention Bailey, all held together by original research of Jamesd1. If you think I am wrong, I will not bother the others editors on this point. (thanks for making the spelling correction) ",
#   'user': 'Kwork',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189552920E09'},
#  {'id': '524316',
#   'root': '524315',
#   'text': "As an editing rule here, it's better to add to people's edits, rephrase, rearrange, etc., rather than remove their changes wholesale. That way there is some back and forth, but in general a kind of incremental progress, and the article improves. Just reverting leads to deadlock, and should be avoided. Don't insist on perfection all at once. When you find something wrong, fix it, but don't just delete it unless there really is no other choice. --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524315',
#   'timestamp': '1.189557480E09'},
#  {'id': '262173',
#   'root': '262173',
#   'text': 'How can the FAR notice be removed from [[chess]]?  I commented it out on the talk page, but it stills says \\"review\\" on the article page.  ',
#   'user': 'Bubba73',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287010080E09'},
#  {'id': '262174',
#   'root': '262173',
#   'text': "The bot will come through and close the review in a while (the schedule tends to be Wednesday and Saturday nights, but this varies sometimes). I'm going to uncomment the tag on the talk page so that it doesn't screw up the bot. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262173',
#   'timestamp': '1.287010980E09'},
#  {'id': '30',
#   'root': '30',
#   'text': 'It doesn\'t look like we\'re getting much feedback on splitting the \\"Gun laws in the United States (by state)\\" article.  I posted notices on [[Wikipedia:WikiProject Law|WikiProject Law]] and [[Wikipedia:WikiProject United States|WikiProject United States]], to no avail.--',
#   'user': 'Jax 0677',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.305965820E09'},
#  {'id': '31',
#   'root': '30',
#   'text': 'I agree, not much feedback so far.  Seven editors have commented, including you and me.  And one of the seven also posted about it on [[Wikipedia:WikiProject Firearms|WikiProject Firearms]]. <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '30',
#   'timestamp': '1.305966720E09'},
#  {'id': '32',
#   'root': '32',
#   'text': "Hi. :) I appreciate all your work in that article and particularly in your diplomatic resolution to the nationality question. Mr. Cage would like us to set the record straight, and he's provided us with a published source so that we can. I've added that his nationality is American. (It's kind an irritable blog entry, but it contains some other biographical information that you might like to incorporate: [http:\\/\\/www.roadcage.com\\/?p=60].) I just wanted to ask you, if you happen to be continuing to maintain the article as you so ably have in the past, to kind of keep an eye out for the return of Canadianism, if it should show up. Mr. Cage vigorously contests its accuracy. --",
#   'user': 'Moonriddengirl',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.306266540E09'},
#  {'id': '33',
#   'root': '32',
#   'text': 'Wow, this is great.  And I love Mr. Cage\'s explanation of his situation, and his views on the Wikipedia process from the perspective of being the subject of an article.  Thanks very much for your help with this!  <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '32',
#   'timestamp': '1.306267560E09'},
#  {'id': '262177',
#   'root': '262177',
#   'text': "Dana, [[Wikipedia talk:Featured article review\\/World Science Festival\\/archive1|this was an incorrect (bad) hack]] that occurred at FAR and only came to my attention because an error was made in the ''Signpost'', indicating the FA had been delisted.[http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Wikipedia:Wikipedia_Signpost\\/2010-10-18\\/Features_and_admins&diff=prev&oldid=391348494]  When I went to check, I found that 2009 content had simply been deleted,[http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=World_Science_Festival,_2008&diff=386458978&oldid=386458738] and the main article (notable) had gone away via a redirect to a [[World Science Festival, 2008|2008 article]].  I have done a partial cleanup, but more work is likely needed-- specifically, I don't know what else may have been deleted during the FAR, and what improvements from the 2008 version need to be restored to the main article.  I will leave a note for {{user|Dank}} and direct him to this conversation. The main article will need review to restore any changes made since 2008.  Someone else may want to update the main article to include 2010 and 2011, which are mentioned in the Festival website.  There are also dead links at the 2008 article that should have been picked up on the FAR.  ",
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287453960E09'},
#  {'id': '262178',
#   'root': '262177',
#   'text': 'You are correct that the main WSF article should exist and include information from all of the years. However, all of the reviewers (including Malleus!) agreed that the WSF 2008 article met FA standards. Most of the dead link tags were invalid - I\'ve removed those and fixed the couple of valid ones. Easy enough. The 2009 info was the only stuff deleted (AFAIK) during the FAR, but I\'m not sure what you mean by the \\"improvements from the 2008 version need to be restored to the main article\\". ',
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262177',
#   'timestamp': '1.287467340E09'},
#  {'id': '262179',
#   'root': '262177',
#   'text': "I dunno-- I may have confused myself between the two versions, but I think it's all up to snuff now!  Thanks!  I was surprised by that FAR :)  ",
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': '262178',
#   'timestamp': '1.287467520E09'},
#  {'id': '34',
#   'root': '34',
#   'text': 'Hey, I noticed [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Garcia_(album)&diff=prev&oldid=434347681 this] yesterday and was wondering if the 24.2ems should be made part of the actual template. There was a discussion on this a short while ago on the template\'s talk page, but I didn\'t think it was possible. Didn\'t occur to me to try decimals. \\u2013&nbsp;<font color=\\"#06266f\\">Ker\\u03b1u<\\/font><font color=\\"#1240AB\\">no\\u03c2co<\\/font><font color=\\"#4671DS\\">pia<\\/font><font color=\\"#A60000\\"><sup>\\u25c1<\\/sup><\\/font><i><sub><font color=\\"#5E1FFF\\">',
#   'user': 'Keraunoscopia',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.308218820E09'},
#  {'id': '35',
#   'root': '34',
#   'text': 'I missed that discussion, but I definitely think it would be very good if the default width of the template was 24.2, so that it would be (I think) the same width as the infobox.  (And as an additional point, I would also favor making \\"state=plain\\" the default.)  <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '34',
#   'timestamp': '1.308219120E09'},
#  {'id': '36',
#   'root': '34',
#   'text': 'I\'m not familiar enough with the states thing, but here\'s the discussion: [[Template_talk:Album_ratings#Width]]. It\'s not very old at all. I would support the 24.2. \\u2013&nbsp;<font color=\\"#06266f\\">Ker\\u03b1u<\\/font><font color=\\"#1240AB\\">no\\u03c2co<\\/font><font color=\\"#4671DS\\">pia<\\/font><font color=\\"#A60000\\"><sup>\\u25c1<\\/sup><\\/font><i><sub><font color=\\"#5E1FFF\\">',
#   'user': 'Keraunoscopia',
#   'meta': {'is-admin': False},
#   'reply-to': '35',
#   'timestamp': '1.308219240E09'},
#  {'id': '37',
#   'root': '34',
#   'text': 'I was wondering if the widths of the infobox and the album ratings template would vary by browser and\\/or by skin, but I didn\'t try to figure that out.  It sounds like they do.  But I think that using 24.2em would make them the same width for most readers, so I would still favor that.  As for \\"state\\", that\'s explained on the [[:Template:Album ratings]] page.  In my opinion \\"state=plain\\" would be the best default, because it displays the ratings without the options to hide or show them.  In most cases having the option is an unnecessary complication, in my view. <font face=\\"cursive\\">\\u2014 ',
#   'user': 'Mudwater',
#   'meta': {'is-admin': False},
#   'reply-to': '36',
#   'timestamp': '1.308219660E09'},
#  {'id': '38',
#   'root': '34',
#   'text': 'Oh, I remember states now. Yeah, not sure why one would collapse the template at all. Kind of a silly option. Well, when I messed around with ems, they varied between skins (I tried Vector, and I always use Modern, otherwise), and I\'m using Safari for a browser, and your 24.2 thing looked fine on Safari\\/skin=Modern, so I assume you\'ve figured out the secret width needed. Not sure how well it would work, but you could always put an infobox and the album ratings template on an otherwise-empty sandbox, then throw that URL into [http:\\/\\/browsershots.org\\/ browsershots.org] and see if the widths vary from browser to browser. They\'d all be in Vector (default) skin, I think. \\u2013&nbsp;<font color=\\"#06266f\\">Ker\\u03b1u<\\/font><font color=\\"#1240AB\\">no\\u03c2co<\\/font><font color=\\"#4671DS\\">pia<\\/font><font color=\\"#A60000\\"><sup>\\u25c1<\\/sup><\\/font><i><sub><font color=\\"#5E1FFF\\">',
#   'user': 'Keraunoscopia',
#   'meta': {'is-admin': False},
#   'reply-to': '37',
#   'timestamp': '1.308220200E09'},
#  {'id': '87387',
#   'root': '87387',
#   'text': 'Thanks for your edits to this article. The thing is, though, they didn\'t play the Australia national cricket team; they played the Australians. Apologies if you already knew this, but there\'s a rigid distinction in operation here: \\"Australia\\" as such \'\'only\'\' play international cricket; all matches against counties, universities and so on are listed as \\"Australians\\". Ditto with other countries, so that (for example) \\"Worcestershire v Pakistanis\\" doesn\'t mean any old Pakistanis, but always the national team playing a non-international match. For that reason I\'m inclined to change those edits back, but I\'ll leave it a day or two in case you want to come back at me. ',
#   'user': 'Loganberry',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.238805900E09'},
#  {'id': '87388',
#   'root': '87387',
#   'text': 'To answer the obvious question, where there is no convenient adjectival form, one just adds \\"XI\\" to the team name, so that you have \\"Barbados v England XI\\" or whatever. For historical reasons, until the 1970s, England played as \\"MCC\\" in non-international tour games. ',
#   'user': 'Loganberry',
#   'meta': {'is-admin': False},
#   'reply-to': '87387',
#   'timestamp': '1.238806140E09'},
#  {'id': '87389',
#   'root': '87387',
#   'text': "Thanks for the explanation Loganberry. I didn't know about that distinction. I'll change it back. ",
#   'user': 'Qwfp',
#   'meta': {'is-admin': False},
#   'reply-to': '87388',
#   'timestamp': '1.238806860E09'},
#  {'id': '87390',
#   'root': '87387',
#   'text': 'Thanks. As with most things cricket, the logic isn\'t perfect (eg theEngland matches against the Australian Forces in 1945 \'\'are\'\' \\"England\\", not \\"England XI\\") but it\'s usually reliable otherwise. ',
#   'user': 'Loganberry',
#   'meta': {'is-admin': False},
#   'reply-to': '87389',
#   'timestamp': '1.239397380E09'},
#  {'id': '262180',
#   'root': '262180',
#   'text': "New photo added by a drive-by to [[Marwari horse]]. Nice image, superficial image check suggests licensing is OK, but it's your article, so may want to peek.  It was in a bad spot, so I moved it, but not sure I improved matters.  ",
#   'user': 'Montanabw',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287465720E09'},
#  {'id': '262181',
#   'root': '262180',
#   'text': "Licensing isn't quite right. I've dropped a note on the editor's talk; won't remove the image for now, but if it's not cleared up shortly it'll need to go. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262180',
#   'timestamp': '1.287467160E09'},
#  {'id': '262182',
#   'root': '262180',
#   'text': "Allright, licensing fixed. All good now - it's a nice image. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262181',
#   'timestamp': '1.287468840E09'},
#  {'id': '262150',
#   'root': '262150',
#   'text': 'mamasita means lady in my native language (for not misunderstanding)--',
#   'user': 'Venerock',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286164740E09'},
#  {'id': '262151',
#   'root': '262150',
#   'text': "Took a quick peek at this.  May be a good idea to review [[List of horse breeds]] and [[Iberian horse]] to see if we already have articles (under a different spelling) for some of the breeds currently redlinked in the template.  Also not sure if we really need a nav template for this group -- WPEQ is a bit template heavy already... and I'd dread to see separate German, Italian, English and (god fobid!) USA templates, especially if we got fights going over which country claims which breed (like we have at Lipizzan!)...  The Italian, Japanese, and Indonesian horse breed articles just have extensive see also sections that cross-ref the others, or, if the Spanish horse list is too huge for a see also, we could expand [[Iberian horse]] into a list something along the lines of [[stock horse]] or [[gaited horse]].  Just a thought, and should this whole thread go over to WPEQ for more folks to discuss?  ",
#   'user': 'Montanabw',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.286195520E09'},
#  {'id': '524327',
#   'root': '524327',
#   'text': '',
#   'user': 'Vicond',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189657020E09'},
#  {'id': '524328',
#   'root': '524327',
#   'text': "Don't worry about it. I doubt many email harvesters will go digging in page histories, and don't know of any downstream sites that copy our histories, just our pages. Removing it from the page should be sufficient. --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524327',
#   'timestamp': '1.189720920E09'},
#  {'id': '262184',
#   'root': '262184',
#   'text': 'See also my discussion at [[User talk:Good Olfactory]], leading to this inquiry. --',
#   'user': 'Bsherr',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287490620E09'},
#  {'id': '262185',
#   'root': '262184',
#   'text': "I've responded at Good Olfactory's page to keep this all in one spot. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262184',
#   'timestamp': '1.287509340E09'},
#  {'id': '524330',
#   'root': '524330',
#   'text': 'My wiki mail option is working but I have to type in the following, http:\\/\\/en.wikipedia.org\\/wiki\\/Special:Emailuser\\/ plus the username to get it to do so. Anyway problem solved and please feel free to not respond to any of my messages today including the 2 I sent by email. And thanks for your help. ...',
#   'user': 'Albion moonlight',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189668060E09'},
#  {'id': '524331',
#   'root': '524330',
#   'text': "I received your 2 emails. I'm not sure I understood the second, but if it's taken care of, that's good too. :-) --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524330',
#   'timestamp': '1.189720800E09'},
#  {'id': '524332',
#   'root': '524332',
#   'text': 'What is the policy when someone writes something like [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Talk:Republic_of_Macedonia&diff=157152659&oldid=156689101 this] ? Does their IP get banned and their comment purged from the talk page? ',
#   'user': 'Capricornis',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189663740E09'},
#  {'id': '524333',
#   'root': '524332',
#   'text': 'I left a warning on their talk page. Looks like others have already removed the offensive comment. ',
#   'user': 'Videmus Omnia',
#   'meta': {'is-admin': False},
#   'reply-to': '524332',
#   'timestamp': '1.189668900E09'},
#  {'id': '524334',
#   'root': '524332',
#   'text': "They would be [[Wikipedia:blocking policy|blocked]], yes, but it looks like they haven't been repeating. [[IP address]]es are usually not [[Wikipedia:Banning policy|banned]], because an IP is usually just a number handed out by a service provider, and will be given to a different person  eventually; certainly when the person signs up with a new service provider, and sometimes even faster than that. Our acquaintaince from Perth editing on that subject has shown the ability to get a new IP number within minutes of the old one being blocked, sometimes several times a day; fortunately, however, this isn't him. --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524333',
#   'timestamp': '1.189721400E09'},
#  {'id': '524335',
#   'root': '524332',
#   'text': 'I see a similar address made a similar comment. [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Talk:Republic_of_Macedonia&diff=157578888&oldid=157499660] If it becomes a regular thing, tell me, and I will semi-protect the article talk page. That will stop all IP addresses without an account from editing there (apparently some do make non-abusive comments[http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Talk:Republic_of_Macedonia&diff=156689101&oldid=156496906]) but if we have to, we will. --',
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524334',
#   'timestamp': '1.189721700E09'},
#  {'id': '262189',
#   'root': '262189',
#   'text': 'Hi Dana.  Thanks for closing [[Wikipedia:Categories_for_discussion\\/Log\\/2010_October_14#Category:Wikipedians_open_to_whale_squishing]].  That was a decent close.  I might have said \\"no consensus for deviating from policy-based arguments\\" instead of mentioning IAR.  You put your closing note at the bottom of the debate.  That is a bit unusual.  Usually, the closing explanation goes at the top, with the close, doesn\'t it?  --',
#   'user': 'SmokeyJoe',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.287993420E09'},
#  {'id': '262190',
#   'root': '262189',
#   'text': "Hi Smokey! Thanks for the nice note! LOL, I guess I'm more used to FAR closures, where closing notes go at the bottom. Feel free to move the comment if you would like. ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262189',
#   'timestamp': '1.287993720E09'},
#  {'id': '262191',
#   'root': '262191',
#   'text': "I think you should close the first one too, as I gave it as an example of a bad FA a few times '''",
#   'user': 'YellowMonkey',
#   'meta': {'is-admin': True},
#   'reply-to': None,
#   'timestamp': '1.287993960E09'},
#  {'id': '262192',
#   'root': '262191',
#   'text': "Will do. When I closed Dorset it wasn't exactly 14 days for those. I'll get to them tomorrow morning (it's getting to be bedtime here!) Have you had a chance to check out the two I pinged you about? ",
#   'user': 'Dana boomer',
#   'meta': {'is-admin': True},
#   'reply-to': '262191',
#   'timestamp': '1.287994200E09'},
#  {'id': '524336',
#   'root': '524336',
#   'text': 'Hello, I did an edit on one of the porn stars pages and I have an editor who just joined [[wikipedia]] who is going onto the article and adding things at random. I removed the personal info like where he lives and the editor put it right back on. Then the editor made an edit and place a description as this [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Arpad_Miklos&diff=prev&oldid=157524752]. COuld you please look at this? I did go onto theri talk page and explain about putting personal info and advertisement onto an article. I hope it helps. Thank you ',
#   'user': 'Junebug52',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.189676400E09'},
#  {'id': '524337',
#   'root': '524336',
#   'text': "You have the right idea; we certainly want confirmation before accusing someone of being an escort, which is usually a euphemism for being a prostitute. However, in this case, he's apparently a prizewinning escort. (Yes, I didn't know there was a prize for that either, but it seems there is ... live and learn. I'll be making an article for the [[International Escort Awards]] soon; it got coverage from the ''[[Village Voice]]'', ''[[DNA Magazine]]'', and even a bit from the ''[[New York Daily News]]''.) Winning the prize is fairly clear confirmation that he does work as an escort. --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524336',
#   'timestamp': '1.189713300E09'},
#  {'id': '524338',
#   'root': '524336',
# ...
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524797',
#   'timestamp': '1.199745000E09'},
#  {'id': '393301',
#   'root': '393301',
#   'text': 'Nope. Thanks. --',
#   'user': 'Calton',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.180452300E09'},
#  {'id': '393302',
#   'root': '393301',
#   'text': 'OK I have an asshole stalking me. Great. ',
#   'user': 'Kappa',
#   'meta': {'is-admin': False},
#   'reply-to': '393301',
#   'timestamp': '1.180452360E09'},
#  {'id': '393303',
#   'root': '393301',
#   'text': 'Not even wrong, but thanks for playing. Oh, by the way, [[WP:NPA|this]] makes for informative reading. Remember it when you comment on the [[Wikipedia:Miscellany for deletion\\/User:Kappa\\/Kaaos|MFD discussion]]. --',
#   'user': 'Calton',
#   'meta': {'is-admin': False},
#   'reply-to': '393302',
#   'timestamp': '1.180453380E09'},
#  {'id': '393304',
#   'root': '393301',
#   'text': 'I voted to keep the material in your userspace.  However, your comments above constitue a personal attack.  Consider this a warning.  <em>&mdash;<font color=\\"Indigo\\">',
#   'user': 'Gaff',
#   'meta': {'is-admin': False},
#   'reply-to': '393303',
#   'timestamp': '1.180491660E09'},
#  {'id': '524801',
#   'root': '524801',
#   'text': "Big day for the Japanese porn project, Anon-- [[Tetsuji Takechi]]-- We've got a GA to our credit! Thank you for prodding me to go through with the process, for all your help and advice with my work here. Cheers! ",
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.199524320E09'},
#  {'id': '524802',
#   'root': '524801',
#   'text': 'Congratulations! Your next steps are either nominating another one or two for GA, or this one for FA. From recent experience, the FA review will naturally be tougher - expect about five people rather than one - but the GA will take a month and a half, rather than a week and a half, so may be more frustrating in that respect. :-) --19:49, 7 January 2008 (UTC)',
#   'user': '{unknown-9}',
#   'meta': {'is-admin': False},
#   'reply-to': '524801',
#   'timestamp': '-1'},
#  {'id': '524803',
#   'root': '524801',
#   'text': "Thanks, Anon. I read through the Takechi article after its passing, and cringed at the awkward wording... I'll keep working away at it, and eventually try it for FA, but not for a while. I think I'll try for more GAs in the meantime. I've found a good, long analysis of ''[[Wife to Be Sacrificed]]'' by a professor of Film. The article's already in fairly good shape. Think I should try for that one next? And, by the way, Happy New Year! ",
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': '524802',
#   'timestamp': '1.199776920E09'},
#  {'id': '524804',
#   'root': '524801',
#   'text': "Seems reasonable. I personally worry about the prominence given to a specific ''sixth of a second'' of film...  <small>squeamish? me?<\\/small>--",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524803',
#   'timestamp': '1.199842740E09'},
#  {'id': '524805',
#   'root': '524801',
#   'text': "Oh? Personally, I'm cackling like a mad scientist and rubbing my hands with glee at just the thought of that appearing on the main page some day... ;) ",
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': '524804',
#   'timestamp': '1.199843400E09'},
#  {'id': '515',
#   'root': '515',
#   'text': '[http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Tatsunoko_vs._Capcom:_Ultimate_All_Stars&diff=next&oldid=238961371 About this edit]. Can you tell me if this date is for the arcade or Wii version? ',
#   'user': 'FullMetal Falcon',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.242804720E09'},
#  {'id': '516',
#   'root': '515',
#   'text': "It's for the Wii version. http:\\/\\/www.1up.com\\/do\\/newsStory?cId=3169973 Why do you ask? ",
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '515',
#   'timestamp': '1.242811200E09'},
#  {'id': '517',
#   'root': '517',
#   'text': 'Out of curiosity, do you remember what \\"materials\\" [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Tatsunoko_vs._Capcom:_Ultimate_All_Stars&diff=next&oldid=231556863] Capcom released stating its number seven? ',
#   'user': 'FullMetal Falcon',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.244612040E09'},
#  {'id': '518',
#   'root': '517',
#   'text': "If I can find a source corroborating that statement, I will present it. However, the only thing I can remember is Capcom promotional materials promoting it as the continuation of the [[Marvel vs. Capcom series]], but I can't recall Capcom specifically numerating which installment it was (Seventh game would indicate that it includes the Capcom vs. SNK games, which have generally been considered as their own series, not combined with the Marvel vs. games). ",
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '517',
#   'timestamp': '1.244618220E09'},
#  {'id': '519',
#   'root': '517',
#   'text': "Ok, thanks. It doesn't seem to be too much of an issue, if you cannot find it. Its just something that bugged me since I want to collect as much information as possible. Regards, ",
#   'user': 'FullMetal Falcon',
#   'meta': {'is-admin': False},
#   'reply-to': '518',
#   'timestamp': '1.244761140E09'},
#  {'id': '524807',
#   'root': '524807',
#   'text': 'Thanks for finding a free image of [[Quanell X]] from Flickr!  It is like a late Christmas present.  How did you know to look for one??  ',
#   'user': 'Deatonjr',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.199792820E09'},
#  {'id': '524808',
#   'root': '524807',
#   'text': "You're welcome. I read the article talk page and saw the request. Why was I looking at the article talk page? I was probably clicking around following interesting links from people's user pages, or contributions, or articles. I'm not sure myself, really. :-) --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524807',
#   'timestamp': '1.199832840E09'},
#  {'id': '521',
#   'root': '521',
#   'text': 'Phew, that was quick. You beat me to [[WP:AIV]] with the report on 202.155.92.10. Persistent isn\'t s\\/he? Regards <span style=\\"text-shadow:grey 0.2em 0.2em 0.1em; class=texhtml\\"> ',
#   'user': 'Davidelit',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.253802180E09'},
#  {'id': '522',
#   'root': '521',
#   'text': "Indeed he\\/she is. I've been keeping a track of this person for over a year now; they're an Indonesian user who constantly vandalizes anime, game and movie studio articles with misinformation. He's IP jumped so many times that I don't think he'll ever be stopped. ",
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '521',
#   'timestamp': '1.253802240E09'},
#  {'id': '523',
#   'root': '521',
#   'text': 'Yes, it is a problem. 202.70.61.148 is another of the IPs. Well, let\'s see what happens. I\'ll wait to see if s\\/he is blocked before reverting again. <span style=\\"text-shadow:grey 0.2em 0.2em 0.1em; class=texhtml\\"> ',
#   'user': 'Davidelit',
#   'meta': {'is-admin': False},
#   'reply-to': '522',
#   'timestamp': '1.253803500E09'},
#  {'id': '524',
#   'root': '521',
#   'text': 'Ditto. That guy\'s persistent, I know (and annoying as well). I\'ve also encountered this guy numerous times, and I was the one who first reported him on WP:AN\\/I ([[Wikipedia:Administrators\' noticeboard\\/IncidentArchive341#Re: Big problem caused by \\"61.5.*.*\\/61.94.*.*\\" IP user|this is the report as archived]]). The guy also operated on the following ranges: 202.70.61.133, 202.70.61.146, 114.59.100.70, and the 118.137.x.x range (which I know you\'re aware already), as well as many others that I can\'t mention here as of this moment, all in Indonesia. It seems no amount of warning, not even in Indonesian, stopped him. I\'ve already told everything about this guy to [[User talk:Nja247|Nja247]], so Nja247 has oftentimes become my go-to admin whenever the vandal strikes or has striken within the last few minutes\\/hours of his last attack. - ',
#   'user': '{unknown-10}',
#   'meta': {'is-admin': False},
#   'reply-to': '523',
#   'timestamp': '1.253815620E09'},
#  {'id': '525',
#   'root': '521',
#   'text': 'I wonder if it would be possible to request multiple, long-term range blocks on the offending ranges. I know I requested such a thing from admin [[User:Nihonjoe]] a while back, and he blocked several offending ranges for 6 months, during which vandalism from this user was relatively quiet (as far as I could tell, anyway) as a result. Maybe a similar set of range blocks (hopefully for a year or longer) could deter this user. ',
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '524',
#   'timestamp': '1.253834220E09'},
#  {'id': '526',
#   'root': '521',
#   'text': "Since the 202.70.61.x range will be automatically unblocked a few minutes from now (MuZemike did the block on 202.70.61.128\\/27 a week ago as an immediate action to [[Wikipedia:Administrators' noticeboard\\/IncidentArchive564#An already big problem by misinformation vandal|my report on the vandal]]), I'm sure the vandal will show up on that range once again. - ",
#   'user': '{unknown-11}',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.253834820E09'},
#  {'id': '527',
#   'root': '521',
#   'text': "'''P. S.:''' I've already told Nja247 about 202.155.92.10, BTW. - ",
#   'user': '{unknown-12}',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.253835240E09'},
#  {'id': '262666',
#   'root': '262666',
#   'text': 'Am doing. After a cursory look, nothing jumps out\\u2014except the fact it was quite well-written :) I\'ll read more thoroughly later, but right now I can\'t fault it on anything major. I thought of perhaps breaking \\"Life\\" up into \\"Personal life\\" and \\"Work\\", but that doesn\'t seem like much of an idea; it might make those sections too short. ',
#   'user': 'Fvasconcellos',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.175132280E09'},
#  {'id': '262667',
#   'root': '262666',
#   'text': 'Catching up on the guidelines is always a good idea :) ',
#   'user': 'Fvasconcellos',
#   'meta': {'is-admin': False},
#   'reply-to': '262666',
#   'timestamp': '1.175133300E09'},
#  {'id': '262668',
#   'root': '262666',
#   'text': "Glad to have helped. I'll have to check my dictionary now, that was force of habit (and my spell-checker, set to U.S. English) ",
#   'user': 'Fvasconcellos',
#   'meta': {'is-admin': False},
#   'reply-to': '262667',
#   'timestamp': '1.175138640E09'},
#  {'id': '262669',
#   'root': '262669',
#   'text': 'There\'s some discussion going on regarding Cite News and the other cite templates on [[Template talk:Cite news|that talk page]].  Would love your input :) -- <span style=\\"background-color: #EECCFF;\\">',
#   'user': 'SatyrTN',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.175504160E09'},
#  {'id': '262670',
#   'root': '262669',
#   'text': 'Please see my reply to the ongoing discussion: the very \'\'\'last\'\'\' thing we want is people charging off in all directions using their own \\"pet\\" styles for citations. We want to get the various citation templates in such a condition that \'\'\'anybody\'\'\' can use them to produce useful citations, rather than placing further artificial restrictions and limiting citation to those \\"experts\\" who \\"know how to format citations correctly\\". We need to stop trying to follow any particular existing \\"Manual of Style\\" and synthesise our own: why else did the various \\"Manuals\\" come into being other than the particular needs of the originating situation? HTH HAND \\u2014',
#   'user': 'Phil Boswell',
#   'meta': {'is-admin': True},
#   'reply-to': '262669',
#   'timestamp': '1.175547480E09'},
#  {'id': '262671',
#   'root': '262671',
#   'text': 'OK, I admit that I got distracted because of all of my travel; can we try to finish this up and poll for consensus?  [http:\\/\\/en.wikipedia.org\\/wiki\\/Wikipedia_talk:Manual_of_Style_%28medicine-related_articles%29#Historical_.3F]  ',
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.175811180E09'},
#  {'id': '262672',
#   'root': '262671',
#   'text': "OK, enough procrastinating from me :-)  Have you noticed that I *really* hate working on policy pages ? <grin> I'd much rather edit and review articles.  I'm going to settle in to my upstairs computer and catch up on this thing, finally.  ",
#   'user': 'SandyGeorgia',
#   'meta': {'is-admin': False},
#   'reply-to': '262671',
#   'timestamp': '1.176421320E09'},
#  {'id': '529',
#   'root': '529',
#   'text': '[[Special:Contributions\\/220.255.178.29|220.255.178.29]] (',
#   'user': '220.255.178.29',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.264443540E09'},
#  {'id': '530',
#   'root': '529',
#   'text': "Because you didn't supply references for the criticisms you listed. Per the sites' [[Wikipedia:Verifiability|verifiability]] policy, any information that can be challenged has to be backed up by a [[Wikipedia:Reliable sources|reliable source]] that is cited in writing. If there is no source supplied, the material added can be removed. Find some reliable sources to cite on the issues you brought up, and what you wrote can stand. ",
#   'user': 'NeoChaosX',
#   'meta': {'is-admin': False},
#   'reply-to': '529',
#   'timestamp': '1.264458360E09'},
#  {'id': '524818',
#   'root': '524818',
#   'text': "Hi again, AnonEMouse. I've just added several [[AVN (magazine)|AVN (magazine)]] reviews\\/profiles, but for some reason the links aren't working. Since it's (I think) a print source as well, the reference is still valid. But is there a trick to linking to the online source? ",
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': None,
#   'timestamp': '1.200106500E09'},
#  {'id': '524819',
#   'root': '524818',
#   'text': 'Looking at your recent edit history, the [http:\\/\\/en.wikipedia.org\\/w\\/index.php?title=Yuki_Asuka&diff=prev&oldid=183679223 link you added to Yuki Asuka], for example, worked for me.  --',
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524818',
#   'timestamp': '1.200106740E09'},
#  {'id': '524820',
#   'root': '524818',
#   'text': 'OK-- must just be this computer. Thanks. ',
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': '524819',
#   'timestamp': '1.200107340E09'},
#  {'id': '524821',
#   'root': '524818',
#   'text': "That said, I'm not sure that every review of every film a star has appeared in is a good use of external links. Just from sheer numbers, I know Japanese stars appear in fewer films than American stars, but still, ten films, each reviewed in two magazines, that's twenty external links, and the content isn't usually very focused on the single actor our article is supposed to be about. --",
#   'user': 'AnonEMouse',
#   'meta': {'is-admin': True},
#   'reply-to': '524820',
#   'timestamp': '1.200107760E09'},
#  {'id': '524822',
#   'root': '524818',
#   'text': "Well, on these particular subjects (Suzi Suzuki excepted), these are Japanese films being reviewed in an English-language source-- pretty rare, and, I would think, some indication of international notability. Also the films are not likely to get their own articles, and most (not all) of the reviews do carry on quite a bit about the actress in question, since she's the star attraction. About Suzuki though, I've long thought she does not belong in Category Japanese porn stars. She's an actress of Japanese (I think) descent who appears in U.S. porn. These ethnic\\/nationality issues get sticky though, and removing her from the category might set off some kind of a squabbling storm... ",
#   'user': 'Dekkappai',
#   'meta': {'is-admin': False},
#   'reply-to': '524821',
#   'timestamp': '1.200108360E09'},
#  ...]

# %%
def clean_text(text):
    tokens = word_tokenize(text.lower())
    words = [word for word in tokens if word.isalnum()]
    words = [word for word in words if word not in stopwords.words("english")]
    return words

# %%
# =================
# Create Profile 1
# =================
user_texts = defaultdict(str)
for utterance in data:
    text = ''.join(utterance['text'])
    user_texts[utterance['user']] += text

top_nouns = {}
top_verbs = {}
top_adjs  = {}

all_noun_counts = {}
all_verb_counts = {}
all_adj_counts  = {}

for user, text in user_texts.items():
  doc = nlp(text)

  nouns = [token.lemma_.lower() for token in doc if token.pos_ == "NOUN" and token.is_alpha and not token.is_stop]
  verbs = [token.lemma_.lower() for token in doc if token.pos_ == "VERB" and token.is_alpha and not token.is_stop]
  adjs  = [token.lemma_.lower() for token in doc if token.pos_ == "ADJ"  and token.is_alpha and not token.is_stop]

  noun_counts = Counter(nouns)
  verb_counts = Counter(verbs)
  adj_counts  = Counter(adjs)

  top_nouns[user] = noun_counts.most_common(10)
  top_verbs[user] = verb_counts.most_common(10)
  top_adjs[user]  = adj_counts.most_common(10)

# %%
user_texts['Kyuubi29']
# Out:
# 'My computer has been hacked by someone that i think is from 4 of these websites that i go to. could you please find out who it is and tell me.'

# %%
for utt in data:
  if utt['user']=='{unknown-49}':
    print(utt)
# Out:
# {'id': '264210', 'root': '264210', 'text': 'Thanks in advance17:47, 23 July 2007 (UTC)', 'user': '{unknown-49}', 'meta': {'is-admin': False}, 'reply-to': None, 'timestamp': '-1'}

# %%
# ============
# Profile 1: Most used 10 Noun
# ============
profile1={}
for user, noun in top_nouns.items():
  profile1[user] = [item[0]for item in noun]

# %%
profile1
# Out:
# {'Frightner': ['point',
#   'template',
#   'image',
#   'domain',
#   'propaganda',
#   'upload',
#   'mind',
#   'source',
#   'grave'],
#  'Revizionist': ['photograph',
#   'material',
#   'photo',
#   'law',
#   'usage',
#   'document',
#   'purpose',
#   'act',
#   'government',
#   'citizen'],
#  'Johannes003': ['page',
#   'site',
#   'nominee',
#   'idea',
#   'section',
#   'opening',
#   'editor',
#   'film',
#   'source',
#   'ceremony'],
#  'Michael-Billa': ['fan', 'cinema', 'web', 'company', 'size', 'family'],
#  'AnonEMouse': ['article',
#   'page',
#   'talk',
#   'user',
#   'source',
#   'people',
#   'thing',
#   'image',
#   'way',
#   'edit'],
#  'FayssalF': ['thank',
#   'case',
#   'time',
#   'question',
#   'dispute',
#   'thing',
#   'cheer',
#   'community',
#   'article',
#   'group'],
#  'Venerock': ['language',
#   'thank',
#   'contribute',
#   'template',
#   'horse',
#   'article',
#   'people',
#   'edit',
#   'day',
#   'lady'],
#  'Dana boomer': ['article',
#   'page',
#   'thank',
#   'review',
#   'talk',
#   'comment',
#   'editor',
#   'image',
#   'time',
#   'source'],
#  'Kudpung': ['page',
#   'article',
#   'school',
#   'talk',
#   'user',
#   'time',
#   'policy',
#   'project',
#   'editor',
#   'discussion'],
#  'Rms125a@hotmail.com': ['edit',
#   'thank',
#   'page',
#   'article',
#   'year',
#   'way',
#   'birth',
#   'comment',
#   'summary',
#   'message'],
#  'Secret of success': ['ip',
#   'manner',
#   'website',
#   'source',
#   'mistake',
#   'contribution',
#   'couple',
#   'section',
#   'article',
#   'template'],
#  'Vensatry': ['article',
#   'user',
#   'source',
#   'page',
#   'award',
#   'film',
#   'version',
#   'day',
#   'editor',
#   'thank'],
#  'JCDenton2052': ['page',
#   'edit',
#   'image',
#   'article',
#   'content',
#   'crisis',
#   'text',
#   'talk',
#   'history',
#   'point'],
#  'Courcelles': ['notice',
#   'article',
#   'template',
#   'page',
#   'time',
#   'administrator',
#   'reviewer',
#   'deletion',
#   'image',
#   'day'],
#  'Karthikndr': ['design',
#   'page',
#   'thing',
#   'work',
#   'abit',
#   'ur',
#   'ty',
#   'info',
#   'link',
#   'asap'],
#  'Capricornis': ['article',
#   'statement',
#   'page',
#   'history',
#   'contribution',
#   'time',
#   'comment',
#   'talk',
#   'plenty',
#   'edit'],
#  'Mr. Neutron': ['comment',
#   'contribution',
#   'attack',
#   'contributor',
#   'death',
#   'thank',
#   'ad',
#   'hominem',
#   'argument',
#   'falacie'],
#  'Bollyjeff': ['article',
#   'source',
#   'film',
#   'edit',
#   'way',
#   'time',
#   'editor',
#   'page',
#   'link',
#   'thing'],
#  'Explicit': ['image',
#   'category',
#   'edit',
#   'discussion',
#   'template',
#   'page',
#   'user',
#   'article',
#   'file',
#   'deletion'],
#  'Good Olfactory': ['category',
#   'comment',
#   'user',
#   'discussion',
#   'thing',
#   'problem',
#   'way',
#   'page',
#   'editor',
#   'time'],
#  'Leahtwosaints': ['photo',
#   'page',
#   'article',
#   'album',
#   'thing',
#   'time',
#   'song',
#   'band',
#   'talk',
#   'people'],
#  'Mudwater': ['article',
#   'page',
#   'thank',
#   'template',
#   'reference',
#   'talk',
#   'infobox',
#   'rating',
#   'section',
#   'album'],
#  'YellowMonkey': ['article',
#   'lot',
#   'thank',
#   'book',
#   'people',
#   'work',
#   'bit',
#   'page',
#   'fa',
#   'talk'],
#  'Cirt': ['article',
#   'page',
#   'cheer',
#   'thank',
#   'talk',
#   'user',
#   'time',
#   'comment',
#   'discussion',
#   'image'],
#  'Mandsford': ['article',
#   'thank',
#   'school',
#   'system',
#   'question',
#   'review',
#   'moment',
#   'addition',
#   'time',
#   'people'],
#  'Anetode': ['image',
#   'article',
#   'sup',
#   'use',
#   'deletion',
#   'thank',
#   'page',
#   'copyright',
#   'disc',
#   'medium'],
#  'Kwork': ['article',
#   'editor',
#   'user',
#   'section',
#   'page',
#   'view',
#   'information',
#   'situation',
#   'look',
#   'issue'],
#  'Bubba73': ['page',
#   'article',
#   'chess',
#   'game',
#   'promotion',
#   'piece',
#   'time',
#   'pawn',
#   'list',
#   'edit'],
#  'Jax 0677': ['article', 'post', 'work', 'feedback', 'law', 'notice', 'way'],
#  'Moonriddengirl': ['article',
#   'copyright',
#   'page',
#   'content',
#   'talk',
#   'time',
#   'source',
#   'contributor',
#   'material',
#   'problem'],
#  'SandyGeorgia': ['article',
#   'page',
#   'talk',
#   'time',
#   'editor',
#   'thank',
#   'issue',
#   'review',
#   'image',
#   'problem'],
#  'Keraunoscopia': ['image',
#   'article',
#   'template',
#   'page',
#   'thank',
#   'talk',
#   'thing',
#   'way',
#   'work',
#   'change'],
#  'Loganberry': ['reason',
#   'article',
#   'cricket',
#   'thank',
#   'comment',
#   'edit',
#   'image',
#   'team',
#   'match',
#   'title'],
#  'Qwfp': ['article',
#   'thank',
#   'regard',
#   'template',
#   'source',
#   'coverage',
#   'wp',
#   'point',
#   'deletion',
#   'file'],
#  'Montanabw': ['article',
#   'horse',
#   'thing',
#   'page',
#   'time',
#   'way',
#   'thank',
#   'stuff',
#   'breed',
#   'work'],
#  'Vicond': [],
#  'Bsherr': ['template',
#   'block',
#   'talk',
#   'page',
#   'user',
#   'thank',
#   'neighborhood',
#   'convention',
#   'uw',
#   'policy'],
#  'Albion moonlight': ['article',
#   'thank',
#   'user',
#   'albion',
#   'moonlight',
#   'edit',
#   'email',
#   'help',
#   'consensus',
#   'thing'],
#  'Videmus Omnia': ['image',
#   'article',
#   'page',
#   'photo',
#   'talk',
#   'user',
#   'mail',
#   'use',
#   'thank',
#   'e'],
#  'SmokeyJoe': ['image',
#   'category',
#   'information',
#   'affair',
#   'article',
#   'subject',
#   'thank',
#   'close',
#   'closing',
#   'deletion'],
#  'Junebug52': ['article',
#   'page',
#   'editor',
#   'talk',
#   'help',
#   'subject',
#   'edit',
#   'issue',
#   'user',
#   'thank'],
#  'Djflem': ['article',
#   'thank',
#   'info',
#   'work',
#   'change',
#   'template',
#   'town',
#   'time',
#   'state',
#   'district'],
#  'PAIRdoc': ['work',
#   'thank',
#   'feedback',
#   'propensity',
#   'detail',
#   'arena',
#   'appeal',
#   'edit',
#   'article',
#   'research'],
#  'Meco': ['article',
#   'page',
#   'talk',
#   'edit',
#   'discussion',
#   'user',
#   'image',
#   'editor',
#   'category',
#   'use'],
#  'Gonzo_fan2007': ['space',
#   'image',
#   'list',
#   'photo',
#   'thank',
#   'article',
#   'page',
#   'license',
#   'copyright',
#   'draft'],
#  'Koavf': ['category',
#   'article',
#   'talk',
#   'discussion',
#   'page',
#   'album',
#   'template',
#   'thank',
#   'deletion',
#   'redirect'],
#  'Ling.Nut': ['talk',
#   'user',
#   'page',
#   'thank',
#   'question',
#   'article',
#   'time',
#   'comment',
#   'input',
#   'line'],
#  'BarkingMoon': ['article',
#   'page',
#   'bird',
#   'way',
#   'time',
#   'user',
#   'tool',
#   'standard',
#   'talk',
#   'post'],
#  '{unknown-0}': ['truth'],
#  '{unknown-1}': ['denial', 'step'],
#  'MBK004': ['article',
#   'page',
#   'edit',
#   'talk',
#   'time',
#   'ship',
#   'thing',
#   'policy',
#   'template',
#   'issue'],
#  'Howard the Duck': ['user',
#   'article',
#   'talk',
#   'list',
#   'template',
#   'thank',
#   'prose',
#   'section',
#   'score',
#   'drum'],
#  'Dream Focus': ['article',
#   'people',
#   'thing',
#   'time',
#   'page',
#   'information',
#   'consensus',
#   'deletion',
#   'reason',
#   'guideline'],
#  'Ktr101': ['page',
#   'article',
#   'thank',
#   'thing',
#   'time',
#   'way',
#   'bit',
#   'day',
#   'source',
#   'edit'],
#  'Tim Song': ['deletion',
#   'page',
#   'article',
#   'talk',
#   'template',
#   'reason',
#   'request',
#   'thank',
#   'discussion',
#   'message'],
#  'Wolfkeeper': ['topic',
#   'way',
#   'question',
#   'article',
#   'term',
#   'power',
#   'laser',
#   'close',
#   'afd',
#   'snow'],
#  'Soap': ['page',
#   'edit',
#   'user',
#   'article',
#   'people',
#   'way',
#   'talk',
#   'rfa',
#   'account',
#   'admin'],
#  'Kevin McE': ['page',
#   'article',
#   'discussion',
#   'consensus',
#   'talk',
#   'flag',
#   'list',
#   'point',
#   'evidence',
#   'name'],
#  'TenPoundHammer': ['otter',
#   'bat',
#   'clue',
#   'span',
#   'talk',
#   'user',
#   'article',
#   'page',
#   'deletion',
#   'source'],
#  'NicholasJr7': ['apology', 'course', 'forum', 'discussion'],
#  'Epbr123': ['adminship',
#   'thank',
#   'article',
#   'user',
#   'time',
#   'afd',
#   'drive',
#   'request',
#   'nomination',
#   'advice'],
#  'PumpkinSky': ['page',
#   'talk',
#   'list',
#   'article',
#   'ref',
#   'thank',
#   'user',
#   'people',
#   'section',
#   'edit'],
#  '{unknown-2}': ['source', 'tag', 'article', 'self', 'amateur'],
#  'Marine 69-71': ['article',
#   'thing',
#   'image',
#   'page',
#   'thank',
#   'people',
#   'user',
#   'time',
#   'talk',
#   'person'],
#  'Deryck Chan': ['article',
#   'reference',
#   'thank',
#   'source',
#   'edit',
#   'link',
#   'work',
#   'book',
#   'example',
#   'talk'],
#  'Tpbradbury': ['article',
#   'thank',
#   'review',
#   'wikipedia',
#   'work',
#   'image',
#   'format',
#   'page',
#   'link',
#   'period'],
#  'Kanatonian': ['thank',
#   'article',
#   'temple',
#   'history',
#   'people',
#   'cleanup',
#   'ability',
#   'month',
#   'align',
#   'padding'],
#  'Reneeholle': ['article',
#   'thank',
#   'type',
#   'information',
#   'pr',
#   'vandalism',
#   'renee',
#   'force',
#   'reason',
#   'diff'],
#  'Crisco 1492': ['thank',
#   'article',
#   'nomination',
#   'page',
#   'template',
#   'talk',
#   't',
#   'comment',
#   'picture',
#   'cheer'],
#  'Eldumpo': ['thank',
#   'list',
#   'regard',
#   'player',
#   'article',
#   'source',
#   'response',
#   'change',
#   'page',
#   'edit'],
#  'Marcd30319': ['article',
#   'operation',
#   'exercise',
#   'talk',
#   'page',
#   'history',
#   'user',
#   'command',
#   'message',
#   'issue'],
#  'Yath': ['fox', 'image', 'reason'],
#  'Oosoom': ['thank',
#   'category',
#   'article',
#   'canal',
#   'reference',
#   'map',
#   'template',
#   'image',
#   'building',
#   'icon'],
#  'Zuwxiv': ['picture', 'fox', 'rabbit'],
#  'Jrcla2': ['article',
#   'basketball',
#   'thank',
#   'template',
#   'category',
#   'coach',
#   'player',
#   'year',
#   'season',
#   'baseball'],
#  '{unknown-3}': ['notice'],
#  'Erebus555': ['thank',
#   'article',
#   'contribution',
#   'edit',
#   'scope',
#   'participant',
#   'list',
#   'project',
#   'work',
#   'editing'],
#  'Erikeltic': ['page',
#   'discussion',
#   'talk',
#   'comment',
#   'thank',
#   'editor',
#   'point',
#   'article',
#   'sock',
#   'sockpuppet'],
#  'Nymf': ['article',
#   'edit',
#   'point',
#   'view',
#   'dispute',
#   'sock',
#   'rant',
#   'couple',
#   'user',
#   'move'],
#  'Jafeluv': ['article',
#   'discussion',
#   'page',
#   'talk',
#   'thank',
#   'way',
#   'disambiguation',
#   'regard',
#   'issue',
#   'list'],
#  'Andypandy.UK': ['admin',
#   'page',
#   'backlog',
#   'user',
#   'edit',
#   'non',
#   'userbox',
#   'notice',
#   'patroller',
#   'userboxe'],
#  '{unknown-4}': ['notice'],
#  'Mlewan': ['article',
#   'picture',
#   'statue',
#   'version',
#   'common',
#   'use',
#   'copyright',
#   'law',
#   'thing',
#   'reader'],
#  'Mike Selinker': ['category',
#   'discussion',
#   'article',
#   'nomination',
#   'consensus',
#   'people',
#   'page',
#   'thing',
#   'thank',
#   'argument'],
#  'Trident13': ['article',
#   'category',
#   'editor',
#   'reference',
#   'edit',
#   'user',
#   'page',
#   'point',
#   'notability',
#   'stub'],
#  'BrianSmithson': ['article',
#   'source',
#   'page',
#   'thank',
#   'copy',
#   'information',
#   'edit',
#   'link',
#   'disambiguation',
#   'congratulation'],
#  'Doops': ['page',
#   'article',
#   'thank',
#   'redirect',
#   'arm',
#   'form',
#   'case',
#   'helm',
#   'meaning',
#   'term'],
#  'Pigsonthewing': ['template',
#   'page',
#   'talk',
#   'thank',
#   'coordinate',
#   'span',
#   'article',
#   'user',
#   'link',
#   'edit'],
#  'WilyD': ['article',
#   'people',
#   'effort',
#   'photo',
#   'page',
#   'lot',
#   'advice',
#   'thing',
#   'work',
#   'help'],
#  'Butwhatdoiknow': ['page',
#   'section',
#   'response',
#   'text',
#   'sentence',
#   'problem',
#   'edit',
#   'objection',
#   'thank',
#   'talk'],
#  'Jappalang': ['image',
#   'article',
#   'photograph',
#   'issue',
#   'copyright',
#   'file',
#   'link',
#   'look',
#   'holder',
#   'concern'],
#  'Ealdgyth': ['article',
#   'source',
#   'page',
#   'horse',
#   'stuff',
#   'time',
#   'work',
#   'thank',
#   'information',
#   'thing'],
#  'Coemgenus': ['article',
#   'thank',
#   'editor',
#   'review',
#   'page',
#   'bot',
#   'comment',
#   'question',
#   'peer',
#   'user'],
#  'harej': ['bot',
#   'talk',
#   'page',
#   'nomination',
#   'user',
#   'template',
#   'domain',
#   'people',
#   'review',
#   'section'],
#  'Pyrotec': ['article',
#   'station',
#   'time',
#   'review',
#   'page',
#   'line',
#   'user',
#   'talk',
#   'comment',
#   'thank'],
#  '86.157.195.116': ['horse',
#   'pony',
#   'inch',
#   'hand',
#   'centimetre',
#   'thing',
#   'country',
#   'website',
#   'change'],
#  'Travb': ['page',
#   'thank',
#   'talk',
#   'tag',
#   'article',
#   'user',
#   'comment',
#   'work',
#   'deletion',
#   'month'],
#  'Schaffman': ['article',
#   'fact',
#   'boundary',
#   'tag',
#   'discussion',
#   'page',
#   'base',
#   'couple',
#   'month',
#   'need'],
#  'Everyking': ['article',
#   'thank',
#   'restriction',
#   'time',
#   'election',
#   'favor',
#   'link',
#   'interest',
#   'issue',
#   'people'],
#  'Acalamari': ['page',
#   'thank',
#   'user',
#   'rollback',
#   'edit',
#   'article',
#   'admin',
#   'talk',
#   'question',
#   'vandalism'],
#  'Legolas2186': ['article',
#   'page',
#   'user',
#   'talk',
#   'edit',
#   'song',
#   'time',
#   'way',
#   'album',
#   'lead'],
#  'Glen S': ['user',
#   'page',
#   'talk',
#   'thank',
#   'request',
#   'message',
#   'thing',
#   'people',
#   'vandalism',
#   'history'],
#  'Kyo cat': ['page',
#   'talk',
#   'table',
#   'barnstar',
#   'time',
#   'tomorrow',
#   'award',
#   'user',
#   'algebra',
#   'userboxe'],
#  'GamerPro64': ['article',
#   'talk',
#   'review',
#   'page',
#   'user',
#   'thank',
#   'game',
#   'link',
#   'fa',
#   'week'],
#  'ShakespeareFan00': ['rationale',
#   'image',
#   'use',
#   'page',
#   'copyright',
#   'question',
#   'medium',
#   'template',
#   'policy',
#   'list'],
#  'Agne27': ['article',
#   'wine',
#   'stub',
#   'page',
#   'work',
#   'talk',
#   'thank',
#   'idea',
#   'time',
#   'source'],
#  'Woodym555': ['article',
#   'thank',
#   'page',
#   'section',
#   'time',
#   'list',
#   'image',
#   'comment',
#   'concern',
#   'talk'],
#  'Eaglizard': ['thank',
#   'page',
#   'talk',
#   'article',
#   'anyway',
#   'user',
#   'dash',
#   'bit',
#   'sockpuppetry',
#   'accusation'],
#  'Erik': ['film',
#   'article',
#   'page',
#   'discussion',
#   'talk',
#   'font',
#   'template',
#   'time',
#   'editor',
#   'topic'],
#  'JaGa': ['page',
#   'thank',
#   'article',
#   'link',
#   'template',
#   'list',
#   'time',
#   'script',
#   'disambig',
#   'note'],
#  'Rodhullandemu': ['page',
#   'article',
#   'editor',
#   'time',
#   'talk',
#   'cheer',
#   'thank',
#   'source',
#   'comment',
#   'opinion'],
#  'Jamesd1': ['email',
#   'section',
#   'biography',
#   'life',
#   'article',
#   'word',
#   'situation',
#   'time',
#   'response',
#   'post'],
#  'Sparklecplenty': ['article',
#   'editor',
#   'thank',
#   'section',
#   'checkout',
#   'rating',
#   'class',
#   'b',
#   'title',
#   'talk'],
#  'PamD': ['page',
#   'article',
#   'thank',
#   'category',
#   'dab',
#   'template',
#   'talk',
#   'edit',
#   'link',
#   'title'],
#  'Derek Andrews': ['thank',
#   'article',
#   'user',
#   'reference',
#   'link',
#   'talk',
#   'info',
#   'photo',
#   'area',
#   'look'],
#  'Max Schwarz': ['icon',
#   'description',
#   'sense',
#   'common',
#   'category',
#   'railway'],
#  'Jimfbleak': ['article',
#   'thank',
#   'image',
#   'bird',
#   'edit',
#   'page',
#   'reason',
#   'bit',
#   'source',
#   'specie'],
#  'SilkTork': ['article',
#   'background',
#   'color',
#   'discussion',
#   'span',
#   'brewery',
#   'beer',
#   'people',
#   'category',
#   'comment'],
#  'WesleyDodds': ['article',
#   'page',
#   'band',
#   'rock',
#   'song',
#   'source',
#   'album',
#   'section',
#   'book',
#   'time'],
#  'Betacommand': ['page',
#   'category',
#   'image',
#   'deletion',
#   'bot',
#   'comment',
#   'article',
#   'list',
#   'user',
#   'medium'],
#  'Parrot of Doom': ['class',
#   'shadow',
#   'article',
#   'source',
#   'thing',
#   'image',
#   'bit',
#   'time',
#   'page',
#   'talk'],
#  'Slomox': ['image',
#   'fox',
#   'language',
#   'support',
#   'creator',
#   'description',
#   'eye',
#   'chain',
#   'rabbit',
#   'clarification'],
#  'Dragon695': ['image',
#   'article',
#   'organization',
#   'way',
#   'common',
#   'use',
#   'right',
#   'reason',
#   'directory',
#   'example'],
#  '{unknown-5}': ['place', 'foot', 'snow', 'time', 'worry'],
#  'Mark Wheaver': ['category',
#   'building',
#   'entry',
#   'problem',
#   'change',
#   'revert',
#   'church',
#   'article',
#   'clanger',
#   'listing'],
#  'Catherineyronwode': ['cat',
#   'page',
#   'thank',
#   'folk',
#   'article',
#   'note',
#   'merge',
#   'proposal',
#   'comment',
#   'person'],
#  'Barneca': ['page',
#   'talk',
#   'thank',
#   'comment',
#   'people',
#   'block',
#   'feedback',
#   'threat',
#   'day',
#   'rfa'],
#  'Lightmouse': ['template',
#   'thank',
#   'spelling',
#   'unit',
#   'article',
#   'issue',
#   'edit',
#   'example',
#   'people',
#   'page'],
#  '{unknown-6}': ['rule',
#   'knowledge',
#   'source',
#   'system',
#   'adherence',
#   'writing',
#   'article',
#   'editor',
#   'subject',
#   'work'],
#  'Ronhjones': ['page',
#   'file',
#   'copyright',
#   'image',
#   'permission',
#   'user',
#   'question',
#   'editor',
#   'evidence',
#   'deletion'],
#  'Malleus_Fatuorum': ['article',
#   'thing',
#   'time',
#   'editor',
#   'way',
#   'review',
#   'bit',
#   'point',
#   'work',
#   'page'],
#  'France3470': ['page',
#   'article',
#   'item',
#   'link',
#   'dab',
#   'information',
#   'time',
#   'talk',
#   'disambiguation',
#   'title'],
#  'Dr. Blofeld': ['article',
#   'time',
#   'page',
#   'source',
#   'people',
#   'list',
#   'editor',
#   'work',
#   'film',
#   'stub'],
#  'Bob1960evens': ['bridge',
#   'map',
#   'page',
#   'thank',
#   'railway',
#   'article',
#   'source',
#   'icon',
#   'bit',
#   'template'],
#  'Ryecatcher773': ['article',
#   'year',
#   'time',
#   'editor',
#   'issue',
#   'abbreviation',
#   'convention',
#   'case',
#   'member',
#   'edit'],
#  'QuiteUnusual': ['article',
#   'thank',
#   'deletion',
#   'protection',
#   'template',
#   'ad',
#   'admin',
#   'request',
#   'page',
#   'vandalism'],
#  'Thomas888b': ['thank',
#   'question',
#   'interest',
#   'signpost',
#   'support',
#   'project',
#   'note',
#   'status',
#   'align',
#   'border'],
#  'Warlordjohncarter': ['article',
#   'category',
#   'project',
#   'assessment',
#   'class',
#   'today',
#   'editor',
#   'way',
#   'section',
#   'subject'],
#  'Enigmaman': ['talk',
#   'article',
#   'edit',
#   'account',
#   'page',
#   'time',
#   'block',
#   'thank',
#   'user',
#   'warning'],
#  'NHRHS2010': ['user',
#   'talk',
#   'vandal',
#   'page',
#   'align',
#   'border',
#   'calamari',
#   'day',
#   'today',
#   'video'],
#  'Canuckle': ['article',
#   'school',
#   'shooting',
#   'redirect',
#   'consensus',
#   'thank',
#   'user',
#   'series',
#   'deletion',
#   'discussion'],
#  'Nburden': ['point', 'list'],
#  'Cosprings': ['way',
#   'info',
#   'g',
#   'funk',
#   'hip',
#   'hop',
#   'action',
#   'people',
#   'thing',
#   'discography'],
#  'CronopioFlotante': ['citation',
#   'index',
#   'h',
#   'counting',
#   'point',
#   'impact',
#   'field',
#   'number',
#   'journal',
#   'report'],
#  'Crusio': ['journal',
#   'article',
#   'project',
#   'page',
#   'category',
#   'tag',
#   'thank',
#   'time',
#   'notability',
#   'deletion'],
#  'Futurebird': ['page',
#   'article',
#   'ban',
#   'evidence',
#   'source',
#   'kind',
#   'point',
#   'thank',
#   'project',
#   'fertility'],
#  'Jnc': ['page',
#   'talk',
#   'article',
#   'thank',
#   'way',
#   'thing',
#   'redirect',
#   'problem',
#   'history',
#   'deletion'],
#  'AEMoreira042281': ['picture',
#   'page',
#   'link',
#   'article',
#   'pic',
#   'file',
#   'move',
#   'convention',
#   'question',
#   'sequence'],
#  'Blackjays1': ['single',
#   'artist',
#   'review',
#   'user',
#   'case',
#   'navboxe',
#   'rhyme',
#   'article',
#   'sense',
#   'chart'],
#  'Bellagio99': ['page',
#   'article',
#   'edit',
#   'day',
#   'thank',
#   'time',
#   'word',
#   'religion',
#   'user',
#   'life'],
#  'Bencherlite': ['category',
#   'regard',
#   'thank',
#   'article',
#   'page',
#   'discussion',
#   'comment',
#   'list',
#   'talk',
#   'user'],
#  'DustFormsWords': ['article',
#   'review',
#   'page',
#   'talk',
#   'concern',
#   'nomination',
#   'time',
#   'work',
#   'problem',
#   'issue'],
#  '70.137.161.241': [],
#  'TimVickers': ['article',
#   'page',
#   'thank',
#   'editor',
#   'time',
#   'people',
#   'talk',
#   'edit',
#   'problem',
#   'bit'],
#  'Miyagawa': ['article',
#   'template',
#   'archive',
#   'state',
#   'prose',
#   'section',
#   'way',
#   'thank',
#   'stub',
#   'regard'],
#  'Parsifal': ['page',
#   'article',
#   'talk',
#   'number',
#   'reference',
#   'thank',
#   'note',
#   'comment',
#   'content',
#   'paragraph'],
#  'WebHamster': ['article',
#   'page',
#   'thank',
#   'notability',
#   'charity',
#   'user',
#   'time',
#   'use',
#   'creator',
#   'copyright'],
#  'Rocky.liu': ['talk',
#   'page',
#   'project',
#   'code',
#   'article',
#   'semester',
#   'mentor',
#   'assignment',
#   'item'],
#  'Dwanyewest': ['article',
#   'way',
#   'rider',
#   'tv',
#   'series',
#   'title',
#   'planet',
#   'evidence',
#   'existence',
#   'year'],
#  'Mgoodyear': ['way',
#   'article',
#   'reference',
#   'lot',
#   'people',
#   'text',
#   'work',
#   'date',
#   'comment',
#   'vendetta'],
#  'Sonic99': ['edit',
#   'skin',
#   'hair',
#   'truth',
#   'ya',
#   'black',
#   'ancestry',
#   'link',
#   'information'],
#  'Nagasheus': ['man',
#   'ancestry',
#   'proposal',
#   'day',
#   'project',
#   'participant',
#   'luck',
#   'participation',
#   'work'],
#  'Yamla': ['image',
#   'use',
#   'page',
#   'article',
#   'link',
#   'rationale',
#   'copyright',
#   'user',
#   'screenshot',
#   'case'],
#  'TaerkastUA': ['thank',
#   'chairman',
#   'article',
#   'page',
#   'talk',
#   'work',
#   'role',
#   'bit',
#   'stuff',
#   'deal'],
#  'Dekkappai': ['article',
#   'thank',
#   'editor',
#   'film',
#   'time',
#   'edit',
#   'subject',
#   'deletion',
#   'page',
#   'project'],
#  'DsgnWrte': [],
#  'Smallman12q': ['template',
#   'article',
#   'menu',
#   'page',
#   'script',
#   'thank',
#   'citation',
#   'support',
#   'datum',
#   'lot'],
#  'TheJazzDalek': ['article',
#   'link',
#   'navbox',
#   'way',
#   'rap',
#   'template',
#   'musician',
#   'consensus',
#   'box',
#   'version'],
#  '67.101.7.21': ['talk',
#   'article',
#   'review',
#   'issue',
#   'work',
#   'progress',
#   'time',
#   'look',
#   'information',
#   'comment'],
#  'Raul654': ['article',
#   'page',
#   'comment',
#   'link',
#   'blurb',
#   'talk',
#   'edit',
#   'thing',
#   'list',
#   'case'],
#  'Bearcat': ['article',
#   'category',
#   'list',
#   'page',
#   'title',
#   'thank',
#   'link',
#   'way',
#   'convention',
#   'station'],
#  'Steven Walling': ['family',
#   'article',
#   'thank',
#   'policy',
#   'school',
#   'work',
#   'source',
#   'deletion',
#   'account',
#   'time'],
#  'AndonicO': ['user',
#   'talk',
#   'basepagename',
#   'picture',
#   'thank',
#   'film',
#   'userpage',
#   'family',
#   'tree',
#   'link'],
#  'Sasuke-kun27': ['user',
#   'page',
#   'thank',
#   'talk',
#   'award',
#   'article',
#   'time',
#   'problem',
#   'edit',
#   'thing'],
#  '66.245.126.161': ['edit', 'x', 'kind', 'z', 'version', 'section'],
#  'Benc': ['mediator',
#   'mind',
#   'twin',
#   'edit',
#   'issue',
#   'talk',
#   'cross',
#   'dressing',
#   'catch',
#   'discussion'],
#  'Moxy': ['article',
#   'people',
#   'page',
#   'music',
#   'talk',
#   'project',
#   'time',
#   'link',
#   'number',
#   'guy'],
#  'The Rambling Man': ['article',
#   'thank',
#   'comment',
#   'list',
#   'page',
#   'time',
#   'cheer',
#   'day',
#   'review',
#   'discussion'],
#  'Woody': ['regard',
#   'article',
#   'discussion',
#   'thank',
#   'talk',
#   'page',
#   'edit',
#   'template',
#   'issue',
#   'time'],
#  'Ruhrfisch': ['thank',
#   'article',
#   'page',
#   'map',
#   'image',
#   'talk',
#   'review',
#   'user',
#   'day',
#   'peer'],
#  'Wilhelmina Will': ['article',
#   'page',
#   'thank',
#   'day',
#   'greeting',
#   'user',
#   'source',
#   'talk',
#   'information',
#   'time'],
#  'Trilobitealive': ['plant',
#   'article',
#   'perception',
#   'page',
#   'theory',
#   'biocommunication',
#   'week',
#   'paranormal',
#   'way',
#   'var'],
#  'IceCreamAntisocial': ['thank',
#   'reference',
#   'spot',
#   'align',
#   'border',
#   'user',
#   'appreciation',
#   'plant',
#   'photo',
#   'fun'],
#  'ThatPeskyCommoner': ['horse',
#   'sample',
#   'history',
#   'thing',
#   'time',
#   'page',
#   'stuff',
#   'coat',
#   'spot',
#   'article'],
#  'Xornok': ['rescue',
#   'op',
#   'reason',
#   'page',
#   'title',
#   'idea',
#   'word',
#   'episode',
#   'reference',
#   'company'],
#  'tone': ['article',
#   'greeting',
#   'regard',
#   'deletion',
#   'problem',
#   'content',
#   'time',
#   'reference',
#   'notability',
#   'prod'],
#  'Jackhynes': ['article',
#   'cheer',
#   'specie',
#   'habitat',
#   'page',
#   'issue',
#   'reviewer',
#   'look',
#   'comment',
#   'section'],
#  'Flyer22': ['article',
#   'talk',
#   'page',
#   'editor',
#   'user',
#   'time',
#   'discussion',
#   'source',
#   'people',
#   'way'],
#  'CorenSearchBot': ['talk',
#   'template',
#   'content',
#   'material',
#   'source',
#   'bot',
#   'similarity',
#   'case',
#   'tag',
#   'message'],
#  'Jesanj': ['thank',
#   'cost',
#   'talk',
#   'theory',
#   'insurer',
#   'price',
#   'care',
#   'link',
#   'study',
#   'fact'],
#  'LeadSongDog': ['edit',
#   'article',
#   'source',
#   'template',
#   'spelling',
#   'talk',
#   'citation',
#   'thank',
#   'case',
#   'number'],
#  'Jackaranga': ['article',
#   'deletion',
#   'image',
#   'tag',
#   'thank',
#   'case',
#   'order',
#   'command',
#   'sentence',
#   'unit'],
#  'Rcej': ['image',
#   'nomination',
#   'hook',
#   'article',
#   'page',
#   'issue',
#   'color',
#   'thank',
#   'section',
#   'submission'],
#  '{unknown-7}': ['reason',
#   'thank',
#   'rearranging',
#   'removal',
#   'house',
#   'price',
#   'people',
#   'type',
#   'lifestyle',
#   'guy'],
#  'Victuallers': ['article',
#   'thank',
#   'page',
#   'school',
#   'user',
#   'image',
#   'museum',
#   'wiki',
#   'source',
#   'link'],
#  'Arhugefan': ['manga', 'image', 'problem', 'lisense'],
#  'Cool Hand Luke': ['article',
#   'category',
#   'comment',
#   'stub',
#   'day',
#   'user',
#   'work',
#   'apostle',
#   'edit',
#   'time'],
#  'Ikkyu2': ['carbamazepine',
#   'article',
#   'way',
#   'epilepsy',
#   'evidence',
#   'oxcarbazepine',
#   'metabolite',
#   'time',
#   'look',
#   'patient'],
#  'Colin': ['article',
#   'page',
#   'talk',
#   'time',
#   'source',
#   'thank',
#   'list',
#   'review',
#   'text',
#   'cheer'],
#  'ErgoSum88': ['article',
#   'family',
#   'thing',
#   'editor',
#   'thank',
#   'problem',
#   'page',
#   'reason',
#   'talk',
#   'time'],
#  'Davemeistermoab': ['work',
#   'article',
#   'admin',
#   'use',
#   'term',
#   'website',
#   'time',
#   'way',
#   'font',
#   'janitor'],
#  'Realkyhick': ['article',
#   'page',
#   'deletion',
#   'notability',
#   'tag',
#   'day',
#   'time',
#   'template',
#   'notice',
#   'thank'],
#  '{unknown-8}': ['fuzzform'],
#  'Fuzzform': ['citation',
#   'reference',
#   'code',
#   'article',
#   'word',
#   'section',
#   'page',
#   'way',
#   'search',
#   'link'],
#  'Rschen7754': ['article',
#   'template',
#   'problem',
#   'thing',
#   'assessment',
#   'road',
#   'newsletter',
#   'time',
#   'discussion',
#   'infobox'],
#  'Moabdave': ['thank',
#   'time',
#   'article',
#   'state',
#   'town',
#   'day',
#   'review',
#   'route',
#   'policy',
#   'highway'],
#  'Durova': ['article',
#   'editor',
#   'people',
#   'thing',
#   'time',
#   'user',
#   'talk',
#   'faith',
#   'page',
#   'post'],
#  'Bradadkins274': ['signature', 'thing'],
#  'Dethomas': ['image',
#   'regard',
#   'page',
#   'question',
#   'use',
#   'medium',
#   'article',
#   'list',
#   'link',
#   'box'],
#  'Brossow': ['san',
#   'article',
#   'image',
#   'line',
#   'time',
#   'information',
#   'research',
#   'discussion',
#   'vote',
#   'reference'],
#  'Imzadi1979': ['article',
#   'highway',
#   'family',
#   'san',
#   'project',
#   'list',
#   'talk',
#   'page',
#   'class',
#   'comment'],
#  'Laser_brain': ['time',
#   'article',
#   'page',
#   'work',
#   'sock',
#   'thank',
#   'comment',
#   'editor',
#   'block',
#   'source'],
#  'SMasters': ['article',
#   'thank',
#   'question',
#   'cheer',
#   'page',
#   'work',
#   'contribution',
#   'crown',
#   'project',
#   'vroom'],
#  'Finetooth': ['article',
#   'list',
#   'page',
#   'thank',
#   'map',
#   'review',
#   'stream',
#   'section',
#   'thing',
#   'peer'],
#  'Ender3057': ['authority',
#   'script',
#   'fool',
#   'doctor',
#   'assurance',
#   'phone',
#   'patient',
#   'guideline'],
#  'Eternal Equinox': ['user', 'finlay', 'talk', 'page', 'watchlist', 'edit'],
#  'CL': ['congratulation', 'fa'],
#  'Midgley': ['article',
#   'thing',
#   'effect',
#   'source',
#   'people',
#   'bit',
#   'time',
#   'science',
#   'page',
#   'use'],
#  'TomasBat': ['day',
#   'award',
#   'consensus',
#   'thank',
#   'rollback',
#   'list',
#   'diff',
#   'spirit',
#   'nomination',
#   'status'],
#  'Aldux': ['article',
#   'time',
#   'user',
#   'editor',
#   'source',
#   'thank',
#   'edit',
#   'sock',
#   'problem',
#   'work'],
#  'NortyNort': ['article',
#   'dam',
#   'project',
#   'source',
#   'page',
#   'text',
#   'category',
#   'edit',
#   'thank',
#   'lot'],
#  'SWAdair': ['article',
#   'page',
#   'time',
#   'edit',
#   'user',
#   'talk',
#   'link',
#   'way',
#   'vandalism',
#   'people'],
#  'Stevouk': ['lot', 'ref', 'date', 'narrative'],
#  'Morhange': ['version', 'page', 'epileptic'],
#  'Sarranduin': ['thank',
#   'example',
#   'article',
#   'organization',
#   'action',
#   'head',
#   'formatting',
#   'size',
#   'heading',
#   'deviation'],
#  'Fredddie': ['list',
#   'template',
#   'article',
#   'idea',
#   'route',
#   'banner',
#   'shield',
#   'interchange',
#   'time',
#   'couple'],
#  'Masterpiece2000': ['regard',
#   'category',
#   'article',
#   'scientist',
#   'contribution',
#   'page',
#   'user',
#   'talk',
#   'reply',
#   'people'],
#  'Nick Garvey': ['deletion',
#   'article',
#   'notice',
#   'process',
#   'criterion',
#   'talk',
#   'tag',
#   'template',
#   'contribution',
#   'inclusion'],
#  'Kappa': ['article',
#   'school',
#   'page',
#   'discussion',
#   'list',
#   'vote',
#   'thank',
#   'tag',
#   'criterion',
#   'coverage'],
#  'Sambc': ['proxy',
#   'policy',
#   'consensus',
#   'lot',
#   'comment',
#   'place',
#   'sense',
#   'behaviour',
#   'way',
#   'point'],
#  'Ntsimp': ['thank',
#   'photo',
#   'way',
#   'couple',
#   'week',
#   'info',
#   'article',
#   'ghost',
#   'town',
#   'year'],
#  'Rune.welsh': ['user',
#   'comment',
#   'page',
#   'regard',
#   'link',
#   'list',
#   'section',
#   'talk',
#   'subject',
#   'contribution'],
#  'Renata3': ['article',
#   'image',
#   'page',
#   'source',
#   'island',
#   'map',
#   'city',
#   'thing',
#   'list',
#   'issue'],
#  'Tony1': ['page',
#   'article',
#   'time',
#   'talk',
#   'thank',
#   'people',
#   'issue',
#   'edit',
#   'link',
#   'text'],
#  'Photouploaded': ['pseudonym',
#   'article',
#   'order',
#   'name',
#   'people',
#   'practice'],
#  'Mike_Searson': ['article',
#   'movie',
#   'list',
#   'source',
#   'thought',
#   'song',
#   'handful',
#   'art',
#   'piece',
#   'help'],
#  'Ugen64': ['user',
#   'page',
#   'policy',
#   'image',
#   'reason',
#   'troll',
#   'evidence',
#   'article',
#   'deletion',
#   'talk'],
#  'NeoChaosX': ['game',
#   'issue',
#   'article',
#   'source',
#   'range',
#   'page',
#   'user',
#   'content',
#   'policy',
#   'site'],
#  'GoodDay': ['article',
#   'page',
#   'editor',
#   'diacritic',
#   'time',
#   'user',
#   'infoboxe',
#   'discussion',
#   'thing',
#   'election'],
#  'Garion96': ['article',
#   'image',
#   'copyright',
#   'page',
#   'template',
#   'edit',
#   'talk',
#   'deletion',
#   'category',
#   'list'],
#  'Mafia Expert': ['image',
#   'background',
#   'medium',
#   'rule',
#   'rationale',
#   'article',
#   'deletion',
#   'title',
#   'entry',
#   'message'],
#  'Fvasconcellos': ['article',
#   'page',
#   'thank',
#   'image',
#   'time',
#   'look',
#   'way',
#   'edit',
#   'talk',
#   'day'],
#  'Garyvdm': [],
#  'Disavian': ['article',
#   'category',
#   'list',
#   'talk',
#   'user',
#   'reference',
#   'look',
#   'image',
#   'way',
#   'quality'],
#  'Canadian Paul': ['article',
#   'cheer',
#   'page',
#   'deletion',
#   'time',
#   'talk',
#   'source',
#   'discussion',
#   'comment',
#   'issue'],
#  '76.199.65.126': ['thank',
#   'care',
#   'paragraph',
#   'bit',
#   'line',
#   'family',
#   'comment',
#   'content',
#   'edit',
#   'help'],
#  'Aguerriero': ['article',
#   'page',
#   'list',
#   'case',
#   'thank',
#   'talk',
#   'citation',
#   'admin',
#   'template',
#   'strategy'],
#  'Stevenfruitsmaak': ['article',
#   'thank',
#   'mail',
#   'study',
#   'e',
#   'image',
#   'work',
#   'epilepsy',
#   'page',
#   'copy'],
#  'Peteforsyth': ['article',
#   'page',
#   'edit',
#   'thank',
#   'discussion',
#   'time',
#   'work',
#   'bit',
#   'image',
#   'talk'],
#  'Tabercil': ['article',
#   'image',
#   'source',
#   'page',
#   'user',
#   'talk',
#   'list',
#   'photo',
#   'picture',
#   'information'],
#  'Nick Graves': ['page',
#   'redirect',
#   'thank',
#   'suggestion',
#   'rewrite',
#   'lead',
#   'criterion',
#   'section',
#   'list',
#   'lowercase'],
#  'Tompw': ['list',
#   'thank',
#   'comment',
#   'election',
#   'map',
#   'image',
#   'county',
#   'nomination',
#   'page',
#   'equivilant'],
#  'Lar': ['page',
#   'thank',
#   'talk',
#   'user',
#   'question',
#   'thing',
#   'admin',
#   'article',
#   'case',
#   'time'],
#  'Larbot': ['user',
#   'admin',
#   'thing',
#   'mistake',
#   'sock',
#   'page',
#   'entry',
#   'finding',
#   'request',
#   'jzg'],
#  'Remember': ['article',
#   'help',
#   'thank',
#   'review',
#   'list',
#   'coach',
#   'source',
#   'basketball',
#   'look',
#   'head'],
#  'Scorpion0422': ['page',
#   'article',
#   'list',
#   'thank',
#   'image',
#   'episode',
#   'time',
#   'season',
#   'character',
#   'way'],
#  'NJMauthor': ['article', 'edit', 'content'],
#  'JuJube': ['thank',
#   'article',
#   'editor',
#   'acceptance',
#   'concern',
#   'anger',
#   'ability',
#   'history',
#   'wp',
#   'user'],
#  'Luna Santin': ['user',
#   'page',
#   'talk',
#   'family',
#   'thank',
#   'time',
#   'block',
#   'comment',
#   'account',
#   'policy'],
#  'Best O Fortuna': ['thank',
#   'talk',
#   'thnk',
#   'time',
#   'message',
#   'page',
#   'age',
#   'record',
#   'thought',
#   'source'],
#  'Davidkevin': ['dozen',
#   'people',
#   'discussion',
#   'comment',
#   'notability',
#   'author',
#   'book',
#   'work',
#   'gap',
#   'politic'],
#  'Rick570': ['thank',
#   'article',
#   'time',
#   'law',
#   'course',
#   'help',
#   'crime',
#   'aspect',
#   'rule',
#   'statute'],
#  'EveryDayJoe45': ['thing',
#   'category',
#   'discussion',
#   'page',
#   'template',
#   'maker',
#   'crystal',
#   'ball',
#   'rule',
#   'speculation'],
#  'Tourskin': ['comment',
#   'talk',
#   'page',
#   'game',
#   'day',
#   'discussion',
#   'pleasure',
#   'time',
#   'problem',
#   'way'],
#  'Calton': ['page',
#   'user',
#   'policy',
#   'way',
#   'action',
#   'thing',
#   'message',
#   'request',
#   'deletion',
#   'ability'],
#  'Gaff': ['material',
#   'userspace',
#   'comment',
#   'attack',
#   'warning',
#   'debate',
#   'afd',
#   'article',
#   'align',
#   'border'],
#  '{unknown-9}': ['half',
#   'congratulation',
#   'step',
#   'experience',
#   'review',
#   'people',
#   'month',
#   'week',
#   'respect'],
#  'FullMetal Falcon': ['thank',
#   'article',
#   'button',
#   'date',
#   'information',
#   'regard',
#   'development',
#   'source',
#   'view',
#   'angle'],
#  'Deatonjr': ['thank', 'image', 'quanell', 'x', 'present'],
#  'Davidelit': ['article',
#   'page',
#   'way',
#   'election',
#   'regard',
#   'reference',
#   'time',
#   'thank',
#   'book',
#   'bit'],
#  '{unknown-10}': ['guy',
#   'range',
#   'ditto',
#   'persistent',
#   'time',
#   'administrator',
#   'problem',
#   'report',
#   'moment',
#   'warning'],
#  '{unknown-11}': ['range',
#   'vandal',
#   'minute',
#   'block',
#   'week',
#   'action',
#   'administrator',
#   'problem',
#   'misinformation',
#   'report'],
#  '{unknown-12}': [],
#  'SatyrTN': ['color',
#   'span',
#   'article',
#   'thank',
#   'page',
#   'category',
#   'talk',
#   'bot',
#   'list',
#   'project'],
#  'Phil Boswell': ['article',
#   'citation',
#   'template',
#   'hand',
#   'thing',
#   'people',
#   'talk',
#   'infobox',
#   'discussion',
#   'situation'],
#  '220.255.178.29': [],
#  'Jongleur100': ['edit',
#   'cheer',
#   'link',
#   'page',
#   'thank',
#   'article',
#   'time',
#   'bit',
#   'name',
#   'county'],
#  'Ronz': ['article',
#   'talk',
#   'page',
#   'discussion',
#   'problem',
#   'edit',
#   'editor',
#   'link',
#   'comment',
#   'time'],
#  'GTBacchus': ['page',
#   'people',
#   'article',
#   'way',
#   'talk',
#   'time',
#   'thing',
#   'editor',
#   'question',
#   'thank'],
#  '78.149.71.17': ['example'],
#  'Iss246': ['school',
#   'violence',
#   'link',
#   'entry',
#   'reader',
#   'article',
#   'library',
#   'style',
#   'vandalism',
#   'site'],
#  'DO11.10': ['article',
#   'thank',
#   'user',
#   'template',
#   'page',
#   'bit',
#   'talk',
#   'series',
#   'version',
#   'information'],
#  'Wildhartlivie': ['article',
#   'page',
#   'editor',
#   'edit',
#   'thank',
#   'talk',
#   'time',
#   'issue',
#   'thing',
#   'source'],
#  'DarkPhoenix': ['edit',
#   'article',
#   'problem',
#   'character',
#   'reversion',
#   'mechanism',
#   'user',
#   'revert'],
#  'MarcoTolo': ['aureus',
#   'work',
#   'edit',
#   'case',
#   'loss',
#   'way',
#   'specie',
#   'portion',
#   'thank',
#   'time'],
#  'Dagoldman': ['job', 'polio', 'survivor', 'list'],
#  'Mark83': ['profit',
#   'company',
#   'thank',
#   'source',
#   'arrow',
#   'template',
#   'reference',
#   'revenue',
#   'evidence',
#   'subsidiary'],
#  'Andy Dingley': ['article',
#   'content',
#   'edit',
#   'editor',
#   'page',
#   'way',
#   'thank',
#   'category',
#   'discussion',
#   'image'],
#  'Muhandes': ['article',
#   'regard',
#   'edit',
#   'source',
#   'page',
#   'time',
#   'certification',
#   'list',
#   'talk',
#   'case'],
#  'Lou Sander': ['article',
#   'edit',
#   'stuff',
#   'page',
#   'material',
#   'source',
#   'people',
#   'time',
#   'talk',
#   'word'],
#  'Prisonnet': ['change', 'decision'],
#  'Arcadian': ['article',
#   'page',
#   'template',
#   'talk',
#   'link',
#   'question',
#   'edit',
#   'reference',
#   'image',
#   'category'],
#  'Eubulides': ['thank',
#   'article',
#   'time',
#   'comment',
#   'problem',
#   'template',
#   'page',
#   'talk',
#   'response',
#   'edit'],
#  'Master of Puppets': ['user',
#   'talk',
#   'cheer',
#   'thank',
#   'time',
#   'thing',
#   'page',
#   'day',
#   'edit',
#   'request'],
#  'Nczempin': ['article',
#   'section',
#   'deletion',
#   'tool',
#   'look',
#   'game',
#   'language',
#   'page',
#   'process',
#   'discussion'],
#  'Greyhood': ['article',
#   'task',
#   'force',
#   'page',
#   'item',
#   'image',
#   'list',
#   'talk',
#   'template',
#   'project'],
#  'Offliner': ['topic',
#   'violation',
#   'dispute',
#   'thank',
#   'ban',
#   'claim',
#   'article',
#   'kind',
#   'republic',
#   'need'],
#  'EdJohnston': ['article',
#   'talk',
#   'page',
#   'edit',
#   'user',
#   'editor',
#   'thank',
#   'discussion',
#   'case',
#   'comment'],
#  'Asperchu': ['allegation', 'group'],
#  'Mateo SA': ['revert', 'issue', 'idea', 'thank'],
#  'Male1979': ['page',
#   'size',
#   'people',
#   'article',
#   'comment',
#   'discussion',
#   'guy',
#   'agreement',
#   'change',
#   'template'],
#  "Sabine's Sunbird": ['article',
#   'page',
#   'editor',
#   'thing',
#   'specie',
#   'bird',
#   'image',
#   'way',
#   'thank',
#   'taxonomy'],
#  'Aoi': ['redirect',
#   'page',
#   'link',
#   'article',
#   'edit',
#   'instruction',
#   'thank',
#   'case',
#   'way',
#   'advice'],
#  'Marshman': ['article',
#   'page',
#   'thing',
#   'specie',
#   'link',
#   'term',
#   'point',
#   'word',
#   'problem',
#   'way'],
#  'Ezhiki': ['article',
#   'page',
#   'category',
#   'way',
#   'guideline',
#   'time',
#   'thing',
#   'template',
#   'place',
#   'case'],
#  'Nanobear': ['article',
#   'page',
#   'source',
#   'script',
#   'task',
#   'force',
#   'tag',
#   'time',
#   'week',
#   'scheme'],
#  'Jfdwolff': ['article',
#   'thank',
#   'comment',
#   'section',
#   'work',
#   'source',
#   'user',
#   'edit',
#   'page',
#   'content'],
#  'Andy F': ['article',
#   'page',
#   'map',
#   'thank',
#   'wish',
#   'viaduct',
#   'talk',
#   'station',
#   'comment',
#   'user'],
#  'Fences and windows': ['article',
#   'source',
#   'page',
#   'editor',
#   'reference',
#   'discussion',
#   'text',
#   'book',
#   'debate',
#   'deletion'],
#  'Royalbroil': ['article',
#   'image',
#   'time',
#   'page',
#   'source',
#   'race',
#   'picture',
#   'font',
#   'people',
#   'thank'],
#  'NCurse': ['note',
#   'thank',
#   'article',
#   'image',
#   'project',
#   'time',
#   'box',
#   'help',
#   'message',
#   'template'],
#  'GW_Simulations': ['article',
#   'spaceflight',
#   'project',
#   'template',
#   'time',
#   'page',
#   'thank',
#   'category',
#   'designation',
#   'proposal'],
#  '{unknown-13}': ['merge',
#   'hemorrhage',
#   'acquaintance',
#   'talk',
#   'content',
#   'page',
#   'sentence',
#   'ball',
#   'rolling',
#   'look'],
#  'delldot': ['thank',
#   'article',
#   'template',
#   'page',
#   'time',
#   'problem',
#   'thing',
#   'work',
#   'talk',
#   'way'],
#  'Cohesion': ['image',
#   'page',
#   'people',
#   'article',
#   'disambiguation',
#   'link',
#   'tag',
#   'copyright',
#   'question',
#   'source'],
#  '{unknown-14}': ['span', 'space'],
#  'Teancum': ['review',
#   'image',
#   'article',
#   'talk',
#   'video',
#   'point',
#   'page',
#   'hold',
#   'week',
#   'improvement'],
#  'Baseball_Bugs': ['user',
#   'article',
#   'page',
#   'time',
#   'thing',
#   'way',
#   'question',
#   'year',
#   'list',
#   'comment'],
#  'Clarityfiend': ['article',
#   'thank',
#   'reference',
#   'page',
#   'time',
#   'edit',
#   'disambiguation',
#   'film',
#   'editor',
#   'bit'],
#  'Vecrumba': ['source',
#   'article',
#   'editor',
#   'topic',
#   'time',
#   'content',
#   'question',
#   'history',
#   'conflict',
#   'example'],
#  '{unknown-15}': ['idea', 'user', 'proposal', 'comment'],
#  '{unknown-16}': ['fl',
#   'vote',
#   'month',
#   'quality',
#   'feedback',
#   'request',
#   'complexity',
#   'complaint',
#   'process',
#   'people'],
#  '{unknown-17}': ['quality',
#   'proposal',
#   'lot',
#   'wp',
#   'type',
#   'mechanism',
#   'competition',
#   'concern',
#   'reconsideration',
#   'feedback'],
#  '{unknown-18}': ['vote',
#   'page',
#   'people',
#   'way',
#   'likelihood',
#   'format',
#   'procedure',
#   'discussion',
#   'talk',
#   'disagre'],
#  '{unknown-19}': ['democracy', 'time', 'man', 'vote'],
#  '{unknown-20}': ['people',
#   'list',
#   'page',
#   'way',
#   'debate',
#   'table',
#   'work',
#   'proposal',
#   'lot',
#   'month'],
#  '{unknown-21}': ['fl',
#   'process',
#   'page',
#   'editor',
#   'opposition',
#   'movement',
#   'proposal',
#   'people',
#   'one',
#   'way'],
#  '{unknown-22}': ['process',
#   'support',
#   'page',
#   'selection',
#   'line',
#   'point',
#   'type',
#   'people',
#   'proposal',
#   'straw'],
#  '{unknown-23}': ['process',
#   'consensus',
#   'idea',
#   'compromise',
#   'tier',
#   'fl',
#   'proposal',
#   'melding',
#   'system',
#   'page'],
#  '{unknown-24}': ['work', 'person', 'consensus', 'process', 'idea', 'page'],
#  'KeithTyler': ['matter',
#   'dispute',
#   'day',
#   'advice',
#   'point',
#   'process',
#   'middle',
#   'familiarity'],
#  'Edwardian': ['thank',
#   'complication',
#   'cataract',
#   'surgery',
#   'violation',
#   'pupil',
#   'debate',
#   'gist',
#   'suggestion',
#   'recreation'],
#  'Hodja Nasreddin': ['book',
#   'article',
#   'lot',
#   'area',
#   'publication',
#   'subject',
#   'number',
#   'source',
#   'result',
#   'people'],
#  'Hob': ['article',
#   'thank',
#   'reference',
#   'leukoencephalopathy',
#   'treatment',
#   'list',
#   'character',
#   'user',
#   'number',
#   'citation'],
#  'Modernist': ['article',
#   'thank',
#   'painting',
#   'work',
#   'image',
#   'time',
#   'art',
#   'page',
#   'user',
#   'artist'],
#  'Mandarax': ['time',
#   'thank',
#   'edit',
#   'talk',
#   'nomination',
#   'page',
#   'article',
#   'people',
#   'contribution',
#   'work'],
#  'Ginger Warrior': ['article',
#   'family',
#   'template',
#   'thank',
#   'rule',
#   'nomination',
#   'section',
#   'lead',
#   'threshold',
#   'nom'],
#  'Drmies': ['article',
#   'thank',
#   'edit',
#   'page',
#   'talk',
#   'thing',
#   'time',
#   'source',
#   'editor',
#   'note'],
#  'The Transhumanist': ['page',
#   'outline',
#   'list',
#   'talk',
#   'topic',
#   'link',
#   'section',
#   'index',
#   'article',
#   'consensus'],
#  '{unknown-25}': ['process',
#   'sort',
#   'notice',
#   'support',
#   'proposal',
#   'trial',
#   'boycott',
#   'reason',
#   'reply',
#   'statement'],
#  '{unknown-26}': ['experiment', 'notice', 'talk', 'page', 'people'],
#  'LadyofShalott': ['page',
#   'article',
#   'talk',
#   'thank',
#   'people',
#   'point',
#   'template',
#   'look',
#   'age',
#   'edit'],
#  'Bgwhite': ['article',
#   'reference',
#   'page',
#   'tag',
#   'talk',
#   'time',
#   'banner',
#   'name',
#   'editor',
#   'lista'],
#  'AndrewGNF': ['user',
#   'page',
#   'policy',
#   'mention',
#   'cheer',
#   'gene',
#   'comment',
#   'pbb',
#   'content',
#   'contribution'],
#  'Semiconscious': ['neuro',
#   'article',
#   'job',
#   'friend',
#   'arcadian',
#   'restructuring',
#   'category',
#   'prosencephalon',
#   'template',
#   'change'],
#  'AshLin': ['article',
#   'thank',
#   'time',
#   'edit',
#   'work',
#   'reference',
#   'page',
#   'information',
#   'lepidoptera',
#   'image'],
#  'Rmky87': ['article',
#   'page',
#   'category',
#   'user',
#   'thing',
#   'primidone',
#   'tag',
#   'edit',
#   'history',
#   'people'],
#  '66.142.45.164': ['trial',
#   'article',
#   'impression',
#   'label',
#   'agency',
#   'approval',
#   'market',
#   'source',
#   'stock',
#   'doctor'],
#  'Kd4ttc': ['page',
#   'article',
#   'section',
#   'inflammation',
#   'comment',
#   'colon',
#   'talk',
#   'symptom',
#   'thing',
#   'reference'],
#  '46.246.177.230': ['image', 'picture', 'code'],
#  'Studerby': ['sort',
#   'case',
#   'article',
#   'key',
#   'bug',
#   'change',
#   'rule',
#   'example',
#   'character',
#   'people'],
#  'Atropos': ['portal',
#   'thing',
#   'spread',
#   'content',
#   'number',
#   'edit',
#   'article',
#   'source',
#   'section',
#   'time'],
#  'Zanimum': ['article',
#   'image',
#   'thank',
#   'page',
#   'time',
#   'project',
#   'logo',
#   'talk',
#   'people',
#   'edit'],
#  'Orangemarlin': ['article',
#   'editor',
#   'edit',
#   'time',
#   'comment',
#   'admin',
#   'sockpuppet',
#   'science',
#   'bit',
#   'point'],
#  'Egg Centric': ['color',
#   'user',
#   'page',
#   'summary',
#   'tool',
#   'attack',
#   'policy',
#   'consensus',
#   'apology',
#   'message'],
#  'Number 57': ['article',
#   'cheer',
#   'club',
#   'category',
#   'election',
#   'time',
#   'league',
#   'page',
#   'football',
#   'case'],
#  'Kcordina': ['article',
#   'category',
#   'page',
#   'list',
#   'lot',
#   'time',
#   'one',
#   'thank',
#   'note',
#   'place'],
#  'Casliber': ['cheer',
#   'article',
#   'bit',
#   'page',
#   'time',
#   'thing',
#   'book',
#   'talk',
#   'material',
#   'idea'],
#  'Postlunarpaintings': ['align', 'padding', 'message', 'regard'],
#  'Hassocks5489': ['list',
#   'article',
#   'church',
#   'building',
#   'work',
#   'cheer',
#   'place',
#   'note',
#   'day',
#   'thank'],
#  'Amandajm': ['article',
#   'page',
#   'edit',
#   'building',
#   'bit',
#   'church',
#   'problem',
#   'pic',
#   'sentence',
#   'image'],
#  'Davidruben': ['article',
#   'page',
#   'talk',
#   'link',
#   'editor',
#   'template',
#   'thank',
#   'edit',
#   'issue',
#   'user'],
#  'Johnson487682': ['edit',
#   'month',
#   'example',
#   'lowercase',
#   'text',
#   'bullet',
#   'item',
#   'solution'],
#  'Anville': ['cat',
#   'bit',
#   'article',
#   'fiction',
#   'wish',
#   'thank',
#   'way',
#   'connote',
#   'word',
#   'couple'],
#  'Rjanag': ['article',
#   'template',
#   'edit',
#   'nomination',
#   'page',
#   'time',
#   'talk',
#   'editor',
#   'people',
#   'discussion'],
#  'Wikid77': ['policy',
#   'article',
#   'template',
#   'people',
#   'page',
#   'year',
#   'problem',
#   'month',
#   'example',
#   'time'],
#  'JHunterJ': ['page',
#   'article',
#   'disambiguation',
#   'dab',
#   'talk',
#   'link',
#   'topic',
#   'list',
#   'edit',
#   'entry'],
#  'EncycloPetey': ['article',
#   'page',
#   'image',
#   'time',
#   'classification',
#   'category',
#   'day',
#   'edit',
#   'plant',
#   'stub'],
#  'Hardin_MD': ['thumbnail',
#   'indicator',
#   'infobox',
#   'image',
#   'thank',
#   'reply',
#   'appearance',
#   'difference',
#   'example',
#   'use'],
#  'Ilyanep': ['variant',
#   'user',
#   'administrator',
#   'look',
#   'thank',
#   'talk',
#   'time',
#   'question',
#   'lot',
#   'program'],
#  'Celestianpower': ['thank',
#   'regard',
#   'member',
#   'page',
#   'kind',
#   'time',
#   'people',
#   'result',
#   'meeting',
#   'note'],
#  'Fainites': ['source',
#   'edit',
#   'talkpage',
#   'article',
#   'thank',
#   'editor',
#   'page',
#   'bit',
#   'discussion',
#   'time'],
#  'Lucy-marie': ['consensus',
#   'page',
#   'user',
#   'comment',
#   'source',
#   'photo',
#   'talk',
#   'side',
#   'case',
#   'discussion'],
#  'Halsteadk': ['blog',
#   'source',
#   'website',
#   'statement',
#   'article',
#   'time',
#   'magazine',
#   'production',
#   'team',
#   'point'],
#  'Fair Shannon': ['source',
#   'edit',
#   'faith',
#   'vandalism',
#   'user',
#   'official',
#   'blog',
#   'time',
#   'case',
#   'addition'],
#  'SushiGeek': ['image',
#   'size',
#   'question',
#   'infobox',
#   'eye',
#   'book',
#   'fan',
#   'fast',
#   'hit',
#   'notability'],
#  'Rewster': ['infobox',
#   'tutorial',
#   'box',
#   'article',
#   'tip',
#   'hyperostosis',
#   'code',
#   'thank',
#   'way',
#   'myopathy'],
#  'Tomlock01': ['source',
#   'thank',
#   'article',
#   'book',
#   'help',
#   'pupil',
#   'co',
#   'nom',
#   'apology',
#   'idea'],
#  'CmdrObot': ['cheer',
#   'thank',
#   'bot',
#   'exception',
#   'article',
#   'list',
#   'change',
#   'edit',
#   'page',
#   'apology'],
#  'Rlevse': ['san',
#   'page',
#   'userbox',
#   'user',
#   'article',
#   'sample',
#   'userpage',
#   'talk',
#   'list',
#   'thank'],
#  'A Link to the Past': ['article',
#   'scan',
#   'game',
#   'source',
#   'screenshot',
#   'people',
#   'list',
#   'version',
#   'system',
#   'image'],
#  'SUIT': ['san',
#   'page',
#   'bit',
#   'help',
#   'user',
#   'vandal',
#   'lot',
#   'article',
#   'align',
#   'border'],
#  'Tohru Honda13': ['user',
#   'talk',
#   'cheer',
#   'thank',
#   'volume',
#   'question',
#   'series',
#   'page',
#   'time',
#   'edit'],
#  'Dbachmann': ['article',
#   'talk',
#   'text',
#   'time',
#   'topic',
#   'point',
#   'user',
#   'block',
#   'people',
#   'edit'],
#  'AED': ['thank',
#   'vision',
#   'loss',
#   'cheer',
#   'redirect',
#   'look',
#   'note',
#   'link',
#   'information',
#   'hit'],
#  'Kjoonlee': ['source',
#   'example',
#   'bit',
#   'policy',
#   'info',
#   'article',
#   'fact',
#   'check',
#   'loanword',
#   'speaker'],
#  'Ebizur': ['population',
#   'language',
#   'haplogroup',
#   'origin',
#   'chromosome',
#   'time',
#   'people',
#   'sample',
#   'frequency',
#   'diversity'],
#  'Mel Etitis': ['article',
#   'edit',
#   'page',
#   'talk',
#   'link',
#   'message',
#   'category',
#   'history',
#   'editor',
#   'redirect'],
#  'Stilldoggy': ['thank',
#   'vote',
#   'confidence',
#   'wikipedia',
#   'work',
#   'page',
#   'discussion'],
#  'Kyle sb': ['vandalism',
#   'edit',
#   'user',
#   'puddlepant',
#   'administrator',
#   'list',
#   'contribution',
#   'fact',
#   'damage'],
#  'WLU': ['page',
#   'thank',
#   'edit',
#   'comment',
#   'talk',
#   'link',
#   'case',
#   'source',
#   'section',
#   'change'],
#  'Wikipeditor': ['ingredient',
#   'duck',
#   'flavour',
#   'list',
#   'food',
#   'experience',
#   'translation',
#   'number',
#   'half',
#   'thank'],
#  'Siteskipper': [],
#  'LittleJerry': ['article',
#   'improvement',
#   'zebra',
#   'curiosity',
#   'status',
#   'reassessment',
#   'assement',
#   'imporantance',
#   'case'],
# ...
#   'deletion',
#   'look',
#   'thank',
#   'page',
#   'school',
#   'stub',
#   'user',
#   'notability',
#   'reference'],
#  'Ad hominem2': ['faith', 'edit', 'message'],
#  'Netscott': ['user',
#   'thank',
#   'page',
#   'template',
#   'talk',
#   'category',
#   'sockpuppet',
#   'editor',
#   'comment',
#   'commentary'],
#  'Cbrown1023': ['page',
#   'category',
#   'talk',
#   'article',
#   'template',
#   'user',
#   'thank',
#   'newsletter',
#   'banner',
#   'film'],
#  '88888': [],
#  '24.136.230.38': ['vandalism',
#   'warning',
#   'one',
#   'user',
#   'page',
#   'anon',
#   'edit',
#   'image',
#   'smile',
#   'revert'],
#  'Bobthefish2': ['page',
#   'edit',
#   'post',
#   'people',
#   'dispute',
#   'way',
#   'time',
#   'party',
#   'comment',
#   'user'],
#  'Benc533': ['author',
#   'source',
#   'example',
#   'location',
#   'reference',
#   'unclear',
#   'book',
#   'feedback',
#   'article',
#   'comment'],
#  'Dposse': ['infomation',
#   'article',
#   'thank',
#   'help',
#   'episode',
#   'book',
#   'end',
#   'guy',
#   'season',
#   'finale'],
#  'Mathstat': ['category',
#   'statistic',
#   'article',
#   'estimation',
#   'theory',
#   'example',
#   'page',
#   'explanation',
#   'minute',
#   'scope'],
#  'Gill110951': ['door',
#   'probability',
#   'question',
#   'way',
#   'answer',
#   'page',
#   'assumption',
#   'editor',
#   'quizmaster',
#   'article'],
#  'Philtime': ['edit',
#   'article',
#   'statistic',
#   'comment',
#   'wiki',
#   'mathematician',
#   'guy',
#   'probability',
#   'theory',
#   'subset'],
#  'Rasillon': [],
#  'Nishkid64': ['family',
#   'article',
#   'page',
#   'user',
#   'thank',
#   'talk',
#   'contribution',
#   'block',
#   'image',
#   'edit'],
#  'Craigy144': ['arm',
#   'thank',
#   'image',
#   'article',
#   'act',
#   'tag',
#   'way',
#   'regard',
#   'difference',
#   'grade'],
#  'Bolivian Unicyclist': ['law',
#   'talk',
#   'page',
#   'legislation',
#   'thank',
#   'message',
#   'discussion',
#   'investigation',
#   'prev',
#   'reference'],
#  'Lugnuts': ['thank',
#   'film',
#   'article',
#   'template',
#   'page',
#   'stub',
#   'work',
#   'edit',
#   'tag',
#   'day'],
#  'Bastique': ['article',
#   'information',
#   'image',
#   'user',
#   'sex',
#   'correspondence',
#   'page',
#   'time',
#   'fact',
#   'version'],
#  'Jellonuts': ['deletion',
#   'image',
#   'page',
#   'review',
#   'discussion',
#   'talk',
#   'author',
#   'owner',
#   'permission',
#   'source'],
#  'Max24': ['sockpuppet',
#   'discography',
#   'article',
#   'today',
#   'album',
#   'page',
#   'reason',
#   'mess',
#   'discussion',
#   'site'],
#  'TheMovieBuff': ['film',
#   'post',
#   'talk',
#   'page',
#   'today',
#   'article',
#   'link',
#   'director',
#   'template'],
#  'SarekOfVulcan': ['article',
#   'edit',
#   'discussion',
#   'page',
#   'thank',
#   'talk',
#   'revert',
#   'case',
#   'editor',
#   'time'],
#  'Hossen27': ['force',
#   'task',
#   'user',
#   'knee',
#   'thank',
#   'list',
#   'week',
#   'surgery',
#   'bit',
#   'position'],
#  'Beyond My Ken': ['article',
#   'thank',
#   'page',
#   'discussion',
#   'image',
#   'editor',
#   'section',
#   'talk',
#   'film',
#   'source'],
#  'Himalayan Explorer': ['nomination',
#   'map',
#   'conflict',
#   'way',
#   'faith',
#   'film',
#   'town',
#   'comment',
#   'response',
#   'lack'],
#  'Ser Amantio di Nicolao': ['text',
#   'article',
#   'time',
#   'work',
#   'stub',
#   'thing',
#   'help',
#   'lot',
#   'tonight',
#   'look'],
#  'Rklawton': ['article',
#   'edit',
#   'editor',
#   'tag',
#   'page',
#   'source',
#   'category',
#   'image',
#   'user',
#   'time'],
#  'ed_g2s': ['family',
#   'image',
#   'page',
#   'copyright',
#   'logo',
#   'template',
#   'question',
#   'case',
#   'need',
#   'policy'],
#  'Si42': ['procedure', 'page', 'debate', 'resolution', 'voice'],
#  'SiGarb': ['page',
#   'thank',
#   'anemone',
#   'image',
#   'reason',
#   'work',
#   'bit',
#   'year',
#   'category',
#   'discussion'],
#  'Redux': ['image',
#   'article',
#   'user',
#   'page',
#   'template',
#   'congratulation',
#   'time',
#   'people',
#   'promotion',
#   'request'],
#  'Bornhj': ['user',
#   'note',
#   'request',
#   'time',
#   'dependency',
#   'error',
#   'congratulation',
#   'luck',
#   'rest',
#   'trial'],
#  'PhantomS': ['template', 'radio', 'version', 'article', 'status'],
#  'Joelr31': ['article',
#   'farc',
#   'reference',
#   'page',
#   'time',
#   'nation',
#   'concern',
#   'talk',
#   'review',
#   'edit'],
#  'Murcielago': ['wiki',
#   'folk',
#   'page',
#   'article',
#   'trail',
#   'biography',
#   'criterion',
#   'lot',
#   'language',
#   'friend'],
#  'Dalejenkins': ['article',
#   'family',
#   'talk',
#   'page',
#   'image',
#   'thank',
#   'template',
#   'section',
#   'afd',
#   'discussion'],
#  "Vrubel's Demons": ['article',
#   'essay',
#   'link',
#   'television',
#   'film',
#   'consensus',
#   'redlink',
#   'template',
#   'discussion',
#   'talk'],
#  '3bulletproof16': ['user',
#   'comment',
#   'page',
#   'image',
#   'thing',
#   'use',
#   'article',
#   'rope',
#   'attack',
#   'talk'],
#  'Rebelguys2': ['image',
#   'use',
#   'template',
#   'page',
#   'warning',
#   'thank',
#   'issue',
#   'size',
#   'space',
#   'concern'],
#  '{unknown-46}': ['user',
#   'page',
#   'member',
#   'wikiproject',
#   'category',
#   'wikipedia',
#   'article',
#   'question',
#   'comment',
#   'interest'],
#  'Kogsquinge': [],
#  'Are You The Cow Of Pain?': ['film',
#   'reason',
#   'template',
#   'nomination',
#   'fact',
#   'second',
#   'direction',
#   'training',
#   'edit',
#   'imdb'],
#  'Oldwildbill': ['congrat'],
#  '{unknown-47}': [],
#  'CTSWyneken': ['page',
#   'article',
#   'time',
#   'work',
#   'way',
#   'thing',
#   'editor',
#   'scholar',
#   'family',
#   'opinion'],
#  'Noroton': ['page',
#   'article',
#   'list',
#   'talk',
#   'block',
#   'museum',
#   'consensus',
#   'people',
#   'information',
#   'discussion'],
#  'The Mink Ermine Fox': ['page',
#   'mud',
#   'notability',
#   'article',
#   'comparison',
#   'existence',
#   'declaration',
#   'validity',
#   'site',
#   'experiment'],
#  'Wallywall': ['notability',
#   'day',
#   'way',
#   'problem',
#   'inclusion',
#   'page',
#   'ground',
#   'quality',
#   'article'],
#  'Lithistman': ['article',
#   'talkpage',
#   'editor',
#   'discussion',
#   'issue',
#   'thank',
#   'notability',
#   'person',
#   'thing',
#   'logo'],
#  'MichaelQSchmidt': ['article',
#   'film',
#   'thank',
#   'user',
#   'source',
#   'work',
#   'page',
#   'discussion',
#   'editor',
#   'afd'],
#  'Prolog': ['article',
#   'source',
#   'thank',
#   'page',
#   'user',
#   'talk',
#   'range',
#   'edit',
#   'problem',
#   'blog'],
#  'Kungfu2187': ['article',
#   'armor',
#   'variant',
#   'cis',
#   'belgium',
#   'information',
#   'cartridge',
#   'week',
#   'month',
#   'computer'],
#  'Propaniac': ['page',
#   'article',
#   'edit',
#   'disambiguation',
#   'tv',
#   'entry',
#   'template',
#   'list',
#   'summary',
#   'topic'],
#  'Drini': ['user',
#   'category',
#   'consensus',
#   'use',
#   'defense',
#   'order',
#   'case',
#   'talk',
#   'outcome',
#   'people'],
#  'Smetanahue': ['template',
#   'film',
#   'decade',
#   'breakdown',
#   'article',
#   'fiction',
#   'navboxe',
#   'case',
#   'edit',
#   'argument'],
#  'MikeGlyer': ['information',
#   'source',
#   'citation',
#   'blog',
#   'curiosity',
#   'encyclopedia',
#   'thank',
#   'answer',
#   'question',
#   'history'],
#  'Ashley Pomeroy': ['right',
#   'source',
#   'moment',
#   'middle',
#   'word',
#   'page',
#   'c',
#   'today',
#   'irony',
#   'specie'],
#  'Fraslet': ['user', 'removal', 'linkspam', 'article', 'violation'],
#  'John Reaves': ['page',
#   'user',
#   'notice',
#   'thank',
#   'article',
#   'talk',
#   'people',
#   'comment',
#   'time',
#   'content'],
#  'BScar23625': ['user',
#   'wish',
#   'talk',
#   'trip',
#   'weather',
#   'departure',
#   'time',
#   'cloud',
#   'visibility',
#   'metre'],
#  'Timl2k4': ['bot',
#   'article',
#   'edit',
#   'page',
#   'category',
#   'user',
#   'thank',
#   'talk',
#   'saro',
#   'problem'],
#  'Ks0stm': ['template',
#   'message',
#   'page',
#   'tornado',
#   'project',
#   'article',
#   'thank',
#   'deletion',
#   'event',
#   'outbreak'],
#  'Lexein': ['editor',
#   'edit',
#   'claim',
#   'deletion',
#   'article',
#   'position',
#   'consensus',
#   'talk',
#   'discussion',
#   'user'],
#  'Sephiroth BCR': ['article',
#   'game',
#   'source',
#   'information',
#   'series',
#   'section',
#   'list',
#   'character',
#   'review',
#   'gameplay'],
#  'TwoMightyGods': ['image',
#   'copyright',
#   'source',
#   'file',
#   'question',
#   'user',
#   'talk',
#   'list',
#   'link',
#   'week'],
#  'CouldOughta': ['thank',
#   'backstage',
#   'area',
#   'heroine',
#   'discussion',
#   'boyfriend',
#   'box',
#   'note'],
#  'UnitedStatesian': ['article',
#   'page',
#   'list',
#   'link',
#   'thank',
#   'talk',
#   'redirect',
#   'discussion',
#   'editor',
#   'deletion'],
#  'Crossmr': ['article',
#   'page',
#   'source',
#   'user',
#   'time',
#   'edit',
#   'citation',
#   'people',
#   'talk',
#   'revert'],
#  'Arwel_Parry': ['thank',
#   'idiot',
#   'talk',
#   'page',
#   'attack',
#   'persistence',
#   'account',
#   'way',
#   'throwaway',
#   'article'],
#  'TML': ['account',
#   'edit',
#   'request',
#   'sock',
#   'adminship',
#   'arbitration',
#   'action',
#   'bit',
#   'source',
#   'article'],
#  'Mrlopez2681': ['photo',
#   'head',
#   'book',
#   'landing',
#   'scene',
#   'image',
#   'copyright',
#   'issue',
#   'collection',
#   'comment'],
#  'Rmrfstar': ['article',
#   'citation',
#   'thank',
#   'page',
#   'work',
#   'edit',
#   'problem',
#   'talk',
#   'lot',
#   'time'],
#  'Deenoe': ['block',
#   'consensus',
#   'worship',
#   'neveeeeermind',
#   'talk',
#   'page',
#   'move'],
#  'Hoverfish': ['film',
#   'article',
#   'template',
#   'way',
#   'page',
#   'thing',
#   'user',
#   'talk',
#   'point',
#   'thank'],
#  'Erwin85Bot': ['image',
#   'file',
#   'repository',
#   'medium',
#   'wiki',
#   'case',
#   'message',
#   'bot',
#   'article',
#   'deletion'],
#  'Tetra Vega': ['page', 'bunch', 'bull'],
#  'Nobunaga24': ['thank',
#   'head',
#   'account',
#   'sockpuppety',
#   'vandalism',
#   'editing',
#   'work',
#   'affair',
#   'revert',
#   'guy'],
#  'Myles325a': ['link',
#   'site',
#   'page',
#   'material',
#   'talk',
#   'article',
#   'example',
#   'query',
#   'list',
#   'puzzle'],
#  'Mholland': ['image',
#   'use',
#   'rationale',
#   'svg',
#   'w',
#   'template',
#   'restriction',
#   'policy',
#   'resolution',
#   'inkscape'],
#  'Vanderdecken': ['signature',
#   'comment',
#   'article',
#   'thing',
#   'crusade',
#   'page',
#   'template',
#   'screenshot',
#   'proof',
#   'term'],
#  'Khukri': ['user',
#   'warning',
#   'cheer',
#   'article',
#   'template',
#   'page',
#   'rugby',
#   'category',
#   'vandalism',
#   'case'],
#  'Finereach': ['cortex',
#   'image',
#   'talk',
#   'thank',
#   'comment',
#   'discrepancy',
#   'file',
#   'help',
#   'discussion',
#   'input'],
#  'Chacor': ['article',
#   'category',
#   'page',
#   'event',
#   'talk',
#   'problem',
#   'weather',
#   'storm',
#   'thank',
#   'edit'],
#  'Berean Hunter': ['class',
#   'talk',
#   'page',
#   'article',
#   'user',
#   'discussion',
#   'editor',
#   'time',
#   'thread',
#   'edit'],
#  'RFD': ['article',
#   'thank',
#   'town',
#   'community',
#   'editor',
#   'citation',
#   'photo',
#   'page',
#   'problem',
#   'time'],
#  'DickClarkMises': ['source',
#   'article',
#   'cheer',
#   'deletion',
#   'assertion',
#   'process',
#   'notability',
#   'event',
#   'time',
#   'work'],
#  'Pm shef': ['image',
#   'page',
#   'ethnicity',
#   'reference',
#   'way',
#   'thank',
#   'edit',
#   'article',
#   'user',
#   'controversy'],
#  'Hurricanehink': ['article',
#   'storm',
#   'list',
#   'thank',
#   'hurricane',
#   'page',
#   'season',
#   'work',
#   'section',
#   'time'],
#  'Anthony DiPierro': ['thing'],
#  'Enochlau': ['article',
#   'page',
#   'word',
#   'thank',
#   'deletion',
#   'image',
#   'user',
#   'edit',
#   'people',
#   'source'],
#  'Best username yet': ['criticism',
#   'thing',
#   'misconception',
#   'bit',
#   'medium',
#   'information',
#   'mother',
#   'community',
#   'google',
#   'search'],
#  'Wowweb': ['industry',
#   'writer',
#   'television',
#   'load',
#   'knowledge',
#   'course',
#   'lot',
#   'hand',
#   'tv',
#   'enthusiast'],
#  'HoneyBee': ['article',
#   'thank',
#   'cast',
#   'character',
#   'example',
#   'jaw',
#   'minute',
#   'time',
#   'dog',
#   'mess'],
#  '{unknown-48}': ['section', 'jaw', 'revenge', 'article', 'example'],
#  'Kt66': ['article',
#   'user',
#   'source',
#   'fact',
#   'look',
#   'point',
#   'validity',
#   'comment',
#   'activity',
#   'page'],
#  'Robertgreer': ['year',
#   'student',
#   'editing',
#   'block',
#   'talk',
#   'page',
#   'thing',
#   'vandalism',
#   'department',
#   'reason'],
#  'Abebenjoe': ['article',
#   'photo',
#   'rule',
#   'spaceflight',
#   'day',
#   'image',
#   'space',
#   'year',
#   'time',
#   'term'],
#  'Private Detective': [],
#  'MONGO': ['article',
#   'page',
#   'time',
#   'editor',
#   'edit',
#   'thing',
#   'comment',
#   'image',
#   'website',
#   'admin'],
#  'Fowler&amp;fowler': ['page',
#   'thank',
#   'talk',
#   'time',
#   'article',
#   'user',
#   'book',
#   'history',
#   'people',
#   'post'],
#  'Ernst_Stavro_Blofeld': ['article',
#   'film',
#   'work',
#   'template',
#   'time',
#   'setting',
#   'list',
#   'history',
#   'fa',
#   'disgrace'],
#  'RobNS': ['page',
#   'colour',
#   'cheer',
#   'table',
#   'background',
#   'people',
#   'jaw',
#   'point',
#   'effort',
#   'history'],
#  'Ginkgo100': ['article',
#   'deletion',
#   'page',
#   'user',
#   'talk',
#   'edit',
#   'reason',
#   'cheer',
#   'hoax',
#   'summary'],
#  'Jam01': ['user',
#   'birthday',
#   'day',
#   'credit',
#   'editor',
#   'cheer',
#   'coffee',
#   'blend',
#   'help',
#   'wish'],
#  'Seresin': ['image',
#   'thank',
#   'userpage',
#   'user',
#   'change',
#   'article',
#   'page',
#   'userboxe',
#   'file',
#   'edit'],
#  '87.114.22.229': ['rant',
#   'comment',
#   'blp',
#   'policy',
#   'insult',
#   'talkpage',
#   'article',
#   'father',
#   'person',
#   'murder'],
#  'Fsecret': ['article',
#   'discussion',
#   'person',
#   'manga',
#   'opposition',
#   'action',
#   'question',
#   'group',
#   'people',
#   'band'],
#  'Quazgaa': ['article',
#   'page',
#   'improvement',
#   'align',
#   'talk',
#   'grammar',
#   'discussion',
#   'padding',
#   'removal',
#   'request'],
#  'Seraphim Whipp': ['page',
#   'article',
#   'user',
#   'message',
#   'prod',
#   'talk',
#   'comment',
#   'ip',
#   'block',
#   'editor'],
#  'Choess': ['article',
#   'page',
#   'title',
#   'genealogy',
#   'list',
#   'talk',
#   'discussion',
#   'thank',
#   'writ',
#   'person'],
#  'Dave101': ['image',
#   'option',
#   'article',
#   'copyright',
#   'permission',
#   'notice',
#   'website',
#   'email',
#   'use',
#   'logo'],
#  'Plastikspork': ['thank',
#   'template',
#   'page',
#   'bot',
#   'discussion',
#   'problem',
#   'deletion',
#   'coordinate',
#   'article',
#   'infobox'],
#  'Matthew': ['source',
#   'article',
#   'template',
#   'edit',
#   'episode',
#   'image',
#   'consensus',
#   'music',
#   'copyright',
#   'way'],
#  'Mercy11': ['article',
#   'street',
#   'building',
#   'source',
#   'thank',
#   'regard',
#   'change',
#   'photo',
#   'day',
#   'map'],
#  '200.209.169.81': ['information'],
#  'Eagle 101': ['user',
#   'page',
#   'talk',
#   'list',
#   'bug',
#   'problem',
#   'program',
#   'edit',
#   'thank',
#   'version'],
#  'Kasper2006': ['tnx', 'article'],
#  'WacoJacko': ['article',
#   'user',
#   'theatre',
#   'thank',
#   'request',
#   'attempt',
#   'virulent',
#   'idea',
#   'feedback',
#   'source'],
#  'THD3': ['user',
#   'article',
#   'page',
#   'way',
#   'editor',
#   'edit',
#   'administrator',
#   'sockpuppet',
#   'book',
#   'request'],
#  'Markhh': ['thank',
#   'excerpt',
#   'recording',
#   'record',
#   'page',
#   'house',
#   'orchestra',
#   'cheer',
#   'group',
#   'series'],
#  'WOSlinker': ['template',
#   'category',
#   'article',
#   'parameter',
#   'comment',
#   'discussion',
#   'page',
#   'artist',
#   'link',
#   'param'],
#  'Kleinzach': ['article',
#   'opera',
#   'project',
#   'page',
#   'regard',
#   'reference',
#   'guideline',
#   'user',
#   'problem',
#   'thank'],
#  'Edito*Magica': ['article',
#   'page',
#   'character',
#   'list',
#   'information',
#   'sub',
#   'foot',
#   'description',
#   'cast',
#   'way'],
#  'Endlessdan': ['pic',
#   'image',
#   'photo',
#   'article',
#   'page',
#   'talk',
#   'tag',
#   'user',
#   'time',
#   'band'],
#  'Infrogmation': ['article',
#   'cheer',
#   'page',
#   'thank',
#   'photo',
#   'image',
#   'work',
#   'talk',
#   'edit',
#   'license'],
#  'RadioFan': ['deletion',
#   'page',
#   'article',
#   'template',
#   'notice',
#   'tag',
#   'discussion',
#   'talk',
#   'process',
#   'source'],
#  '{unknown-49}': ['thank'],
#  '{unknown-50}': ['comment', 'place', 'family'],
#  'ScreaminEagle': ['thank',
#   'lot',
#   'article',
#   'piggy',
#   'backing',
#   'people',
#   'comment',
#   'silver',
#   'son',
#   'family'],
#  'Will Beback': ['article',
#   'editor',
#   'page',
#   'talk',
#   'material',
#   'user',
#   'topic',
#   'source',
#   'edit',
#   'thank'],
#  'Kyuubi29': ['computer', 'website'],
#  'TheVirginiaHistorian': ['thank',
#   'article',
#   'way',
#   'context',
#   'battle',
#   'voice',
#   'bot',
#   'inch',
#   'page',
#   'webpage'],
#  'Michael Bednarek': ['article',
#   'image',
#   'edit',
#   'page',
#   'template',
#   'link',
#   'title',
#   'category',
#   'reference',
#   'talk'],
#  'Jog1973': [],
#  ...}

# %%
top_verbs
# Out:
# {'Frightner': [('look', 2),
#   ('know', 2),
#   ('say', 1),
#   ('belong', 1),
#   ('think', 1),
#   ('stop', 1),
#   ('spread', 1),
#   ('greet', 1),
#   ('add', 1),
#   ('block', 1)],
#  'Revizionist': [('agree', 2),
#   ('permit', 1),
#   ('issue', 1),
#   ('allow', 1),
#   ('photograph', 1),
#   ('exclude', 1),
#   ('spend', 1),
#   ('prepare', 1),
#   ('upload', 1),
#   ('ask', 1)],
#  'Johannes003': [('think', 5),
#   ('know', 3),
#   ('check', 3),
#   ('add', 3),
#   ('look', 2),
#   ('remove', 2),
#   ('leave', 2),
#   ('find', 2),
#   ('edit', 2),
#   ('support', 2)],
#  'Michael-Billa': [('call', 1), ('maintain', 1), ('base', 1)],
#  'AnonEMouse': [('think', 128),
#   ('write', 111),
#   ('know', 88),
#   ('look', 83),
#   ('want', 74),
#   ('ask', 57),
#   ('find', 57),
#   ('try', 57),
#   ('say', 54),
#   ('get', 50)],
#  'FayssalF': [('need', 11),
#   ('believe', 7),
#   ('hope', 7),
#   ('know', 6),
#   ('think', 6),
#   ('work', 6),
#   ('find', 6),
#   ('ask', 6),
#   ('answer', 6),
#   ('get', 6)],
#  'Venerock': [('tell', 2),
#   ('m', 2),
#   ('think', 1),
#   ('fix', 1),
#   ('enjoy', 1),
#   ('mean', 1),
#   ('s', 1),
#   ('delete', 1),
#   ('cheer', 1)],
#  'Dana boomer': [('think', 54),
#   ('work', 51),
#   ('need', 50),
#   ('know', 48),
#   ('thank', 43),
#   ('go', 43),
#   ('look', 36),
#   ('add', 33),
#   ('find', 33),
#   ('say', 28)],
#  'Kudpung': [('think', 59),
#   ('know', 58),
#   ('need', 54),
#   ('delete', 46),
#   ('help', 31),
#   ('find', 29),
#   ('like', 29),
#   ('go', 29),
#   ('come', 29),
#   ('work', 27)],
#  'Rms125a@hotmail.com': [('think', 12),
#   ('know', 7),
#   ('get', 6),
#   ('apologize', 5),
#   ('try', 5),
#   ('understand', 5),
#   ('write', 4),
#   ('appear', 4),
#   ('offend', 4),
#   ('bear', 4)],
#  'Secret of success': [('understand', 2),
#   ('say', 2),
#   ('get', 1),
#   ('contact', 1),
#   ('ask', 1),
#   ('correct', 1),
#   ('want', 1),
#   ('remove', 1),
#   ('bother', 1),
#   ('think', 1)],
#  'Vensatry': [('add', 11),
#   ('work', 11),
#   ('remove', 10),
#   ('list', 9),
#   ('create', 7),
#   ('get', 6),
#   ('expand', 6),
#   ('find', 6),
#   ('know', 6),
#   ('feel', 6)],
#  'JCDenton2052': [('remove', 4),
#   ('restore', 3),
#   ('revert', 3),
#   ('edit', 3),
#   ('use', 3),
#   ('check', 2),
#   ('find', 2),
#   ('thank', 2),
#   ('appear', 2),
#   ('specify', 2)],
#  'Courcelles': [('remove', 78),
#   ('ask', 78),
#   ('want', 74),
#   ('delete', 63),
#   ('thank', 58),
#   ('orphan', 54),
#   ('note', 52),
#   ('describe', 52),
#   ('edit', 46),
#   ('find', 45)],
#  'Karthikndr': [('copy', 2),
#   ('know', 2),
#   ('agree', 1),
#   ('get', 1),
#   ('mind', 1),
#   ('look', 1),
#   ('create', 1),
#   ('help', 1),
#   ('patrol', 1)],
#  'Capricornis': [('look', 2),
#   ('prove', 2),
#   ('talk', 2),
#   ('attack', 2),
#   ('find', 1),
#   ('deal', 1),
#   ('push', 1),
#   ('think', 1),
#   ('want', 1),
#   ('know', 1)],
#  'Mr. Neutron': [('insinuate', 2),
#   ('go', 2),
#   ('let', 2),
#   ('stop', 1),
#   ('refrain', 1),
#   ('warn', 1),
#   ('commit', 1),
#   ('report', 1),
#   ('want', 1),
#   ('bring', 1)],
#  'Bollyjeff': [('say', 19),
#   ('think', 18),
#   ('add', 16),
#   ('look', 11),
#   ('know', 9),
#   ('find', 8),
#   ('use', 8),
#   ('like', 7),
#   ('want', 7),
#   ('see', 6)],
#  'Explicit': [('add', 6),
#   ('find', 6),
#   ('thank', 6),
#   ('delete', 5),
#   ('like', 5),
#   ('remove', 4),
#   ('explain', 3),
#   ('upload', 3),
#   ('nominate', 3),
#   ('involve', 3)],
#  'Good Olfactory': [('think', 91),
#   ('know', 45),
#   ('say', 38),
#   ('go', 36),
#   ('want', 34),
#   ('create', 34),
#   ('change', 27),
#   ('need', 25),
#   ('try', 24),
#   ('mean', 24)],
#  'Leahtwosaints': [('know', 124),
#   ('think', 89),
#   ('find', 84),
#   ('upload', 80),
#   ('want', 76),
#   ('look', 64),
#   ('help', 57),
#   ('need', 56),
#   ('ask', 54),
#   ('work', 44)],
#  'Mudwater': [('think', 10),
#   ('look', 9),
#   ('font', 7),
#   ('add', 7),
#   ('change', 6),
#   ('say', 5),
#   ('remove', 5),
#   ('work', 5),
#   ('let', 4),
#   ('feel', 4)],
#  'YellowMonkey': [('think', 15),
#   ('go', 8),
#   ('add', 6),
#   ('need', 5),
#   ('get', 5),
#   ('give', 4),
#   ('edit', 4),
#   ('happen', 4),
#   ('authorise', 4),
#   ('start', 4)],
#  'Cirt': [('thank', 95),
#   ('add', 39),
#   ('think', 31),
#   ('appreciate', 25),
#   ('block', 21),
#   ('feature', 20),
#   ('address', 19),
#   ('go', 18),
#   ('feel', 17),
#   ('work', 16)],
#  'Mandsford': [('know', 5),
#   ('look', 4),
#   ('appreciate', 4),
#   ('write', 3),
#   ('get', 3),
#   ('add', 3),
#   ('ask', 3),
#   ('like', 3),
#   ('cite', 2),
#   ('move', 2)],
#  'Anetode': [('think', 8),
#   ('know', 5),
#   ('upload', 4),
#   ('satisfy', 4),
#   ('disagree', 4),
#   ('add', 4),
#   ('want', 4),
#   ('look', 4),
#   ('scratch', 4),
#   ('consider', 3)],
#  'Kwork': [('think', 15),
#   ('edit', 12),
#   ('write', 10),
#   ('make', 8),
#   ('remove', 7),
#   ('explain', 7),
#   ('discuss', 6),
#   ('understand', 6),
#   ('allow', 6),
#   ('block', 6)],
#  'Bubba73': [('think', 28),
#   ('say', 20),
#   ('look', 16),
#   ('change', 15),
#   ('know', 14),
#   ('add', 10),
#   ('win', 10),
#   ('read', 10),
#   ('go', 10),
#   ('remove', 9)],
#  'Jax 0677': [('see', 3),
#   ('get', 2),
#   ('post', 2),
#   ('sign', 2),
#   ('happen', 2),
#   ('suppose', 2),
#   ('dispositione', 2),
#   ('look', 1),
#   ('split', 1),
#   ('state', 1)],
#  'Moonriddengirl': [('know', 101),
#   ('need', 77),
#   ('want', 65),
#   ('copy', 63),
#   ('help', 62),
#   ('let', 55),
#   ('think', 55),
#   ('remove', 46),
#   ('find', 45),
#   ('look', 43)],
#  'SandyGeorgia': [('know', 146),
#   ('think', 106),
#   ('go', 104),
#   ('need', 99),
#   ('help', 84),
#   ('look', 78),
#   ('get', 78),
#   ('work', 76),
#   ('feature', 74),
#   ('want', 73)],
#  'Keraunoscopia': [('know', 13),
#   ('think', 12),
#   ('work', 8),
#   ('remove', 8),
#   ('find', 7),
#   ('thank', 7),
#   ('go', 5),
#   ('try', 4),
#   ('look', 4),
#   ('want', 4)],
#  'Loganberry': [('play', 5),
#   ('change', 5),
#   ('add', 5),
#   ('think', 4),
#   ('know', 3),
#   ('match', 2),
#   ('list', 2),
#   ('leave', 2),
#   ('come', 2),
#   ('explain', 2)],
#  'Qwfp': [('think', 11),
#   ('add', 7),
#   ('look', 7),
#   ('remove', 6),
#   ('delete', 5),
#   ('appear', 4),
#   ('need', 4),
#   ('change', 3),
#   ('move', 3),
#   ('link', 3)],
#  'Montanabw': [('think', 70),
#   ('need', 64),
#   ('want', 60),
#   ('know', 52),
#   ('get', 41),
#   ('go', 36),
#   ('add', 32),
#   ('find', 29),
#   ('try', 28),
#   ('look', 27)],
#  'Vicond': [],
#  'Bsherr': [('think', 9),
#   ('apply', 7),
#   ('semiprotecte', 4),
#   ('require', 4),
#   ('use', 3),
#   ('mean', 3),
#   ('work', 3),
#   ('block', 3),
#   ('develop', 3),
#   ('bring', 3)],
#  'Albion moonlight': [('think', 8),
#   ('help', 4),
#   ('work', 3),
#   ('feel', 3),
#   ('assume', 2),
#   ('go', 2),
#   ('start', 2),
#   ('make', 2),
#   ('block', 2),
#   ('know', 2)],
#  'Videmus Omnia': [('get', 22),
#   ('look', 21),
#   ('want', 17),
#   ('add', 15),
#   ('need', 13),
#   ('remove', 11),
#   ('know', 11),
#   ('think', 10),
#   ('check', 8),
#   ('tag', 8)],
#  'SmokeyJoe': [('create', 6),
#   ('look', 4),
#   ('think', 4),
#   ('read', 3),
#   ('redirect', 3),
#   ('appreciate', 3),
#   ('say', 2),
#   ('delete', 2),
#   ('nominate', 2),
#   ('close', 1)],
#  'Junebug52': [('feel', 21),
#   ('look', 20),
#   ('need', 19),
#   ('go', 14),
#   ('think', 14),
#   ('help', 11),
#   ('want', 11),
#   ('find', 8),
#   ('try', 8),
#   ('remove', 7)],
#  'Djflem': [('wonder', 3),
#   ('follow', 3),
#   ('add', 3),
#   ('mind', 3),
#   ('appreciate', 3),
#   ('discuss', 2),
#   ('suggest', 2),
#   ('list', 2),
#   ('get', 2),
#   ('need', 1)],
#  'PAIRdoc': [('continue', 1),
#   ('look', 1),
#   ('release', 1),
#   ('consider', 1),
#   ('lay', 1),
#   ('leave', 1),
#   ('relish', 1),
#   ('wonder', 1),
#   ('construct', 1)],
#  'Meco': [('think', 33),
#   ('find', 23),
#   ('read', 19),
#   ('know', 19),
#   ('believe', 18),
#   ('appreciate', 16),
#   ('look', 16),
#   ('remove', 16),
#   ('write', 15),
#   ('want', 15)],
#  'Gonzo_fan2007': [('think', 22),
#   ('know', 11),
#   ('go', 9),
#   ('say', 8),
#   ('try', 8),
#   ('let', 7),
#   ('look', 7),
#   ('delete', 6),
#   ('want', 6),
#   ('feel', 6)],
#  'Koavf': [('know', 28),
#   ('add', 23),
#   ('remove', 21),
#   ('think', 20),
#   ('nominate', 19),
#   ('want', 19),
#   ('thank', 17),
#   ('like', 17),
#   ('respond', 15),
#   ('post', 14)],
#  'Ling.Nut': [('think', 43),
#   ('feel', 41),
#   ('drop', 41),
#   ('know', 32),
#   ('look', 30),
#   ('need', 27),
#   ('try', 20),
#   ('go', 18),
#   ('believe', 18),
#   ('ask', 17)],
#  'BarkingMoon': [('know', 8),
#   ('use', 8),
#   ('help', 5),
#   ('find', 5),
#   ('edit', 5),
#   ('change', 5),
#   ('let', 4),
#   ('want', 4),
#   ('show', 4),
#   ('say', 3)],
#  '{unknown-0}': [('say', 1), ('ndash', 1)],
#  '{unknown-1}': [('ndash', 1)],
#  'MBK004': [('need', 24),
#   ('remove', 19),
#   ('look', 18),
#   ('know', 18),
#   ('revert', 18),
#   ('see', 17),
#   ('think', 17),
#   ('discuss', 17),
#   ('leave', 16),
#   ('add', 16)],
#  'Howard the Duck': [('change', 4),
#   ('want', 3),
#   ('come', 3),
#   ('need', 3),
#   ('use', 3),
#   ('suggest', 3),
#   ('revert', 3),
#   ('abide', 3),
#   ('apply', 2),
#   ('follow', 2)],
#  'Dream Focus': [('delete', 53),
#   ('say', 37),
#   ('read', 37),
#   ('try', 32),
#   ('go', 30),
#   ('want', 27),
#   ('find', 26),
#   ('mention', 23),
#   ('add', 21),
#   ('think', 20)],
#  'Ktr101': [('know', 89),
#   ('think', 88),
#   ('look', 60),
#   ('work', 54),
#   ('want', 50),
#   ('create', 43),
#   ('go', 40),
#   ('fix', 40),
#   ('try', 39),
#   ('feel', 38)],
#  'Tim Song': [('nominate', 4),
#   ('ask', 4),
#   ('ping', 4),
#   ('warn', 3),
#   ('think', 3),
#   ('explain', 3),
#   ('address', 3),
#   ('decline', 3),
#   ('add', 3),
#   ('mean', 2)],
#  'Wolfkeeper': [('think', 5),
#   ('cover', 5),
#   ('mean', 4),
#   ('find', 4),
#   ('try', 3),
#   ('undo', 2),
#   ('let', 2),
#   ('need', 2),
#   ('answer', 2),
#   ('fuck', 2)],
#  'Soap': [('think', 11),
#   ('find', 10),
#   ('edit', 9),
#   ('say', 8),
#   ('want', 7),
#   ('know', 7),
#   ('revert', 7),
#   ('go', 6),
#   ('see', 5),
#   ('change', 5)],
#  'Kevin McE': [('think', 6),
#   ('make', 5),
#   ('consider', 5),
#   ('believe', 5),
#   ('defend', 4),
#   ('need', 4),
#   ('wish', 3),
#   ('ask', 3),
#   ('represent', 3),
#   ('revert', 3)],
#  'TenPoundHammer': [('think', 50),
#   ('add', 34),
#   ('remove', 26),
#   ('say', 22),
#   ('know', 20),
#   ('need', 18),
#   ('delete', 17),
#   ('edit', 15),
#   ('find', 15),
#   ('want', 14)],
#  'NicholasJr7': [('ignore', 1), ('write', 1)],
#  'Epbr123': [('think', 9),
#   ('wonder', 8),
#   ('let', 8),
#   ('nominate', 8),
#   ('consider', 7),
#   ('start', 4),
#   ('delete', 3),
#   ('thank', 2),
#   ('know', 2),
#   ('make', 2)],
#  'PumpkinSky': [('help', 10),
#   ('add', 9),
#   ('think', 9),
#   ('need', 9),
#   ('look', 8),
#   ('remove', 8),
#   ('want', 7),
#   ('change', 7),
#   ('work', 7),
#   ('make', 6)],
#  '{unknown-2}': [('say', 2),
#   ('try', 1),
#   ('add', 1),
#   ('remove', 1),
#   ('think', 1),
#   ('publish', 1)],
#  'Marine 69-71': [('know', 105),
#   ('think', 79),
#   ('thank', 66),
#   ('tell', 53),
#   ('want', 51),
#   ('like', 46),
#   ('look', 41),
#   ('go', 39),
#   ('write', 35),
#   ('believe', 32)],
#  'Deryck Chan': [('think', 7),
#   ('use', 6),
#   ('try', 5),
#   ('write', 4),
#   ('help', 4),
#   ('ask', 3),
#   ('hope', 3),
#   ('find', 3),
#   ('need', 3),
#   ('block', 3)],
#  'Tpbradbury': [('add', 9),
#   ('think', 8),
#   ('look', 6),
#   ('use', 6),
#   ('work', 5),
#   ('notice', 5),
#   ('feature', 5),
#   ('know', 4),
#   ('change', 4),
#   ('get', 3)],
#  'Kanatonian': [('notice', 1),
#   ('edit', 1),
#   ('change', 1),
#   ('help', 1),
#   ('continue', 1),
#   ('fight', 1),
#   ('relate', 1),
#   ('get', 1),
#   ('involve', 1),
#   ('create', 1)],
#  'Reneeholle': [('ask', 4),
#   ('add', 3),
#   ('notice', 3),
#   ('edit', 3),
#   ('think', 3),
#   ('smack', 3),
#   ('count', 3),
#   ('appropriate', 2),
#   ('begin', 2),
#   ('feel', 2)],
#  'Crisco 1492': [('know', 20),
#   ('think', 17),
#   ('wonder', 15),
#   ('want', 14),
#   ('add', 13),
#   ('try', 13),
#   ('review', 12),
#   ('need', 11),
#   ('work', 10),
#   ('let', 10)],
#  'Eldumpo': [('add', 22),
#   ('play', 14),
#   ('include', 10),
#   ('post', 9),
#   ('know', 9),
#   ('note', 8),
#   ('think', 8),
#   ('go', 8),
#   ('wonder', 7),
#   ('look', 7)],
#  'Marcd30319': [('know', 3),
#   ('add', 2),
#   ('get', 2),
#   ('review', 2),
#   ('take', 1),
#   ('exist', 1),
#   ('mention', 1),
#   ('plan', 1),
#   ('find', 1),
#   ('appear', 1)],
#  'Yath': [('refer', 1), ('think', 1), ('domesticate', 1), ('release', 1)],
#  'Oosoom': [('add', 9),
#   ('know', 9),
#   ('think', 7),
#   ('find', 5),
#   ('use', 4),
#   ('link', 4),
#   ('read', 4),
#   ('look', 4),
#   ('mean', 3),
#   ('try', 3)],
#  'Zuwxiv': [('see', 1),
#   ('think', 1),
#   ('relate', 1),
#   ('look', 1),
#   ('figure', 1),
#   ('open', 1)],
#  'Jrcla2': [('know', 28),
#   ('want', 20),
#   ('think', 19),
#   ('create', 17),
#   ('need', 13),
#   ('make', 13),
#   ('work', 13),
#   ('let', 12),
#   ('write', 11),
#   ('find', 11)],
#  '{unknown-3}': [],
#  'Erebus555': [('add', 2),
#   ('expand', 2),
#   ('think', 2),
#   ('focus', 1),
#   ('participate', 1),
#   ('echo', 1),
#   ('say', 1),
#   ('notice', 1),
#   ('anticipate', 1),
#   ('start', 1)],
#  'Erikeltic': [('say', 6),
#   ('think', 5),
#   ('happen', 4),
#   ('start', 4),
#   ('give', 4),
#   ('block', 4),
#   ('provide', 4),
#   ('contribute', 3),
#   ('allow', 3),
#   ('stand', 3)],
#  'Nymf': [('note', 3),
#   ('bring', 3),
#   ('let', 3),
#   ('refer', 3),
#   ('perceive', 3),
#   ('lead', 3),
#   ('quote', 3),
#   ('present', 3),
#   ('get', 3),
#   ('block', 2)],
#  'Jafeluv': [('think', 6),
#   ('request', 6),
#   ('propose', 6),
#   ('remove', 6),
#   ('move', 5),
#   ('ask', 5),
#   ('close', 4),
#   ('want', 4),
#   ('discuss', 4),
#   ('look', 4)],
#  'Andypandy.UK': [('think', 4),
#   ('add', 4),
#   ('want', 4),
#   ('try', 3),
#   ('edit', 3),
#   ('get', 2),
#   ('thank', 2),
#   ('grow', 2),
#   ('know', 2),
#   ('detail', 2)],
#  '{unknown-4}': [],
#  'Mlewan': [('retouch', 1),
#   ('upload', 1),
#   ('guess', 1),
#   ('come', 1),
#   ('hope', 1),
#   ('mind', 1),
#   ('leave', 1),
#   ('think', 1),
#   ('want', 1),
#   ('blur', 1)],
#  'Mike Selinker': [('think', 43),
#   ('know', 30),
#   ('close', 29),
#   ('want', 29),
#   ('need', 21),
#   ('feel', 19),
#   ('like', 17),
#   ('try', 17),
#   ('let', 17),
#   ('find', 17)],
#  'Trident13': [('think', 14),
#   ('add', 9),
#   ('create', 7),
#   ('know', 6),
#   ('tag', 4),
#   ('look', 4),
#   ('find', 4),
#   ('notice', 4),
#   ('place', 4),
#   ('try', 3)],
#  'BrianSmithson': [('change', 4),
#   ('try', 3),
#   ('add', 3),
#   ('remove', 2),
#   ('go', 2),
#   ('feature', 2),
#   ('cite', 2),
#   ('run', 2),
#   ('gurp', 2),
#   ('get', 2)],
#  'Doops': [('think', 6),
#   ('delete', 6),
#   ('read', 3),
#   ('feel', 3),
#   ('fix', 2),
#   ('exist', 2),
#   ('create', 2),
#   ('leave', 2),
#   ('belong', 2),
#   ('publish', 1)],
#  'Pigsonthewing': [('think', 11),
#   ('thank', 9),
#   ('add', 8),
#   ('make', 7),
#   ('like', 6),
#   ('suggest', 5),
#   ('know', 5),
#   ('use', 5),
#   ('cause', 5),
#   ('find', 4)],
#  'WilyD': [('think', 13),
#   ('know', 7),
#   ('go', 7),
#   ('ask', 6),
#   ('try', 6),
#   ('involve', 6),
#   ('hope', 6),
#   ('offer', 6),
#   ('fight', 6),
#   ('get', 5)],
#  'Butwhatdoiknow': [('work', 2),
#   ('point', 2),
#   ('turn', 2),
#   ('want', 2),
#   ('thank', 2),
#   ('consider', 2),
#   ('seek', 2),
#   ('find', 2),
#   ('think', 1),
#   ('sound', 1)],
#  'Jappalang': [('thank', 23),
#   ('think', 8),
#   ('point', 6),
#   ('base', 6),
#   ('leave', 6),
#   ('take', 6),
#   ('state', 5),
#   ('copyright', 5),
#   ('believe', 4),
#   ('bring', 4)],
#  'Ealdgyth': [('need', 42),
#   ('go', 40),
#   ('think', 34),
#   ('know', 32),
#   ('get', 30),
#   ('look', 29),
#   ('work', 21),
#   ('try', 20),
#   ('find', 19),
#   ('add', 18)],
#  'Coemgenus': [('write', 6),
#   ('list', 5),
#   ('think', 5),
#   ('delete', 4),
#   ('start', 4),
#   ('know', 4),
#   ('see', 4),
#   ('read', 4),
#   ('add', 4),
#   ('leave', 3)],
#  'harej': [('go', 6),
#   ('talk', 5),
#   ('run', 4),
#   ('look', 3),
#   ('request', 3),
#   ('withdraw', 3),
#   ('think', 3),
#   ('edit', 3),
#   ('transclude', 2),
#   ('mark', 2)],
#  'Pyrotec': [('review', 17),
#   ('check', 14),
#   ('find', 13),
#   ('start', 12),
#   ('try', 11),
#   ('get', 11),
#   ('need', 11),
#   ('think', 11),
#   ('run', 11),
#   ('state', 10)],
#  '86.157.195.116': [('measure', 1),
#   ('hand', 1),
#   ('s', 1),
#   ('get', 1),
#   ('revert', 1)],
#  'Travb': [('think', 7),
#   ('look', 6),
#   ('work', 6),
#   ('know', 5),
#   ('like', 4),
#   ('change', 3),
#   ('help', 2),
#   ('say', 2),
#   ('make', 2),
#   ('let', 2)],
#  'Schaffman': [('work', 2),
#   ('find', 2),
#   ('know', 2),
#   ('see', 1),
#   ('want', 1),
#   ('touch', 1),
#   ('exist', 1),
#   ('lack', 1),
#   ('try', 1),
#   ('clean', 1)],
#  'Everyking': [('think', 7),
#   ('like', 4),
#   ('need', 4),
#   ('notice', 3),
#   ('feel', 3),
#   ('say', 3),
#   ('let', 3),
#   ('create', 3),
#   ('add', 3),
#   ('know', 3)],
#  'Acalamari': [('ask', 331),
#   ('revert', 303),
#   ('know', 263),
#   ('think', 262),
#   ('hesitate', 203),
#   ('thank', 199),
#   ('remove', 198),
#   ('want', 189),
#   ('block', 171),
#   ('grant', 165)],
#  'Legolas2186': [('think', 31),
#   ('know', 21),
#   ('go', 20),
#   ('ask', 19),
#   ('add', 17),
#   ('revert', 17),
#   ('need', 16),
#   ('see', 15),
#   ('find', 15),
#   ('font', 13)],
#  'Glen S': [('think', 6),
#   ('know', 6),
#   ('add', 4),
#   ('let', 4),
#   ('remove', 3),
#   ('smile', 2),
#   ('read', 2),
#   ('delete', 2),
#   ('work', 2),
#   ('get', 2)],
#  'Kyo cat': [('think', 16),
#   ('help', 14),
#   ('font', 12),
#   ('want', 9),
#   ('hope', 7),
#   ('feel', 7),
#   ('take', 6),
#   ('give', 6),
#   ('go', 6),
#   ('work', 6)],
#  'GamerPro64': [('know', 14),
#   ('think', 11),
#   ('find', 11),
#   ('like', 7),
#   ('need', 7),
#   ('write', 7),
#   ('look', 6),
#   ('work', 6),
#   ('try', 6),
#   ('notice', 6)],
#  'ShakespeareFan00': [('upload', 13),
#   ('thank', 8),
#   ('consider', 7),
#   ('ask', 5),
#   ('miss', 5),
#   ('provide', 5),
#   ('check', 4),
#   ('specify', 4),
#   ('find', 4),
#   ('delete', 4)],
#  'Agne27': [('think', 13),
#   ('know', 11),
#   ('go', 6),
#   ('feel', 6),
#   ('want', 6),
#   ('see', 6),
#   ('wonder', 5),
#   ('work', 5),
#   ('find', 4),
#   ('have', 4)],
#  'Woodym555': [('think', 19),
#   ('need', 19),
#   ('ask', 8),
#   ('give', 7),
#   ('agree', 6),
#   ('know', 6),
#   ('leave', 6),
#   ('fix', 6),
#   ('move', 6),
#   ('try', 5)],
#  'Eaglizard': [('see', 3),
#   ('find', 3),
#   ('agree', 3),
#   ('ask', 2),
#   ('feel', 2),
#   ('notice', 2),
#   ('edit', 2),
#   ('use', 2),
#   ('think', 2),
#   ('come', 2)],
#  'Erik': [('think', 52),
#   ('know', 45),
#   ('want', 30),
#   ('try', 27),
#   ('let', 25),
#   ('add', 21),
#   ('work', 21),
#   ('find', 20),
#   ('come', 19),
#   ('look', 19)],
#  'JaGa': [('know', 67),
#   ('think', 56),
#   ('look', 50),
#   ('let', 43),
#   ('go', 43),
#   ('fix', 38),
#   ('want', 36),
#   ('get', 36),
#   ('need', 36),
#   ('work', 30)],
#  'Rodhullandemu': [('think', 17),
#   ('know', 15),
#   ('go', 14),
#   ('want', 12),
#   ('let', 11),
#   ('take', 9),
#   ('link', 9),
#   ('try', 8),
#   ('edit', 8),
#   ('look', 8)],
#  'Jamesd1': [('come', 1),
#   ('reach', 1),
#   ('change', 1),
#   ('sign', 1),
#   ('check', 1),
#   ('need', 1),
#   ('contact', 1),
#   ('use', 1),
#   ('click', 1),
#   ('look', 1)],
#  'Sparklecplenty': [('classify', 1),
#   ('place', 1),
#   ('revert', 1),
#   ('revise', 1),
#   ('read', 1),
#   ('understand', 1),
#   ('wish', 1),
#   ('balance', 1),
#   ('enter', 1)],
#  'PamD': [('think', 22),
#   ('add', 21),
#   ('look', 14),
#   ('create', 11),
#   ('need', 10),
#   ('know', 9),
#   ('list', 9),
#   ('sort', 8),
#   ('include', 8),
#   ('change', 7)],
#  'Derek Andrews': [('add', 5),
#   ('wonder', 4),
#   ('want', 4),
#   ('notice', 3),
#   ('look', 3),
#   ('know', 3),
#   ('find', 2),
#   ('originate', 2),
#   ('raise', 2),
#   ('work', 2)],
#  'Max Schwarz': [('upload', 2), ('notice', 1), ('use', 1)],
#  'Jimfbleak': [('think', 20),
#   ('know', 14),
#   ('need', 10),
#   ('go', 8),
#   ('give', 7),
#   ('look', 7),
#   ('write', 7),
#   ('see', 7),
#   ('revert', 7),
#   ('delete', 6)],
#  'SilkTork': [('feel', 51),
#   ('need', 38),
#   ('know', 34),
#   ('think', 31),
#   ('look', 29),
#   ('let', 26),
#   ('start', 23),
#   ('work', 20),
#   ('want', 20),
#   ('make', 18)],
#  'WesleyDodds': [('think', 77),
#   ('work', 72),
#   ('need', 69),
#   ('find', 55),
#   ('want', 49),
#   ('look', 47),
#   ('go', 47),
#   ('write', 46),
#   ('try', 46),
#   ('know', 40)],
#  'Betacommand': [('know', 3),
#   ('say', 3),
#   ('miss', 3),
#   ('give', 3),
#   ('check', 2),
#   ('delete', 2),
#   ('thank', 2),
#   ('let', 2),
#   ('bring', 2),
#   ('upload', 1)],
#  'Parrot of Doom': [('think', 31),
#   ('find', 19),
#   ('know', 15),
#   ('read', 14),
#   ('create', 10),
#   ('go', 10),
#   ('try', 10),
#   ('work', 9),
#   ('wonder', 9),
#   ('look', 9)],
#  'Slomox': [('thank', 3),
#   ('look', 3),
#   ('support', 2),
#   ('stuff', 1),
#   ('note', 1),
#   ('stage', 1),
#   ('suspect', 1),
#   ('wonder', 1),
#   ('pull', 1),
#   ('search', 1)],
#  'Dragon695': [('believe', 6),
#   ('think', 5),
#   ('work', 5),
#   ('try', 4),
#   ('want', 4),
#   ('support', 4),
#   ('use', 3),
#   ('know', 3),
#   ('convict', 2),
#   ('plan', 2)],
#  '{unknown-5}': [('know', 1), ('live', 1), ('answer', 1)],
#  'Mark Wheaver': [('list', 2),
#   ('improve', 2),
#   ('like', 1),
#   ('join', 1),
#   ('talk', 1),
#   ('impact', 1),
#   ('try', 1),
#   ('categorize', 1)],
#  'Catherineyronwode': [('help', 3),
#   ('thank', 3),
#   ('leave', 3),
#   ('ask', 2),
#   ('vote', 2),
#   ('work', 2),
#   ('find', 2),
#   ('request', 2),
#   ('second', 1),
#   ('say', 1)],
#  'Barneca': [('think', 8),
#   ('block', 7),
#   ('feel', 6),
#   ('know', 6),
#   ('hope', 5),
#   ('see', 4),
#   ('refer', 4),
#   ('need', 3),
#   ('try', 3),
#   ('go', 3)],
#  'Lightmouse': [('know', 10),
#   ('work', 9),
#   ('think', 8),
#   ('add', 7),
#   ('say', 6),
#   ('help', 6),
#   ('look', 6),
#   ('want', 6),
#   ('create', 5),
#   ('hope', 5)],
#  '{unknown-6}': [('want', 2),
#   ('understand', 1),
#   ('work', 1),
#   ('leave', 1),
#   ('shape', 1),
#   ('bias', 1),
#   ('follow', 1),
#   ('find', 1),
#   ('select', 1),
#   ('support', 1)],
#  'Ronhjones': [('find', 18),
#   ('add', 15),
#   ('use', 15),
#   ('create', 14),
#   ('delete', 14),
#   ('ask', 14),
#   ('check', 13),
#   ('thank', 12),
#   ('agree', 11),
#   ('consider', 10)],
#  'Malleus_Fatuorum': [('think', 145),
#   ('know', 52),
#   ('look', 50),
#   ('get', 48),
#   ('need', 40),
#   ('say', 37),
#   ('believe', 36),
#   ('ask', 36),
#   ('try', 33),
#   ('find', 32)],
#  'France3470': [('create', 10),
#   ('add', 8),
#   ('know', 6),
#   ('feel', 5),
#   ('thank', 5),
#   ('think', 5),
#   ('tag', 4),
#   ('require', 4),
#   ('find', 4),
#   ('read', 3)],
#  'Dr. Blofeld': [('think', 89),
#   ('need', 48),
#   ('create', 48),
#   ('find', 41),
#   ('look', 39),
#   ('start', 37),
#   ('add', 36),
#   ('remove', 33),
#   ('use', 32),
#   ('want', 32)],
#  'Bob1960evens': [('think', 11),
#   ('use', 9),
#   ('add', 9),
#   ('include', 7),
#   ('know', 6),
#   ('need', 5),
#   ('continue', 5),
#   ('find', 5),
#   ('show', 5),
#   ('go', 4)],
#  'Ryecatcher773': [('move', 10),
#   ('name', 4),
#   ('ask', 3),
#   ('thank', 3),
#   ('go', 3),
#   ('serve', 3),
#   ('add', 2),
#   ('mean', 2),
#   ('require', 2),
#   ('bring', 2)],
#  'QuiteUnusual': [('think', 3),
#   ('qualify', 1),
#   ('font', 1),
#   ('turn', 1),
#   ('face', 1),
#   ('pick', 1),
#   ('remove', 1),
#   ('propose', 1),
#   ('leave', 1),
#   ('notify', 1)],
#  'Thomas888b': [('answer', 3),
#   ('confirm', 2),
#   ('interview', 2),
#   ('notice', 1),
#   ('say', 1),
#   ('show', 1),
#   ('deserve', 1),
#   ('like', 1)],
#  'Warlordjohncarter': [('add', 7),
#   ('know', 6),
#   ('try', 5),
#   ('believe', 5),
#   ('relate', 5),
#   ('say', 3),
#   ('consider', 3),
#   ('give', 3),
#   ('express', 3),
#   ('change', 3)],
#  'Enigmaman': [('block', 31),
#   ('know', 24),
#   ('think', 15),
#   ('create', 13),
#   ('add', 11),
#   ('go', 11),
#   ('get', 10),
#   ('want', 10),
#   ('consider', 7),
#   ('ask', 7)],
#  'NHRHS2010': [('know', 12),
#   ('like', 9),
#   ('fry', 9),
#   ('create', 8),
#   ('block', 8),
#   ('think', 7),
#   ('get', 7),
#   ('revert', 6),
#   ('protect', 6),
#   ('kristen', 6)],
#  'Canuckle': [('appreciate', 2),
#   ('undo', 2),
#   ('feel', 2),
#   ('stand', 2),
#   ('come', 1),
#   ('want', 1),
#   ('wrap', 1),
#   ('name', 1),
#   ('achieve', 1),
#   ('mean', 1)],
#  'Nburden': [],
#  'Cosprings': [('need', 2),
#   ('create', 2),
#   ('call', 2),
#   ('think', 2),
#   ('link', 2),
#   ('find', 1),
#   ('credit', 1),
#   ('know', 1),
#   ('suggest', 1),
#   ('center', 1)],
#  'CronopioFlotante': [('measure', 1),
#   ('let', 1),
#   ('discuss', 1),
#   ('accept', 1),
#   ('say', 1),
#   ('base', 1)],
#  'Crusio': [('think', 17),
#   ('publish', 11),
#   ('read', 9),
#   ('include', 9),
#   ('know', 9),
#   ('mean', 9),
#   ('say', 8),
#   ('leave', 8),
#   ('look', 8),
#   ('need', 7)],
#  'Futurebird': [('think', 8),
#   ('add', 4),
#   ('know', 3),
#   ('want', 3),
#   ('have', 3),
#   ('help', 3),
#   ('present', 3),
#   ('look', 2),
#   ('need', 2),
#   ('post', 2)],
#  'Jnc': [('delete', 8),
#   ('want', 7),
#   ('need', 5),
#   ('think', 5),
#   ('click', 5),
#   ('look', 3),
#   ('link', 3),
#   ('like', 2),
#   ('make', 2),
#   ('suggest', 2)],
#  'AEMoreira042281': [('shoot', 2),
#   ('take', 1),
#   ('clean', 1),
#   ('move', 1),
#   ('upload', 1),
#   ('include', 1),
#   ('need', 1),
#   ('save', 1),
#   ('log', 1),
#   ('require', 1)],
#  'Blackjays1': [('think', 4),
#   ('include', 2),
#   ('doubt', 1),
#   ('hook', 1),
#   ('start', 1),
#   ('call', 1),
#   ('refuse', 1),
#   ('revert', 1),
#   ('make', 1),
#   ('know', 1)],
#  'Bellagio99': [('look', 6),
#   ('go', 4),
#   ('know', 4),
#   ('check', 3),
#   ('get', 3),
#   ('keep', 3),
#   ('listen', 3),
#   ('help', 3),
#   ('miss', 2),
#   ('agree', 2)],
#  'Bencherlite': [('think', 39),
#   ('know', 33),
#   ('delete', 28),
#   ('look', 23),
#   ('let', 22),
#   ('try', 19),
#   ('add', 19),
#   ('suggest', 18),
#   ('start', 18),
#   ('want', 17)],
#  'DustFormsWords': [('review', 8),
#   ('thank', 7),
#   ('address', 7),
#   ('know', 7),
#   ('require', 6),
#   ('agree', 5),
#   ('work', 4),
#   ('improve', 4),
#   ('go', 4),
#   ('remain', 4)],
#  '70.137.161.241': [],
#  'TimVickers': [('think', 35),
#   ('try', 23),
#   ('thank', 20),
#   ('need', 17),
#   ('add', 16),
#   ('deal', 16),
#   ('find', 14),
#   ('want', 12),
#   ('know', 12),
#   ('look', 11)],
#  'Miyagawa': [('add', 4),
#   ('want', 2),
#   ('find', 2),
#   ('go', 1),
#   ('search', 1),
#   ('bring', 1),
#   ('construct', 1),
#   ('cite', 1),
#   ('pende', 1),
#   ('get', 1)],
#  'Parsifal': [('support', 3),
#   ('know', 2),
#   ('correct', 2),
#   ('write', 2),
#   ('find', 2),
#   ('need', 2),
#   ('post', 2),
#   ('link', 2),
#   ('add', 1),
#   ('follow', 1)],
#  'WebHamster': [('start', 5),
#   ('get', 4),
#   ('delete', 4),
#   ('add', 4),
#   ('know', 4),
#   ('revert', 3),
#   ('take', 2),
#   ('need', 2),
#   ('think', 2),
#   ('doubt', 2)],
#  'Rocky.liu': [('work', 1),
#   ('serve', 1),
#   ('thank', 1),
#   ('add', 1),
#   ('help', 1),
#   ('translate', 1)],
#  'Dwanyewest': [('forget', 3),
#   ('think', 2),
#   ('believe', 2),
#   ('keep', 2),
#   ('redirect', 2),
#   ('write', 2),
#   ('show', 2),
#   ('provide', 2),
#   ('mention', 2),
#   ('create', 1)],
#  'Mgoodyear': [('know', 3),
#   ('work', 3),
#   ('look', 3),
#   ('need', 2),
#   ('remove', 2),
#   ('happen', 2),
#   ('try', 2),
#   ('say', 2),
#   ('set', 2),
#   ('read', 2)],
#  'Sonic99': [('provide', 2),
#   ('change', 1),
#   ('see', 1),
#   ('accept', 1),
#   ('wish', 1),
#   ('identify', 1),
#   ('skin', 1),
#   ('think', 1),
#   ('deny', 1),
#   ('need', 1)],
#  'Nagasheus': [('start', 2),
#   ('welcome', 1),
#   ('need', 1),
#   ('fall', 1),
#   ('add', 1)],
#  'Yamla': [('add', 17),
#   ('use', 15),
#   ('note', 13),
#   ('know', 12),
#   ('remove', 11),
#   ('upload', 11),
#   ('let', 10),
#   ('depict', 10),
#   ('think', 9),
#   ('delete', 9)],
#  'TaerkastUA': [('think', 4),
#   ('hope', 3),
#   ('go', 3),
#   ('need', 2),
#   ('pass', 2),
#   ('find', 2),
#   ('know', 2),
#   ('clean', 2),
#   ('end', 2),
#   ('happen', 2)],
#  'Dekkappai': [('think', 38),
#   ('work', 29),
#   ('know', 29),
#   ('delete', 20),
#   ('look', 20),
#   ('get', 19),
#   ('come', 18),
#   ('source', 18),
#   ('start', 17),
#   ('remove', 16)],
#  'DsgnWrte': [],
#  'Smallman12q': [('add', 14),
#   ('like', 11),
#   ('know', 9),
#   ('use', 7),
#   ('create', 7),
#   ('write', 6),
#   ('let', 5),
#   ('work', 5),
#   ('give', 5),
#   ('want', 4)],
#  'TheJazzDalek': [('suppose', 2),
#   ('change', 2),
#   ('like', 2),
#   ('appear', 2),
#   ('delete', 2),
#   ('include', 1),
#   ('exist', 1),
#   ('mean', 1),
#   ('list', 1),
#   ('talk', 1)],
#  '67.101.7.21': [('need', 2),
#   ('write', 1),
#   ('complete', 1),
#   ('feature', 1),
#   ('tell', 1),
#   ('discuss', 1),
#   ('lead', 1),
#   ('assess', 1)],
#  'Raul654': [('think', 21),
#   ('get', 14),
#   ('need', 13),
#   ('want', 13),
#   ('know', 13),
#   ('see', 10),
#   ('feature', 10),
#   ('go', 10),
#   ('look', 9),
#   ('fix', 9)],
#  'Bearcat': [('know', 30),
#   ('need', 27),
#   ('add', 26),
#   ('think', 19),
#   ('use', 18),
#   ('go', 18),
#   ('file', 16),
#   ('want', 15),
#   ('create', 13),
#   ('move', 13)],
#  'Steven Walling': [('know', 8),
#   ('think', 5),
#   ('let', 5),
#   ('talk', 4),
#   ('add', 4),
#   ('need', 4),
#   ('delete', 4),
#   ('assert', 4),
#   ('get', 4),
#   ('email', 4)],
#  'AndonicO': [('thank', 4),
#   ('take', 3),
#   ('try', 2),
#   ('say', 2),
#   ('understand', 2),
#   ('come', 2),
#   ('hope', 2),
#   ('look', 2),
#   ('fix', 2),
#   ('know', 2)],
#  'Sasuke-kun27': [('know', 13),
#   ('think', 12),
#   ('look', 11),
#   ('help', 10),
#   ('thank', 10),
#   ('take', 9),
#   ('like', 8),
#   ('want', 8),
#   ('say', 7),
#   ('give', 7)],
#  '66.245.126.161': [('revert', 1), ('mismatch', 1), ('match', 1)],
#  'Benc': [('help', 4),
#   ('see', 2),
#   ('hope', 2),
#   ('read', 2),
#   ('entitle', 1),
#   ('change', 1),
#   ('finish', 1),
#   ('settle', 1),
#   ('let', 1),
#   ('know', 1)],
#  'Moxy': [('find', 14),
#   ('think', 12),
#   ('remove', 9),
#   ('go', 7),
#   ('add', 6),
#   ('need', 6),
#   ('take', 6),
#   ('ask', 5),
#   ('talk', 5),
#   ('revert', 5)],
#  'The Rambling Man': [('know', 71),
#   ('think', 60),
#   ('need', 52),
#   ('let', 50),
#   ('add', 48),
#   ('look', 30),
#   ('go', 29),
#   ('want', 29),
#   ('hope', 25),
#   ('help', 25)],
#  'Woody': [('think', 63),
#   ('need', 24),
#   ('block', 20),
#   ('know', 18),
#   ('leave', 18),
#   ('revert', 17),
#   ('find', 15),
#   ('note', 14),
#   ('go', 13),
#   ('read', 12)],
#  'Ruhrfisch': [('add', 78),
#   ('think', 72),
#   ('know', 67),
#   ('want', 39),
#   ('find', 37),
#   ('look', 34),
#   ('try', 34),
#   ('let', 30),
#   ('help', 24),
#   ('work', 24)],
#  'Wilhelmina Will': [('know', 6),
#   ('need', 4),
#   ('look', 4),
#   ('thank', 4),
#   ('notice', 3),
#   ('delete', 3),
#   ('mention', 3),
#   ('hope', 3),
#   ('think', 2),
#   ('ask', 2)],
#  'Trilobitealive': [('blank', 2),
#   ('know', 2),
#   ('tell', 2),
#   ('panic', 2),
#   ('see', 2),
#   ('identify', 2),
#   ('try', 2),
#   ('disentangle', 2),
#   ('hit', 2),
#   ('put', 2)],
#  'IceCreamAntisocial': [('look', 1),
#   ('let', 1),
#   ('verify', 1),
#   ('expand', 1),
#   ('reword', 1),
#   ('post', 1),
#   ('honor', 1),
#   ('write', 1),
#   ('capture', 1),
#   ('thank', 1)],
#  'ThatPeskyCommoner': [('think', 9),
#   ('look', 8),
#   ('find', 4),
#   ('come', 4),
#   ('notice', 3),
#   ('exist', 3),
#   ('know', 3),
#   ('domesticate', 3),
#   ('like', 3),
#   ('play', 3)],
#  'Xornok': [('know', 1),
#   ('call', 1),
#   ('describe', 1),
#   ('go', 1),
#   ('move', 1),
#   ('worry', 1)],
#  'tone': [('delete', 209),
#   ('restore', 151),
#   ('think', 79),
#   ('need', 65),
#   ('help', 64),
#   ('write', 53),
#   ('hope', 51),
#   ('know', 48),
#   ('add', 46),
#   ('fix', 45)],
#  'Jackhynes': [('appreciate', 3),
#   ('create', 3),
#   ('capitalise', 3),
#   ('feature', 2),
#   ('restart', 2),
#   ('know', 2),
#   ('think', 2),
#   ('change', 2),
#   ('follow', 2),
#   ('slow', 1)],
#  'Flyer22': [('need', 56),
#   ('state', 56),
#   ('feel', 52),
#   ('know', 46),
#   ('mean', 31),
#   ('think', 31),
#   ('add', 28),
#   ('thank', 26),
#   ('see', 26),
#   ('revert', 26)],
#  'CorenSearchBot': [('copyright', 176),
#   ('donate', 176),
#   ('find', 113),
#   ('exist', 113),
#   ('remove', 113),
#   ('confuse', 109),
#   ('place', 101),
#   ('appreciate', 101),
#   ('drop', 101),
#   ('locate', 100)],
#  'Jesanj': [('think', 5),
#   ('reply', 3),
#   ('thank', 3),
#   ('say', 2),
#   ('integrate', 2),
#   ('mean', 2),
#   ('know', 2),
#   ('review', 2),
#   ('push', 2),
#   ('submit', 1)],
#  'LeadSongDog': [('thank', 9),
#   ('need', 8),
#   ('find', 8),
#   ('go', 7),
#   ('give', 6),
#   ('add', 6),
#   ('know', 6),
#   ('discuss', 6),
#   ('use', 5),
#   ('say', 5)],
#  'Jackaranga': [('like', 4),
#   ('live', 2),
#   ('give', 2),
#   ('move', 2),
#   ('think', 2),
#   ('translate', 2),
#   ('change', 2),
#   ('add', 2),
#   ('allow', 1),
#   ('keep', 1)],
#  'Rcej': [('know', 7),
#   ('review', 6),
#   ('need', 5),
#   ('contribute', 5),
#   ('thank', 4),
#   ('start', 3),
#   ('think', 3),
#   ('clarify', 3),
#   ('respond', 3),
#   ('grab', 2)],
#  '{unknown-7}': [('wonder', 1),
#   ('live', 1),
#   ('include', 1),
#   ('go', 1),
#   ('readd', 1),
#   ('remove', 1),
#   ('talk', 1)],
#  'Victuallers': [('think', 25),
#   ('need', 12),
#   ('help', 12),
#   ('find', 11),
#   ('want', 11),
#   ('look', 11),
#   ('hope', 10),
#   ('tell', 10),
#   ('go', 9),
#   ('know', 9)],
#  'Arhugefan': [('use', 1), ('color', 1)],
#  'Cool Hand Luke': [('think', 27),
#   ('look', 13),
#   ('know', 9),
#   ('delete', 8),
#   ('respond', 8),
#   ('go', 8),
#   ('talk', 8),
#   ('like', 8),
#   ('try', 7),
#   ('check', 6)],
#  'Ikkyu2': [('appear', 2),
#   ('die', 2),
#   ('take', 2),
#   ('look', 2),
#   ('try', 2),
#   ('like', 2),
#   ('read', 1),
#   ('welcome', 1),
#   ('guess', 1),
#   ('need', 1)],
#  'Colin': [('think', 60),
#   ('know', 31),
#   ('look', 30),
#   ('need', 23),
#   ('help', 20),
#   ('find', 19),
#   ('change', 18),
#   ('want', 18),
#   ('read', 17),
#   ('write', 15)],
#  'ErgoSum88': [('know', 10),
#   ('go', 8),
#   ('dot', 7),
#   ('try', 7),
#   ('edit', 4),
#   ('make', 4),
#   ('stop', 4),
#   ('enjoy', 4),
#   ('help', 4),
#   ('want', 4)],
#  'Davemeistermoab': [('think', 8),
#   ('go', 5),
#   ('know', 5),
#   ('look', 4),
#   ('suck', 4),
#   ('try', 4),
#   ('find', 3),
#   ('need', 3),
#   ('come', 2),
#   ('intervene', 2)],
#  'Realkyhick': [('think', 19),
#   ('add', 11),
#   ('delete', 10),
#   ('post', 9),
#   ('help', 9),
#   ('meet', 7),
#   ('write', 7),
#   ('take', 6),
#   ('say', 6),
#   ('work', 6)],
#  '{unknown-8}': [],
#  'Fuzzform': [('look', 4),
#   ('try', 4),
#   ('come', 2),
#   ('make', 2),
#   ('cite', 2),
#   ('keep', 2),
#   ('go', 2),
#   ('place', 2),
#   ('send', 2),
#   ('suppose', 1)],
#  'Rschen7754': [('want', 10),
#   ('need', 5),
#   ('use', 5),
#   ('think', 5),
#   ('block', 4),
#   ('go', 3),
#   ('try', 3),
#   ('fail', 3),
#   ('help', 3),
#   ('receive', 3)],
#  'Moabdave': [('like', 8),
#   ('leave', 6),
#   ('find', 5),
#   ('say', 4),
#   ('check', 4),
#   ('hope', 4),
#   ('come', 4),
#   ('know', 4),
#   ('create', 4),
#   ('go', 4)],
#  'Durova': [('think', 20),
#   ('font', 19),
#   ('post', 19),
#   ('want', 15),
#   ('know', 15),
#   ('feature', 15),
#   ('help', 14),
#   ('come', 13),
#   ('go', 13),
#   ('hope', 11)],
#  'Bradadkins274': [('work', 2)],
#  'Dethomas': [('upload', 5),
#   ('delete', 3),
#   ('thank', 3),
#   ('check', 2),
#   ('find', 2),
#   ('edit', 2),
#   ('click', 2),
#   ('locate', 2),
#   ('log', 2),
#   ('select', 2)],
#  'Brossow': [('upload', 4),
#   ('delete', 4),
#   ('think', 4),
#   ('say', 4),
#   ('vote', 3),
#   ('check', 3),
#   ('signify', 2),
#   ('remember', 2),
#   ('feel', 2),
#   ('contact', 2)],
#  'Imzadi1979': [('add', 28),
#   ('tag', 16),
#   ('need', 15),
#   ('change', 14),
#   ('think', 13),
#   ('use', 12),
#   ('want', 10),
#   ('find', 10),
#   ('know', 9),
#   ('show', 8)],
#  'Laser_brain': [('work', 11),
#   ('think', 11),
#   ('know', 11),
#   ('try', 10),
#   ('look', 9),
#   ('need', 8),
#   ('get', 7),
#   ('go', 7),
#   ('believe', 7),
#   ('find', 6)],
#  'SMasters': [('need', 7),
#   ('thank', 6),
#   ('wear', 5),
#   ('remove', 4),
#   ('think', 4),
#   ('add', 4),
#   ('mean', 4),
#   ('help', 4),
#   ('look', 4),
#   ('let', 3)],
#  'Finetooth': [('think', 34),
#   ('look', 24),
#   ('add', 24),
#   ('find', 17),
#   ('work', 17),
#   ('like', 14),
#   ('help', 13),
#   ('nominate', 10),
#   ('use', 9),
#   ('come', 9)],
#  'Ender3057': [('let', 1), ('meet', 1)],
#  'Eternal Equinox': [('go', 1), ('check', 1)],
#  'CL': [],
#  'Midgley': [('think', 6),
#   ('read', 4),
#   ('work', 4),
#   ('write', 3),
#   ('leave', 3),
#   ('look', 3),
#   ('need', 3),
#   ('copy', 2),
#   ('note', 2),
#   ('exist', 2)],
#  'TomasBat': [('font', 1),
#   ('guess', 1),
#   ('believe', 1),
#   ('retain', 1),
#   ('skip', 1),
#   ('carry', 1),
#   ('think', 1),
#   ('start', 1),
#   ('hope', 1),
#   ('return', 1)],
#  'Aldux': [('know', 33),
#   ('think', 32),
#   ('find', 32),
#   ('try', 24),
#   ('ask', 20),
#   ('give', 19),
#   ('write', 18),
#   ('speak', 18),
#   ('use', 18),
#   ('tell', 17)],
#  'NortyNort': [('think', 27),
#   ('look', 21),
#   ('work', 16),
#   ('find', 16),
#   ('know', 15),
#   ('add', 12),
#   ('let', 11),
#   ('want', 10),
#   ('help', 10),
#   ('notice', 10)],
#  'SWAdair': [('thank', 54),
#   ('check', 32),
#   ('delete', 27),
#   ('want', 26),
#   ('think', 23),
#   ('block', 23),
#   ('look', 22),
#   ('know', 22),
#   ('help', 21),
#   ('list', 20)],
#  'Stevouk': [('recall', 1),
#   ('think', 1),
#   ('look', 1),
#   ('wipe', 1),
#   ('need', 1),
#   ('cut', 1),
#   ('paste', 1),
#   ('build', 1),
#   ('forget', 1)],
#  'Morhange': [('mention', 1)],
#  'Sarranduin': [('feel', 2),
#   ('have', 2),
#   ('work', 2),
#   ('kick', 1),
#   ('reduce', 1),
#   ('look', 1),
#   ('change', 1),
#   ('come', 1),
#   ('regret', 1),
#   ('take', 1)],
#  'Fredddie': [('think', 6),
#   ('revert', 4),
#   ('look', 4),
#   ('create', 3),
#   ('feel', 3),
#   ('try', 3),
#   ('find', 3),
#   ('work', 3),
#   ('read', 2),
#   ('get', 2)],
#  'Masterpiece2000': [('thank', 15),
#   ('appear', 4),
#   ('create', 4),
#   ('remove', 3),
#   ('know', 3),
#   ('delete', 3),
#   ('download', 2),
#   ('reply', 2),
#   ('see', 2),
#   ('think', 2)],
#  'Nick Garvey': [('remove', 4),
#   ('delete', 3),
#   ('propose', 3),
#   ('improve', 3),
#   ('meet', 3),
#   ('add', 2),
#   ('explain', 2),
#   ('plan', 2),
#   ('suggest', 1),
#   ('accord', 1)],
#  'Kappa': [('think', 16),
#   ('delete', 10),
#   ('try', 10),
#   ('know', 8),
#   ('say', 7),
#   ('find', 6),
#   ('look', 6),
#   ('merge', 5),
#   ('want', 5),
#   ('take', 5)],
#  'Sambc': [('mean', 4),
#   ('block', 3),
#   ('guess', 2),
#   ('think', 2),
#   ('want', 2),
#   ('go', 2),
#   ('imply', 1),
#   ('advise', 1),
#   ('describe', 1),
#   ('draft', 1)],
#  'Ntsimp': [('add', 3),
#   ('help', 3),
#   ('stop', 2),
#   ('pass', 2),
#   ('improve', 1),
#   ('owe', 1),
#   ('try', 1),
#   ('post', 1),
#   ('come', 1)],
#  'Rune.welsh': [('let', 2),
#   ('know', 2),
#   ('read', 1),
#   ('list', 1),
#   ('want', 1),
#   ('think', 1),
#   ('expect', 1),
#   ('suggest', 1),
#   ('convert', 1),
#   ('fill', 1)],
#  'Renata3': [('think', 14),
#   ('know', 9),
#   ('create', 8),
#   ('need', 7),
#   ('thank', 6),
#   ('work', 5),
#   ('address', 4),
#   ('nominate', 3),
#   ('look', 3),
#   ('place', 3)],
#  'Tony1': [('think', 56),
#   ('know', 37),
#   ('need', 25),
#   ('write', 22),
#   ('want', 21),
#   ('link', 20),
#   ('ask', 20),
#   ('change', 19),
#   ('go', 19),
#   ('say', 19)],
#  'Photouploaded': [('follow', 2),
#   ('state', 1),
#   ('know', 1),
#   ('appear', 1),
#   ('title', 1),
#   ('think', 1),
#   ('leave', 1)],
#  'Mike_Searson': [('add', 3),
#   ('know', 3),
#   ('agree', 2),
#   ('take', 2),
#   ('split', 2),
#   ('film', 2),
#   ('relate', 2),
#   ('outweigh', 2),
#   ('want', 2),
#   ('use', 2)],
#  'Ugen64': [('revert', 8),
#   ('provide', 4),
#   ('suggest', 3),
#   ('feel', 3),
#   ('violate', 3),
#   ('edit', 3),
#   ('remember', 3),
#   ('want', 2),
#   ('delete', 2),
#   ('comment', 2)],
#  'NeoChaosX': [('cite', 3),
#   ('come', 2),
#   ('belong', 2),
#   ('remember', 2),
#   ('include', 2),
#   ('find', 2),
#   ('request', 2),
#   ('supply', 2),
#   ('deal', 1),
#   ('base', 1)],
#  'GoodDay': [('think', 22),
#   ('remove', 17),
#   ('leave', 15),
#   ('continue', 14),
#   ('let', 13),
#   ('go', 13),
#   ('know', 12),
#   ('add', 12),
#   ('see', 11),
#   ('try', 10)],
#  'Garion96': [('delete', 24),
#   ('see', 15),
#   ('think', 11),
#   ('remove', 11),
#   ('change', 11),
#   ('add', 10),
#   ('state', 9),
#   ('need', 9),
#   ('revert', 8),
#   ('work', 8)],
#  'Mafia Expert': [('mention', 4),
#   ('understand', 2),
#   ('establish', 2),
#   ('speak', 2),
#   ('list', 1),
#   ('search', 1),
#   ('find', 1),
#   ('delete', 1),
#   ('leave', 1),
#   ('explain', 1)],
#  'Fvasconcellos': [('think', 86),
#   ('thank', 60),
#   ('know', 55),
#   ('add', 51),
#   ('hope', 42),
#   ('like', 34),
#   ('look', 33),
#   ('ask', 32),
#   ('get', 31),
#   ('use', 28)],
#  'Garyvdm': [],
#  'Disavian': [('think', 4),
#   ('go', 3),
#   ('get', 3),
#   ('nominate', 2),
#   ('like', 2),
#   ('know', 2),
#   ('start', 2),
#   ('need', 2),
#   ('figure', 2),
#   ('remove', 2)],
#  'Canadian Paul': [('find', 17),
#   ('think', 14),
#   ('know', 13),
#   ('nominate', 11),
#   ('delete', 10),
#   ('get', 9),
#   ('add', 9),
#   ('need', 8),
#   ('list', 8),
#   ('say', 8)],
#  '76.199.65.126': [('try', 2),
#   ('delete', 2),
#   ('think', 2),
#   ('point', 2),
#   ('assist', 1),
#   ('adopt', 1),
#   ('recommend', 1),
#   ('go', 1),
#   ('tweak', 1),
#   ('paint', 1)],
#  'Aguerriero': [('ask', 7),
#   ('post', 4),
#   ('understand', 4),
#   ('say', 4),
#   ('review', 3),
#   ('request', 3),
#   ('know', 3),
#   ('reference', 3),
#   ('occur', 3),
#   ('reply', 2)],
#  'Stevenfruitsmaak': [('think', 8),
#   ('create', 4),
#   ('write', 4),
#   ('get', 4),
#   ('like', 4),
#   ('read', 3),
#   ('find', 3),
#   ('correct', 3),
#   ('use', 3),
#   ('need', 3)],
#  'Peteforsyth': [('think', 14),
#   ('know', 10),
#   ('look', 9),
#   ('want', 6),
#   ('find', 5),
#   ('read', 5),
#   ('let', 4),
#   ('set', 4),
#   ('get', 4),
#   ('notice', 4)],
#  'Tabercil': [('look', 26),
#   ('say', 23),
#   ('need', 21),
#   ('try', 21),
#   ('think', 20),
#   ('find', 17),
#   ('want', 17),
#   ('add', 16),
#   ('delete', 16),
#   ('upload', 14)],
#  'Nick Graves': [('thank', 4),
#   ('delete', 3),
#   ('think', 2),
#   ('change', 2),
#   ('look', 2),
#   ('vote', 2),
#   ('remove', 2),
#   ('type', 2),
#   ('expand', 1),
#   ('suggest', 1)],
#  'Tompw': [('wonder', 2),
#   ('feature', 1),
#   ('know', 1),
#   ('welcome', 1),
#   ('sort', 1),
#   ('come', 1),
#   ('read', 1),
#   ('neglect', 1),
#   ('update', 1),
#   ('try', 1)],
#  'Lar': [('think', 72),
#   ('need', 26),
#   ('want', 25),
#   ('know', 21),
#   ('ask', 21),
#   ('answer', 21),
#   ('hope', 19),
#   ('go', 19),
#   ('feel', 19),
#   ('work', 17)],
#  'Larbot': [('run', 5),
#   ('think', 3),
#   ('find', 3),
#   ('look', 3),
#   ('block', 3),
#   ('move', 2),
#   ('want', 2),
#   ('ask', 2),
#   ('need', 2),
#   ('decline', 2)],
#  'Remember': [('think', 10),
#   ('appreciate', 8),
#   ('want', 7),
#   ('find', 6),
#   ('work', 6),
#   ('know', 6),
#   ('go', 5),
#   ('help', 4),
#   ('base', 4),
#   ('let', 4)],
#  'Scorpion0422': [('add', 30),
#   ('think', 29),
#   ('remove', 18),
#   ('look', 17),
#   ('need', 17),
#   ('go', 16),
#   ('say', 16),
#   ('want', 16),
#   ('know', 14),
#   ('like', 13)],
#  'NJMauthor': [('understand', 1), ('change', 1), ('describe', 1)],
#  'JuJube': [('decide', 5),
#   ('think', 4),
#   ('withdraw', 4),
#   ('try', 4),
#   ('prove', 4),
#   ('interfere', 4),
#   ('remove', 4),
#   ('know', 4),
#   ('look', 3),
#   ('change', 3)],
#  'Luna Santin': [('ndash', 31),
#   ('look', 20),
#   ('block', 15),
#   ('know', 13),
#   ('let', 13),
#   ('think', 12),
#   ('ask', 10),
#   ('set', 9),
#   ('find', 8),
#   ('mention', 7)],
#  'Best O Fortuna': [('think', 4),
#   ('leave', 3),
#   ('say', 3),
#   ('try', 2),
#   ('hold', 2),
#   ('catch', 1),
#   ('light', 1),
#   ('work', 1),
#   ('know', 1),
#   ('remember', 1)],
#  'Davidkevin': [('spawn', 1),
#   ('see', 1),
#   ('plan', 1),
#   ('know', 1),
#   ('agree', 1),
#   ('expect', 1),
#   ('stalk', 1)],
#  'Rick570': [('know', 2),
#   ('promulgate', 2),
#   ('explain', 2),
#   ('thank', 2),
#   ('check', 2),
#   ('help', 2),
#   ('create', 2),
#   ('tell', 2),
#   ('change', 2),
#   ('publish', 1)],
#  'EveryDayJoe45': [('add', 7),
#   ('say', 6),
#   ('disagree', 4),
#   ('think', 4),
#   ('go', 4),
#   ('know', 3),
#   ('mind', 3),
#   ('spend', 3),
#   ('name', 3),
#   ('ask', 3)],
#  'Tourskin': [('add', 4),
#   ('work', 3),
#   ('think', 2),
#   ('follow', 2),
#   ('give', 1),
#   ('fix', 1),
#   ('know', 1),
#   ('participate', 1),
#   ('alert', 1),
#   ('propose', 1)],
#  'Calton': [('look', 5),
#   ('find', 5),
#   ('remove', 5),
#   ('ask', 4),
#   ('word', 3),
#   ('question', 3),
#   ('understand', 3),
#   ('write', 3),
#   ('post', 3),
#   ('stop', 3)],
#  'Gaff': [('vote', 1),
#   ('constitue', 1),
#   ('consider', 1),
#   ('spring', 1),
#   ('fight', 1),
#   ('hit', 1)],
#  '{unknown-9}': [('nominate', 1), ('expect', 1)],
#  'FullMetal Falcon': [('find', 6),
#   ('think', 5),
#   ('want', 4),
#   ('know', 4),
#   ('try', 4),
#   ('take', 4),
#   ('tell', 3),
#   ('work', 3),
#   ('get', 3),
#   ('use', 2)],
#  'Deatonjr': [('find', 1), ('know', 1), ('look', 1)],
#  'Davidelit': [('write', 12),
#   ('think', 7),
#   ('give', 5),
#   ('go', 5),
#   ('try', 5),
#   ('work', 5),
#   ('ask', 4),
#   ('look', 4),
#   ('read', 4),
#   ('edit', 4)],
#  '{unknown-10}': [('know', 2),
#   ('encounter', 1),
#   ('report', 1),
#   ('cause', 1),
#   ('archive', 1),
#   ('operate', 1),
#   ('follow', 1),
#   ('mention', 1),
#   ('stop', 1),
#   ('tell', 1)],
#  '{unknown-11}': [],
#  '{unknown-12}': [('tell', 1)],
#  'SatyrTN': [('think', 10),
#   ('know', 9),
#   ('add', 7),
#   ('cite', 6),
#   ('leave', 6),
#   ('run', 5),
#   ('let', 5),
#   ('say', 5),
#   ('delete', 5),
#   ('work', 5)],
#  'Phil Boswell': [('work', 5),
#   ('want', 2),
#   ('produce', 2),
#   ('format', 2),
#   ('need', 2),
#   ('find', 2),
#   ('ask', 2),
#   ('miss', 2),
#   ('provide', 2),
#   ('refer', 2)],
#  '220.255.178.29': [],
#  'Jongleur100': [('think', 8),
#   ('happen', 4),
#   ('live', 3),
#   ('remove', 2),
#   ('place', 2),
#   ('look', 2),
#   ('read', 2),
#   ('like', 2),
#   ('add', 2),
#   ('hear', 2)],
#  'Ronz': [('remove', 20),
#   ('think', 19),
#   ('add', 13),
#   ('continue', 13),
#   ('work', 12),
#   ('start', 11),
#   ('discuss', 9),
#   ('want', 9),
#   ('respond', 8),
#   ('look', 8)],
#  'GTBacchus': [('think', 471),
#   ('know', 298),
#   ('say', 201),
#   ('try', 196),
#   ('want', 176),
#   ('talk', 163),
#   ('go', 157),
#   ('get', 152),
#   ('work', 149),
#   ('let', 135)],
#  '78.149.71.17': [],
#  'Iss246': [('think', 5),
#   ('write', 4),
#   ('cover', 3),
#   ('access', 3),
#   ('cite', 3),
#   ('remove', 2),
#   ('mean', 2),
#   ('add', 2),
#   ('want', 2),
#   ('publish', 2)],
#  'DO11.10': [('think', 18),
#   ('know', 8),
#   ('ask', 6),
#   ('thank', 6),
#   ('add', 6),
#   ('find', 4),
#   ('want', 4),
#   ('try', 4),
#   ('need', 4),
#   ('read', 4)],
#  'Wildhartlivie': [('think', 32),
#   ('know', 25),
#   ('remove', 25),
#   ('note', 23),
#   ('come', 20),
#   ('say', 17),
#   ('want', 15),
#   ('add', 15),
#   ('change', 14),
#   ('try', 14)],
#  'DarkPhoenix': [('show', 1), ('corrupt', 1), ('happen', 1)],
#  'MarcoTolo': [('cite', 4),
#   ('take', 2),
#   ('let', 1),
#   ('second', 1),
#   ('organize', 1),
#   ('reference', 1),
#   ('deserve', 1),
#   ('count', 1),
#   ('leave', 1),
#   ('find', 1)],
#  'Dagoldman': [('write', 1)],
#  'Mark83': [('think', 10),
#   ('know', 8),
#   ('change', 8),
#   ('say', 7),
#   ('explain', 4),
#   ('make', 4),
#   ('rename', 4),
#   ('want', 4),
#   ('look', 4),
#   ('go', 4)],
#  'Andy Dingley': [('add', 9),
#   ('write', 7),
#   ('delete', 7),
#   ('think', 7),
#   ('list', 6),
#   ('see', 6),
#   ('find', 6),
#   ('look', 5),
#   ('know', 5),
#   ('fit', 5)],
#  'Muhandes': [('add', 51),
#   ('think', 35),
#   ('remove', 25),
#   ('want', 19),
#   ('say', 19),
#   ('know', 18),
#   ('help', 17),
#   ('use', 17),
#   ('create', 16),
#   ('go', 14)],
#  'Lou Sander': [('think', 8),
#   ('know', 4),
#   ('post', 4),
#   ('find', 4),
#   ('say', 3),
#   ('delete', 3),
#   ('hope', 3),
#   ('replace', 3),
#   ('remember', 2),
#   ('read', 2)],
#  'Prisonnet': [('think', 1), ('agree', 1), ('reach', 1)],
#  'Arcadian': [('add', 102),
#   ('think', 72),
#   ('want', 66),
#   ('look', 51),
#   ('help', 48),
#   ('need', 39),
#   ('know', 38),
#   ('recommend', 36),
#   ('talk', 34),
#   ('try', 32)],
#  'Eubulides': [('fix', 8),
#   ('leave', 7),
#   ('follow', 6),
#   ('know', 5),
#   ('suggest', 4),
#   ('work', 4),
#   ('save', 3),
#   ('feature', 3),
#   ('modify', 3),
#   ('look', 3)],
#  'Master of Puppets': [('want', 21),
#   ('hope', 19),
#   ('appreciate', 19),
#   ('work', 17),
#   ('like', 17),
#   ('know', 16),
#   ('start', 15),
#   ('think', 12),
#   ('vote', 11),
#   ('run', 11)],
#  'Nczempin': [('provide', 4),
#   ('write', 4),
#   ('revert', 3),
#   ('want', 3),
#   ('improve', 2),
#   ('say', 2),
#   ('help', 2),
#   ('think', 2),
#   ('look', 2),
#   ('notice', 2)],
#  'Greyhood': [('think', 14),
#   ('post', 10),
#   ('relate', 8),
#   ('start', 8),
#   ('hope', 6),
#   ('add', 6),
#   ('help', 5),
#   ('update', 5),
#   ('need', 5),
#   ('want', 5)],
#  'Offliner': [('know', 2),
#   ('think', 2),
#   ('try', 2),
#   ('appreciate', 1),
#   ('figure', 1),
#   ('establish', 1),
#   ('demonstrate', 1),
#   ('involve', 1),
#   ('present', 1),
#   ('prohibit', 1)],
#  'EdJohnston': [('think', 49),
#   ('add', 36),
#   ('need', 31),
#   ('thank', 29),
#   ('block', 26),
#   ('know', 25),
#   ('report', 24),
#   ('appear', 23),
#   ('edit', 22),
#   ('revert', 21)],
#  'Asperchu': [('refer', 1), ('exist', 1)],
#  'Mateo SA': [('look', 3),
#   ('write', 2),
#   ('revert', 1),
#   ('realize', 1),
#   ('sound', 1),
#   ('mean', 1),
#   ('apologize', 1),
#   ('plan', 1),
#   ('hope', 1)],
#  'Male1979': [('tell', 2),
#   ('think', 2),
#   ('find', 2),
#   ('understand', 1),
#   ('like', 1),
#   ('provide', 1),
#   ('matter', 1),
#   ('cross', 1),
#   ('take', 1),
#   ('exist', 1)],
#  "Sabine's Sunbird": [('try', 9),
#   ('think', 9),
#   ('leave', 7),
#   ('add', 7),
#   ('change', 6),
#   ('work', 5),
#   ('know', 5),
#   ('guess', 5),
#   ('need', 5),
#   ('notice', 4)],
#  'Aoi': [('thank', 7),
#   ('tell', 6),
#   ('change', 5),
#   ('have', 4),
#   ('realize', 2),
#   ('read', 2),
#   ('state', 2),
#   ('avoid', 2),
#   ('know', 2),
#   ('understand', 2)],
#  'Marshman': [('think', 32),
#   ('mean', 19),
#   ('know', 18),
#   ('look', 16),
#   ('come', 14),
#   ('go', 14),
#   ('check', 13),
#   ('need', 13),
#   ('say', 12),
#   ('find', 12)],
#  'Ezhiki': [('know', 61),
#   ('find', 37),
#   ('let', 36),
#   ('want', 34),
#   ('need', 29),
#   ('think', 28),
#   ('add', 27),
#   ('go', 26),
#   ('work', 25),
#   ('help', 24)],
#  'Nanobear': [('think', 14),
#   ('write', 5),
#   ('find', 4),
#   ('add', 4),
#   ('look', 4),
#   ('run', 4),
#   ('say', 3),
#   ('create', 3),
#   ('call', 3),
#   ('use', 3)],
#  'Jfdwolff': [('think', 20),
#   ('add', 11),
#   ('need', 9),
#   ('hope', 9),
#   ('create', 8),
#   ('find', 7),
#   ('remove', 7),
#   ('let', 7),
#   ('know', 7),
#   ('wonder', 7)],
#  'Andy F': [('add', 15),
# ...
#  'SiGarb': [('think', 5),
#   ('mean', 3),
#   ('feel', 3),
#   ('like', 2),
#   ('ask', 2),
#   ('give', 2),
#   ('change', 2),
#   ('fill', 2),
#   ('find', 2),
#   ('look', 2)],
#  'Redux': [('need', 9),
#   ('know', 9),
#   ('try', 9),
#   ('take', 9),
#   ('thank', 8),
#   ('upload', 7),
#   ('start', 7),
#   ('look', 6),
#   ('mean', 6),
#   ('happen', 6)],
#  'Bornhj': [('know', 4),
#   ('change', 4),
#   ('let', 3),
#   ('withdraw', 3),
#   ('appreciate', 3),
#   ('compile', 3),
#   ('vote', 2),
#   ('pass', 2),
#   ('occur', 2),
#   ('learn', 2)],
#  'PhantomS': [('need', 1), ('promote', 1), ('feature', 1)],
#  'Joelr31': [('ask', 4),
#   ('update', 4),
#   ('feel', 4),
#   ('give', 3),
#   ('think', 3),
#   ('block', 3),
#   ('delete', 3),
#   ('close', 3),
#   ('let', 3),
#   ('list', 3)],
#  'Murcielago': [('lead', 2),
#   ('start', 1),
#   ('go', 1),
#   ('delete', 1),
#   ('stop', 1),
#   ('come', 1),
#   ('try', 1),
#   ('kyboshe', 1),
#   ('contribute', 1),
#   ('vote', 1)],
#  'Dalejenkins': [('remove', 3),
#   ('protect', 3),
#   ('edit', 3),
#   ('check', 2),
#   ('continue', 2),
#   ('suggest', 2),
#   ('read', 2),
#   ('reach', 2),
#   ('confirm', 2),
#   ('address', 1)],
#  "Vrubel's Demons": [('include', 3),
#   ('remove', 2),
#   ('develop', 2),
#   ('exclude', 1),
#   ('note', 1),
#   ('cite', 1),
#   ('know', 1),
#   ('say', 1),
#   ('allow', 1),
#   ('exist', 1)],
#  '3bulletproof16': [('thank', 6),
#   ('help', 5),
#   ('add', 5),
#   ('continue', 5),
#   ('appreciate', 5),
#   ('claim', 4),
#   ('get', 4),
#   ('edit', 4),
#   ('sign', 4),
#   ('tell', 4)],
#  'Rebelguys2': [('block', 6),
#   ('go', 5),
#   ('need', 4),
#   ('leave', 4),
#   ('upload', 4),
#   ('add', 3),
#   ('mean', 3),
#   ('break', 3),
#   ('bring', 3),
#   ('think', 3)],
#  '{unknown-46}': [('create', 3),
#   ('join', 2),
#   ('tell', 2),
#   ('consider', 1),
#   ('make', 1),
#   ('call', 1),
#   ('wonder', 1),
#   ('notice', 1),
#   ('live', 1),
#   ('improve', 1)],
#  'Kogsquinge': [],
#  'Are You The Cow Of Pain?': [('direct', 5),
#   ('establish', 3),
#   ('imagine', 2),
#   ('remove', 2),
#   ('stop', 2),
#   ('see', 1),
#   ('thank', 1),
#   ('check', 1),
#   ('search', 1),
#   ('revert', 1)],
#  'Oldwildbill': [],
#  '{unknown-47}': [],
#  'CTSWyneken': [('think', 13),
#   ('work', 12),
#   ('need', 10),
#   ('try', 10),
#   ('like', 8),
#   ('help', 8),
#   ('talk', 8),
#   ('know', 8),
#   ('look', 7),
#   ('say', 7)],
#  'Noroton': [('think', 43),
#   ('want', 15),
#   ('go', 15),
#   ('say', 12),
#   ('get', 12),
#   ('try', 10),
#   ('come', 9),
#   ('look', 9),
#   ('mention', 8),
#   ('take', 8)],
#  'The Mink Ermine Fox': [('find', 2),
#   ('take', 2),
#   ('go', 1),
#   ('admit', 1),
#   ('retract', 1),
#   ('say', 1),
#   ('feel', 1),
#   ('rate', 1),
#   ('originate', 1),
#   ('grow', 1)],
#  'Wallywall': [('tag', 2),
#   ('help', 1),
#   ('solve', 1),
#   ('demand', 1),
#   ('include', 1),
#   ('identify', 1),
#   ('exist', 1),
#   ('increase', 1),
#   ('know', 1)],
#  'Lithistman': [('think', 13),
#   ('give', 6),
#   ('go', 5),
#   ('know', 4),
#   ('make', 4),
#   ('fix', 4),
#   ('hope', 4),
#   ('read', 4),
#   ('redirect', 4),
#   ('wonder', 3)],
#  'MichaelQSchmidt': [('think', 28),
#   ('find', 27),
#   ('thank', 22),
#   ('look', 19),
#   ('need', 18),
#   ('consider', 15),
#   ('appreciate', 15),
#   ('work', 15),
#   ('go', 14),
#   ('source', 14)],
#  'Prolog': [('block', 20),
#   ('add', 10),
#   ('create', 9),
#   ('think', 9),
#   ('remove', 7),
#   ('go', 5),
#   ('use', 5),
#   ('revert', 5),
#   ('give', 5),
#   ('write', 5)],
#  'Kungfu2187': [('thank', 7),
#   ('pierce', 4),
#   ('decide', 2),
#   ('miss', 2),
#   ('redevelop', 2),
#   ('need', 2),
#   ('set', 1),
#   ('violate', 1),
#   ('create', 1),
#   ('follow', 1)],
#  'Propaniac': [('know', 13),
#   ('think', 12),
#   ('say', 11),
#   ('look', 9),
#   ('go', 9),
#   ('delete', 9),
#   ('remove', 8),
#   ('want', 8),
#   ('move', 8),
#   ('undo', 7)],
#  'Drini': [('stop', 3),
#   ('go', 3),
#   ('request', 2),
#   ('say', 2),
#   ('understand', 2),
#   ('revert', 2),
#   ('find', 2),
#   ('delete', 1),
#   ('edit', 1),
#   ('apply', 1)],
#  'Smetanahue': [('think', 7),
#   ('revert', 3),
#   ('change', 3),
#   ('include', 2),
#   ('list', 2),
#   ('make', 1),
#   ('avoid', 1),
#   ('encourage', 1),
#   ('leave', 1),
#   ('communicate', 1)],
#  'MikeGlyer': [('see', 1),
#   ('keep', 1),
#   ('come', 1),
#   ('discard', 1),
#   ('pique', 1),
#   ('think', 1),
#   ('work', 1),
#   ('delete', 1),
#   ('ask', 1)],
#  'Ashley Pomeroy': [('look', 2),
#   ('give', 2),
#   ('consider', 1),
#   ('leave', 1),
#   ('write', 1),
#   ('publish', 1),
#   ('exist', 1),
#   ('get', 1),
#   ('prove', 1),
#   ('say', 1)],
#  'Fraslet': [('revert', 1), ('believe', 1)],
#  'John Reaves': [('revert', 5),
#   ('notice', 4),
#   ('sign', 3),
#   ('mean', 3),
#   ('need', 3),
#   ('guess', 3),
#   ('forget', 3),
#   ('suppose', 3),
#   ('see', 3),
#   ('attempt', 2)],
#  'BScar23625': [('mean', 3),
#   ('like', 2),
#   ('plan', 1),
#   ('pick', 1),
#   ('miss', 1),
#   ('meet', 1),
#   ('wish', 1),
#   ('look', 1),
#   ('sod', 1),
#   ('suggest', 1)],
#  'Timl2k4': [('hide', 5),
#   ('understand', 5),
#   ('add', 4),
#   ('look', 4),
#   ('mean', 4),
#   ('help', 4),
#   ('think', 3),
#   ('capitalize', 3),
#   ('wonder', 3),
#   ('discuss', 3)],
#  'Ks0stm': [('leave', 24),
#   ('reply', 22),
#   ('think', 7),
#   ('find', 6),
#   ('want', 4),
#   ('end', 3),
#   ('bother', 3),
#   ('know', 3),
#   ('add', 3),
#   ('include', 3)],
#  'Lexein': [('support', 4),
#   ('read', 4),
#   ('revert', 4),
#   ('think', 3),
#   ('write', 3),
#   ('thank', 3),
#   ('find', 3),
#   ('discuss', 3),
#   ('stand', 3),
#   ('establish', 2)],
#  'Sephiroth BCR': [('add', 7),
#   ('want', 5),
#   ('find', 4),
#   ('go', 3),
#   ('remove', 3),
#   ('appreciate', 3),
#   ('think', 3),
#   ('believe', 3),
#   ('confirm', 2),
#   ('fix', 2)],
#  'TwoMightyGods': [('upload', 2),
#   ('tag', 2),
#   ('delete', 2),
#   ('consider', 1),
#   ('check', 1),
#   ('specify', 1),
#   ('find', 1),
#   ('follow', 1),
#   ('describe', 1),
#   ('copyright', 1)],
#  'CouldOughta': [('get', 1),
#   ('suppose', 1),
#   ('perform', 1),
#   ('meet', 1),
#   ('wish', 1),
#   ('take', 1)],
#  'UnitedStatesian': [('think', 20),
#   ('remove', 18),
#   ('delete', 13),
#   ('fix', 10),
#   ('know', 8),
#   ('say', 8),
#   ('see', 7),
#   ('look', 7),
#   ('let', 6),
#   ('move', 6)],
#  'Crossmr': [('provide', 22),
#   ('remove', 19),
#   ('want', 19),
#   ('think', 16),
#   ('find', 15),
#   ('read', 14),
#   ('edit', 14),
#   ('know', 13),
#   ('block', 13),
#   ('mean', 12)],
#  'Arwel_Parry': [('handle', 1),
#   ('create', 1),
#   ('throw', 1),
#   ('protect', 1),
#   ('wonder', 1),
#   ('account', 1),
#   ('get', 1),
#   ('note', 1),
#   ('state', 1),
#   ('revert', 1)],
#  'TML': [('think', 2),
#   ('block', 2),
#   ('appear', 1),
#   ('create', 1),
#   ('stand', 1),
#   ('discover', 1),
#   ('edit', 1),
#   ('watchlist', 1),
#   ('revert', 1),
#   ('wonder', 1)],
#  'Mrlopez2681': [('get', 3),
#   ('scan', 2),
#   ('show', 2),
#   ('thank', 1),
#   ('read', 1),
#   ('guess', 1),
#   ('think', 1),
#   ('pay', 1),
#   ('name', 1),
#   ('look', 1)],
#  'Rmrfstar': [('fix', 7),
#   ('look', 6),
#   ('think', 6),
#   ('write', 4),
#   ('challenge', 4),
#   ('need', 4),
#   ('appreciate', 3),
#   ('read', 3),
#   ('review', 3),
#   ('know', 3)],
#  'Deenoe': [('effect', 1),
#   ('remove', 1),
#   ('let', 1),
#   ('edit', 1),
#   ('answer', 1),
#   ('think', 1),
#   ('want', 1)],
#  'Hoverfish': [('find', 7),
#   ('add', 6),
#   ('know', 6),
#   ('try', 6),
#   ('ask', 6),
#   ('miss', 5),
#   ('hope', 5),
#   ('thank', 5),
#   ('notice', 4),
#   ('start', 4)],
#  'Erwin85Bot': [('upload', 274),
#   ('note', 168),
#   ('delete', 137),
#   ('mean', 137),
#   ('embed', 137),
#   ('inform', 134),
#   ('copy', 134),
#   ('view', 4),
#   ('turn', 4),
#   ('hold', 3)],
#  'Tetra Vega': [('vandalise', 1), ('revert', 1)],
#  'Nobunaga24': [('think', 2),
#   ('report', 2),
#   ('violate', 1),
#   ('create', 1),
#   ('lighthearte', 1),
#   ('believe', 1),
#   ('know', 1),
#   ('get', 1),
#   ('battle', 1)],
#  'Myles325a': [('think', 3),
#   ('delete', 2),
#   ('begin', 2),
#   ('deal', 2),
#   ('answer', 1),
#   ('bother', 1),
#   ('feature', 1),
#   ('kenken', 1),
#   ('include', 1),
#   ('ask', 1)],
#  'Mholland': [('need', 2),
#   ('add', 2),
#   ('delete', 1),
#   ('apply', 1),
#   ('think', 1),
#   ('notice', 1),
#   ('tag', 1),
#   ('place', 1),
#   ('reduce', 1),
#   ('understand', 1)],
#  'Vanderdecken': [('click', 4),
#   ('agree', 2),
#   ('change', 2),
#   ('tell', 2),
#   ('remember', 2),
#   ('say', 2),
#   ('know', 2),
#   ('see', 2),
#   ('vandalise', 1),
#   ('relate', 1)],
#  'Khukri': [('block', 11),
#   ('look', 8),
#   ('leave', 6),
#   ('report', 6),
#   ('receive', 6),
#   ('know', 6),
#   ('work', 6),
#   ('wonder', 5),
#   ('remove', 5),
#   ('revert', 5)],
#  'Finereach': [('highlight', 1), ('think', 1), ('ask', 1), ('welcome', 1)],
#  'Chacor': [('ndash', 42),
#   ('think', 6),
#   ('add', 6),
#   ('say', 5),
#   ('mention', 4),
#   ('know', 4),
#   ('want', 3),
#   ('use', 3),
#   ('round', 3),
#   ('restore', 3)],
#  'Berean Hunter': [('try', 20),
#   ('think', 12),
#   ('look', 12),
#   ('know', 12),
#   ('revert', 11),
#   ('post', 11),
#   ('want', 11),
#   ('edit', 10),
#   ('see', 10),
#   ('come', 10)],
#  'RFD': [('start', 79),
#   ('thank', 67),
#   ('add', 42),
#   ('come', 36),
#   ('need', 33),
#   ('hope', 31),
#   ('go', 29),
#   ('take', 25),
#   ('know', 24),
#   ('think', 23)],
#  'DickClarkMises': [('publish', 4),
#   ('delete', 3),
#   ('find', 3),
#   ('try', 2),
#   ('contest', 2),
#   ('cite', 2),
#   ('write', 2),
#   ('appear', 2),
#   ('state', 2),
#   ('discuss', 2)],
#  'Pm shef': [('revert', 4),
#   ('continue', 3),
#   ('find', 3),
#   ('feel', 3),
#   ('edit', 3),
#   ('remove', 3),
#   ('create', 2),
#   ('think', 2),
#   ('want', 2),
#   ('thank', 2)],
#  'Hurricanehink': [('think', 54),
#   ('know', 48),
#   ('work', 32),
#   ('need', 21),
#   ('ask', 21),
#   ('look', 20),
#   ('want', 18),
#   ('find', 18),
#   ('go', 18),
#   ('add', 17)],
#  'Anthony DiPierro': [('see', 1)],
#  'Enochlau': [('delete', 22),
#   ('like', 5),
#   ('want', 5),
#   ('tag', 5),
#   ('think', 5),
#   ('look', 5),
#   ('mean', 5),
#   ('know', 4),
#   ('use', 4),
#   ('need', 4)],
#  'Best username yet': [('find', 2),
#   ('work', 2),
#   ('think', 2),
#   ('call', 2),
#   ('say', 2),
#   ('revert', 1),
#   ('know', 1),
#   ('mention', 1),
#   ('explain', 1),
#   ('keep', 1)],
#  'Wowweb': [('work', 2),
#   ('notice', 1),
#   ('wonder', 1),
#   ('mention', 1),
#   ('think', 1)],
#  'HoneyBee': [('create', 2),
#   ('think', 2),
#   ('spare', 2),
#   ('check', 2),
#   ('look', 2),
#   ('advice', 2),
#   ('dunno', 2),
#   ('like', 1),
#   ('add', 1),
#   ('merge', 1)],
#  '{unknown-48}': [('got', 1), ('cast', 1), ('read', 1), ('think', 1)],
#  'Kt66': [('remove', 4),
#   ('thank', 4),
#   ('ask', 4),
#   ('think', 3),
#   ('include', 2),
#   ('balance', 2),
#   ('leave', 2),
#   ('give', 2),
#   ('wish', 2),
#   ('work', 2)],
#  'Robertgreer': [('thank', 3),
#   ('contact', 2),
#   ('edit', 2),
#   ('provide', 2),
#   ('like', 1),
#   ('remove', 1),
#   ('throw', 1),
#   ('begin', 1),
#   ('clutter', 1),
#   ('take', 1)],
#  'Abebenjoe': [('write', 4),
#   ('delete', 4),
#   ('deal', 3),
#   ('use', 3),
#   ('lose', 2),
#   ('dissolve', 2),
#   ('swear', 2),
#   ('clear', 2),
#   ('take', 2),
#   ('meet', 2)],
#  'Private Detective': [('know', 1)],
#  'MONGO': [('think', 238),
#   ('know', 189),
#   ('try', 152),
#   ('go', 149),
#   ('look', 143),
#   ('need', 135),
#   ('add', 114),
#   ('want', 96),
#   ('ask', 93),
#   ('block', 93)],
#  'Fowler&amp;fowler': [('know', 13),
#   ('look', 12),
#   ('need', 11),
#   ('like', 10),
#   ('mean', 10),
#   ('read', 9),
#   ('take', 9),
#   ('say', 9),
#   ('find', 9),
#   ('edit', 9)],
#  'Ernst_Stavro_Blofeld': [('think', 4),
#   ('set', 3),
#   ('create', 3),
#   ('hope', 3),
#   ('add', 2),
#   ('look', 2),
#   ('like', 2),
#   ('take', 2),
#   ('correct', 2),
#   ('found', 2)],
#  'RobNS': [('think', 7),
#   ('wish', 7),
#   ('add', 7),
#   ('remove', 4),
#   ('try', 4),
#   ('go', 3),
#   ('know', 3),
#   ('look', 2),
#   ('appreciate', 2),
#   ('contribute', 2)],
#  'Ginkgo100': [('block', 6),
#   ('think', 5),
#   ('mean', 5),
#   ('delete', 4),
#   ('take', 4),
#   ('get', 3),
#   ('look', 3),
#   ('hope', 3),
#   ('disagree', 3),
#   ('remove', 3)],
#  'Jam01': [('enjoy', 2),
#   ('agree', 1),
#   ('look', 1),
#   ('design', 1),
#   ('percolate', 1),
#   ('hear', 1),
#   ('stress', 1),
#   ('hope', 1)],
#  'Seresin': [('refer', 3),
#   ('know', 3),
#   ('upload', 2),
#   ('make', 2),
#   ('work', 2),
#   ('contain', 2),
#   ('remove', 2),
#   ('write', 2),
#   ('find', 2),
#   ('block', 1)],
#  '87.114.22.229': [('think', 2),
#   ('describe', 1),
#   ('comply', 1),
#   ('express', 1),
#   ('resort', 1),
#   ('call', 1),
#   ('murder', 1),
#   ('edit', 1),
#   ('need', 1)],
#  'Fsecret': [('like', 4),
#   ('point', 4),
#   ('describe', 4),
#   ('delete', 2),
#   ('voice', 2),
#   ('feature', 2),
#   ('serve', 2),
#   ('demonstrate', 2),
#   ('think', 2),
#   ('know', 2)],
#  'Quazgaa': [('improve', 3),
#   ('undo', 3),
#   ('try', 2),
#   ('leave', 2),
#   ('add', 2),
#   ('insert', 1),
#   ('feel', 1),
#   ('correct', 1),
#   ('remember', 1),
#   ('call', 1)],
#  'Seraphim Whipp': [('remove', 5),
#   ('help', 5),
#   ('give', 4),
#   ('delete', 3),
#   ('need', 3),
#   ('want', 3),
#   ('take', 3),
#   ('think', 2),
#   ('block', 2),
#   ('like', 2)],
#  'Choess': [('work', 10),
#   ('think', 9),
#   ('find', 8),
#   ('try', 6),
#   ('look', 6),
#   ('move', 5),
#   ('want', 5),
#   ('start', 4),
#   ('add', 4),
#   ('go', 3)],
#  'Dave101': [('feel', 3),
#   ('think', 3),
#   ('request', 2),
#   ('need', 2),
#   ('remove', 2),
#   ('leave', 2),
#   ('delete', 1),
#   ('allow', 1),
#   ('point', 1),
#   ('find', 1)],
#  'Plastikspork': [('work', 14),
#   ('think', 12),
#   ('check', 12),
#   ('use', 11),
#   ('add', 11),
#   ('want', 9),
#   ('create', 9),
#   ('thank', 9),
#   ('know', 9),
#   ('remove', 8)],
#  'Matthew': [('prove', 8),
#   ('agree', 6),
#   ('revert', 6),
#   ('provide', 6),
#   ('read', 6),
#   ('say', 5),
#   ('feel', 5),
#   ('state', 5),
#   ('support', 5),
#   ('list', 5)],
#  'Mercy11': [('know', 12),
#   ('think', 6),
#   ('check', 5),
#   ('leave', 4),
#   ('call', 4),
#   ('include', 4),
#   ('use', 4),
#   ('intend', 3),
#   ('vandalise', 3),
#   ('lose', 3)],
#  '200.209.169.81': [('erase', 1)],
#  'Eagle 101': [('tell', 18),
#   ('think', 16),
#   ('need', 15),
#   ('work', 13),
#   ('know', 13),
#   ('fix', 11),
#   ('go', 10),
#   ('log', 9),
#   ('post', 8),
#   ('remove', 8)],
#  'Kasper2006': [('add', 1)],
#  'WacoJacko': [('mention', 5),
#   ('think', 5),
#   ('guess', 3),
#   ('thank', 3),
#   ('take', 2),
#   ('say', 2),
#   ('add', 2),
#   ('set', 2),
#   ('want', 2),
#   ('know', 1)],
#  'THD3': [('believe', 4),
#   ('want', 4),
#   ('list', 3),
#   ('edit', 3),
#   ('think', 3),
#   ('know', 3),
#   ('reinstate', 2),
#   ('add', 2),
#   ('get', 2),
#   ('remember', 2)],
#  'Markhh': [('record', 2),
#   ('make', 2),
#   ('use', 1),
#   ('post', 1),
#   ('focus', 1),
#   ('expand', 1),
#   ('replace', 1),
#   ('know', 1),
#   ('check', 1),
#   ('belong', 1)],
#  'WOSlinker': [('add', 8),
#   ('update', 5),
#   ('change', 5),
#   ('deprecate', 5),
#   ('nominate', 4),
#   ('need', 4),
#   ('remove', 4),
#   ('invite', 3),
#   ('comment', 3),
#   ('thank', 3)],
#  'Kleinzach': [('think', 17),
#   ('know', 11),
#   ('wonder', 7),
#   ('try', 5),
#   ('explain', 5),
#   ('use', 5),
#   ('ask', 4),
#   ('help', 4),
#   ('revert', 4),
#   ('find', 4)],
#  'Edito*Magica': [('find', 5),
#   ('use', 3),
#   ('attack', 3),
#   ('look', 3),
#   ('divide', 3),
#   ('incorperate', 2),
#   ('go', 2),
#   ('remove', 2),
#   ('resolve', 2),
#   ('say', 2)],
#  'Endlessdan': [('talk', 18),
#   ('upload', 4),
#   ('thank', 3),
#   ('look', 3),
#   ('believe', 3),
#   ('know', 3),
#   ('link', 3),
#   ('help', 2),
#   ('edit', 2),
#   ('place', 2)],
#  'Infrogmation': [('upload', 11),
#   ('add', 10),
#   ('take', 8),
#   ('help', 7),
#   ('ask', 7),
#   ('look', 6),
#   ('wish', 6),
#   ('know', 6),
#   ('suggest', 6),
#   ('note', 6)],
#  'RadioFan': [('add', 21),
#   ('delete', 15),
#   ('remove', 14),
#   ('improve', 10),
#   ('exist', 9),
#   ('meet', 7),
#   ('think', 6),
#   ('nominate', 6),
#   ('edit', 6),
#   ('address', 6)],
#  '{unknown-49}': [],
#  '{unknown-50}': [('want', 1), ('bump', 1)],
#  'ScreaminEagle': [('ask', 4),
#   ('think', 2),
#   ('find', 1),
#   ('award', 1),
#   ('call', 1),
#   ('say', 1),
#   ('hunt', 1),
#   ('publish', 1),
#   ('contact', 1),
#   ('read', 1)],
#  'Will Beback': [('think', 73),
#   ('add', 54),
#   ('edit', 47),
#   ('delete', 47),
#   ('know', 44),
#   ('ask', 38),
#   ('find', 35),
#   ('post', 32),
#   ('make', 32),
#   ('say', 27)],
#  'Kyuubi29': [('hack', 1), ('think', 1), ('find', 1), ('tell', 1)],
#  'TheVirginiaHistorian': [('look', 3),
#   ('think', 3),
#   ('lay', 3),
#   ('find', 3),
#   ('say', 2),
#   ('come', 2),
#   ('compete', 2),
#   ('jump', 2),
#   ('lose', 2),
#   ('start', 2)],
#  'Michael Bednarek': [('change', 6),
#   ('think', 6),
#   ('use', 5),
#   ('find', 5),
#   ('need', 5),
#   ('provide', 5),
#   ('revert', 4),
#   ('thank', 4),
#   ('refer', 4),
#   ('move', 4)],
#  'Jog1973': [('review', 1)],
#  ...}

# %%
# ============================
# Profile 2: Most used 10 verbs
# ============================

profile2={}
for user, verb in top_verbs.items():
  profile2[user] = [item[0]for item in verb]

# %%
profile2
# Out:
# 38462

# %%
# ============================
# Profile 3: P1 + P2
# ============================
profile3 = {}
for user in profile1:
  profile3[user] = profile1[user] + profile2[user]

# %%
profile3
# Out:
# {'Frightner': ['point',
#   'template',
#   'image',
#   'domain',
#   'propaganda',
#   'upload',
#   'mind',
#   'source',
#   'grave',
#   'look',
#   'know',
#   'say',
#   'belong',
#   'think',
#   'stop',
#   'spread',
#   'greet',
#   'add',
#   'block'],
#  'Revizionist': ['photograph',
#   'material',
#   'photo',
#   'law',
#   'usage',
#   'document',
#   'purpose',
#   'act',
#   'government',
#   'citizen',
#   'agree',
#   'permit',
#   'issue',
#   'allow',
#   'photograph',
#   'exclude',
#   'spend',
#   'prepare',
#   'upload',
#   'ask'],
#  'Johannes003': ['page',
#   'site',
#   'nominee',
#   'idea',
#   'section',
#   'opening',
#   'editor',
#   'film',
#   'source',
#   'ceremony',
#   'think',
#   'know',
#   'check',
#   'add',
#   'look',
#   'remove',
#   'leave',
#   'find',
#   'edit',
#   'support'],
#  'Michael-Billa': ['fan',
#   'cinema',
#   'web',
#   'company',
#   'size',
#   'family',
#   'call',
#   'maintain',
#   'base'],
#  'AnonEMouse': ['article',
#   'page',
#   'talk',
#   'user',
#   'source',
#   'people',
#   'thing',
#   'image',
#   'way',
#   'edit',
#   'think',
#   'write',
#   'know',
#   'look',
#   'want',
#   'ask',
#   'find',
#   'try',
#   'say',
#   'get'],
#  'FayssalF': ['thank',
#   'case',
#   'time',
#   'question',
#   'dispute',
#   'thing',
#   'cheer',
#   'community',
#   'article',
#   'group',
#   'need',
#   'believe',
#   'hope',
#   'know',
#   'think',
#   'work',
#   'find',
#   'ask',
#   'answer',
#   'get'],
#  'Venerock': ['language',
#   'thank',
#   'contribute',
#   'template',
#   'horse',
#   'article',
#   'people',
#   'edit',
#   'day',
#   'lady',
#   'tell',
#   'm',
#   'think',
#   'fix',
#   'enjoy',
#   'mean',
#   's',
#   'delete',
#   'cheer'],
#  'Dana boomer': ['article',
#   'page',
#   'thank',
#   'review',
#   'talk',
#   'comment',
#   'editor',
#   'image',
#   'time',
#   'source',
#   'think',
#   'work',
#   'need',
#   'know',
#   'thank',
#   'go',
#   'look',
#   'add',
#   'find',
#   'say'],
#  'Kudpung': ['page',
#   'article',
#   'school',
#   'talk',
#   'user',
#   'time',
#   'policy',
#   'project',
#   'editor',
#   'discussion',
#   'think',
#   'know',
#   'need',
#   'delete',
#   'help',
#   'find',
#   'like',
#   'go',
#   'come',
#   'work'],
#  'Rms125a@hotmail.com': ['edit',
#   'thank',
#   'page',
#   'article',
#   'year',
#   'way',
#   'birth',
#   'comment',
#   'summary',
#   'message',
#   'think',
#   'know',
#   'get',
#   'apologize',
#   'try',
#   'understand',
#   'write',
#   'appear',
#   'offend',
#   'bear'],
#  'Secret of success': ['ip',
#   'manner',
#   'website',
#   'source',
#   'mistake',
#   'contribution',
#   'couple',
#   'section',
#   'article',
#   'template',
#   'understand',
#   'say',
#   'get',
#   'contact',
#   'ask',
#   'correct',
#   'want',
#   'remove',
#   'bother',
#   'think'],
#  'Vensatry': ['article',
#   'user',
#   'source',
#   'page',
#   'award',
#   'film',
#   'version',
#   'day',
#   'editor',
#   'thank',
#   'add',
#   'work',
#   'remove',
#   'list',
#   'create',
#   'get',
#   'expand',
#   'find',
#   'know',
#   'feel'],
#  'JCDenton2052': ['page',
#   'edit',
#   'image',
#   'article',
#   'content',
#   'crisis',
#   'text',
#   'talk',
#   'history',
#   'point',
#   'remove',
#   'restore',
#   'revert',
#   'edit',
#   'use',
#   'check',
#   'find',
#   'thank',
#   'appear',
#   'specify'],
#  'Courcelles': ['notice',
#   'article',
#   'template',
#   'page',
#   'time',
#   'administrator',
#   'reviewer',
#   'deletion',
#   'image',
#   'day',
#   'remove',
#   'ask',
#   'want',
#   'delete',
#   'thank',
#   'orphan',
#   'note',
#   'describe',
#   'edit',
#   'find'],
#  'Karthikndr': ['design',
#   'page',
#   'thing',
#   'work',
#   'abit',
#   'ur',
#   'ty',
#   'info',
#   'link',
#   'asap',
#   'copy',
#   'know',
#   'agree',
#   'get',
#   'mind',
#   'look',
#   'create',
#   'help',
#   'patrol'],
#  'Capricornis': ['article',
#   'statement',
#   'page',
#   'history',
#   'contribution',
#   'time',
#   'comment',
#   'talk',
#   'plenty',
#   'edit',
#   'look',
#   'prove',
#   'talk',
#   'attack',
#   'find',
#   'deal',
#   'push',
#   'think',
#   'want',
#   'know'],
#  'Mr. Neutron': ['comment',
#   'contribution',
#   'attack',
#   'contributor',
#   'death',
#   'thank',
#   'ad',
#   'hominem',
#   'argument',
#   'falacie',
#   'insinuate',
#   'go',
#   'let',
#   'stop',
#   'refrain',
#   'warn',
#   'commit',
#   'report',
#   'want',
#   'bring'],
#  'Bollyjeff': ['article',
#   'source',
#   'film',
#   'edit',
#   'way',
#   'time',
#   'editor',
#   'page',
#   'link',
#   'thing',
#   'say',
#   'think',
#   'add',
#   'look',
#   'know',
#   'find',
#   'use',
#   'like',
#   'want',
#   'see'],
#  'Explicit': ['image',
#   'category',
#   'edit',
#   'discussion',
#   'template',
#   'page',
#   'user',
#   'article',
#   'file',
#   'deletion',
#   'add',
#   'find',
#   'thank',
#   'delete',
#   'like',
#   'remove',
#   'explain',
#   'upload',
#   'nominate',
#   'involve'],
#  'Good Olfactory': ['category',
#   'comment',
#   'user',
#   'discussion',
#   'thing',
#   'problem',
#   'way',
#   'page',
#   'editor',
#   'time',
#   'think',
#   'know',
#   'say',
#   'go',
#   'want',
#   'create',
#   'change',
#   'need',
#   'try',
#   'mean'],
#  'Leahtwosaints': ['photo',
#   'page',
#   'article',
#   'album',
#   'thing',
#   'time',
#   'song',
#   'band',
#   'talk',
#   'people',
#   'know',
#   'think',
#   'find',
#   'upload',
#   'want',
#   'look',
#   'help',
#   'need',
#   'ask',
#   'work'],
#  'Mudwater': ['article',
#   'page',
#   'thank',
#   'template',
#   'reference',
#   'talk',
#   'infobox',
#   'rating',
#   'section',
#   'album',
#   'think',
#   'look',
#   'font',
#   'add',
#   'change',
#   'say',
#   'remove',
#   'work',
#   'let',
#   'feel'],
#  'YellowMonkey': ['article',
#   'lot',
#   'thank',
#   'book',
#   'people',
#   'work',
#   'bit',
#   'page',
#   'fa',
#   'talk',
#   'think',
#   'go',
#   'add',
#   'need',
#   'get',
#   'give',
#   'edit',
#   'happen',
#   'authorise',
#   'start'],
#  'Cirt': ['article',
#   'page',
#   'cheer',
#   'thank',
#   'talk',
#   'user',
#   'time',
#   'comment',
#   'discussion',
#   'image',
#   'thank',
#   'add',
#   'think',
#   'appreciate',
#   'block',
#   'feature',
#   'address',
#   'go',
#   'feel',
#   'work'],
#  'Mandsford': ['article',
#   'thank',
#   'school',
#   'system',
#   'question',
#   'review',
#   'moment',
#   'addition',
#   'time',
#   'people',
#   'know',
#   'look',
#   'appreciate',
#   'write',
#   'get',
#   'add',
#   'ask',
#   'like',
#   'cite',
#   'move'],
#  'Anetode': ['image',
#   'article',
#   'sup',
#   'use',
#   'deletion',
#   'thank',
#   'page',
#   'copyright',
#   'disc',
#   'medium',
#   'think',
#   'know',
#   'upload',
#   'satisfy',
#   'disagree',
#   'add',
#   'want',
#   'look',
#   'scratch',
#   'consider'],
#  'Kwork': ['article',
#   'editor',
#   'user',
#   'section',
#   'page',
#   'view',
#   'information',
#   'situation',
#   'look',
#   'issue',
#   'think',
#   'edit',
#   'write',
#   'make',
#   'remove',
#   'explain',
#   'discuss',
#   'understand',
#   'allow',
#   'block'],
#  'Bubba73': ['page',
#   'article',
#   'chess',
#   'game',
#   'promotion',
#   'piece',
#   'time',
#   'pawn',
#   'list',
#   'edit',
#   'think',
#   'say',
#   'look',
#   'change',
#   'know',
#   'add',
#   'win',
#   'read',
#   'go',
#   'remove'],
#  'Jax 0677': ['article',
#   'post',
#   'work',
#   'feedback',
#   'law',
#   'notice',
#   'way',
#   'see',
#   'get',
#   'post',
#   'sign',
#   'happen',
#   'suppose',
#   'dispositione',
#   'look',
#   'split',
#   'state'],
#  'Moonriddengirl': ['article',
#   'copyright',
#   'page',
#   'content',
#   'talk',
#   'time',
#   'source',
#   'contributor',
#   'material',
#   'problem',
#   'know',
#   'need',
#   'want',
#   'copy',
#   'help',
#   'let',
#   'think',
#   'remove',
#   'find',
#   'look'],
#  'SandyGeorgia': ['article',
#   'page',
#   'talk',
#   'time',
#   'editor',
#   'thank',
#   'issue',
#   'review',
#   'image',
#   'problem',
#   'know',
#   'think',
#   'go',
#   'need',
#   'help',
#   'look',
#   'get',
#   'work',
#   'feature',
#   'want'],
#  'Keraunoscopia': ['image',
#   'article',
#   'template',
#   'page',
#   'thank',
#   'talk',
#   'thing',
#   'way',
#   'work',
#   'change',
#   'know',
#   'think',
#   'work',
#   'remove',
#   'find',
#   'thank',
#   'go',
#   'try',
#   'look',
#   'want'],
#  'Loganberry': ['reason',
#   'article',
#   'cricket',
#   'thank',
#   'comment',
#   'edit',
#   'image',
#   'team',
#   'match',
#   'title',
#   'play',
#   'change',
#   'add',
#   'think',
#   'know',
#   'match',
#   'list',
#   'leave',
#   'come',
#   'explain'],
#  'Qwfp': ['article',
#   'thank',
#   'regard',
#   'template',
#   'source',
#   'coverage',
#   'wp',
#   'point',
#   'deletion',
#   'file',
#   'think',
#   'add',
#   'look',
#   'remove',
#   'delete',
#   'appear',
#   'need',
#   'change',
#   'move',
#   'link'],
#  'Montanabw': ['article',
#   'horse',
#   'thing',
#   'page',
#   'time',
#   'way',
#   'thank',
#   'stuff',
#   'breed',
#   'work',
#   'think',
#   'need',
#   'want',
#   'know',
#   'get',
#   'go',
#   'add',
#   'find',
#   'try',
#   'look'],
#  'Vicond': [],
#  'Bsherr': ['template',
#   'block',
#   'talk',
#   'page',
#   'user',
#   'thank',
#   'neighborhood',
#   'convention',
#   'uw',
#   'policy',
#   'think',
#   'apply',
#   'semiprotecte',
#   'require',
#   'use',
#   'mean',
#   'work',
#   'block',
#   'develop',
#   'bring'],
#  'Albion moonlight': ['article',
#   'thank',
#   'user',
#   'albion',
#   'moonlight',
#   'edit',
#   'email',
#   'help',
#   'consensus',
#   'thing',
#   'think',
#   'help',
#   'work',
#   'feel',
#   'assume',
#   'go',
#   'start',
#   'make',
#   'block',
#   'know'],
#  'Videmus Omnia': ['image',
#   'article',
#   'page',
#   'photo',
#   'talk',
#   'user',
#   'mail',
#   'use',
#   'thank',
#   'e',
#   'get',
#   'look',
#   'want',
#   'add',
#   'need',
#   'remove',
#   'know',
#   'think',
#   'check',
#   'tag'],
#  'SmokeyJoe': ['image',
#   'category',
#   'information',
#   'affair',
#   'article',
#   'subject',
#   'thank',
#   'close',
#   'closing',
#   'deletion',
#   'create',
#   'look',
#   'think',
#   'read',
#   'redirect',
#   'appreciate',
#   'say',
#   'delete',
#   'nominate',
#   'close'],
#  'Junebug52': ['article',
#   'page',
#   'editor',
#   'talk',
#   'help',
#   'subject',
#   'edit',
#   'issue',
#   'user',
#   'thank',
#   'feel',
#   'look',
#   'need',
#   'go',
#   'think',
#   'help',
#   'want',
#   'find',
#   'try',
#   'remove'],
#  'Djflem': ['article',
#   'thank',
#   'info',
#   'work',
#   'change',
#   'template',
#   'town',
#   'time',
#   'state',
#   'district',
#   'wonder',
#   'follow',
#   'add',
#   'mind',
#   'appreciate',
#   'discuss',
#   'suggest',
#   'list',
#   'get',
#   'need'],
#  'PAIRdoc': ['work',
#   'thank',
#   'feedback',
#   'propensity',
#   'detail',
#   'arena',
#   'appeal',
#   'edit',
#   'article',
#   'research',
#   'continue',
#   'look',
#   'release',
#   'consider',
#   'lay',
#   'leave',
#   'relish',
#   'wonder',
#   'construct'],
#  'Meco': ['article',
#   'page',
#   'talk',
#   'edit',
#   'discussion',
#   'user',
#   'image',
#   'editor',
#   'category',
#   'use',
#   'think',
#   'find',
#   'read',
#   'know',
#   'believe',
#   'appreciate',
#   'look',
#   'remove',
#   'write',
#   'want'],
#  'Gonzo_fan2007': ['space',
#   'image',
#   'list',
#   'photo',
#   'thank',
#   'article',
#   'page',
#   'license',
#   'copyright',
#   'draft',
#   'think',
#   'know',
#   'go',
#   'say',
#   'try',
#   'let',
#   'look',
#   'delete',
#   'want',
#   'feel'],
#  'Koavf': ['category',
#   'article',
#   'talk',
#   'discussion',
#   'page',
#   'album',
#   'template',
#   'thank',
#   'deletion',
#   'redirect',
#   'know',
#   'add',
#   'remove',
#   'think',
#   'nominate',
#   'want',
#   'thank',
#   'like',
#   'respond',
#   'post'],
#  'Ling.Nut': ['talk',
#   'user',
#   'page',
#   'thank',
#   'question',
#   'article',
#   'time',
#   'comment',
#   'input',
#   'line',
#   'think',
#   'feel',
#   'drop',
#   'know',
#   'look',
#   'need',
#   'try',
#   'go',
#   'believe',
#   'ask'],
#  'BarkingMoon': ['article',
#   'page',
#   'bird',
#   'way',
#   'time',
#   'user',
#   'tool',
#   'standard',
#   'talk',
#   'post',
#   'know',
#   'use',
#   'help',
#   'find',
#   'edit',
#   'change',
#   'let',
#   'want',
#   'show',
#   'say'],
#  '{unknown-0}': ['truth', 'say', 'ndash'],
#  '{unknown-1}': ['denial', 'step', 'ndash'],
#  'MBK004': ['article',
#   'page',
#   'edit',
#   'talk',
#   'time',
#   'ship',
#   'thing',
#   'policy',
#   'template',
#   'issue',
#   'need',
#   'remove',
#   'look',
#   'know',
#   'revert',
#   'see',
#   'think',
#   'discuss',
#   'leave',
#   'add'],
#  'Howard the Duck': ['user',
#   'article',
#   'talk',
#   'list',
#   'template',
#   'thank',
#   'prose',
#   'section',
#   'score',
#   'drum',
#   'change',
#   'want',
#   'come',
#   'need',
#   'use',
#   'suggest',
#   'revert',
#   'abide',
#   'apply',
#   'follow'],
#  'Dream Focus': ['article',
#   'people',
#   'thing',
#   'time',
#   'page',
#   'information',
#   'consensus',
#   'deletion',
#   'reason',
#   'guideline',
#   'delete',
#   'say',
#   'read',
#   'try',
#   'go',
#   'want',
#   'find',
#   'mention',
#   'add',
#   'think'],
#  'Ktr101': ['page',
#   'article',
#   'thank',
#   'thing',
#   'time',
#   'way',
#   'bit',
#   'day',
#   'source',
#   'edit',
#   'know',
#   'think',
#   'look',
#   'work',
#   'want',
#   'create',
#   'go',
#   'fix',
#   'try',
#   'feel'],
#  'Tim Song': ['deletion',
#   'page',
#   'article',
#   'talk',
#   'template',
#   'reason',
#   'request',
#   'thank',
#   'discussion',
#   'message',
#   'nominate',
#   'ask',
#   'ping',
#   'warn',
#   'think',
#   'explain',
#   'address',
#   'decline',
#   'add',
#   'mean'],
#  'Wolfkeeper': ['topic',
#   'way',
#   'question',
#   'article',
#   'term',
#   'power',
#   'laser',
#   'close',
#   'afd',
#   'snow',
#   'think',
#   'cover',
#   'mean',
#   'find',
#   'try',
#   'undo',
#   'let',
#   'need',
#   'answer',
#   'fuck'],
#  'Soap': ['page',
#   'edit',
#   'user',
#   'article',
#   'people',
#   'way',
#   'talk',
#   'rfa',
#   'account',
#   'admin',
#   'think',
#   'find',
#   'edit',
#   'say',
#   'want',
#   'know',
#   'revert',
#   'go',
#   'see',
#   'change'],
#  'Kevin McE': ['page',
#   'article',
#   'discussion',
#   'consensus',
#   'talk',
#   'flag',
#   'list',
#   'point',
#   'evidence',
#   'name',
#   'think',
#   'make',
#   'consider',
#   'believe',
#   'defend',
#   'need',
#   'wish',
#   'ask',
#   'represent',
#   'revert'],
#  'TenPoundHammer': ['otter',
#   'bat',
#   'clue',
#   'span',
#   'talk',
#   'user',
#   'article',
#   'page',
#   'deletion',
#   'source',
#   'think',
#   'add',
#   'remove',
#   'say',
#   'know',
#   'need',
#   'delete',
#   'edit',
#   'find',
#   'want'],
#  'NicholasJr7': ['apology',
#   'course',
#   'forum',
#   'discussion',
#   'ignore',
#   'write'],
#  'Epbr123': ['adminship',
#   'thank',
#   'article',
#   'user',
#   'time',
#   'afd',
#   'drive',
#   'request',
#   'nomination',
#   'advice',
#   'think',
#   'wonder',
#   'let',
#   'nominate',
#   'consider',
#   'start',
#   'delete',
#   'thank',
#   'know',
#   'make'],
#  'PumpkinSky': ['page',
#   'talk',
#   'list',
#   'article',
#   'ref',
#   'thank',
#   'user',
#   'people',
#   'section',
#   'edit',
#   'help',
#   'add',
#   'think',
#   'need',
#   'look',
#   'remove',
#   'want',
#   'change',
#   'work',
#   'make'],
#  '{unknown-2}': ['source',
#   'tag',
#   'article',
#   'self',
#   'amateur',
#   'say',
#   'try',
#   'add',
#   'remove',
#   'think',
#   'publish'],
#  'Marine 69-71': ['article',
#   'thing',
#   'image',
#   'page',
#   'thank',
#   'people',
#   'user',
#   'time',
#   'talk',
#   'person',
#   'know',
#   'think',
#   'thank',
#   'tell',
#   'want',
#   'like',
#   'look',
#   'go',
#   'write',
#   'believe'],
#  'Deryck Chan': ['article',
#   'reference',
#   'thank',
#   'source',
#   'edit',
#   'link',
#   'work',
#   'book',
#   'example',
#   'talk',
#   'think',
#   'use',
#   'try',
#   'write',
#   'help',
#   'ask',
#   'hope',
#   'find',
#   'need',
#   'block'],
#  'Tpbradbury': ['article',
#   'thank',
#   'review',
#   'wikipedia',
#   'work',
#   'image',
#   'format',
#   'page',
#   'link',
#   'period',
#   'add',
#   'think',
#   'look',
#   'use',
#   'work',
#   'notice',
#   'feature',
#   'know',
#   'change',
#   'get'],
#  'Kanatonian': ['thank',
#   'article',
#   'temple',
#   'history',
#   'people',
#   'cleanup',
#   'ability',
#   'month',
#   'align',
#   'padding',
#   'notice',
#   'edit',
#   'change',
#   'help',
#   'continue',
#   'fight',
#   'relate',
#   'get',
#   'involve',
#   'create'],
#  'Reneeholle': ['article',
#   'thank',
#   'type',
#   'information',
#   'pr',
#   'vandalism',
#   'renee',
#   'force',
#   'reason',
#   'diff',
#   'ask',
#   'add',
#   'notice',
#   'edit',
#   'think',
#   'smack',
#   'count',
#   'appropriate',
#   'begin',
#   'feel'],
#  'Crisco 1492': ['thank',
#   'article',
#   'nomination',
#   'page',
#   'template',
#   'talk',
#   't',
#   'comment',
#   'picture',
#   'cheer',
#   'know',
#   'think',
#   'wonder',
#   'want',
#   'add',
#   'try',
#   'review',
#   'need',
#   'work',
#   'let'],
#  'Eldumpo': ['thank',
#   'list',
#   'regard',
#   'player',
#   'article',
#   'source',
#   'response',
#   'change',
#   'page',
#   'edit',
#   'add',
#   'play',
#   'include',
#   'post',
#   'know',
#   'note',
#   'think',
#   'go',
#   'wonder',
#   'look'],
#  'Marcd30319': ['article',
#   'operation',
#   'exercise',
#   'talk',
#   'page',
#   'history',
#   'user',
#   'command',
#   'message',
#   'issue',
#   'know',
#   'add',
#   'get',
#   'review',
#   'take',
#   'exist',
#   'mention',
#   'plan',
#   'find',
#   'appear'],
#  'Yath': ['fox',
#   'image',
#   'reason',
#   'refer',
#   'think',
#   'domesticate',
#   'release'],
#  'Oosoom': ['thank',
#   'category',
#   'article',
#   'canal',
#   'reference',
#   'map',
#   'template',
#   'image',
#   'building',
#   'icon',
#   'add',
#   'know',
#   'think',
#   'find',
#   'use',
#   'link',
#   'read',
#   'look',
#   'mean',
#   'try'],
#  'Zuwxiv': ['picture',
#   'fox',
#   'rabbit',
#   'see',
#   'think',
#   'relate',
#   'look',
#   'figure',
#   'open'],
#  'Jrcla2': ['article',
#   'basketball',
#   'thank',
#   'template',
#   'category',
#   'coach',
#   'player',
#   'year',
#   'season',
#   'baseball',
#   'know',
#   'want',
#   'think',
#   'create',
#   'need',
#   'make',
#   'work',
#   'let',
#   'write',
#   'find'],
#  '{unknown-3}': ['notice'],
#  'Erebus555': ['thank',
#   'article',
#   'contribution',
#   'edit',
#   'scope',
#   'participant',
#   'list',
#   'project',
#   'work',
#   'editing',
#   'add',
#   'expand',
#   'think',
#   'focus',
#   'participate',
#   'echo',
#   'say',
#   'notice',
#   'anticipate',
#   'start'],
#  'Erikeltic': ['page',
#   'discussion',
#   'talk',
#   'comment',
#   'thank',
#   'editor',
#   'point',
#   'article',
#   'sock',
#   'sockpuppet',
#   'say',
#   'think',
#   'happen',
#   'start',
#   'give',
#   'block',
#   'provide',
#   'contribute',
#   'allow',
#   'stand'],
#  'Nymf': ['article',
#   'edit',
#   'point',
#   'view',
#   'dispute',
#   'sock',
#   'rant',
#   'couple',
#   'user',
#   'move',
#   'note',
#   'bring',
#   'let',
#   'refer',
#   'perceive',
#   'lead',
#   'quote',
#   'present',
#   'get',
#   'block'],
#  'Jafeluv': ['article',
#   'discussion',
#   'page',
#   'talk',
#   'thank',
#   'way',
#   'disambiguation',
#   'regard',
#   'issue',
#   'list',
#   'think',
#   'request',
#   'propose',
#   'remove',
#   'move',
#   'ask',
#   'close',
#   'want',
#   'discuss',
#   'look'],
#  'Andypandy.UK': ['admin',
#   'page',
#   'backlog',
#   'user',
#   'edit',
#   'non',
#   'userbox',
#   'notice',
#   'patroller',
#   'userboxe',
#   'think',
#   'add',
#   'want',
#   'try',
#   'edit',
#   'get',
#   'thank',
#   'grow',
#   'know',
#   'detail'],
#  '{unknown-4}': ['notice'],
#  'Mlewan': ['article',
#   'picture',
#   'statue',
#   'version',
#   'common',
#   'use',
#   'copyright',
#   'law',
#   'thing',
#   'reader',
#   'retouch',
#   'upload',
#   'guess',
#   'come',
#   'hope',
#   'mind',
#   'leave',
#   'think',
#   'want',
#   'blur'],
#  'Mike Selinker': ['category',
#   'discussion',
#   'article',
#   'nomination',
#   'consensus',
#   'people',
#   'page',
#   'thing',
#   'thank',
#   'argument',
#   'think',
#   'know',
#   'close',
#   'want',
#   'need',
#   'feel',
#   'like',
#   'try',
#   'let',
#   'find'],
#  'Trident13': ['article',
#   'category',
#   'editor',
#   'reference',
#   'edit',
#   'user',
#   'page',
#   'point',
#   'notability',
#   'stub',
#   'think',
#   'add',
#   'create',
#   'know',
#   'tag',
#   'look',
#   'find',
#   'notice',
#   'place',
#   'try'],
#  'BrianSmithson': ['article',
#   'source',
#   'page',
#   'thank',
#   'copy',
#   'information',
#   'edit',
#   'link',
#   'disambiguation',
#   'congratulation',
#   'change',
#   'try',
#   'add',
#   'remove',
#   'go',
#   'feature',
#   'cite',
#   'run',
#   'gurp',
#   'get'],
#  'Doops': ['page',
#   'article',
#   'thank',
#   'redirect',
#   'arm',
#   'form',
#   'case',
#   'helm',
#   'meaning',
#   'term',
#   'think',
#   'delete',
#   'read',
#   'feel',
#   'fix',
#   'exist',
#   'create',
#   'leave',
#   'belong',
#   'publish'],
#  'Pigsonthewing': ['template',
#   'page',
#   'talk',
#   'thank',
#   'coordinate',
#   'span',
#   'article',
#   'user',
#   'link',
#   'edit',
#   'think',
#   'thank',
#   'add',
#   'make',
#   'like',
#   'suggest',
#   'know',
#   'use',
#   'cause',
#   'find'],
#  'WilyD': ['article',
#   'people',
#   'effort',
#   'photo',
#   'page',
#   'lot',
#   'advice',
#   'thing',
#   'work',
#   'help',
#   'think',
#   'know',
#   'go',
#   'ask',
#   'try',
#   'involve',
#   'hope',
#   'offer',
#   'fight',
#   'get'],
#  'Butwhatdoiknow': ['page',
#   'section',
#   'response',
#   'text',
#   'sentence',
#   'problem',
#   'edit',
#   'objection',
#   'thank',
#   'talk',
#   'work',
#   'point',
#   'turn',
#   'want',
#   'thank',
#   'consider',
#   'seek',
#   'find',
#   'think',
#   'sound'],
#  'Jappalang': ['image',
#   'article',
#   'photograph',
#   'issue',
#   'copyright',
#   'file',
#   'link',
#   'look',
#   'holder',
#   'concern',
#   'thank',
#   'think',
#   'point',
#   'base',
#   'leave',
#   'take',
#   'state',
#   'copyright',
#   'believe',
#   'bring'],
#  'Ealdgyth': ['article',
#   'source',
#   'page',
#   'horse',
#   'stuff',
#   'time',
#   'work',
#   'thank',
#   'information',
#   'thing',
#   'need',
#   'go',
#   'think',
#   'know',
#   'get',
#   'look',
#   'work',
#   'try',
#   'find',
#   'add'],
#  'Coemgenus': ['article',
#   'thank',
#   'editor',
#   'review',
#   'page',
#   'bot',
#   'comment',
#   'question',
#   'peer',
#   'user',
#   'write',
#   'list',
#   'think',
#   'delete',
#   'start',
#   'know',
#   'see',
#   'read',
#   'add',
#   'leave'],
#  'harej': ['bot',
#   'talk',
#   'page',
#   'nomination',
#   'user',
#   'template',
#   'domain',
#   'people',
#   'review',
#   'section',
#   'go',
#   'talk',
#   'run',
#   'look',
#   'request',
#   'withdraw',
#   'think',
#   'edit',
#   'transclude',
#   'mark'],
#  'Pyrotec': ['article',
#   'station',
#   'time',
#   'review',
#   'page',
#   'line',
#   'user',
#   'talk',
#   'comment',
#   'thank',
#   'review',
#   'check',
#   'find',
#   'start',
#   'try',
#   'get',
#   'need',
#   'think',
#   'run',
#   'state'],
#  '86.157.195.116': ['horse',
#   'pony',
#   'inch',
#   'hand',
#   'centimetre',
#   'thing',
#   'country',
#   'website',
#   'change',
#   'measure',
#   'hand',
#   's',
#   'get',
#   'revert'],
#  'Travb': ['page',
#   'thank',
#   'talk',
#   'tag',
#   'article',
#   'user',
#   'comment',
#   'work',
#   'deletion',
#   'month',
#   'think',
#   'look',
#   'work',
#   'know',
#   'like',
#   'change',
#   'help',
#   'say',
#   'make',
#   'let'],
#  'Schaffman': ['article',
#   'fact',
#   'boundary',
#   'tag',
#   'discussion',
#   'page',
#   'base',
#   'couple',
#   'month',
#   'need',
#   'work',
#   'find',
#   'know',
#   'see',
#   'want',
#   'touch',
#   'exist',
#   'lack',
#   'try',
#   'clean'],
#  'Everyking': ['article',
#   'thank',
#   'restriction',
#   'time',
#   'election',
#   'favor',
#   'link',
#   'interest',
#   'issue',
#   'people',
#   'think',
#   'like',
#   'need',
#   'notice',
#   'feel',
#   'say',
#   'let',
#   'create',
#   'add',
#   'know'],
#  'Acalamari': ['page',
#   'thank',
#   'user',
#   'rollback',
#   'edit',
#   'article',
#   'admin',
#   'talk',
#   'question',
#   'vandalism',
#   'ask',
#   'revert',
#   'know',
#   'think',
#   'hesitate',
#   'thank',
#   'remove',
#   'want',
#   'block',
#   'grant'],
#  'Legolas2186': ['article',
#   'page',
#   'user',
#   'talk',
#   'edit',
#   'song',
#   'time',
#   'way',
#   'album',
#   'lead',
#   'think',
#   'know',
#   'go',
#   'ask',
#   'add',
#   'revert',
#   'need',
#   'see',
#   'find',
#   'font'],
#  'Glen S': ['user',
#   'page',
#   'talk',
#   'thank',
#   'request',
#   'message',
#   'thing',
#   'people',
#   'vandalism',
#   'history',
#   'think',
#   'know',
#   'add',
#   'let',
#   'remove',
#   'smile',
#   'read',
#   'delete',
#   'work',
#   'get'],
#  'Kyo cat': ['page',
#   'talk',
#   'table',
#   'barnstar',
#   'time',
#   'tomorrow',
#   'award',
#   'user',
#   'algebra',
#   'userboxe',
#   'think',
#   'help',
#   'font',
#   'want',
#   'hope',
#   'feel',
#   'take',
#   'give',
#   'go',
#   'work'],
#  'GamerPro64': ['article',
#   'talk',
#   'review',
#   'page',
#   'user',
#   'thank',
#   'game',
#   'link',
#   'fa',
#   'week',
#   'know',
#   'think',
#   'find',
#   'like',
#   'need',
#   'write',
#   'look',
#   'work',
#   'try',
#   'notice'],
#  'ShakespeareFan00': ['rationale',
#   'image',
#   'use',
#   'page',
#   'copyright',
#   'question',
#   'medium',
#   'template',
#   'policy',
#   'list',
#   'upload',
#   'thank',
#   'consider',
#   'ask',
#   'miss',
#   'provide',
#   'check',
#   'specify',
#   'find',
#   'delete'],
#  'Agne27': ['article',
#   'wine',
#   'stub',
#   'page',
#   'work',
#   'talk',
#   'thank',
#   'idea',
#   'time',
#   'source',
#   'think',
#   'know',
#   'go',
#   'feel',
#   'want',
#   'see',
#   'wonder',
#   'work',
#   'find',
#   'have'],
#  'Woodym555': ['article',
#   'thank',
#   'page',
#   'section',
#   'time',
#   'list',
#   'image',
#   'comment',
#   'concern',
#   'talk',
#   'think',
#   'need',
#   'ask',
#   'give',
#   'agree',
#   'know',
#   'leave',
#   'fix',
#   'move',
#   'try'],
#  'Eaglizard': ['thank',
#   'page',
#   'talk',
#   'article',
#   'anyway',
#   'user',
#   'dash',
#   'bit',
#   'sockpuppetry',
#   'accusation',
#   'see',
#   'find',
#   'agree',
#   'ask',
#   'feel',
#   'notice',
#   'edit',
#   'use',
#   'think',
#   'come'],
#  'Erik': ['film',
#   'article',
#   'page',
#   'discussion',
#   'talk',
#   'font',
#   'template',
#   'time',
#   'editor',
#   'topic',
#   'think',
#   'know',
#   'want',
#   'try',
#   'let',
#   'add',
#   'work',
#   'find',
#   'come',
#   'look'],
#  'JaGa': ['page',
#   'thank',
#   'article',
#   'link',
#   'template',
#   'list',
#   'time',
#   'script',
#   'disambig',
#   'note',
#   'know',
#   'think',
#   'look',
#   'let',
#   'go',
#   'fix',
#   'want',
#   'get',
#   'need',
#   'work'],
#  'Rodhullandemu': ['page',
#   'article',
#   'editor',
#   'time',
#   'talk',
#   'cheer',
#   'thank',
#   'source',
#   'comment',
#   'opinion',
#   'think',
#   'know',
#   'go',
#   'want',
#   'let',
#   'take',
#   'link',
#   'try',
#   'edit',
#   'look'],
#  'Jamesd1': ['email',
#   'section',
#   'biography',
#   'life',
#   'article',
#   'word',
#   'situation',
#   'time',
#   'response',
#   'post',
#   'come',
#   'reach',
#   'change',
#   'sign',
#   'check',
#   'need',
#   'contact',
#   'use',
#   'click',
#   'look'],
#  'Sparklecplenty': ['article',
#   'editor',
#   'thank',
#   'section',
#   'checkout',
#   'rating',
#   'class',
#   'b',
#   'title',
#   'talk',
#   'classify',
#   'place',
#   'revert',
#   'revise',
#   'read',
#   'understand',
#   'wish',
#   'balance',
#   'enter'],
#  'PamD': ['page',
#   'article',
#   'thank',
#   'category',
#   'dab',
#   'template',
#   'talk',
#   'edit',
#   'link',
#   'title',
#   'think',
#   'add',
#   'look',
#   'create',
#   'need',
#   'know',
#   'list',
#   'sort',
#   'include',
#   'change'],
#  'Derek Andrews': ['thank',
#   'article',
#   'user',
#   'reference',
#   'link',
#   'talk',
#   'info',
#   'photo',
#   'area',
#   'look',
#   'add',
#   'wonder',
#   'want',
#   'notice',
#   'look',
#   'know',
#   'find',
#   'originate',
#   'raise',
#   'work'],
#  'Max Schwarz': ['icon',
#   'description',
#   'sense',
#   'common',
#   'category',
#   'railway',
#   'upload',
#   'notice',
#   'use'],
#  'Jimfbleak': ['article',
#   'thank',
#   'image',
#   'bird',
#   'edit',
#   'page',
#   'reason',
#   'bit',
#   'source',
#   'specie',
#   'think',
#   'know',
#   'need',
#   'go',
#   'give',
#   'look',
#   'write',
#   'see',
#   'revert',
#   'delete'],
#  'SilkTork': ['article',
#   'background',
#   'color',
#   'discussion',
#   'span',
#   'brewery',
#   'beer',
#   'people',
#   'category',
#   'comment',
#   'feel',
#   'need',
#   'know',
#   'think',
#   'look',
#   'let',
#   'start',
#   'work',
#   'want',
#   'make'],
#  'WesleyDodds': ['article',
#   'page',
#   'band',
#   'rock',
#   'song',
#   'source',
#   'album',
#   'section',
#   'book',
#   'time',
#   'think',
#   'work',
#   'need',
#   'find',
#   'want',
#   'look',
#   'go',
#   'write',
#   'try',
#   'know'],
#  'Betacommand': ['page',
#   'category',
#   'image',
#   'deletion',
#   'bot',
#   'comment',
#   'article',
#   'list',
#   'user',
#   'medium',
#   'know',
#   'say',
#   'miss',
#   'give',
#   'check',
#   'delete',
#   'thank',
#   'let',
#   'bring',
#   'upload'],
#  'Parrot of Doom': ['class',
#   'shadow',
#   'article',
#   'source',
#   'thing',
#   'image',
#   'bit',
#   'time',
#   'page',
#   'talk',
#   'think',
#   'find',
#   'know',
#   'read',
#   'create',
#   'go',
#   'try',
#   'work',
#   'wonder',
#   'look'],
#  'Slomox': ['image',
#   'fox',
#   'language',
#   'support',
#   'creator',
#   'description',
#   'eye',
#   'chain',
#   'rabbit',
#   'clarification',
#   'thank',
#   'look',
#   'support',
#   'stuff',
#   'note',
#   'stage',
#   'suspect',
#   'wonder',
#   'pull',
#   'search'],
#  'Dragon695': ['image',
#   'article',
#   'organization',
#   'way',
#   'common',
#   'use',
#   'right',
#   'reason',
#   'directory',
#   'example',
#   'believe',
#   'think',
#   'work',
#   'try',
#   'want',
#   'support',
#   'use',
#   'know',
#   'convict',
#   'plan'],
#  '{unknown-5}': ['place',
#   'foot',
#   'snow',
#   'time',
#   'worry',
#   'know',
#   'live',
#   'answer'],
#  'Mark Wheaver': ['category',
#   'building',
#   'entry',
#   'problem',
#   'change',
#   'revert',
#   'church',
#   'article',
#   'clanger',
#   'listing',
#   'list',
#   'improve',
#   'like',
#   'join',
#   'talk',
#   'impact',
#   'try',
#   'categorize'],
#  'Catherineyronwode': ['cat',
#   'page',
#   'thank',
#   'folk',
#   'article',
#   'note',
#   'merge',
#   'proposal',
#   'comment',
#   'person',
#   'help',
#   'thank',
#   'leave',
#   'ask',
#   'vote',
#   'work',
#   'find',
#   'request',
#   'second',
#   'say'],
#  'Barneca': ['page',
#   'talk',
#   'thank',
#   'comment',
#   'people',
#   'block',
#   'feedback',
#   'threat',
#   'day',
#   'rfa',
#   'think',
#   'block',
#   'feel',
#   'know',
#   'hope',
#   'see',
#   'refer',
#   'need',
#   'try',
#   'go'],
#  'Lightmouse': ['template',
#   'thank',
#   'spelling',
#   'unit',
#   'article',
#   'issue',
#   'edit',
#   'example',
#   'people',
#   'page',
#   'know',
#   'work',
#   'think',
#   'add',
#   'say',
#   'help',
#   'look',
#   'want',
#   'create',
#   'hope'],
#  '{unknown-6}': ['rule',
#   'knowledge',
#   'source',
#   'system',
#   'adherence',
#   'writing',
#   'article',
#   'editor',
#   'subject',
#   'work',
#   'want',
#   'understand',
#   'work',
#   'leave',
#   'shape',
#   'bias',
#   'follow',
#   'find',
#   'select',
#   'support'],
#  'Ronhjones': ['page',
#   'file',
#   'copyright',
#   'image',
#   'permission',
#   'user',
#   'question',
#   'editor',
#   'evidence',
#   'deletion',
#   'find',
#   'add',
#   'use',
#   'create',
#   'delete',
#   'ask',
#   'check',
#   'thank',
#   'agree',
#   'consider'],
#  'Malleus_Fatuorum': ['article',
#   'thing',
#   'time',
#   'editor',
#   'way',
#   'review',
#   'bit',
#   'point',
#   'work',
#   'page',
#   'think',
#   'know',
#   'look',
#   'get',
#   'need',
#   'say',
#   'believe',
#   'ask',
#   'try',
#   'find'],
#  'France3470': ['page',
#   'article',
#   'item',
#   'link',
#   'dab',
#   'information',
#   'time',
#   'talk',
#   'disambiguation',
#   'title',
#   'create',
#   'add',
#   'know',
#   'feel',
#   'thank',
#   'think',
#   'tag',
#   'require',
#   'find',
#   'read'],
#  'Dr. Blofeld': ['article',
#   'time',
#   'page',
#   'source',
#   'people',
#   'list',
#   'editor',
#   'work',
#   'film',
#   'stub',
#   'think',
#   'need',
#   'create',
#   'find',
#   'look',
#   'start',
#   'add',
#   'remove',
#   'use',
#   'want'],
#  'Bob1960evens': ['bridge',
#   'map',
#   'page',
#   'thank',
#   'railway',
#   'article',
#   'source',
#   'icon',
#   'bit',
#   'template',
#   'think',
#   'use',
#   'add',
#   'include',
#   'know',
#   'need',
#   'continue',
#   'find',
#   'show',
#   'go'],
#  'Ryecatcher773': ['article',
#   'year',
#   'time',
#   'editor',
#   'issue',
#   'abbreviation',
#   'convention',
#   'case',
#   'member',
#   'edit',
#   'move',
#   'name',
#   'ask',
#   'thank',
#   'go',
#   'serve',
#   'add',
#   'mean',
#   'require',
#   'bring'],
#  'QuiteUnusual': ['article',
#   'thank',
#   'deletion',
#   'protection',
#   'template',
#   'ad',
#   'admin',
#   'request',
#   'page',
#   'vandalism',
#   'think',
#   'qualify',
#   'font',
#   'turn',
#   'face',
#   'pick',
#   'remove',
#   'propose',
#   'leave',
#   'notify'],
#  'Thomas888b': ['thank',
#   'question',
#   'interest',
#   'signpost',
#   'support',
#   'project',
#   'note',
#   'status',
#   'align',
#   'border',
#   'answer',
#   'confirm',
#   'interview',
#   'notice',
#   'say',
#   'show',
#   'deserve',
#   'like'],
#  'Warlordjohncarter': ['article',
#   'category',
#   'project',
#   'assessment',
#   'class',
#   'today',
#   'editor',
#   'way',
#   'section',
#   'subject',
#   'add',
#   'know',
#   'try',
#   'believe',
#   'relate',
#   'say',
#   'consider',
#   'give',
#   'express',
#   'change'],
#  'Enigmaman': ['talk',
#   'article',
#   'edit',
#   'account',
#   'page',
#   'time',
#   'block',
#   'thank',
#   'user',
#   'warning',
#   'block',
#   'know',
#   'think',
#   'create',
#   'add',
#   'go',
#   'get',
#   'want',
#   'consider',
#   'ask'],
#  'NHRHS2010': ['user',
#   'talk',
#   'vandal',
#   'page',
#   'align',
#   'border',
#   'calamari',
#   'day',
#   'today',
#   'video',
#   'know',
#   'like',
#   'fry',
#   'create',
#   'block',
#   'think',
#   'get',
#   'revert',
#   'protect',
#   'kristen'],
#  'Canuckle': ['article',
#   'school',
#   'shooting',
#   'redirect',
#   'consensus',
#   'thank',
#   'user',
#   'series',
#   'deletion',
#   'discussion',
#   'appreciate',
#   'undo',
#   'feel',
#   'stand',
#   'come',
#   'want',
#   'wrap',
#   'name',
#   'achieve',
#   'mean'],
#  'Nburden': ['point', 'list'],
#  'Cosprings': ['way',
#   'info',
#   'g',
#   'funk',
#   'hip',
#   'hop',
#   'action',
#   'people',
#   'thing',
#   'discography',
#   'need',
#   'create',
#   'call',
#   'think',
#   'link',
#   'find',
#   'credit',
#   'know',
#   'suggest',
#   'center'],
#  'CronopioFlotante': ['citation',
#   'index',
#   'h',
#   'counting',
#   'point',
#   'impact',
#   'field',
#   'number',
#   'journal',
#   'report',
#   'measure',
#   'let',
#   'discuss',
#   'accept',
#   'say',
#   'base'],
#  'Crusio': ['journal',
#   'article',
#   'project',
#   'page',
#   'category',
#   'tag',
#   'thank',
#   'time',
#   'notability',
#   'deletion',
#   'think',
#   'publish',
#   'read',
#   'include',
#   'know',
#   'mean',
#   'say',
#   'leave',
#   'look',
#   'need'],
#  'Futurebird': ['page',
#   'article',
#   'ban',
#   'evidence',
#   'source',
#   'kind',
#   'point',
#   'thank',
#   'project',
#   'fertility',
#   'think',
#   'add',
#   'know',
#   'want',
#   'have',
#   'help',
#   'present',
#   'look',
#   'need',
#   'post'],
#  'Jnc': ['page',
#   'talk',
#   'article',
#   'thank',
#   'way',
#   'thing',
#   'redirect',
#   'problem',
#   'history',
#   'deletion',
#   'delete',
#   'want',
#   'need',
#   'think',
#   'click',
#   'look',
#   'link',
#   'like',
#   'make',
#   'suggest'],
#  'AEMoreira042281': ['picture',
#   'page',
#   'link',
#   'article',
#   'pic',
#   'file',
#   'move',
#   'convention',
#   'question',
#   'sequence',
#   'shoot',
#   'take',
#   'clean',
#   'move',
#   'upload',
#   'include',
#   'need',
#   'save',
#   'log',
#   'require'],
#  'Blackjays1': ['single',
#   'artist',
#   'review',
#   'user',
#   'case',
#   'navboxe',
#   'rhyme',
#   'article',
#   'sense',
#   'chart',
#   'think',
#   'include',
#   'doubt',
#   'hook',
#   'start',
#   'call',
#   'refuse',
#   'revert',
#   'make',
#   'know'],
#  'Bellagio99': ['page',
#   'article',
#   'edit',
#   'day',
#   'thank',
#   'time',
#   'word',
#   'religion',
#   'user',
#   'life',
#   'look',
#   'go',
#   'know',
#   'check',
#   'get',
#   'keep',
#   'listen',
#   'help',
#   'miss',
#   'agree'],
#  'Bencherlite': ['category',
#   'regard',
#   'thank',
#   'article',
#   'page',
#   'discussion',
#   'comment',
#   'list',
#   'talk',
#   'user',
#   'think',
#   'know',
#   'delete',
#   'look',
#   'let',
#   'try',
#   'add',
#   'suggest',
#   'start',
#   'want'],
#  'DustFormsWords': ['article',
#   'review',
#   'page',
#   'talk',
#   'concern',
#   'nomination',
#   'time',
#   'work',
#   'problem',
#   'issue',
#   'review',
#   'thank',
#   'address',
#   'know',
#   'require',
#   'agree',
#   'work',
#   'improve',
#   'go',
#   'remain'],
#  '70.137.161.241': [],
#  'TimVickers': ['article',
#   'page',
#   'thank',
#   'editor',
#   'time',
#   'people',
#   'talk',
#   'edit',
#   'problem',
#   'bit',
#   'think',
#   'try',
#   'thank',
#   'need',
#   'add',
#   'deal',
#   'find',
#   'want',
#   'know',
#   'look'],
#  'Miyagawa': ['article',
#   'template',
#   'archive',
#   'state',
#   'prose',
#   'section',
#   'way',
#   'thank',
#   'stub',
#   'regard',
#   'add',
#   'want',
#   'find',
#   'go',
#   'search',
#   'bring',
#   'construct',
#   'cite',
#   'pende',
#   'get'],
#  'Parsifal': ['page',
#   'article',
#   'talk',
#   'number',
#   'reference',
#   'thank',
#   'note',
#   'comment',
#   'content',
#   'paragraph',
#   'support',
#   'know',
#   'correct',
#   'write',
#   'find',
#   'need',
#   'post',
#   'link',
#   'add',
#   'follow'],
#  'WebHamster': ['article',
#   'page',
#   'thank',
#   'notability',
#   'charity',
#   'user',
#   'time',
#   'use',
#   'creator',
#   'copyright',
#   'start',
#   'get',
#   'delete',
#   'add',
#   'know',
#   'revert',
#   'take',
#   'need',
#   'think',
#   'doubt'],
#  'Rocky.liu': ['talk',
#   'page',
#   'project',
#   'code',
#   'article',
#   'semester',
#   'mentor',
#   'assignment',
#   'item',
#   'work',
#   'serve',
#   'thank',
#   'add',
#   'help',
#   'translate'],
#  'Dwanyewest': ['article',
#   'way',
#   'rider',
#   'tv',
#   'series',
#   'title',
#   'planet',
#   'evidence',
#   'existence',
#   'year',
#   'forget',
#   'think',
#   'believe',
#   'keep',
#   'redirect',
#   'write',
#   'show',
#   'provide',
#   'mention',
#   'create'],
#  'Mgoodyear': ['way',
#   'article',
#   'reference',
#   'lot',
#   'people',
#   'text',
#   'work',
#   'date',
#   'comment',
#   'vendetta',
#   'know',
#   'work',
#   'look',
#   'need',
#   'remove',
#   'happen',
#   'try',
#   'say',
#   'set',
#   'read'],
#  'Sonic99': ['edit',
#   'skin',
#   'hair',
#   'truth',
#   'ya',
#   'black',
#   'ancestry',
#   'link',
#   'information',
#   'provide',
#   'change',
#   'see',
#   'accept',
#   'wish',
#   'identify',
#   'skin',
#   'think',
#   'deny',
#   'need'],
#  'Nagasheus': ['man',
#   'ancestry',
#   'proposal',
#   'day',
#   'project',
#   'participant',
#   'luck',
#   'participation',
#   'work',
#   'start',
#   'welcome',
#   'need',
#   'fall',
#   'add'],
#  'Yamla': ['image',
#   'use',
#   'page',
#   'article',
#   'link',
#   'rationale',
#   'copyright',
#   'user',
#   'screenshot',
#   'case',
#   'add',
#   'use',
#   'note',
#   'know',
#   'remove',
#   'upload',
#   'let',
#   'depict',
#   'think',
#   'delete'],
#  'TaerkastUA': ['thank',
#   'chairman',
#   'article',
#   'page',
#   'talk',
#   'work',
#   'role',
#   'bit',
#   'stuff',
#   'deal',
#   'think',
#   'hope',
#   'go',
#   'need',
#   'pass',
#   'find',
#   'know',
#   'clean',
#   'end',
#   'happen'],
#  'Dekkappai': ['article',
#   'thank',
#   'editor',
#   'film',
#   'time',
#   'edit',
#   'subject',
#   'deletion',
#   'page',
#   'project',
#   'think',
#   'work',
#   'know',
#   'delete',
#   'look',
#   'get',
#   'come',
#   'source',
#   'start',
#   'remove'],
#  'DsgnWrte': [],
#  'Smallman12q': ['template',
#   'article',
#   'menu',
#   'page',
#   'script',
#   'thank',
#   'citation',
#   'support',
#   'datum',
#   'lot',
#   'add',
#   'like',
#   'know',
#   'use',
#   'create',
#   'write',
#   'let',
#   'work',
#   'give',
#   'want'],
#  'TheJazzDalek': ['article',
#   'link',
#   'navbox',
#   'way',
#   'rap',
#   'template',
#   'musician',
#   'consensus',
#   'box',
#   'version',
#   'suppose',
#   'change',
#   'like',
#   'appear',
#   'delete',
#   'include',
#   'exist',
#   'mean',
#   'list',
#   'talk'],
#  '67.101.7.21': ['talk',
#   'article',
#   'review',
#   'issue',
#   'work',
#   'progress',
#   'time',
#   'look',
#   'information',
#   'comment',
#   'need',
#   'write',
#   'complete',
#   'feature',
#   'tell',
#   'discuss',
#   'lead',
#   'assess'],
#  'Raul654': ['article',
#   'page',
#   'comment',
#   'link',
#   'blurb',
#   'talk',
#   'edit',
#   'thing',
#   'list',
#   'case',
#   'think',
#   'get',
#   'need',
#   'want',
#   'know',
#   'see',
#   'feature',
#   'go',
#   'look',
#   'fix'],
#  'Bearcat': ['article',
#   'category',
#   'list',
#   'page',
#   'title',
#   'thank',
#   'link',
#   'way',
#   'convention',
#   'station',
#   'know',
#   'need',
#   'add',
#   'think',
#   'use',
#   'go',
#   'file',
#   'want',
#   'create',
#   'move'],
#  'Steven Walling': ['family',
#   'article',
#   'thank',
#   'policy',
#   'school',
#   'work',
#   'source',
#   'deletion',
#   'account',
#   'time',
#   'know',
#   'think',
#   'let',
#   'talk',
#   'add',
#   'need',
#   'delete',
#   'assert',
#   'get',
#   'email'],
#  'AndonicO': ['user',
#   'talk',
#   'basepagename',
#   'picture',
#   'thank',
#   'film',
#   'userpage',
#   'family',
#   'tree',
#   'link',
#   'thank',
#   'take',
#   'try',
#   'say',
#   'understand',
#   'come',
#   'hope',
#   'look',
#   'fix',
#   'know'],
#  'Sasuke-kun27': ['user',
#   'page',
#   'thank',
#   'talk',
#   'award',
#   'article',
#   'time',
#   'problem',
#   'edit',
#   'thing',
#   'know',
#   'think',
#   'look',
#   'help',
#   'thank',
#   'take',
#   'like',
#   'want',
#   'say',
#   'give'],
#  '66.245.126.161': ['edit',
#   'x',
#   'kind',
#   'z',
#   'version',
#   'section',
#   'revert',
#   'mismatch',
#   'match'],
#  'Benc': ['mediator',
#   'mind',
#   'twin',
#   'edit',
#   'issue',
#   'talk',
#   'cross',
#   'dressing',
#   'catch',
#   'discussion',
#   'help',
#   'see',
#   'hope',
#   'read',
#   'entitle',
#   'change',
#   'finish',
#   'settle',
#   'let',
#   'know'],
#  'Moxy': ['article',
#   'people',
#   'page',
#   'music',
#   'talk',
#   'project',
#   'time',
#   'link',
#   'number',
#   'guy',
#   'find',
#   'think',
#   'remove',
#   'go',
#   'add',
#   'need',
#   'take',
#   'ask',
#   'talk',
#   'revert'],
#  'The Rambling Man': ['article',
#   'thank',
#   'comment',
#   'list',
#   'page',
#   'time',
#   'cheer',
#   'day',
#   'review',
#   'discussion',
#   'know',
#   'think',
#   'need',
#   'let',
#   'add',
#   'look',
#   'go',
#   'want',
#   'hope',
#   'help'],
#  'Woody': ['regard',
#   'article',
#   'discussion',
#   'thank',
#   'talk',
#   'page',
#   'edit',
#   'template',
#   'issue',
#   'time',
#   'think',
#   'need',
#   'block',
#   'know',
#   'leave',
#   'revert',
#   'find',
#   'note',
#   'go',
#   'read'],
#  'Ruhrfisch': ['thank',
#   'article',
#   'page',
#   'map',
#   'image',
#   'talk',
#   'review',
#   'user',
#   'day',
#   'peer',
#   'add',
#   'think',
#   'know',
#   'want',
#   'find',
#   'look',
#   'try',
#   'let',
#   'help',
#   'work'],
#  'Wilhelmina Will': ['article',
#   'page',
#   'thank',
#   'day',
#   'greeting',
#   'user',
#   'source',
#   'talk',
#   'information',
#   'time',
#   'know',
#   'need',
#   'look',
#   'thank',
#   'notice',
#   'delete',
#   'mention',
#   'hope',
#   'think',
#   'ask'],
#  'Trilobitealive': ['plant',
#   'article',
#   'perception',
#   'page',
#   'theory',
#   'biocommunication',
#   'week',
#   'paranormal',
#   'way',
#   'var',
#   'blank',
#   'know',
#   'tell',
#   'panic',
#   'see',
#   'identify',
#   'try',
#   'disentangle',
#   'hit',
#   'put'],
#  'IceCreamAntisocial': ['thank',
#   'reference',
#   'spot',
#   'align',
#   'border',
#   'user',
#   'appreciation',
#   'plant',
#   'photo',
#   'fun',
#   'look',
#   'let',
#   'verify',
#   'expand',
#   'reword',
#   'post',
#   'honor',
#   'write',
#   'capture',
#   'thank'],
#  'ThatPeskyCommoner': ['horse',
#   'sample',
#   'history',
#   'thing',
#   'time',
#   'page',
#   'stuff',
#   'coat',
#   'spot',
#   'article',
#   'think',
#   'look',
#   'find',
#   'come',
#   'notice',
#   'exist',
#   'know',
#   'domesticate',
#   'like',
#   'play'],
#  'Xornok': ['rescue',
#   'op',
#   'reason',
#   'page',
#   'title',
#   'idea',
#   'word',
#   'episode',
#   'reference',
#   'company',
#   'know',
#   'call',
#   'describe',
#   'go',
#   'move',
#   'worry'],
#  'tone': ['article',
#   'greeting',
#   'regard',
#   'deletion',
#   'problem',
#   'content',
#   'time',
#   'reference',
#   'notability',
#   'prod',
#   'delete',
#   'restore',
#   'think',
#   'need',
#   'help',
#   'write',
#   'hope',
#   'know',
#   'add',
#   'fix'],
#  'Jackhynes': ['article',
#   'cheer',
#   'specie',
#   'habitat',
#   'page',
#   'issue',
#   'reviewer',
#   'look',
#   'comment',
#   'section',
#   'appreciate',
#   'create',
#   'capitalise',
#   'feature',
#   'restart',
#   'know',
#   'think',
#   'change',
#   'follow',
#   'slow'],
#  'Flyer22': ['article',
#   'talk',
#   'page',
#   'editor',
#   'user',
#   'time',
#   'discussion',
#   'source',
#   'people',
#   'way',
#   'need',
#   'state',
#   'feel',
#   'know',
#   'mean',
#   'think',
#   'add',
#   'thank',
#   'see',
#   'revert'],
#  'CorenSearchBot': ['talk',
#   'template',
#   'content',
#   'material',
#   'source',
#   'bot',
#   'similarity',
#   'case',
#   'tag',
#   'message',
#   'copyright',
#   'donate',
#   'find',
#   'exist',
#   'remove',
#   'confuse',
#   'place',
#   'appreciate',
#   'drop',
#   'locate'],
#  'Jesanj': ['thank',
#   'cost',
#   'talk',
#   'theory',
#   'insurer',
#   'price',
#   'care',
#   'link',
#   'study',
#   'fact',
#   'think',
#   'reply',
#   'thank',
#   'say',
#   'integrate',
#   'mean',
#   'know',
#   'review',
#   'push',
#   'submit'],
#  'LeadSongDog': ['edit',
#   'article',
#   'source',
#   'template',
#   'spelling',
#   'talk',
#   'citation',
#   'thank',
#   'case',
#   'number',
#   'thank',
#   'need',
#   'find',
#   'go',
#   'give',
#   'add',
#   'know',
#   'discuss',
#   'use',
#   'say'],
#  'Jackaranga': ['article',
#   'deletion',
#   'image',
#   'tag',
#   'thank',
#   'case',
#   'order',
#   'command',
#   'sentence',
#   'unit',
#   'like',
#   'live',
#   'give',
#   'move',
#   'think',
#   'translate',
#   'change',
#   'add',
#   'allow',
#   'keep'],
#  'Rcej': ['image',
#   'nomination',
#   'hook',
#   'article',
#   'page',
#   'issue',
#   'color',
#   'thank',
#   'section',
#   'submission',
#   'know',
#   'review',
#   'need',
#   'contribute',
#   'thank',
#   'start',
#   'think',
#   'clarify',
#   'respond',
#   'grab'],
#  '{unknown-7}': ['reason',
#   'thank',
#   'rearranging',
#   'removal',
#   'house',
#   'price',
#   'people',
#   'type',
#   'lifestyle',
#   'guy',
#   'wonder',
#   'live',
#   'include',
#   'go',
#   'readd',
#   'remove',
#   'talk'],
#  'Victuallers': ['article',
#   'thank',
#   'page',
#   'school',
#   'user',
#   'image',
#   'museum',
#   'wiki',
#   'source',
#   'link',
#   'think',
#   'need',
#   'help',
#   'find',
#   'want',
#   'look',
#   'hope',
#   'tell',
#   'go',
#   'know'],
#  'Arhugefan': ['manga', 'image', 'problem', 'lisense', 'use', 'color'],
#  'Cool Hand Luke': ['article',
#   'category',
#   'comment',
#   'stub',
#   'day',
#   'user',
#   'work',
#   'apostle',
#   'edit',
#   'time',
#   'think',
#   'look',
#   'know',
#   'delete',
#   'respond',
#   'go',
#   'talk',
#   'like',
#   'try',
#   'check'],
#  'Ikkyu2': ['carbamazepine',
#   'article',
#   'way',
#   'epilepsy',
#   'evidence',
#   'oxcarbazepine',
#   'metabolite',
#   'time',
#   'look',
#   'patient',
#   'appear',
#   'die',
#   'take',
#   'look',
#   'try',
#   'like',
#   'read',
#   'welcome',
#   'guess',
#   'need'],
#  'Colin': ['article',
#   'page',
#   'talk',
#   'time',
#   'source',
#   'thank',
#   'list',
#   'review',
#   'text',
#   'cheer',
#   'think',
#   'know',
#   'look',
#   'need',
#   'help',
#   'find',
#   'change',
#   'want',
#   'read',
#   'write'],
#  'ErgoSum88': ['article',
#   'family',
#   'thing',
#   'editor',
#   'thank',
#   'problem',
#   'page',
#   'reason',
#   'talk',
#   'time',
#   'know',
#   'go',
#   'dot',
#   'try',
#   'edit',
#   'make',
#   'stop',
#   'enjoy',
#   'help',
#   'want'],
#  'Davemeistermoab': ['work',
#   'article',
#   'admin',
#   'use',
#   'term',
#   'website',
#   'time',
#   'way',
#   'font',
#   'janitor',
#   'think',
#   'go',
#   'know',
#   'look',
#   'suck',
#   'try',
#   'find',
#   'need',
#   'come',
#   'intervene'],
#  'Realkyhick': ['article',
#   'page',
#   'deletion',
#   'notability',
#   'tag',
#   'day',
#   'time',
#   'template',
#   'notice',
#   'thank',
#   'think',
#   'add',
#   'delete',
#   'post',
#   'help',
#   'meet',
#   'write',
#   'take',
#   'say',
#   'work'],
#  '{unknown-8}': ['fuzzform'],
#  'Fuzzform': ['citation',
#   'reference',
#   'code',
#   'article',
#   'word',
#   'section',
#   'page',
#   'way',
#   'search',
#   'link',
#   'look',
#   'try',
#   'come',
#   'make',
#   'cite',
#   'keep',
#   'go',
#   'place',
#   'send',
#   'suppose'],
#  'Rschen7754': ['article',
#   'template',
#   'problem',
#   'thing',
#   'assessment',
#   'road',
#   'newsletter',
#   'time',
#   'discussion',
#   'infobox',
#   'want',
#   'need',
#   'use',
#   'think',
#   'block',
#   'go',
#   'try',
#   'fail',
#   'help',
#   'receive'],
#  'Moabdave': ['thank',
#   'time',
#   'article',
#   'state',
#   'town',
#   'day',
#   'review',
#   'route',
#   'policy',
#   'highway',
#   'like',
#   'leave',
#   'find',
#   'say',
#   'check',
#   'hope',
#   'come',
#   'know',
#   'create',
#   'go'],
#  'Durova': ['article',
#   'editor',
#   'people',
#   'thing',
#   'time',
#   'user',
#   'talk',
#   'faith',
#   'page',
#   'post',
#   'think',
#   'font',
#   'post',
#   'want',
#   'know',
#   'feature',
#   'help',
#   'come',
#   'go',
#   'hope'],
#  'Bradadkins274': ['signature', 'thing', 'work'],
#  'Dethomas': ['image',
#   'regard',
#   'page',
#   'question',
#   'use',
#   'medium',
#   'article',
#   'list',
#   'link',
#   'box',
#   'upload',
#   'delete',
#   'thank',
#   'check',
#   'find',
#   'edit',
#   'click',
#   'locate',
#   'log',
#   'select'],
#  'Brossow': ['san',
#   'article',
#   'image',
#   'line',
#   'time',
#   'information',
#   'research',
#   'discussion',
#   'vote',
#   'reference',
#   'upload',
#   'delete',
#   'think',
#   'say',
#   'vote',
#   'check',
#   'signify',
#   'remember',
#   'feel',
#   'contact'],
#  'Imzadi1979': ['article',
#   'highway',
#   'family',
#   'san',
#   'project',
#   'list',
#   'talk',
#   'page',
#   'class',
#   'comment',
#   'add',
#   'tag',
#   'need',
#   'change',
#   'think',
#   'use',
#   'want',
#   'find',
#   'know',
#   'show'],
#  'Laser_brain': ['time',
#   'article',
#   'page',
#   'work',
#   'sock',
#   'thank',
#   'comment',
#   'editor',
#   'block',
#   'source',
#   'work',
#   'think',
#   'know',
#   'try',
#   'look',
#   'need',
#   'get',
#   'go',
#   'believe',
#   'find'],
#  'SMasters': ['article',
#   'thank',
#   'question',
#   'cheer',
#   'page',
#   'work',
#   'contribution',
#   'crown',
#   'project',
#   'vroom',
#   'need',
#   'thank',
#   'wear',
#   'remove',
#   'think',
#   'add',
#   'mean',
#   'help',
#   'look',
#   'let'],
#  'Finetooth': ['article',
#   'list',
#   'page',
#   'thank',
#   'map',
#   'review',
#   'stream',
#   'section',
#   'thing',
#   'peer',
#   'think',
#   'look',
#   'add',
#   'find',
#   'work',
#   'like',
#   'help',
#   'nominate',
#   'use',
#   'come'],
#  'Ender3057': ['authority',
#   'script',
#   'fool',
#   'doctor',
#   'assurance',
#   'phone',
#   'patient',
#   'guideline',
#   'let',
#   'meet'],
#  'Eternal Equinox': ['user',
#   'finlay',
#   'talk',
#   'page',
#   'watchlist',
#   'edit',
#   'go',
#   'check'],
#  'CL': ['congratulation', 'fa'],
#  'Midgley': ['article',
#   'thing',
#   'effect',
#   'source',
#   'people',
#   'bit',
#   'time',
#   'science',
#   'page',
#   'use',
#   'think',
#   'read',
#   'work',
#   'write',
#   'leave',
#   'look',
#   'need',
#   'copy',
#   'note',
#   'exist'],
#  'TomasBat': ['day',
#   'award',
#   'consensus',
#   'thank',
#   'rollback',
#   'list',
#   'diff',
#   'spirit',
#   'nomination',
#   'status',
#   'font',
#   'guess',
#   'believe',
#   'retain',
#   'skip',
#   'carry',
#   'think',
#   'start',
#   'hope',
#   'return'],
#  'Aldux': ['article',
#   'time',
#   'user',
#   'editor',
#   'source',
#   'thank',
#   'edit',
#   'sock',
#   'problem',
#   'work',
#   'know',
#   'think',
#   'find',
#   'try',
#   'ask',
#   'give',
#   'write',
#   'speak',
#   'use',
#   'tell'],
# ...
#   'guess',
#   'forget',
#   'suppose',
#   'see',
#   'attempt'],
#  'BScar23625': ['user',
#   'wish',
#   'talk',
#   'trip',
#   'weather',
#   'departure',
#   'time',
#   'cloud',
#   'visibility',
#   'metre',
#   'mean',
#   'like',
#   'plan',
#   'pick',
#   'miss',
#   'meet',
#   'wish',
#   'look',
#   'sod',
#   'suggest'],
#  'Timl2k4': ['bot',
#   'article',
#   'edit',
#   'page',
#   'category',
#   'user',
#   'thank',
#   'talk',
#   'saro',
#   'problem',
#   'hide',
#   'understand',
#   'add',
#   'look',
#   'mean',
#   'help',
#   'think',
#   'capitalize',
#   'wonder',
#   'discuss'],
#  'Ks0stm': ['template',
#   'message',
#   'page',
#   'tornado',
#   'project',
#   'article',
#   'thank',
#   'deletion',
#   'event',
#   'outbreak',
#   'leave',
#   'reply',
#   'think',
#   'find',
#   'want',
#   'end',
#   'bother',
#   'know',
#   'add',
#   'include'],
#  'Lexein': ['editor',
#   'edit',
#   'claim',
#   'deletion',
#   'article',
#   'position',
#   'consensus',
#   'talk',
#   'discussion',
#   'user',
#   'support',
#   'read',
#   'revert',
#   'think',
#   'write',
#   'thank',
#   'find',
#   'discuss',
#   'stand',
#   'establish'],
#  'Sephiroth BCR': ['article',
#   'game',
#   'source',
#   'information',
#   'series',
#   'section',
#   'list',
#   'character',
#   'review',
#   'gameplay',
#   'add',
#   'want',
#   'find',
#   'go',
#   'remove',
#   'appreciate',
#   'think',
#   'believe',
#   'confirm',
#   'fix'],
#  'TwoMightyGods': ['image',
#   'copyright',
#   'source',
#   'file',
#   'question',
#   'user',
#   'talk',
#   'list',
#   'link',
#   'week',
#   'upload',
#   'tag',
#   'delete',
#   'consider',
#   'check',
#   'specify',
#   'find',
#   'follow',
#   'describe',
#   'copyright'],
#  'CouldOughta': ['thank',
#   'backstage',
#   'area',
#   'heroine',
#   'discussion',
#   'boyfriend',
#   'box',
#   'note',
#   'get',
#   'suppose',
#   'perform',
#   'meet',
#   'wish',
#   'take'],
#  'UnitedStatesian': ['article',
#   'page',
#   'list',
#   'link',
#   'thank',
#   'talk',
#   'redirect',
#   'discussion',
#   'editor',
#   'deletion',
#   'think',
#   'remove',
#   'delete',
#   'fix',
#   'know',
#   'say',
#   'see',
#   'look',
#   'let',
#   'move'],
#  'Crossmr': ['article',
#   'page',
#   'source',
#   'user',
#   'time',
#   'edit',
#   'citation',
#   'people',
#   'talk',
#   'revert',
#   'provide',
#   'remove',
#   'want',
#   'think',
#   'find',
#   'read',
#   'edit',
#   'know',
#   'block',
#   'mean'],
#  'Arwel_Parry': ['thank',
#   'idiot',
#   'talk',
#   'page',
#   'attack',
#   'persistence',
#   'account',
#   'way',
#   'throwaway',
#   'article',
#   'handle',
#   'create',
#   'throw',
#   'protect',
#   'wonder',
#   'account',
#   'get',
#   'note',
#   'state',
#   'revert'],
#  'TML': ['account',
#   'edit',
#   'request',
#   'sock',
#   'adminship',
#   'arbitration',
#   'action',
#   'bit',
#   'source',
#   'article',
#   'think',
#   'block',
#   'appear',
#   'create',
#   'stand',
#   'discover',
#   'edit',
#   'watchlist',
#   'revert',
#   'wonder'],
#  'Mrlopez2681': ['photo',
#   'head',
#   'book',
#   'landing',
#   'scene',
#   'image',
#   'copyright',
#   'issue',
#   'collection',
#   'comment',
#   'get',
#   'scan',
#   'show',
#   'thank',
#   'read',
#   'guess',
#   'think',
#   'pay',
#   'name',
#   'look'],
#  'Rmrfstar': ['article',
#   'citation',
#   'thank',
#   'page',
#   'work',
#   'edit',
#   'problem',
#   'talk',
#   'lot',
#   'time',
#   'fix',
#   'look',
#   'think',
#   'write',
#   'challenge',
#   'need',
#   'appreciate',
#   'read',
#   'review',
#   'know'],
#  'Deenoe': ['block',
#   'consensus',
#   'worship',
#   'neveeeeermind',
#   'talk',
#   'page',
#   'move',
#   'effect',
#   'remove',
#   'let',
#   'edit',
#   'answer',
#   'think',
#   'want'],
#  'Hoverfish': ['film',
#   'article',
#   'template',
#   'way',
#   'page',
#   'thing',
#   'user',
#   'talk',
#   'point',
#   'thank',
#   'find',
#   'add',
#   'know',
#   'try',
#   'ask',
#   'miss',
#   'hope',
#   'thank',
#   'notice',
#   'start'],
#  'Erwin85Bot': ['image',
#   'file',
#   'repository',
#   'medium',
#   'wiki',
#   'case',
#   'message',
#   'bot',
#   'article',
#   'deletion',
#   'upload',
#   'note',
#   'delete',
#   'mean',
#   'embed',
#   'inform',
#   'copy',
#   'view',
#   'turn',
#   'hold'],
#  'Tetra Vega': ['page', 'bunch', 'bull', 'vandalise', 'revert'],
#  'Nobunaga24': ['thank',
#   'head',
#   'account',
#   'sockpuppety',
#   'vandalism',
#   'editing',
#   'work',
#   'affair',
#   'revert',
#   'guy',
#   'think',
#   'report',
#   'violate',
#   'create',
#   'lighthearte',
#   'believe',
#   'know',
#   'get',
#   'battle'],
#  'Myles325a': ['link',
#   'site',
#   'page',
#   'material',
#   'talk',
#   'article',
#   'example',
#   'query',
#   'list',
#   'puzzle',
#   'think',
#   'delete',
#   'begin',
#   'deal',
#   'answer',
#   'bother',
#   'feature',
#   'kenken',
#   'include',
#   'ask'],
#  'Mholland': ['image',
#   'use',
#   'rationale',
#   'svg',
#   'w',
#   'template',
#   'restriction',
#   'policy',
#   'resolution',
#   'inkscape',
#   'need',
#   'add',
#   'delete',
#   'apply',
#   'think',
#   'notice',
#   'tag',
#   'place',
#   'reduce',
#   'understand'],
#  'Vanderdecken': ['signature',
#   'comment',
#   'article',
#   'thing',
#   'crusade',
#   'page',
#   'template',
#   'screenshot',
#   'proof',
#   'term',
#   'click',
#   'agree',
#   'change',
#   'tell',
#   'remember',
#   'say',
#   'know',
#   'see',
#   'vandalise',
#   'relate'],
#  'Khukri': ['user',
#   'warning',
#   'cheer',
#   'article',
#   'template',
#   'page',
#   'rugby',
#   'category',
#   'vandalism',
#   'case',
#   'block',
#   'look',
#   'leave',
#   'report',
#   'receive',
#   'know',
#   'work',
#   'wonder',
#   'remove',
#   'revert'],
#  'Finereach': ['cortex',
#   'image',
#   'talk',
#   'thank',
#   'comment',
#   'discrepancy',
#   'file',
#   'help',
#   'discussion',
#   'input',
#   'highlight',
#   'think',
#   'ask',
#   'welcome'],
#  'Chacor': ['article',
#   'category',
#   'page',
#   'event',
#   'talk',
#   'problem',
#   'weather',
#   'storm',
#   'thank',
#   'edit',
#   'ndash',
#   'think',
#   'add',
#   'say',
#   'mention',
#   'know',
#   'want',
#   'use',
#   'round',
#   'restore'],
#  'Berean Hunter': ['class',
#   'talk',
#   'page',
#   'article',
#   'user',
#   'discussion',
#   'editor',
#   'time',
#   'thread',
#   'edit',
#   'try',
#   'think',
#   'look',
#   'know',
#   'revert',
#   'post',
#   'want',
#   'edit',
#   'see',
#   'come'],
#  'RFD': ['article',
#   'thank',
#   'town',
#   'community',
#   'editor',
#   'citation',
#   'photo',
#   'page',
#   'problem',
#   'time',
#   'start',
#   'thank',
#   'add',
#   'come',
#   'need',
#   'hope',
#   'go',
#   'take',
#   'know',
#   'think'],
#  'DickClarkMises': ['source',
#   'article',
#   'cheer',
#   'deletion',
#   'assertion',
#   'process',
#   'notability',
#   'event',
#   'time',
#   'work',
#   'publish',
#   'delete',
#   'find',
#   'try',
#   'contest',
#   'cite',
#   'write',
#   'appear',
#   'state',
#   'discuss'],
#  'Pm shef': ['image',
#   'page',
#   'ethnicity',
#   'reference',
#   'way',
#   'thank',
#   'edit',
#   'article',
#   'user',
#   'controversy',
#   'revert',
#   'continue',
#   'find',
#   'feel',
#   'edit',
#   'remove',
#   'create',
#   'think',
#   'want',
#   'thank'],
#  'Hurricanehink': ['article',
#   'storm',
#   'list',
#   'thank',
#   'hurricane',
#   'page',
#   'season',
#   'work',
#   'section',
#   'time',
#   'think',
#   'know',
#   'work',
#   'need',
#   'ask',
#   'look',
#   'want',
#   'find',
#   'go',
#   'add'],
#  'Anthony DiPierro': ['thing', 'see'],
#  'Enochlau': ['article',
#   'page',
#   'word',
#   'thank',
#   'deletion',
#   'image',
#   'user',
#   'edit',
#   'people',
#   'source',
#   'delete',
#   'like',
#   'want',
#   'tag',
#   'think',
#   'look',
#   'mean',
#   'know',
#   'use',
#   'need'],
#  'Best username yet': ['criticism',
#   'thing',
#   'misconception',
#   'bit',
#   'medium',
#   'information',
#   'mother',
#   'community',
#   'google',
#   'search',
#   'find',
#   'work',
#   'think',
#   'call',
#   'say',
#   'revert',
#   'know',
#   'mention',
#   'explain',
#   'keep'],
#  'Wowweb': ['industry',
#   'writer',
#   'television',
#   'load',
#   'knowledge',
#   'course',
#   'lot',
#   'hand',
#   'tv',
#   'enthusiast',
#   'work',
#   'notice',
#   'wonder',
#   'mention',
#   'think'],
#  'HoneyBee': ['article',
#   'thank',
#   'cast',
#   'character',
#   'example',
#   'jaw',
#   'minute',
#   'time',
#   'dog',
#   'mess',
#   'create',
#   'think',
#   'spare',
#   'check',
#   'look',
#   'advice',
#   'dunno',
#   'like',
#   'add',
#   'merge'],
#  '{unknown-48}': ['section',
#   'jaw',
#   'revenge',
#   'article',
#   'example',
#   'got',
#   'cast',
#   'read',
#   'think'],
#  'Kt66': ['article',
#   'user',
#   'source',
#   'fact',
#   'look',
#   'point',
#   'validity',
#   'comment',
#   'activity',
#   'page',
#   'remove',
#   'thank',
#   'ask',
#   'think',
#   'include',
#   'balance',
#   'leave',
#   'give',
#   'wish',
#   'work'],
#  'Robertgreer': ['year',
#   'student',
#   'editing',
#   'block',
#   'talk',
#   'page',
#   'thing',
#   'vandalism',
#   'department',
#   'reason',
#   'thank',
#   'contact',
#   'edit',
#   'provide',
#   'like',
#   'remove',
#   'throw',
#   'begin',
#   'clutter',
#   'take'],
#  'Abebenjoe': ['article',
#   'photo',
#   'rule',
#   'spaceflight',
#   'day',
#   'image',
#   'space',
#   'year',
#   'time',
#   'term',
#   'write',
#   'delete',
#   'deal',
#   'use',
#   'lose',
#   'dissolve',
#   'swear',
#   'clear',
#   'take',
#   'meet'],
#  'Private Detective': ['know'],
#  'MONGO': ['article',
#   'page',
#   'time',
#   'editor',
#   'edit',
#   'thing',
#   'comment',
#   'image',
#   'website',
#   'admin',
#   'think',
#   'know',
#   'try',
#   'go',
#   'look',
#   'need',
#   'add',
#   'want',
#   'ask',
#   'block'],
#  'Fowler&amp;fowler': ['page',
#   'thank',
#   'talk',
#   'time',
#   'article',
#   'user',
#   'book',
#   'history',
#   'people',
#   'post',
#   'know',
#   'look',
#   'need',
#   'like',
#   'mean',
#   'read',
#   'take',
#   'say',
#   'find',
#   'edit'],
#  'Ernst_Stavro_Blofeld': ['article',
#   'film',
#   'work',
#   'template',
#   'time',
#   'setting',
#   'list',
#   'history',
#   'fa',
#   'disgrace',
#   'think',
#   'set',
#   'create',
#   'hope',
#   'add',
#   'look',
#   'like',
#   'take',
#   'correct',
#   'found'],
#  'RobNS': ['page',
#   'colour',
#   'cheer',
#   'table',
#   'background',
#   'people',
#   'jaw',
#   'point',
#   'effort',
#   'history',
#   'think',
#   'wish',
#   'add',
#   'remove',
#   'try',
#   'go',
#   'know',
#   'look',
#   'appreciate',
#   'contribute'],
#  'Ginkgo100': ['article',
#   'deletion',
#   'page',
#   'user',
#   'talk',
#   'edit',
#   'reason',
#   'cheer',
#   'hoax',
#   'summary',
#   'block',
#   'think',
#   'mean',
#   'delete',
#   'take',
#   'get',
#   'look',
#   'hope',
#   'disagree',
#   'remove'],
#  'Jam01': ['user',
#   'birthday',
#   'day',
#   'credit',
#   'editor',
#   'cheer',
#   'coffee',
#   'blend',
#   'help',
#   'wish',
#   'enjoy',
#   'agree',
#   'look',
#   'design',
#   'percolate',
#   'hear',
#   'stress',
#   'hope'],
#  'Seresin': ['image',
#   'thank',
#   'userpage',
#   'user',
#   'change',
#   'article',
#   'page',
#   'userboxe',
#   'file',
#   'edit',
#   'refer',
#   'know',
#   'upload',
#   'make',
#   'work',
#   'contain',
#   'remove',
#   'write',
#   'find',
#   'block'],
#  '87.114.22.229': ['rant',
#   'comment',
#   'blp',
#   'policy',
#   'insult',
#   'talkpage',
#   'article',
#   'father',
#   'person',
#   'murder',
#   'think',
#   'describe',
#   'comply',
#   'express',
#   'resort',
#   'call',
#   'murder',
#   'edit',
#   'need'],
#  'Fsecret': ['article',
#   'discussion',
#   'person',
#   'manga',
#   'opposition',
#   'action',
#   'question',
#   'group',
#   'people',
#   'band',
#   'like',
#   'point',
#   'describe',
#   'delete',
#   'voice',
#   'feature',
#   'serve',
#   'demonstrate',
#   'think',
#   'know'],
#  'Quazgaa': ['article',
#   'page',
#   'improvement',
#   'align',
#   'talk',
#   'grammar',
#   'discussion',
#   'padding',
#   'removal',
#   'request',
#   'improve',
#   'undo',
#   'try',
#   'leave',
#   'add',
#   'insert',
#   'feel',
#   'correct',
#   'remember',
#   'call'],
#  'Seraphim Whipp': ['page',
#   'article',
#   'user',
#   'message',
#   'prod',
#   'talk',
#   'comment',
#   'ip',
#   'block',
#   'editor',
#   'remove',
#   'help',
#   'give',
#   'delete',
#   'need',
#   'want',
#   'take',
#   'think',
#   'block',
#   'like'],
#  'Choess': ['article',
#   'page',
#   'title',
#   'genealogy',
#   'list',
#   'talk',
#   'discussion',
#   'thank',
#   'writ',
#   'person',
#   'work',
#   'think',
#   'find',
#   'try',
#   'look',
#   'move',
#   'want',
#   'start',
#   'add',
#   'go'],
#  'Dave101': ['image',
#   'option',
#   'article',
#   'copyright',
#   'permission',
#   'notice',
#   'website',
#   'email',
#   'use',
#   'logo',
#   'feel',
#   'think',
#   'request',
#   'need',
#   'remove',
#   'leave',
#   'delete',
#   'allow',
#   'point',
#   'find'],
#  'Plastikspork': ['thank',
#   'template',
#   'page',
#   'bot',
#   'discussion',
#   'problem',
#   'deletion',
#   'coordinate',
#   'article',
#   'infobox',
#   'work',
#   'think',
#   'check',
#   'use',
#   'add',
#   'want',
#   'create',
#   'thank',
#   'know',
#   'remove'],
#  'Matthew': ['source',
#   'article',
#   'template',
#   'edit',
#   'episode',
#   'image',
#   'consensus',
#   'music',
#   'copyright',
#   'way',
#   'prove',
#   'agree',
#   'revert',
#   'provide',
#   'read',
#   'say',
#   'feel',
#   'state',
#   'support',
#   'list'],
#  'Mercy11': ['article',
#   'street',
#   'building',
#   'source',
#   'thank',
#   'regard',
#   'change',
#   'photo',
#   'day',
#   'map',
#   'know',
#   'think',
#   'check',
#   'leave',
#   'call',
#   'include',
#   'use',
#   'intend',
#   'vandalise',
#   'lose'],
#  '200.209.169.81': ['information', 'erase'],
#  'Eagle 101': ['user',
#   'page',
#   'talk',
#   'list',
#   'bug',
#   'problem',
#   'program',
#   'edit',
#   'thank',
#   'version',
#   'tell',
#   'think',
#   'need',
#   'work',
#   'know',
#   'fix',
#   'go',
#   'log',
#   'post',
#   'remove'],
#  'Kasper2006': ['tnx', 'article', 'add'],
#  'WacoJacko': ['article',
#   'user',
#   'theatre',
#   'thank',
#   'request',
#   'attempt',
#   'virulent',
#   'idea',
#   'feedback',
#   'source',
#   'mention',
#   'think',
#   'guess',
#   'thank',
#   'take',
#   'say',
#   'add',
#   'set',
#   'want',
#   'know'],
#  'THD3': ['user',
#   'article',
#   'page',
#   'way',
#   'editor',
#   'edit',
#   'administrator',
#   'sockpuppet',
#   'book',
#   'request',
#   'believe',
#   'want',
#   'list',
#   'edit',
#   'think',
#   'know',
#   'reinstate',
#   'add',
#   'get',
#   'remember'],
#  'Markhh': ['thank',
#   'excerpt',
#   'recording',
#   'record',
#   'page',
#   'house',
#   'orchestra',
#   'cheer',
#   'group',
#   'series',
#   'record',
#   'make',
#   'use',
#   'post',
#   'focus',
#   'expand',
#   'replace',
#   'know',
#   'check',
#   'belong'],
#  'WOSlinker': ['template',
#   'category',
#   'article',
#   'parameter',
#   'comment',
#   'discussion',
#   'page',
#   'artist',
#   'link',
#   'param',
#   'add',
#   'update',
#   'change',
#   'deprecate',
#   'nominate',
#   'need',
#   'remove',
#   'invite',
#   'comment',
#   'thank'],
#  'Kleinzach': ['article',
#   'opera',
#   'project',
#   'page',
#   'regard',
#   'reference',
#   'guideline',
#   'user',
#   'problem',
#   'thank',
#   'think',
#   'know',
#   'wonder',
#   'try',
#   'explain',
#   'use',
#   'ask',
#   'help',
#   'revert',
#   'find'],
#  'Edito*Magica': ['article',
#   'page',
#   'character',
#   'list',
#   'information',
#   'sub',
#   'foot',
#   'description',
#   'cast',
#   'way',
#   'find',
#   'use',
#   'attack',
#   'look',
#   'divide',
#   'incorperate',
#   'go',
#   'remove',
#   'resolve',
#   'say'],
#  'Endlessdan': ['pic',
#   'image',
#   'photo',
#   'article',
#   'page',
#   'talk',
#   'tag',
#   'user',
#   'time',
#   'band',
#   'talk',
#   'upload',
#   'thank',
#   'look',
#   'believe',
#   'know',
#   'link',
#   'help',
#   'edit',
#   'place'],
#  'Infrogmation': ['article',
#   'cheer',
#   'page',
#   'thank',
#   'photo',
#   'image',
#   'work',
#   'talk',
#   'edit',
#   'license',
#   'upload',
#   'add',
#   'take',
#   'help',
#   'ask',
#   'look',
#   'wish',
#   'know',
#   'suggest',
#   'note'],
#  'RadioFan': ['deletion',
#   'page',
#   'article',
#   'template',
#   'notice',
#   'tag',
#   'discussion',
#   'talk',
#   'process',
#   'source',
#   'add',
#   'delete',
#   'remove',
#   'improve',
#   'exist',
#   'meet',
#   'think',
#   'nominate',
#   'edit',
#   'address'],
#  '{unknown-49}': ['thank'],
#  '{unknown-50}': ['comment', 'place', 'family', 'want', 'bump'],
#  'ScreaminEagle': ['thank',
#   'lot',
#   'article',
#   'piggy',
#   'backing',
#   'people',
#   'comment',
#   'silver',
#   'son',
#   'family',
#   'ask',
#   'think',
#   'find',
#   'award',
#   'call',
#   'say',
#   'hunt',
#   'publish',
#   'contact',
#   'read'],
#  'Will Beback': ['article',
#   'editor',
#   'page',
#   'talk',
#   'material',
#   'user',
#   'topic',
#   'source',
#   'edit',
#   'thank',
#   'think',
#   'add',
#   'edit',
#   'delete',
#   'know',
#   'ask',
#   'find',
#   'post',
#   'make',
#   'say'],
#  'Kyuubi29': ['computer', 'website', 'hack', 'think', 'find', 'tell'],
#  'TheVirginiaHistorian': ['thank',
#   'article',
#   'way',
#   'context',
#   'battle',
#   'voice',
#   'bot',
#   'inch',
#   'page',
#   'webpage',
#   'look',
#   'think',
#   'lay',
#   'find',
#   'say',
#   'come',
#   'compete',
#   'jump',
#   'lose',
#   'start'],
#  'Michael Bednarek': ['article',
#   'image',
#   'edit',
#   'page',
#   'template',
#   'link',
#   'title',
#   'category',
#   'reference',
#   'talk',
#   'change',
#   'think',
#   'use',
#   'find',
#   'need',
#   'provide',
#   'revert',
#   'thank',
#   'refer',
#   'move'],
#  'Jog1973': ['review'],
#  ...}

# %%
def save_profiles_as_json(profiles, filename):
  """Saves the given profiles dictionary to a JSON file."""
  with open(filename, 'w') as f:
    json.dump(profiles, f, indent=4)


save_profiles_as_json(profile1, '/content/drive/MyDrive/Perspective Paper/Original_Data/profile1.json')
save_profiles_as_json(profile2, '/content/drive/MyDrive/Perspective Paper/Original_Data/profile2.json')
save_profiles_as_json(profile3, '/content/drive/MyDrive/Perspective Paper/Original_Data/profile3.json')
